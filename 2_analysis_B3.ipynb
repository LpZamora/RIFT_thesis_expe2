# %%
data_path = '/home/lea/Documents/obsidian_notes/masterADS/ads_thesis_RIFT/my_code_expe2'
data_file = '/data/B3/data.mat'
epoch_file = '/data/B3/preprocessing/B3_EEG_epo.fif'

relevant_electrodes = ['O2','PO4','P4','P6','P2','P1','P3','P5','PO3','O1','Pz','POz','Oz','Iz']

# Dic to index trial_info matrix
info_colnames = {'reaction_times':0,'reaction_err':1, 'answer':2,'base_delay':3,\
                      'target_timings':4, 'flicker_sides':5, 'cued_side':6, 'orients_L':7, 'orients_R':8,\
                      'angle_magnitude':9, 'probe_sides':10, 'targets_binary':12, 'attention_type_block':13,\
                      'trial_num_my_rec':14}
info_colnumtonames = {v: k for k, v in info_colnames.items()}

# %%
import scipy.io as sio
import scipy
import numpy as np
import pandas as pd
import mne
from mne.time_frequency import EpochsTFRArray
import matplotlib.pyplot as plt
import copy
from collections import Counter
from frequency_tagging_funs import snr_spectrum, frequency_rescaling

from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedKFold
from mne.decoding import SlidingEstimator, cross_val_multiscore

f = sio.loadmat(f'{data_path}{data_file}')

# Create pd df to pass to mne metadata
pd_info = {}
for i, column in enumerate(f['data'][0][0]):
    if i in info_colnames.values():
        # Remove practice trials
        column = column[4:,:]
        # Collapse to trial indexes
        original_shape = column.shape
        new_shape = (original_shape[0] * original_shape[1],) + original_shape[2:]
        column = np.reshape(column, new_shape)
        pd_info[info_colnumtonames[i]] = column
pd_info = pd.DataFrame(pd_info, columns=info_colnames.keys())
pd_info 

# Load eeg epochs .fif and add metadata
epochs = mne.read_epochs(f'{data_path}{epoch_file}')
epoch_good = [x for x,y in enumerate(epochs.drop_log) if len(y) == 0]
epochs.metadata = pd_info.iloc[epoch_good]
# Out:
# Reading /home/lea/Documents/obsidian_notes/masterADS/ads_thesis_RIFT/my_code_expe2/data/B3/preprocessing/B3_EEG_epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 510 matching events found
# No baseline correction applied
# 0 projection items activated
# Adding metadata with 14 columns

# %%
# Keep only trials where there was no target
epochs = epochs['targets_binary==0']

# %% [markdown]
# # 1. Presence of the tagged frequencies
# ## 1 FFT & SNR

# %%
# Simplify metadata
epochs.metadata['flicker_sides'] = epochs.metadata['flicker_sides'].replace({0: 6064, 1: 6460})
epochs.metadata['cued_side'] = epochs.metadata['cued_side'].replace({0: 'left', 1: 'right'})

condition_1 = ((epochs.metadata['flicker_sides'] == 6064.0) & (epochs.metadata['cued_side'] == 'left')) | \
    ((epochs.metadata['flicker_sides'] == 6460.0) & (epochs.metadata['cued_side'] == 'right'))
condition_2 = ((epochs.metadata['flicker_sides'] == 6064.0) & (epochs.metadata['cued_side'] == 'right')) | \
    ((epochs.metadata['flicker_sides'] == 6460.0) & (epochs.metadata['cued_side'] == 'left'))
epochs.metadata['cued_tag'] = np.where(condition_1, 60, np.where(condition_2, 64, np.nan))
epochs_endo = epochs['attention_type_block==1'].copy()
epochs_exo = epochs['attention_type_block==0'].copy()

# %%
# Fast Fourier Transform
# adapted from https://mne.tools/dev/auto_tutorials/time-freq/50_ssvep.html

sfreq = epochs.info["sfreq"]
tmin = 0 # Search in window starting from cue (when SSVEP is expected)
tmax = 2
fmin = 1.0
fmax = 90

# Spectrum of the signal averaged over trials
spectrum_endo = epochs_endo.copy().average().compute_psd(
    "welch",
    n_fft=int(sfreq * (tmax - tmin)),
    n_overlap=0,
    n_per_seg=None,
    tmin=tmin,
    tmax=tmax,
    fmin=fmin,
    fmax=fmax,
    window="hamming",
    verbose=False,
)
psds_endo, freqs_psd = spectrum_endo.get_data(return_freqs=True)
spectrum_exo = epochs_exo.copy().average().compute_psd(
    "welch",
    n_fft=int(sfreq * (tmax - tmin)),
    n_overlap=0,
    n_per_seg=None,
    tmin=tmin,
    tmax=tmax,
    fmin=fmin,
    fmax=fmax,
    window="hamming",
    verbose=False,
)
psds_exo, freqs_psd = spectrum_exo.get_data(return_freqs=True)


# Get bins to exlude from regularization (close neighbors ±0.5Hz)  
bin_size = np.diff(freqs_psd)[0]
skip_nei = int((0.5 - bin_size/2)//bin_size) 

# Get bins to include in regularization (neighbors within +/- 2-0.5Hz)
used_nei = int((2 - bin_size/2) // bin_size)  # Total bins within ±2 Hz
used_nei = used_nei - skip_nei # Bins within (0.5 Hz, 2 Hz]

snrs_endo = snr_spectrum(psds_endo, noise_n_neighbor_freqs=used_nei, noise_skip_neighbor_freqs = skip_nei)
snrs_exo = snr_spectrum(psds_exo, noise_n_neighbor_freqs=used_nei, noise_skip_neighbor_freqs = skip_nei)

fig, axes = plt.subplots(2, 2, sharex="all", sharey="none", figsize=(8, 5))
freq_range = range(
    np.where(np.floor(freqs_psd) == 1.0)[0][0], np.where(np.ceil(freqs_psd) == fmax - 1)[0][0]
)

psds_plot = 10 * np.log10(psds_endo)
psds_mean = psds_plot.mean(axis=(0))[freq_range]
psds_std = psds_plot.std(axis=(0))[freq_range]
axes[0,0].plot(freqs_psd[freq_range], psds_mean, color="b")
axes[0,0].fill_between(
    freqs_psd[freq_range], psds_mean - psds_std, psds_mean + psds_std, color="b", alpha=0.2
)
axes[0,0].set(title="PSD spectrum endogeneous", ylabel="Power Spectral Density [dB]")
psds_plot = 10 * np.log10(psds_exo)
psds_mean = psds_plot.mean(axis=(0))[freq_range]
psds_std = psds_plot.std(axis=(0))[freq_range]
axes[0,1].plot(freqs_psd[freq_range], psds_mean, color="b")
axes[0,1].fill_between(
    freqs_psd[freq_range], psds_mean - psds_std, psds_mean + psds_std, color="b", alpha=0.2
)
axes[0,1].set(title="PSD spectrum exogeneous", ylabel="Power Spectral Density [dB]")

# SNR spectrum
snr_mean = snrs_endo.mean(axis=(0))[freq_range]
snr_std = snrs_endo.std(axis=(0))[freq_range]

axes[1,0].plot(freqs_psd[freq_range], snr_mean, color="r")
axes[1,0].fill_between(
    freqs_psd[freq_range], snr_mean - snr_std, snr_mean + snr_std, color="r", alpha=0.2
)
axes[1,0].set(
    title="SNR spectrum endogeneous",
    xlabel="Frequency [Hz]",
    ylabel="SNR",
    ylim=[-2, 15],
    xlim=[fmin, fmax],
)
snr_mean = snrs_exo.mean(axis=(0))[freq_range]
snr_std = snrs_exo.std(axis=(0))[freq_range]

axes[1,1].plot(freqs_psd[freq_range], snr_mean, color="r")
axes[1,1].fill_between(
    freqs_psd[freq_range], snr_mean - snr_std, snr_mean + snr_std, color="r", alpha=0.2
)
axes[1,1].set(
    title="SNR spectrum exogeneous",
    xlabel="Frequency [Hz]",
    ylabel="SNR",
    ylim=[-2, 15],
    xlim=[fmin, fmax],
)
plt.tight_layout()
fig.show()

# Extract SNR values at the stimulation frequency
stim_freq1 = 60
stim_freq2 = 64

# find index of frequency bin closest to stimulation frequency
i_bin_1 = np.argmin(abs(freqs_psd - stim_freq1))
i_bin_2 = np.argmin(abs(freqs_psd - stim_freq2))

# Apply the subset
snrs_target1_endo = snrs_endo[:, i_bin_1]
snrs_target2_endo = snrs_endo[:, i_bin_2]
print(f'SNR at {stim_freq1}Hz in endogenous condition: {snrs_target1_endo.mean()}')
print(f'SNR at {stim_freq2}Hz in endogenous: {snrs_target2_endo.mean()}')
snrs_target1_exo = snrs_exo[:, i_bin_1]
snrs_target2_exo = snrs_exo[:, i_bin_2]
print(f'SNR at {stim_freq1}Hz in exogenous condition: {snrs_target1_exo.mean()}')
print(f'SNR at {stim_freq2}Hz in exogenous: {snrs_target2_exo.mean()}')
# Out:
# /tmp/ipykernel_14765/4082944448.py:102: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# SNR at 60Hz in endogenous condition: 3.1885380913299923
# SNR at 64Hz in endogenous: 2.814768219624701
# SNR at 60Hz in exogenous condition: 4.0364224686812555
# SNR at 64Hz in exogenous: 4.566389695009376

# %% [markdown]
# ## 1.2 Topography of the SNR

# %%
# plot SNR topography
fig, ax = plt.subplots(2,2)
mne.viz.plot_topomap(snrs_target1_endo, epochs.info, vlim=(1, None), axes=ax[0,0], show=False, extrapolate='local')
mne.viz.plot_topomap(snrs_target2_endo, epochs.info, vlim=(1, None), axes=ax[0,1], show=False, extrapolate='local')
mne.viz.plot_topomap(snrs_target1_exo, epochs.info, vlim=(1, None), axes=ax[1,0], show=False, extrapolate='local')
mne.viz.plot_topomap(snrs_target2_exo, epochs.info, vlim=(1, None), axes=ax[1,1], show=False, extrapolate='local')
ax[0,0].set_title('Endogeneous 60Hz')
ax[0,1].set_title('Exogeneous 60H')
ax[1,0].set_title('Endogeneous 64Hz')
ax[1,1].set_title('Exogeneous 64H')
plt.show()

# Channels with the highest SNR 
print(f'Channels with highest SNR for 60Hz endo {np.array(epochs.info['ch_names'])[np.argsort(snrs_target1_endo)[::-1]][:6]}')
print(f'Channels with highest SNR for 64Hz endo{np.array(epochs.info['ch_names'])[np.argsort(snrs_target2_endo)[::-1]][:6]}')
print(f'Channels with highest SNR for 60Hz exo {np.array(epochs.info['ch_names'])[np.argsort(snrs_target1_exo)[::-1]][:6]}')
print(f'Channels with highest SNR for 64Hz exo {np.array(epochs.info['ch_names'])[np.argsort(snrs_target2_exo)[::-1]][:6]}')
#select electrodes from 60 as the top electrodes are parietal and occipital
SNR_best_electrodes_60_endo = np.array(epochs.info['ch_names'])[np.argsort(snrs_target1_endo)[::-1]][:6]
SNR_best_electrodes_64_endo = np.array(epochs.info['ch_names'])[np.argsort(snrs_target2_endo)[::-1]][:6]
SNR_best_electrodes_60_exo = np.array(epochs.info['ch_names'])[np.argsort(snrs_target1_exo)[::-1]][:6]
SNR_best_electrodes_64_exo = np.array(epochs.info['ch_names'])[np.argsort(snrs_target2_exo)[::-1]][:6]
# Out:
# Channels with highest SNR for 60Hz endo ['P2' 'PO4' 'O2' 'CP1' 'POz' 'P1']
# Channels with highest SNR for 64Hz endo['Pz' 'CP1' 'PO3' 'PO4' 'POz' 'P2']
# Channels with highest SNR for 60Hz exo ['P2' 'PO4' 'CP1' 'O2' 'POz' 'P1']
# Channels with highest SNR for 64Hz exo ['P1' 'POz' 'O2' 'P3' 'P2' 'PO3']

# %% [markdown]
# ## 1.3 Time frequency analysis of coherence by electrode
# Coherence is studied in the time window between trial start and onset of the stimuli (the post stimuli window is likely contaminated by attentional catching due to their onset).

# %% [markdown]
# ### Inter-trial coherence with Morlet estimation

# %%
# n_cylce: trade-off temporal vs frequency resolution (is how many cycles of the frequency to include in the Gaussian envelope). 
# Frequency resolution is emphasized.

# time window from -1 sec to 1 sec relative to cue
tmin, tmax = -1, 1
# Define range of frequencies of interest
freqs = np.arange(55, 75, step = 0.5)

_, itc_endo = epochs_endo.copy().crop(tmin, tmax).compute_tfr(
    method="morlet", freqs=freqs, n_cycles=freqs,return_itc=True, average=True
)
_, itc_exo = epochs_exo.copy().crop(tmin, tmax).compute_tfr(
    method="morlet", freqs=freqs, n_cycles=freqs,return_itc=True, average=True
)

# Baseline (-1 to 0s) correction
itc_endo = itc_endo.apply_baseline(baseline=(tmin, 0))
itc_exo = itc_exo.apply_baseline(baseline=(tmin, 0))

fig, axes = plt.subplots(3, 6, figsize=(18, 9), sharey = True) 
axes = axes.flatten() 

channels = epochs.info['ch_names']

# Plot each electrode
for e, (channel, ax) in enumerate(zip(channels, axes)):
    itc_endo.plot(
        picks=[channel],
        baseline=None,
        vlim=(-.4, .4),
        axes=ax,
        colorbar=False,
        show=False 
    )
    ax.set_title(channel) 
    ax.axhline(y=60, color='r', linestyle='--', linewidth=1)
    ax.axhline(y=64, color='r', linestyle='--', linewidth=1)
    
plt.tight_layout()
plt.show()
fig, axes = plt.subplots(3, 6, figsize=(18, 9), sharey = True) 
axes = axes.flatten() 

channels = epochs.info['ch_names']

# Plot each electrode
for e, (channel, ax) in enumerate(zip(channels, axes)):
    itc_exo.plot(
        picks=[channel],
        baseline=None,
        vlim=(-.4, .4),
        axes=ax,
        colorbar=False,
        show=False 
    )
    ax.set_title(channel) 
    ax.axhline(y=60, color='r', linestyle='--', linewidth=1)
    ax.axhline(y=64, color='r', linestyle='--', linewidth=1)
    
plt.tight_layout()
plt.show()
# Out:
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:   20.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:   19.3s
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied

# %%
# Check whether the expected frequencies are indeed the highest
itc_arr, frex_idx = itc_endo.get_data(return_freqs=True)
print(f'Frequencies in endogeneous with the maximum coherence in descending order : {frex_idx[itc_arr.mean(axis=(0,2)).argsort()[::-1]][:4]}')
print(f'From best to 6th \nChannels with the highest coherence with 64 in endo:{np.array(epochs.info['ch_names'])[np.argsort(np.squeeze(itc_arr[:,np.where(frex_idx==60),:].max(axis = -1)))[::-1]][:6]} \
                        \nChannels with the highest coherence with 60 in endo:{np.array(epochs.info['ch_names'])[np.argsort(np.squeeze(itc_arr[:,np.where(frex_idx==64),:].max(axis = -1)))[::-1]][:6]}')
best_electrodes_coherence_stockwell_60_endo = np.array(epochs.info['ch_names'])[np.argsort(np.squeeze(itc_arr[:,np.where(frex_idx==60),:].max(axis = -1)))[::-1]][:6]
best_electrodes_coherence_stockwell_64_endo = np.array(epochs.info['ch_names'])[np.argsort(np.squeeze(itc_arr[:,np.where(frex_idx==64),:].max(axis = -1)))[::-1]][:6]

itc_arr, frex_idx = itc_exo.get_data(return_freqs=True)
print(f'Frequencies in exogeneous with the maximum coherence in descending order : {frex_idx[itc_arr.mean(axis=(0,2)).argsort()[::-1]][:4]}')
print(f'From best to 6th \nChannels with the highest coherence with 64 in exo:{np.array(epochs.info['ch_names'])[np.argsort(np.squeeze(itc_arr[:,np.where(frex_idx==60),:].max(axis = -1)))[::-1]][:6]} \
                        \nChannels with the highest coherence with 60 in enxxo:{np.array(epochs.info['ch_names'])[np.argsort(np.squeeze(itc_arr[:,np.where(frex_idx==64),:].max(axis = -1)))[::-1]][:6]}')
best_electrodes_coherence_stockwell_60_exo = np.array(epochs.info['ch_names'])[np.argsort(np.squeeze(itc_arr[:,np.where(frex_idx==60),:].max(axis = -1)))[::-1]][:6]
best_electrodes_coherence_stockwell_64_exo = np.array(epochs.info['ch_names'])[np.argsort(np.squeeze(itc_arr[:,np.where(frex_idx==64),:].max(axis = -1)))[::-1]][:6]
# Out:
# Frequencies in endogeneous with the maximum coherence in descending order : [64.  64.5 59.5 63.5]
# From best to 6th
# Channels with the highest coherence with 64 in endo:['PO4' 'CP1' 'P2' 'PO3' 'POz' 'Pz']
# Channels with the highest coherence with 60 in endo:['P1' 'Pz' 'CP1' 'O1' 'PO4' 'PO3']
# Frequencies in exogeneous with the maximum coherence in descending order : [60.  59.5 64.  60.5]
# From best to 6th
# Channels with the highest coherence with 64 in exo:['PO4' 'POz' 'P2' 'O2' 'Pz' 'O1']
# Channels with the highest coherence with 60 in enxxo:['CP1' 'P1' 'P2' 'POz' 'Pz' 'PO3']

# %% [markdown]
# ## 1.4 Select electrodes based on previous analysis

# %%
print(f'Top 6 electrodes for SNR 60 endo {SNR_best_electrodes_60_endo}')
print(f'Top 6 electrodes for SNR 64 endo {SNR_best_electrodes_64_endo}')
print(f'Top 6 electrodes for SNR 60 exo {SNR_best_electrodes_60_exo}')
print(f'Top 6 electrodes for SNR 64 exo {SNR_best_electrodes_64_exo}')
# print(f'Top 6 electrodes for Coherence 60 {best_electrodes_coherence_60}')
# print(f'Top 6 electrodes for Coherence 64 {best_electrodes_coherence_64}')
print(f'Top 6 electrodes for ITC stockwell 60 endo {best_electrodes_coherence_stockwell_60_endo}')
print(f'Top 6 electrodes for ITC stockwell 64 endo {best_electrodes_coherence_stockwell_64_endo}')

print(f'Top 6 electrodes for ITC stockwell 60 exo {best_electrodes_coherence_stockwell_60_exo}')
print(f'Top 6 electrodes for ITC stockwell 64 exo {best_electrodes_coherence_stockwell_64_exo}')
# Out:
# Top 6 electrodes for SNR 60 endo ['P2' 'PO4' 'O2' 'CP1' 'POz' 'P1']
# Top 6 electrodes for SNR 64 endo ['Pz' 'CP1' 'PO3' 'PO4' 'POz' 'P2']
# Top 6 electrodes for SNR 60 exo ['P2' 'PO4' 'CP1' 'O2' 'POz' 'P1']
# Top 6 electrodes for SNR 64 exo ['P1' 'POz' 'O2' 'P3' 'P2' 'PO3']
# Top 6 electrodes for ITC stockwell 60 endo ['PO4' 'CP1' 'P2' 'PO3' 'POz' 'Pz']
# Top 6 electrodes for ITC stockwell 64 endo ['P1' 'Pz' 'CP1' 'O1' 'PO4' 'PO3']
# Top 6 electrodes for ITC stockwell 60 exo ['PO4' 'POz' 'P2' 'O2' 'Pz' 'O1']
# Top 6 electrodes for ITC stockwell 64 exo ['CP1' 'P1' 'P2' 'POz' 'Pz' 'PO3']

# %%
# Select top 6 electrodes that are the most often the best according to SNR, IT coherence and MS coherence
all_electrodes = (list(SNR_best_electrodes_60_endo) + 
                  list(SNR_best_electrodes_64_endo) + 
                  list(SNR_best_electrodes_60_exo) + 
                  list(SNR_best_electrodes_64_exo) + 
                  # list(best_electrodes_coherence_60) + 
                  # list(best_electrodes_coherence_64) + 
                  list(best_electrodes_coherence_stockwell_60_endo) + 
                  list(best_electrodes_coherence_stockwell_64_endo) + 
                  list(best_electrodes_coherence_stockwell_60_exo) + 
                  list(best_electrodes_coherence_stockwell_64_exo))

# Count the occurrences of each electrode
electrode_counts = Counter(all_electrodes)

best_electrodes = [electrode for electrode, count in electrode_counts.most_common(6)]

print(f'selected electrodes: {best_electrodes}')
# Out:
# selected electrodes: ['P2', 'POz', 'PO4', 'CP1', 'P1', 'Pz']

# %% [markdown]
# # 2 - Testing for an attentional effect
# ### Comparing SNR across cued conditions

# %%
queries = ["cued_tag == 60 & attention_type_block==0", "cued_tag == 64 & attention_type_block==0",
          "cued_tag == 60 & attention_type_block==1", "cued_tag == 64 & attention_type_block==1"]
vals = {}
stim_freq1 = 60
stim_freq2 = 64

sfreq = epochs_endo.info['sfreq']
tmin = 0 # Search in window starting from cue (when SSVEP is expected)
tmax = 2
fmin = 1.0
fmax = 90.0

for query in queries:
    # Spectrum averaged over all trials
    spectrum = epochs[query].copy().pick(best_electrodes).compute_psd(
        "welch",
        n_fft=int(sfreq * (tmax - tmin)),
        n_overlap=0,
        n_per_seg=None,
        tmin=tmin,
        tmax=tmax,
        fmin=fmin,
        fmax=fmax,
        window="hamming",
        verbose=False,
    )
    psds, freqs_psd = spectrum.get_data(return_freqs=True)

    # find index of frequency bin closest to stimulation frequency
    i_bin_1 = np.argmin(abs(freqs_psd - stim_freq1))
    i_bin_2 = np.argmin(abs(freqs_psd - stim_freq2))
    
    # Apply the subset
    vals[str(int(stim_freq1))+query] = copy.deepcopy(np.mean(psds,axis=0)[:, i_bin_1])
    vals[str(int(stim_freq2))+query] = copy.deepcopy(np.mean(psds,axis=0)[:, i_bin_2])

# %%
fig, ax = plt.subplots(2,2, figsize=(7,6), sharex=True, sharey=True)
for e, elec in enumerate(best_electrodes):
    ax[0,0].plot([0,1], [vals['60cued_tag == 64 & attention_type_block==0'][e], vals['60cued_tag == 60 & attention_type_block==0'][e]], 'o-', label=elec)
    ax[1,0].plot([0,1], [vals['64cued_tag == 60 & attention_type_block==0'][e], vals['64cued_tag == 64 & attention_type_block==0'][e]], 'o-', label=elec)
    ax[0,1].plot([0,1], [vals['60cued_tag == 64 & attention_type_block==1'][e], vals['60cued_tag == 60 & attention_type_block==1'][e]], 'o-', label=elec)
    ax[1,1].plot([0,1], [vals['64cued_tag == 60 & attention_type_block==1'][e], vals['64cued_tag == 64 & attention_type_block==1'][e]], 'o-', label=elec)

ax[0,0].set_title('PSD at 60Hz endogeneous')
ax[0,1].set_title('PSD at 60Hz exogeneous')
ax[1,0].set_title('PSD at 64Hz endogeneous')
ax[1,1].set_title('PSD at 64Hz exogeneous')
ax[0,0].set_ylabel('PSD at 60Hz')
ax[1,0].set_ylabel('PSD at 64Hz')
ax[1,0].set_xticks([0,1], ['Not cued', 'Cued'])
ax[1,1].set_xticks([0,1], ['Not cued', 'Cued'])
ax[1,1].set_xlim(-.5, 1.5)
plt.legend(bbox_to_anchor=(1,1))
plt.tight_layout()
plt.show()

# %%
# Normalize the frequency amplitudes as in Adamian & Andersen, 2024
npsd56 = frequency_rescaling(np.vstack([vals['60cued_tag == 60 & attention_type_block==0'],\
                                        vals['60cued_tag == 64 & attention_type_block==0'],
                                        vals['60cued_tag == 60 & attention_type_block==1'],
                                        vals['60cued_tag == 64 & attention_type_block==1'],]).T)
npsd60 = frequency_rescaling(np.vstack([vals['64cued_tag == 64 & attention_type_block==0'],\
                                        vals['64cued_tag == 60 & attention_type_block==0'],
                                        vals['64cued_tag == 64 & attention_type_block==1'],
                                        vals['64cued_tag == 60 & attention_type_block==1'],]).T)
npsds = np.stack([npsd56,npsd60])

# Average over electrodes
npsds = npsds.mean(axis=1)
np.save('files/B3_normalizes_psds.npy', npsds)

# %% [markdown]
# ### Comparing inter-trial coherence across cued conditions

# %%
# time window from -1 sec to 1 sec relative to cue
tmin, tmax = -1, 1

# Get inter-trial coherence with 60 and 64Hz by cued frequency 
freqs6064 = np.array([60, 64])
_, itc_64_endo = epochs_endo['cued_tag == 64'].copy().crop(tmin, tmax).compute_tfr(
    method="morlet", freqs=freqs6064, n_cycles=freqs6064/2,return_itc=True, average=True
)

_, itc_60_endo = epochs_endo['cued_tag == 60'].copy().crop(tmin, tmax).compute_tfr(
    method="morlet", freqs=freqs6064, n_cycles=freqs6064/2,return_itc=True, average=True
)
_, itc_64_exo = epochs_exo['cued_tag == 64'].copy().crop(tmin, tmax).compute_tfr(
    method="morlet", freqs=freqs6064, n_cycles=freqs6064/2,return_itc=True, average=True
)

_, itc_60_exo = epochs_exo['cued_tag == 60'].copy().crop(tmin, tmax).compute_tfr(
    method="morlet", freqs=freqs6064, n_cycles=freqs6064/2,return_itc=True, average=True
)

elec_idx = np.where(np.isin(epochs.info['ch_names'], best_electrodes))[0]

coherence = {}
itc_64_arr, times_coh, freqs_idx = itc_64_endo.get_data(return_freqs = True, return_times = True)
itc_60_arr = itc_60_endo.get_data()
coherence['with64_for64cued_endo'] = itc_64_arr[elec_idx,1,:]
coherence['with60_for64cued_endo'] = itc_64_arr[elec_idx,0,:]
coherence['with64_for60cued_endo'] = itc_60_arr[elec_idx,1,:]
coherence['with60_for60cued_endo'] = itc_60_arr[elec_idx,0,:]
itc_64_arr, times_coh, freqs_idx = itc_64_exo.get_data(return_freqs = True, return_times = True)
itc_60_arr = itc_60_exo.get_data()
coherence['with64_for64cued_exo'] = itc_64_arr[elec_idx,1,:]
coherence['with60_for64cued_exo'] = itc_64_arr[elec_idx,0,:]
coherence['with64_for60cued_exo'] = itc_60_arr[elec_idx,1,:]
coherence['with60_for60cued_exo'] = itc_60_arr[elec_idx,0,:]
# Out:
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.5s

# %%
fig, ax = plt.subplots(2,2, sharex=True, sharey=True, figsize=(10,5))
ax[0,0].plot(times_coh, coherence['with60_for60cued_endo'].T - coherence['with60_for64cued_endo'].T, label = best_electrodes)
ax[0,0].set_ylabel('Coherence 60Hz')
ax[0,0].set_title('Endogeneous difference 60Hz cued-uncued')
ax[1,0].plot(times_coh, coherence['with64_for64cued_endo'].T - coherence['with64_for60cued_endo'].T, label = best_electrodes)
ax[1,0].set_ylabel('Coherence 64Hz')
ax[1,0].set_title('Endogeneous difference 64Hz cued-uncued')
ax[0,1].plot(times_coh, coherence['with60_for60cued_exo'].T - coherence['with60_for64cued_exo'].T, label = best_electrodes)
ax[0,1].set_title('Exogeneous difference 60Hz cued-uncued')
ax[1,1].plot(times_coh, coherence['with64_for64cued_exo'].T - coherence['with64_for60cued_exo'].T, label = best_electrodes)
ax[1,1].set_title('Exogeneous difference 64Hz cued-uncued')

# for axi in ax.flatten():
#     axi.vlines(0, -.4, .4, color='black')

plt.legend(bbox_to_anchor=(1,1))
ax[1,0].set_xlabel('Time from cue (second)')
ax[1,1].set_xlabel('Time from cue (second)')
plt.show()

# %%
# Export for group analysis

def pd_coh(coherence_dic, cued, coh_with, condition):
    coherence = pd.DataFrame(coherence_dic[f'with{coh_with}_for{cued}cued_{condition}'])
    coherence['channel'] = best_electrodes
    coherence['cued'] = cued
    coherence['coh_with'] = coh_with
    coherence['condition'] = condition
    coherence = coherence.melt(id_vars=['channel','cued','coh_with','condition'])
    coherence['time'] = coherence['variable']*(1/epochs_endo.info['sfreq']) + tmin
    return coherence

coh64_cue64_endo = pd_coh(coherence, 64, 64, 'endo')
coh64_cue60_endo = pd_coh(coherence, 60, 64, 'endo')
coh60_cue64_endo = pd_coh(coherence, 64, 60, 'endo')
coh60_cue60_endo = pd_coh(coherence, 60, 60, 'endo')
coh64_cue64_exo = pd_coh(coherence, 64, 64, 'exo')
coh64_cue60_exo = pd_coh(coherence, 60, 64, 'exo')
coh60_cue64_exo = pd_coh(coherence, 64, 60, 'exo')
coh60_cue60_exo = pd_coh(coherence, 60, 60, 'exo')

ITcoh_B3 = pd.concat([coh60_cue60_endo, coh60_cue64_endo, coh64_cue60_endo, coh64_cue64_endo,
                     coh60_cue60_exo, coh60_cue64_exo, coh64_cue60_exo, coh64_cue64_exo])
ITcoh_B3.columns = ['channel', 'cued', 'coh_with', 'condition', 'timepoint', 'ITcoherence', 'time']
ITcoh_B3.to_csv('files/ITcoh_B3.csv',index=False)

# %% [markdown]
# # 3 - Predict cued side with a classifier

# %%
def pre_post_training(epochs, tmin_training,tmax_training,tmin_prediction,tmax_prediction):
    '''
    Function to train on a given period and test on another.
    tmax_training and tmin_training are used for training the model
    tmax_prediciton and tmin_prediciton are used for prediction only based on the best training time
    '''
    epochs_posttraining = epochs.copy().crop(tmin=tmin_training, tmax=tmax_training)
    epochs_pretraining = epochs.copy().crop(tmin=tmin_prediction, tmax=tmax_prediction ).copy()
    
    # Data and label to train on (predicting side that was cued)
    X = epochs_posttraining.copy().get_data()
    y = epochs_posttraining.metadata['cued_side'].values
    
    # Model fitting with logistic regression, using 10 CV
    clf = make_pipeline(StandardScaler(), LogisticRegression(solver="liblinear"))
    time_decod = SlidingEstimator(clf, n_jobs=10, scoring="roc_auc", verbose=True)
    scores = cross_val_multiscore(time_decod, X, y, cv=10, n_jobs=10)
    
    # Find the best time point during training period, first average scores over splits and pick max score
    mean_scores = np.mean(scores, axis=0)
    best_time_idx = np.argmax(mean_scores)
    best_time = epochs_posttraining.times[best_time_idx]
    best_score = mean_scores[best_time_idx]
    print(f"Best time point post-250ms: {best_time} seconds with score: {best_score}")
    
    # Re-train the model on the best time during the training period only
    best_time_data = X[:, :, best_time_idx]
    clf_best = make_pipeline(StandardScaler(), LogisticRegression(solver="liblinear"))
    clf_best.fit(best_time_data, y)
    
    # Evaluate the model on data for each time point during prediction period separately for endo and exo
    exo = epochs_pretraining['attention_type_block==0'].copy()
    endo = epochs_pretraining['attention_type_block==1'].copy()
    # Automatically perform kfold
    skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
    cv_scores_pretraining_exo = []
    cv_scores_pretraining_endo = []
    
    # Iterate through each time point in the prediction period
    for t in range(len(exo.times)):
        X_pretraining_exo = exo.get_data()[:, :, t]
        X_pretraining_endo = endo.get_data()[:, :, t]
        y_exo = exo.metadata['cued_side'].values
        y_endo = endo.metadata['cued_side'].values
        fold_scores_exo = []
        fold_scores_endo = []
        
        # Iterate through each fold of cross-validation
        for train_index, test_index in skf.split(X_pretraining_exo, y_exo):
            X_train, X_test = X_pretraining_exo[train_index], X_pretraining_exo[test_index]
            y_train, y_test = y_exo[train_index], y_exo[test_index]
            
            # Use the previously trained model to predict the time point data in the prediction period
            predictions = clf_best.predict(X_pretraining_exo[test_index])
            score_exo = roc_auc_score(y_test, predictions)
            fold_scores_exo.append(score_exo)
        # Average score across folds for this time point
        avg_score_exo = np.mean(fold_scores_exo, axis=-1)
        cv_scores_pretraining_exo.append(avg_score_exo)
        
        # Same for endo
        for train_index, test_index in skf.split(X_pretraining_endo, y_endo):
            X_train, X_test = X_pretraining_endo[train_index], X_pretraining_endo[test_index]
            y_train, y_test = y_endo[train_index], y_endo[test_index]
            
            predictions = clf_best.predict(X_pretraining_endo[test_index])
            score_endo = roc_auc_score(y_test, predictions)
            fold_scores_endo.append(score_endo)
        
        avg_score_endo = np.mean(fold_scores_endo, axis=-1)
        cv_scores_pretraining_endo.append(avg_score_endo)

    cv_scores_pretraining_exo = np.array(cv_scores_pretraining_exo)
    cv_scores_pretraining_endo = np.array(cv_scores_pretraining_endo)
    
    # Make all scores > .50 as there are only two labels
    cv_scores_pretraining_exo = np.abs(cv_scores_pretraining_exo - cv_scores_pretraining_exo.mean())+.5
    cv_scores_pretraining_endo = np.abs(cv_scores_pretraining_endo - cv_scores_pretraining_endo.mean())+.5

    pd_prediction = pd.DataFrame({'exo':cv_scores_pretraining_exo,
                     'endo':cv_scores_pretraining_endo,
                     'time':epochs_pretraining.times})
    pd_prediction = pd_prediction.melt(id_vars='time')
    pd_prediction.columns = ['time', 'attention', 'score']
    pd_prediction['best_time'] = best_time
    return pd_prediction

# %%
# Load eeg epochs again to use all channels
epochs = mne.read_epochs(f'{data_path}{epoch_file}')
epoch_good = [x for x,y in enumerate(epochs.drop_log) if len(y) == 0]
epochs.metadata = pd_info.iloc[epoch_good]

# Remove trials where a target occured
epochs = epochs['targets_binary == 0']

# Downsample for speed
epochs.resample(200).pick_types(eeg=True)
# Out:
# Reading /home/lea/Documents/obsidian_notes/masterADS/ads_thesis_RIFT/my_code_expe2/data/B3/preprocessing/B3_EEG_epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 510 matching events found
# No baseline correction applied
# 0 projection items activated
# Adding metadata with 14 columns
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# <EpochsFIF |  414 events (all good), -1 – 1.995 s, baseline -1 – 0 s, ~121.4 MB, data loaded, with metadata,
#  '3': 414>

# %% [markdown]
# ## Training on the attention window (target onset period)

# %%
# Data preparation for training and prediction periods
tmin_training, tmax_training = .125, .8
# Take some time after training for plotting purposes 
tmin_prediction, tmax_prediction = -.2, .8
target_period = pre_post_training(epochs, tmin_training, tmax_training, tmin_prediction, tmax_prediction)
# Out:
# /tmp/ipykernel_14765/132503421.py:11: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X = epochs_posttraining.copy().get_data()
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
#  38%|███▊      | Fitting SlidingEstimator : 52/136 [00:00<00:00,  250.18it/s]
#  44%|████▍     | Fitting SlidingEstimator : 60/136 [00:00<00:00,  246.99it/s]
#  52%|█████▏    | Fitting SlidingEstimator : 71/136 [00:00<00:00,  249.70it/s][A
#  58%|█████▊    | Fitting SlidingEstimator : 79/136 [00:00<00:00,  247.04it/s]
#  63%|██████▎   | Fitting SlidingEstimator : 86/136 [00:00<00:00,  242.08it/s]
#  71%|███████▏  | Fitting SlidingEstimator : 97/136 [00:00<00:00,  248.05it/s]
#  75%|███████▌  | Fitting SlidingEstimator : 102/136 [00:00<00:00,  237.80it/s][A
#  80%|████████  | Fitting SlidingEstimator : 109/136 [00:00<00:00,  233.50it/s][A
#  87%|████████▋ | Fitting SlidingEstimator : 118/136 [00:00<00:00,  234.87it/s][A
#  93%|█████████▎| Fitting SlidingEstimator : 126/136 [00:00<00:00,  234.19it/s][A
# 100%|██████████| Fitting SlidingEstimator : 136/136 [00:00<00:00,  234.90it/s][A
#
#
#   0%|          | Fitting SlidingEstimator : 0/136 [00:00<?,       ?it/s]
#  54%|█████▍    | Fitting SlidingEstimator : 74/136 [00:00<00:00,  204.02it/s]
#  59%|█████▉    | Fitting SlidingEstimator : 80/136 [00:00<00:00,  200.56it/s]
#
#   7%|▋         | Fitting SlidingEstimator : 10/136 [00:00<00:00,  135.45it/s]
#  63%|██████▎   | Fitting SlidingEstimator : 86/136 [00:00<00:00,  196.89it/s]
#
#  11%|█         | Fitting SlidingEstimator : 15/136 [00:00<00:00,  139.38it/s]
#  68%|██████▊   | Fitting SlidingEstimator : 92/136 [00:00<00:00,  194.93it/s]
#
#  17%|█▋        | Fitting SlidingEstimator : 23/136 [00:00<00:00,  157.16it/s]
#  73%|███████▎  | Fitting SlidingEstimator : 99/136 [00:00<00:00,  190.60it/s]
#
#  21%|██▏       | Fitting SlidingEstimator : 29/136 [00:00<00:00,  156.01it/s]
#  79%|███████▉  | Fitting SlidingEstimator : 108/136 [00:00<00:00,  193.48it/s]
#
#  26%|██▌       | Fitting SlidingEstimator : 35/136 [00:00<00:00,  158.10it/s]
#  83%|████████▎ | Fitting SlidingEstimator : 113/136 [00:00<00:00,  186.83it/s]
#
#  30%|███       | Fitting SlidingEstimator : 41/136 [00:00<00:00,  158.41it/s]
#  87%|████████▋ | Fitting SlidingEstimator : 118/136 [00:00<00:00,  183.07it/s]
#
#  33%|███▎      | Fitting SlidingEstimator : 45/136 [00:00<00:00,  152.77it/s]
#  93%|█████████▎| Fitting SlidingEstimator : 126/136 [00:00<00:00,  186.50it/s]
#
#  39%|███▉      | Fitting SlidingEstimator : 53/136 [00:00<00:00,  162.17it/s]
# 100%|██████████| Fitting SlidingEstimator : 136/136 [00:00<00:00,  189.56it/s]
#
#
#  44%|████▍     | Fitting SlidingEstimator : 60/136 [00:00<00:00,  163.48it/s]
#
#
#   0%|          | Fitting SlidingEstimator : 0/136 [00:00<?,       ?it/s]
#
#  49%|████▊     | Fitting SlidingEstimator : 66/136 [00:00<00:00,  163.80it/s]
#
#  56%|█████▌    | Fitting SlidingEstimator : 76/136 [00:00<00:00,  173.15it/s]
#
#
#   3%|▎         | Fitting SlidingEstimator : 4/136 [00:00<00:02,   58.25it/s]
#
#  60%|█████▉    | Fitting SlidingEstimator : 81/136 [00:00<00:00,  170.80it/s]
#
#
#   8%|▊         | Fitting SlidingEstimator : 11/136 [00:00<00:01,  105.01it/s]
#
#  64%|██████▍   | Fitting SlidingEstimator : 87/136 [00:00<00:00,  170.89it/s]
#
#
#  12%|█▏        | Fitting SlidingEstimator : 16/136 [00:00<00:01,  115.19it/s]
#
#  69%|██████▉   | Fitting SlidingEstimator : 94/136 [00:00<00:00,  172.74it/s]
#
#
#  17%|█▋        | Fitting SlidingEstimator : 23/136 [00:00<00:00,  131.46it/s]
#
#  75%|███████▌  | Fitting SlidingEstimator : 102/136 [00:00<00:00,  174.09it/s]
#
#
#  22%|██▏       | Fitting SlidingEstimator : 30/136 [00:00<00:00,  141.10it/s]
#
#
#
#   0%|          | Fitting SlidingEstimator : 0/136 [00:00<?,       ?it/s]
#
#
#  28%|██▊       | Fitting SlidingEstimator : 38/136 [00:00<00:00,  149.94it/s]
#
#  82%|████████▏ | Fitting SlidingEstimator : 111/136 [00:00<00:00,  173.13it/s]
#
#
#  30%|███       | Fitting SlidingEstimator : 41/136 [00:00<00:00,  140.60it/s]
#
#  88%|████████▊ | Fitting SlidingEstimator : 119/136 [00:00<00:00,  174.18it/s]
#
#
#
#   3%|▎         | Fitting SlidingEstimator : 4/136 [00:00<00:02,   55.38it/s]
#
#
#  36%|███▌      | Fitting SlidingEstimator : 49/136 [00:00<00:00,  152.16it/s]
#
#  93%|█████████▎| Fitting SlidingEstimator : 126/136 [00:00<00:00,  175.34it/s]
#
#
#
#   7%|▋         | Fitting SlidingEstimator : 9/136 [00:00<00:01,   85.37it/s]
#
#
#  40%|████      | Fitting SlidingEstimator : 55/136 [00:00<00:00,  152.97it/s]
#
#  97%|█████████▋| Fitting SlidingEstimator : 132/136 [00:00<00:00,  174.66it/s]
#
#
#
#  10%|▉         | Fitting SlidingEstimator : 13/136 [00:00<00:01,   92.07it/s]
#
# 100%|██████████| Fitting SlidingEstimator : 136/136 [00:00<00:00,  172.63it/s]
#
#
#
#  46%|████▌     | Fitting SlidingEstimator : 62/136 [00:00<00:00,  155.27it/s]
#
#
#
#  15%|█▌        | Fitting SlidingEstimator : 21/136 [00:00<00:00,  118.98it/s]
#
#
#
#
#   0%|          | Fitting SlidingEstimator : 0/136 [00:00<?,       ?it/s]
#
#
#  51%|█████     | Fitting SlidingEstimator : 69/136 [00:00<00:00,  159.28it/s]
#
#
#
#  22%|██▏       | Fitting SlidingEstimator : 30/136 [00:00<00:00,  141.93it/s]
#
#
#  56%|█████▌    | Fitting SlidingEstimator : 76/136 [00:00<00:00,  161.42it/s]
#
#
#
#  25%|██▌       | Fitting SlidingEstimator : 34/136 [00:00<00:00,  137.15it/s]
#
#
#
#
#   2%|▏         | Fitting SlidingEstimator : 3/136 [00:00<00:03,   39.13it/s]
#
#
#  60%|█████▉    | Fitting SlidingEstimator : 81/136 [00:00<00:00,  158.62it/s]
#
#
#
#  30%|███       | Fitting SlidingEstimator : 41/136 [00:00<00:00,  143.75it/s]
#
#
#
#
#   7%|▋         | Fitting SlidingEstimator : 9/136 [00:00<00:01,   82.88it/s]
#
#
#  65%|██████▍   | Fitting SlidingEstimator : 88/136 [00:00<00:00,  162.72it/s]
#
#
#
#  35%|███▌      | Fitting SlidingEstimator : 48/136 [00:00<00:00,  150.98it/s]
#
#
#
#
#  11%|█         | Fitting SlidingEstimator : 15/136 [00:00<00:01,  103.98it/s]
#
#
#  70%|██████▉   | Fitting SlidingEstimator : 95/136 [00:00<00:00,  164.85it/s]
#
#
#
#  39%|███▉      | Fitting SlidingEstimator : 53/136 [00:00<00:00,  149.12it/s]
#
#
#
#
#  15%|█▍        | Fitting SlidingEstimator : 20/136 [00:00<00:01,  110.45it/s]
#
#
#
#
#
#   0%|          | Fitting SlidingEstimator : 0/136 [00:00<?,       ?it/s]
#
#
#  74%|███████▎  | Fitting SlidingEstimator : 100/136 [00:00<00:00,  160.59it/s]
#
#
#
#  43%|████▎     | Fitting SlidingEstimator : 58/136 [00:00<00:00,  145.34it/s]
#
#
#
#
#  20%|█▉        | Fitting SlidingEstimator : 27/136 [00:00<00:00,  124.35it/s]
#
#
#  78%|███████▊  | Fitting SlidingEstimator : 106/136 [00:00<00:00,  157.63it/s]
#
#
#
#  49%|████▊     | Fitting SlidingEstimator : 66/136 [00:00<00:00,  153.25it/s]
#
#
#
#
#  23%|██▎       | Fitting SlidingEstimator : 31/136 [00:00<00:00,  123.02it/s]
#
#
#
#
#
#   2%|▏         | Fitting SlidingEstimator : 3/136 [00:00<00:03,   34.26it/s]
#
#
#  81%|████████  | Fitting SlidingEstimator : 110/136 [00:00<00:00,  153.87it/s]
#
#
#
#
#
#
#
#
#  51%|█████▏    | Fitting SlidingEstimator : 70/136 [00:00<00:00,  148.12it/s]
#
#
#
#
#
#
#
#
#  85%|████████▌ | Fitting SlidingEstimator : 116/136 [00:00<00:00,  154.88it/s][A
#
#
#
#
#  30%|███       | Fitting SlidingEstimator : 41/136 [00:00<00:00,  126.40it/s]
#
#
#
#  56%|█████▌    | Fitting SlidingEstimator : 76/136 [00:00<00:00,  144.39it/s]
#
#
#
#
#
#
#
#
#  88%|████████▊ | Fitting SlidingEstimator : 119/136 [00:00<00:00,  149.46it/s]
#
#
#
#
#  33%|███▎      | Fitting SlidingEstimator : 45/136 [00:00<00:00,  124.98it/s]
#
#
#
#  60%|█████▉    | Fitting SlidingEstimator : 81/136 [00:00<00:00,  141.36it/s]
#
#
#
#
#
#  15%|█▌        | Fitting SlidingEstimator : 21/136 [00:00<00:01,  106.63it/s]
#
#
#  92%|█████████▏| Fitting SlidingEstimator : 125/136 [00:00<00:00,  148.67it/s]
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | Fitting SlidingEstimator : 0/136 [00:00<?,       ?it/s]
#
#
#
#  63%|██████▎   | Fitting SlidingEstimator : 86/136 [00:00<00:00,  140.35it/s]
#
#
#  97%|█████████▋| Fitting SlidingEstimator : 132/136 [00:00<00:00,  152.31it/s]
#
#
#
#
#
#  19%|█▉        | Fitting SlidingEstimator : 26/136 [00:00<00:00,  110.66it/s]
#
#
#
#
#
#
#
#
#  69%|██████▉   | Fitting SlidingEstimator : 94/136 [00:00<00:00,  146.32it/s]
#
#
# 100%|██████████| Fitting SlidingEstimator : 136/136 [00:00<00:00,  151.65it/s]
#
#
#
#
#
#
#  24%|██▎       | Fitting SlidingEstimator : 32/136 [00:00<00:00,  119.68it/s]
#
#
#
#
#
#
#   1%|▏         | Fitting SlidingEstimator : 2/136 [00:00<00:04,   28.36it/s]
#
#
#
#  72%|███████▏  | Fitting SlidingEstimator : 98/136 [00:00<00:00,  144.27it/s]
#
#
#
#
#  46%|████▋     | Fitting SlidingEstimator : 63/136 [00:00<00:00,  129.64it/s]
#
#
#
#
#
#
#   6%|▌         | Fitting SlidingEstimator : 8/136 [00:00<00:01,   74.45it/s]
#
#
#
#
#
#  29%|██▊       | Fitting SlidingEstimator : 39/136 [00:00<00:00,  123.16it/s]
#
#
#
#  76%|███████▌  | Fitting SlidingEstimator : 103/136 [00:00<00:00,  143.35it/s]
#
#
#
#
#  49%|████▉     | Fitting SlidingEstimator : 67/136 [00:00<00:00,  128.64it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#   9%|▉         | Fitting SlidingEstimator : 12/136 [00:00<00:01,   85.02it/s]
#
#
#
#
#  52%|█████▏    | Fitting SlidingEstimator : 71/136 [00:00<00:00,  126.48it/s]
#
#
#
#  79%|███████▉  | Fitting SlidingEstimator : 108/136 [00:00<00:00,  140.89it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#  36%|███▌      | Fitting SlidingEstimator : 49/136 [00:00<00:00,  126.06it/s]
#
#
#
#
#
#
#
#
#  83%|████████▎ | Fitting SlidingEstimator : 113/136 [00:00<00:00,  141.07it/s]
#
#
#
#
#
#
#
#   0%|          | Fitting SlidingEstimator : 0/136 [00:00<?,       ?it/s]
#
#
#
#
#
#  40%|████      | Fitting SlidingEstimator : 55/136 [00:00<00:00,  128.07it/s]
#
#
#
#
#
#
#  18%|█▊        | Fitting SlidingEstimator : 24/136 [00:00<00:01,  105.81it/s]
#
#
#
#
#
#
#
#
#  59%|█████▉    | Fitting SlidingEstimator : 80/136 [00:00<00:00,  125.80it/s]
#
#
#
#
#
#  44%|████▍     | Fitting SlidingEstimator : 60/136 [00:00<00:00,  128.63it/s]
#
#
#
#  93%|█████████▎| Fitting SlidingEstimator : 126/136 [00:00<00:00,  145.60it/s]
#
#
#
#
#
#
#  21%|██        | Fitting SlidingEstimator : 28/136 [00:00<00:01,  102.91it/s]
#
#
#
#
#
#  49%|████▉     | Fitting SlidingEstimator : 67/136 [00:00<00:00,  135.24it/s]
#
#
#
#
#
#
#
#   1%|▏         | Fitting SlidingEstimator : 2/136 [00:00<00:05,   22.58it/s]
#
#
#
#
# [Parallel(n_jobs=10)]: Done   3 out of  10 | elapsed:    3.1s remaining:    7.2s
#
#
#
#
#  67%|██████▋   | Fitting SlidingEstimator : 91/136 [00:00<00:00,  130.95it/s]
#
#
#
#
#
#
#  26%|██▋       | Fitting SlidingEstimator : 36/136 [00:00<00:00,  116.84it/s]
#
#
#
#
#
#  52%|█████▏    | Fitting SlidingEstimator : 71/136 [00:00<00:00,  133.29it/s]
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| Fitting SlidingEstimator : 136/136 [00:00<00:00,  144.49it/s]A
#
#
#
#
#
#
#
#  29%|██▉       | Fitting SlidingEstimator : 40/136 [00:00<00:00,  116.21it/s]
#
#
#
#
#  73%|███████▎  | Fitting SlidingEstimator : 99/136 [00:00<00:00,  131.45it/s]
#
#
#
#
#
#  56%|█████▌    | Fitting SlidingEstimator : 76/136 [00:00<00:00,  132.90it/s]
#
#
#
#
#
#
#
#   8%|▊         | Fitting SlidingEstimator : 11/136 [00:00<00:01,   69.42it/s]
#
#
#
#
#
#
#  35%|███▌      | Fitting SlidingEstimator : 48/136 [00:00<00:00,  124.99it/s]
#
#
#
#
#  78%|███████▊  | Fitting SlidingEstimator : 106/136 [00:00<00:00,  134.65it/s]
#
#
#
#
#
#  60%|██████    | Fitting SlidingEstimator : 82/136 [00:00<00:00,  135.95it/s]
#
#
#
#
#
#
#
#  12%|█▎        | Fitting SlidingEstimator : 17/136 [00:00<00:01,   89.99it/s]
#
#
#
#
#
#
#
#
#   0%|          | Fitting SlidingEstimator : 0/136 [00:00<?,       ?it/s]
#
#
#
#
#
#
#  40%|███▉      | Fitting SlidingEstimator : 54/136 [00:00<00:00,  129.08it/s]
#
#
#
#
#
#  62%|██████▎   | Fitting SlidingEstimator : 85/136 [00:00<00:00,  132.20it/s]
#
#
#
#
#
#
#
#  16%|█▌        | Fitting SlidingEstimator : 22/136 [00:00<00:01,   99.18it/s]
#
#
#
#
#  81%|████████  | Fitting SlidingEstimator : 110/136 [00:00<00:00,  131.51it/s]
#
#
#
#
#
#
#  44%|████▍     | Fitting SlidingEstimator : 60/136 [00:00<00:00,  132.50it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#  21%|██        | Fitting SlidingEstimator : 28/136 [00:00<00:00,  109.96it/s]
#
#
#
#
#
#  68%|██████▊   | Fitting SlidingEstimator : 93/136 [00:00<00:00,  137.54it/s]
#
#
#
#
#
#
#
#
#   1%|▏         | Fitting SlidingEstimator : 2/136 [00:00<00:04,   27.60it/s]
#
#
#
#
#
#
#  49%|████▊     | Fitting SlidingEstimator : 66/136 [00:00<00:00,  135.04it/s]
#
#
#
#
#
#
#
#  25%|██▌       | Fitting SlidingEstimator : 34/136 [00:00<00:00,  118.53it/s]
#
#
#
#
#  89%|████████▉ | Fitting SlidingEstimator : 121/136 [00:00<00:00,  134.49it/s]
#
#
#
#
#
#  72%|███████▏  | Fitting SlidingEstimator : 98/136 [00:00<00:00,  135.67it/s]
#
#
#
#
#
#
#
#
#   6%|▌         | Fitting SlidingEstimator : 8/136 [00:00<00:01,   70.09it/s]
#
#
#
#
#
#
#  51%|█████▏    | Fitting SlidingEstimator : 70/136 [00:00<00:00,  133.33it/s]
#
#
#
#
#  94%|█████████▍| Fitting SlidingEstimator : 128/136 [00:00<00:00,  138.75it/s]
#
#
#
#
#
#
#
#  28%|██▊       | Fitting SlidingEstimator : 38/136 [00:00<00:00,  117.27it/s]
#
#
#
#
#
#  76%|███████▌  | Fitting SlidingEstimator : 103/136 [00:00<00:00,  135.55it/s]
#
#
#
#
#
#
#
#
#  10%|▉         | Fitting SlidingEstimator : 13/136 [00:00<00:01,   88.33it/s]
#
#
#
#
#
#
#  54%|█████▍    | Fitting SlidingEstimator : 74/136 [00:00<00:00,  130.80it/s]
#
#
#
#
#  99%|█████████▊| Fitting SlidingEstimator : 134/136 [00:00<00:00,  140.92it/s]
#
#
#
#
#
#
#
#  34%|███▍      | Fitting SlidingEstimator : 46/136 [00:00<00:00,  130.06it/s]
#
#
#
#
#
#  79%|███████▊  | Fitting SlidingEstimator : 107/136 [00:00<00:00,  132.92it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| Fitting SlidingEstimator : 136/136 [00:01<00:00,  133.99it/s]
#  12%|█▎        | Fitting SlidingEstimator : 17/136 [00:00<00:01,   91.98it/s]
#
#
#
#
#
#
#  59%|█████▉    | Fitting SlidingEstimator : 80/136 [00:00<00:00,  133.31it/s]
#
#
#
#
#
#
#
#  40%|███▉      | Fitting SlidingEstimator : 54/136 [00:00<00:00,  136.40it/s]
#
#
#
#
#
#  82%|████████▏ | Fitting SlidingEstimator : 112/136 [00:00<00:00,  133.73it/s]
#
#
#
#
#
#
#  63%|██████▎   | Fitting SlidingEstimator : 86/136 [00:00<00:00,  135.54it/s]
#
#
#
#
#
#
#
#
#  17%|█▋        | Fitting SlidingEstimator : 23/136 [00:00<00:01,   97.87it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  89%|████████▉ | Fitting SlidingEstimator : 121/136 [00:00<00:00,  140.99it/s][A
#
#
#
#
#
#
#  68%|██████▊   | Fitting SlidingEstimator : 93/136 [00:00<00:00,  140.28it/s]
#
#
#
#
#
#
#
#
#  22%|██▏       | Fitting SlidingEstimator : 30/136 [00:00<00:00,  111.86it/s]
#
#
#
#
#
#
#
#  47%|████▋     | Fitting SlidingEstimator : 64/136 [00:00<00:00,  135.70it/s]
#
#
#
#
#
#  92%|█████████▏| Fitting SlidingEstimator : 125/136 [00:00<00:00,  138.53it/s]
#
#
#
#
#
#
#  71%|███████   | Fitting SlidingEstimator : 96/136 [00:00<00:00,  136.03it/s]
#
#
#
#
#
#
#
#
#  25%|██▌       | Fitting SlidingEstimator : 34/136 [00:00<00:00,  112.62it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| Fitting SlidingEstimator : 136/136 [00:00<00:00,  139.26it/s][A
#
#
#
#
#
#
#
#  76%|███████▋  | Fitting SlidingEstimator : 104/136 [00:00<00:00,  142.13it/s]
#
#
#
#
#
#
#
#
#  30%|███       | Fitting SlidingEstimator : 41/136 [00:00<00:00,  122.71it/s]
#
#
#
#
#
#
#
#  57%|█████▋    | Fitting SlidingEstimator : 77/136 [00:00<00:00,  142.72it/s]
#
#
#
#
#
#
#  82%|████████▏ | Fitting SlidingEstimator : 112/136 [00:00<00:00,  146.70it/s]
#
#
#
#
#
#
#
#
#  37%|███▋      | Fitting SlidingEstimator : 50/136 [00:00<00:00,  135.23it/s]
#
#
#
#
#
#
#
#  62%|██████▏   | Fitting SlidingEstimator : 84/136 [00:00<00:00,  147.16it/s]
#
#
#
#
#
#
#  87%|████████▋ | Fitting SlidingEstimator : 118/136 [00:00<00:00,  148.72it/s]
#
#
#
#
#
#
#
#
#  39%|███▉      | Fitting SlidingEstimator : 53/136 [00:00<00:00,  130.05it/s]
#
#
#
#
#
#
#
#  65%|██████▌   | Fitting SlidingEstimator : 89/136 [00:00<00:00,  147.01it/s]
#
#
#
#
#
#
#  92%|█████████▏| Fitting SlidingEstimator : 125/136 [00:00<00:00,  152.48it/s]
#
#
#
#
#
#
#
#
#  45%|████▍     | Fitting SlidingEstimator : 61/136 [00:00<00:00,  139.95it/s]
#
#
#
#
#
#
#
#  71%|███████   | Fitting SlidingEstimator : 96/136 [00:00<00:00,  151.22it/s]
#
#
#
#
#
#
# 100%|██████████| Fitting SlidingEstimator : 136/136 [00:00<00:00,  148.43it/s]
#
#
#
#
#
#
#
#
#
#  53%|█████▎    | Fitting SlidingEstimator : 72/136 [00:00<00:00,  152.35it/s]
#
#
#
#
#
#
#
#  76%|███████▋  | Fitting SlidingEstimator : 104/136 [00:00<00:00,  156.24it/s]
#
#
#
#
#
#
#
#
#  60%|█████▉    | Fitting SlidingEstimator : 81/136 [00:00<00:00,  160.33it/s]
#
#
#
#
#
#
#
#  84%|████████▍ | Fitting SlidingEstimator : 114/136 [00:00<00:00,  164.80it/s]
#
#
#
#
#
#
#
#
#  67%|██████▋   | Fitting SlidingEstimator : 91/136 [00:00<00:00,  169.40it/s]
#
#
#
#
#
#
#
#  90%|█████████ | Fitting SlidingEstimator : 123/136 [00:00<00:00,  169.92it/s]
#
#
#
#
#
#
#
#
#  73%|███████▎  | Fitting SlidingEstimator : 99/136 [00:00<00:00,  174.31it/s]
#
#
#
#
#
#
#
# 100%|██████████| Fitting SlidingEstimator : 136/136 [00:00<00:00,  162.66it/s]
#
#
#
#
#
#
#
#
#
#  80%|████████  | Fitting SlidingEstimator : 109/136 [00:00<00:00,  183.27it/s]
#
#
#
#
#
#
#
#
#  89%|████████▉ | Fitting SlidingEstimator : 121/136 [00:00<00:00,  195.60it/s]
#
#
#
#
#
#
#
#
# 100%|██████████| Fitting SlidingEstimator : 136/136 [00:00<00:00,  186.37it/s]
# [Parallel(n_jobs=10)]: Done   6 out of  10 | elapsed:    3.9s remaining:    2.6s
# [Parallel(n_jobs=10)]: Done  10 out of  10 | elapsed:    4.2s finished
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# Best time point post-250ms: 0.18500000000000005 seconds with score: 0.9045047412904555
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# ...
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]

# %%
plt.plot(target_period[target_period.attention == 'exo'].time, target_period[target_period.attention == 'exo'].score)
plt.plot(target_period[target_period.attention == 'endo'].time, target_period[target_period.attention == 'endo'].score)

# %%
target_period.to_csv('files/B3_target_period.csv')

# %% [markdown]
# ## Training on the period after the ERP

# %%
# First plotting ERP for exogeneous attention, for eahc cued side
epochs["attention_type_block==0 & cued_side == 0"].copy().crop(tmin=-.1, tmax=.7).pick(relevant_electrodes).average().plot_joint(times=[.1,.15,.2,.3]);
epochs["attention_type_block==0 & cued_side == 1"].copy().crop(tmin=-.1, tmax=.7).pick(relevant_electrodes).average().plot_joint(times=[.1,.15,.2,.3]);
# Out:
# No projector specified for this dataset. Please consider the method self.add_proj.
# No projector specified for this dataset. Please consider the method self.add_proj.

# %%
# First plotting ERP for endogeneous attention, for eahc cued side
epochs["attention_type_block==1 & cued_side == 0"].copy().crop(tmin=-.1, tmax=.7).pick(relevant_electrodes).average().plot_joint(times=[.1,.15,.2,.3]);
epochs["attention_type_block==1 & cued_side == 1"].copy().crop(tmin=-.1, tmax=.7).pick(relevant_electrodes).average().plot_joint(times=[.1,.15,.2,.3]);
# Out:
# No projector specified for this dataset. Please consider the method self.add_proj.
# No projector specified for this dataset. Please consider the method self.add_proj.

# %%
# Extract all averaged ERPs for all relevant electrodes for cued_side and attention blocks
queries = ["attention_type_block==0 & cued_side == 0", "attention_type_block==0 & cued_side == 1", "attention_type_block==1 & cued_side == 0", "attention_type_block==1 & cued_side == 1"]
erp = {}
# Baseline for the ERP
tmin = -.1
for query in queries:
    erp[query] = epochs[query].copy().crop(tmin=tmin, tmax=.7).pick(relevant_electrodes).average().get_data()

# Export for group analysis
def pd_erp(erp_dic, attention, cued_side):
    erp = pd.DataFrame(erp_dic[f'attention_type_block=={attention} & cued_side == {cued_side}'])
    erp['channel'] = relevant_electrodes
    erp['attention'] = attention
    erp['cued_side'] = cued_side
    erp = erp.melt(id_vars=['channel','attention','cued_side'])
    erp['time'] = erp['variable']*(1/epochs.info['sfreq']) + tmin
    return erp

exo_left = pd_erp(erp, 0, 0)
exo_right = pd_erp(erp, 0, 1)
endo_left = pd_erp(erp, 1, 0)
endo_right = pd_erp(erp, 1, 1)

erp_B3 = pd.concat([exo_left, exo_right, endo_left, endo_right])
erp_B3.columns = ['channel', 'attention', 'cued_side', 'timepoint', 'erp', 'time']
erp_B3.to_csv('files/erp_B3.csv',index=False)

# %%
# Data preparation for training and prediction periods
tmin_training, tmax_training = .5, 1.1
# Take some time after training for plotting purposes 
tmin_prediction, tmax_prediction = -.2, .8
post_erp = pre_post_training(epochs, tmin_training, tmax_training, tmin_prediction, tmax_prediction)
# Out:
# /tmp/ipykernel_14765/132503421.py:11: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X = epochs_posttraining.copy().get_data()
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
#  24%|██▍       | Fitting SlidingEstimator : 29/121 [00:00<00:00,  267.16it/s]
#  34%|███▍      | Fitting SlidingEstimator : 41/121 [00:00<00:00,  286.84it/s]
#  42%|████▏     | Fitting SlidingEstimator : 51/121 [00:00<00:00,  285.67it/s][A
#  51%|█████     | Fitting SlidingEstimator : 62/121 [00:00<00:00,  290.43it/s]
#  20%|█▉        | Fitting SlidingEstimator : 24/121 [00:00<00:00,  230.59it/s]
#
#  58%|█████▊    | Fitting SlidingEstimator : 70/121 [00:00<00:00,  281.27it/s]A
#  28%|██▊       | Fitting SlidingEstimator : 34/121 [00:00<00:00,  241.62it/s]
#
#  65%|██████▌   | Fitting SlidingEstimator : 79/121 [00:00<00:00,  278.59it/s][A
#  35%|███▍      | Fitting SlidingEstimator : 42/121 [00:00<00:00,  236.70it/s]
#
#  70%|███████   | Fitting SlidingEstimator : 85/121 [00:00<00:00,  264.46it/s]
#  41%|████▏     | Fitting SlidingEstimator : 50/121 [00:00<00:00,  234.23it/s]
#
#  78%|███████▊  | Fitting SlidingEstimator : 94/121 [00:00<00:00,  263.99it/s]
#
#
#   0%|          | Fitting SlidingEstimator : 0/121 [00:00<?,       ?it/s]
#  48%|████▊     | Fitting SlidingEstimator : 58/121 [00:00<00:00,  228.74it/s]
#
#  83%|████████▎ | Fitting SlidingEstimator : 100/121 [00:00<00:00,  253.20it/s][A
#
#
#  88%|████████▊ | Fitting SlidingEstimator : 107/121 [00:00<00:00,  247.15it/s][A
#
#
#   6%|▌         | Fitting SlidingEstimator : 7/121 [00:00<00:01,   95.43it/s]
#  59%|█████▊    | Fitting SlidingEstimator : 71/121 [00:00<00:00,  216.99it/s]
#
#  95%|█████████▌| Fitting SlidingEstimator : 115/121 [00:00<00:00,  245.80it/s][A
#
#
#   8%|▊         | Fitting SlidingEstimator : 10/121 [00:00<00:01,   93.15it/s]
#  65%|██████▌   | Fitting SlidingEstimator : 79/121 [00:00<00:00,  216.55it/s]
#
# 100%|██████████| Fitting SlidingEstimator : 121/121 [00:00<00:00,  244.64it/s][A
#
#
#
#  15%|█▍        | Fitting SlidingEstimator : 18/121 [00:00<00:00,  127.34it/s]
#
#
#
#   0%|          | Fitting SlidingEstimator : 0/121 [00:00<?,       ?it/s]
#  70%|███████   | Fitting SlidingEstimator : 85/121 [00:00<00:00,  211.33it/s]
#
#  40%|████      | Fitting SlidingEstimator : 49/121 [00:00<00:00,  168.56it/s]
#
#
#  21%|██        | Fitting SlidingEstimator : 25/121 [00:00<00:00,  137.24it/s]
#  77%|███████▋  | Fitting SlidingEstimator : 93/121 [00:00<00:00,  211.77it/s]
#
#  48%|████▊     | Fitting SlidingEstimator : 58/121 [00:00<00:00,  177.42it/s]
#
#
#  27%|██▋       | Fitting SlidingEstimator : 33/121 [00:00<00:00,  153.02it/s]
#
#
#
#   3%|▎         | Fitting SlidingEstimator : 4/121 [00:00<00:02,   55.47it/s]
#  81%|████████  | Fitting SlidingEstimator : 98/121 [00:00<00:00,  204.90it/s]
#
#  53%|█████▎    | Fitting SlidingEstimator : 64/121 [00:00<00:00,  168.52it/s]
#
#
#  31%|███       | Fitting SlidingEstimator : 37/121 [00:00<00:00,  147.32it/s]
#
#
#
#   8%|▊         | Fitting SlidingEstimator : 10/121 [00:00<00:01,   94.76it/s]
#  87%|████████▋ | Fitting SlidingEstimator : 105/121 [00:00<00:00,  204.07it/s]
#
#  57%|█████▋    | Fitting SlidingEstimator : 69/121 [00:00<00:00,  166.16it/s]
#
#
#  35%|███▍      | Fitting SlidingEstimator : 42/121 [00:00<00:00,  147.26it/s]
#
#
#
#  14%|█▍        | Fitting SlidingEstimator : 17/121 [00:00<00:00,  123.39it/s]
#  91%|█████████ | Fitting SlidingEstimator : 110/121 [00:00<00:00,  197.54it/s]
#
#
#
#
#   0%|          | Fitting SlidingEstimator : 0/121 [00:00<?,       ?it/s]
#
#  63%|██████▎   | Fitting SlidingEstimator : 76/121 [00:00<00:00,  169.55it/s]
#
#
#
#  18%|█▊        | Fitting SlidingEstimator : 22/121 [00:00<00:00,  124.19it/s]
#  97%|█████████▋| Fitting SlidingEstimator : 117/121 [00:00<00:00,  198.13it/s]
#
#
#  41%|████▏     | Fitting SlidingEstimator : 50/121 [00:00<00:00,  150.24it/s]
#
#
#
#
#   1%|          | Fitting SlidingEstimator : 1/121 [00:00<00:04,   26.51it/s]
#
#  67%|██████▋   | Fitting SlidingEstimator : 81/121 [00:00<00:00,  166.33it/s]
#
#
#
#
# 100%|██████████| Fitting SlidingEstimator : 121/121 [00:00<00:00,  198.30it/s]
#  23%|██▎       | Fitting SlidingEstimator : 28/121 [00:00<00:00,  133.42it/s]
#
#
#  46%|████▋     | Fitting SlidingEstimator : 56/121 [00:00<00:00,  150.94it/s]
#
#
#
#
#   2%|▏         | Fitting SlidingEstimator : 3/121 [00:00<00:03,   38.76it/s]
#
#  73%|███████▎  | Fitting SlidingEstimator : 88/121 [00:00<00:00,  168.53it/s]
#
#
#
#  26%|██▌       | Fitting SlidingEstimator : 31/121 [00:00<00:00,  123.02it/s]
#
#
#  52%|█████▏    | Fitting SlidingEstimator : 63/121 [00:00<00:00,  155.56it/s]
#
#
#
#
#   7%|▋         | Fitting SlidingEstimator : 9/121 [00:00<00:01,   82.77it/s]
#
#  76%|███████▌  | Fitting SlidingEstimator : 92/121 [00:00<00:00,  162.61it/s]
#
#
#
#  31%|███▏      | Fitting SlidingEstimator : 38/121 [00:00<00:00,  134.15it/s]
#
#
#  57%|█████▋    | Fitting SlidingEstimator : 69/121 [00:00<00:00,  157.19it/s]
#
#
#
#
#  12%|█▏        | Fitting SlidingEstimator : 14/121 [00:00<00:01,   93.52it/s]
#
#
#
#
#
#   0%|          | Fitting SlidingEstimator : 0/121 [00:00<?,       ?it/s]
#
#
#
#  36%|███▌      | Fitting SlidingEstimator : 43/121 [00:00<00:00,  133.09it/s]
#
#  83%|████████▎ | Fitting SlidingEstimator : 100/121 [00:00<00:00,  162.47it/s]
#
#
#  61%|██████    | Fitting SlidingEstimator : 74/121 [00:00<00:00,  154.07it/s]
#
#
#
#
#  16%|█▌        | Fitting SlidingEstimator : 19/121 [00:00<00:00,  103.63it/s]
#
#
#
#
#
#  40%|████      | Fitting SlidingEstimator : 49/121 [00:00<00:00,  136.03it/s]
#
#
#  65%|██████▌   | Fitting SlidingEstimator : 79/121 [00:00<00:00,  153.26it/s]
#
#
#
#
#  21%|██        | Fitting SlidingEstimator : 25/121 [00:00<00:00,  115.78it/s]
#
#
#
#
#
#   2%|▏         | Fitting SlidingEstimator : 2/121 [00:00<00:04,   27.65it/s]
#
#  91%|█████████ | Fitting SlidingEstimator : 110/121 [00:00<00:00,  159.82it/s]
#
#
#
#  45%|████▍     | Fitting SlidingEstimator : 54/121 [00:00<00:00,  136.79it/s]
#
#
#  68%|██████▊   | Fitting SlidingEstimator : 82/121 [00:00<00:00,  146.76it/s]
#
#
#
#
#  22%|██▏       | Fitting SlidingEstimator : 27/121 [00:00<00:00,  106.43it/s]
#
#
#
#
#
#   4%|▍         | Fitting SlidingEstimator : 5/121 [00:00<00:02,   45.85it/s]
#
#  94%|█████████▍| Fitting SlidingEstimator : 114/121 [00:00<00:00,  156.77it/s]
#
#
#
#
#
#
#  48%|████▊     | Fitting SlidingEstimator : 58/121 [00:00<00:00,  130.84it/s]
#
#
#
#
#  26%|██▌       | Fitting SlidingEstimator : 31/121 [00:00<00:00,  104.86it/s]
#
#
#
#
#
#  11%|█         | Fitting SlidingEstimator : 13/121 [00:00<00:01,   90.80it/s]
#
#  99%|█████████▉| Fitting SlidingEstimator : 120/121 [00:00<00:00,  157.10it/s]
#
#
#
#
#
#
#   0%|          | Fitting SlidingEstimator : 0/121 [00:00<?,       ?it/s]
#
#
#
#
#
#
#
#  75%|███████▌  | Fitting SlidingEstimator : 91/121 [00:00<00:00,  141.36it/s]
#
#
#
#  31%|███       | Fitting SlidingEstimator : 37/121 [00:00<00:00,  113.83it/s]
#
# 100%|██████████| Fitting SlidingEstimator : 121/121 [00:00<00:00,  156.29it/s]
#
#
#
#
#
#
#  16%|█▌        | Fitting SlidingEstimator : 19/121 [00:00<00:01,  100.01it/s]
#
#
#  79%|███████▉  | Fitting SlidingEstimator : 96/121 [00:00<00:00,  140.91it/s]
#
#
#
#
#
#
#
#
#  35%|███▍      | Fitting SlidingEstimator : 42/121 [00:00<00:00,  114.94it/s]
#
#
#
#
#
#  18%|█▊        | Fitting SlidingEstimator : 22/121 [00:00<00:01,   96.33it/s]
#
#
#
#
#
#
#   1%|          | Fitting SlidingEstimator : 1/121 [00:00<00:09,   12.56it/s]
#
#
#
#  60%|██████    | Fitting SlidingEstimator : 73/121 [00:00<00:00,  130.60it/s]
#
#
#  83%|████████▎ | Fitting SlidingEstimator : 100/121 [00:00<00:00,  136.29it/s]
#
#
#
#
#  40%|███▉      | Fitting SlidingEstimator : 48/121 [00:00<00:00,  112.27it/s]
#
#
#
#
#
#  22%|██▏       | Fitting SlidingEstimator : 27/121 [00:00<00:00,   98.51it/s]
#
#
#
#
#
#
#   7%|▋         | Fitting SlidingEstimator : 8/121 [00:00<00:01,   70.93it/s]
#
#
#
#  63%|██████▎   | Fitting SlidingEstimator : 76/121 [00:00<00:00,  126.06it/s]
#
#
#  88%|████████▊ | Fitting SlidingEstimator : 107/121 [00:00<00:00,  140.20it/s]
#
#
#
#
#  43%|████▎     | Fitting SlidingEstimator : 52/121 [00:00<00:00,  112.67it/s]
#
#
#
#
#
#  27%|██▋       | Fitting SlidingEstimator : 33/121 [00:00<00:00,  107.13it/s]
#
#
#
#
#
#
#   9%|▉         | Fitting SlidingEstimator : 11/121 [00:00<00:01,   73.89it/s]
#
#
#
#  65%|██████▌   | Fitting SlidingEstimator : 79/121 [00:00<00:00,  122.70it/s]
#
#
#
#
#
#
#
#   0%|          | Fitting SlidingEstimator : 0/121 [00:00<?,       ?it/s]
#
#
#  93%|█████████▎| Fitting SlidingEstimator : 113/121 [00:00<00:00,  141.45it/s]
#
#
#
#
#
#  31%|███       | Fitting SlidingEstimator : 37/121 [00:00<00:00,  108.20it/s]
#
#
#
#
#  46%|████▋     | Fitting SlidingEstimator : 56/121 [00:00<00:00,  111.53it/s]
#
#
#
#
#
#
#
#
#
#
#  12%|█▏        | Fitting SlidingEstimator : 14/121 [00:00<00:01,   75.35it/s]
#
#
#  98%|█████████▊| Fitting SlidingEstimator : 118/121 [00:00<00:00,  140.00it/s]
#
#
#
#
#
#  33%|███▎      | Fitting SlidingEstimator : 40/121 [00:00<00:00,  105.93it/s]
#
#
#
#
#  51%|█████     | Fitting SlidingEstimator : 62/121 [00:00<00:00,  116.87it/s]
#
#
# 100%|██████████| Fitting SlidingEstimator : 121/121 [00:00<00:00,  142.25it/s]
#
#
#
#
#
#
#
#
#
#
#
#  74%|███████▍  | Fitting SlidingEstimator : 90/121 [00:00<00:00,  127.16it/s]
#
#
#
#
#
#
#
#   2%|▏         | Fitting SlidingEstimator : 2/121 [00:00<00:04,   25.46it/s]
#
#
#
#
#
#
#
#
#
#
#  39%|███▉      | Fitting SlidingEstimator : 47/121 [00:00<00:00,  113.56it/s]
#
#
#
#  79%|███████▊  | Fitting SlidingEstimator : 95/121 [00:00<00:00,  126.47it/s]
#
#
#
#
#
#
#  22%|██▏       | Fitting SlidingEstimator : 27/121 [00:00<00:00,  102.41it/s]
#
#
#
#
#
#
#
#   4%|▍         | Fitting SlidingEstimator : 5/121 [00:00<00:02,   44.10it/s]
#
#
#
#
#  60%|█████▉    | Fitting SlidingEstimator : 72/121 [00:00<00:00,  119.30it/s]
#
#
#
#
#
#  44%|████▍     | Fitting SlidingEstimator : 53/121 [00:00<00:00,  115.60it/s]
#
#
#
#  82%|████████▏ | Fitting SlidingEstimator : 99/121 [00:00<00:00,  125.49it/s]
#
#
#
#
#
#
#
#  10%|▉         | Fitting SlidingEstimator : 12/121 [00:00<00:01,   82.22it/s]
#
#
#
#
#
#
#  26%|██▋       | Fitting SlidingEstimator : 32/121 [00:00<00:00,  104.15it/s]
#
#
#
#
#  63%|██████▎   | Fitting SlidingEstimator : 76/121 [00:00<00:00,  119.19it/s]
#
#
#
#
#
#
#
#
#   0%|          | Fitting SlidingEstimator : 0/121 [00:00<?,       ?it/s]
#
#
#
#
#
#
#
#
#
#  47%|████▋     | Fitting SlidingEstimator : 57/121 [00:00<00:00,  114.28it/s]
#
#
#
#
#
#
#
#  12%|█▏        | Fitting SlidingEstimator : 15/121 [00:00<00:01,   80.60it/s]
#
#
#
#
#
#
#  31%|███       | Fitting SlidingEstimator : 37/121 [00:00<00:00,  106.94it/s]
#
#
#
#
#  64%|██████▍   | Fitting SlidingEstimator : 78/121 [00:00<00:00,  113.35it/s]
#
#
#
#  89%|████████▉ | Fitting SlidingEstimator : 108/121 [00:00<00:00,  124.88it/s]
#
#
#
#
#
#  52%|█████▏    | Fitting SlidingEstimator : 63/121 [00:00<00:00,  117.39it/s]
#
#
#
#
#
#
#
#  17%|█▋        | Fitting SlidingEstimator : 21/121 [00:00<00:01,   95.23it/s]
#
#
#
#
#
#
#  34%|███▍      | Fitting SlidingEstimator : 41/121 [00:00<00:00,  106.67it/s]
#
#
#
#
#  70%|███████   | Fitting SlidingEstimator : 85/121 [00:00<00:00,  118.85it/s]
#
#
#
#
#
#
#
#
#   1%|          | Fitting SlidingEstimator : 1/121 [00:00<00:09,   13.31it/s]
#
#
#
#  94%|█████████▍| Fitting SlidingEstimator : 114/121 [00:00<00:00,  127.46it/s]
#
#
#
#
#
#  55%|█████▍    | Fitting SlidingEstimator : 66/121 [00:00<00:00,  114.51it/s]
#
#
#
#
#
#
#
#  21%|██        | Fitting SlidingEstimator : 25/121 [00:00<00:00,   97.92it/s]
#
#
#
#
#
#
#  38%|███▊      | Fitting SlidingEstimator : 46/121 [00:00<00:00,  106.71it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   6%|▌         | Fitting SlidingEstimator : 7/121 [00:00<00:01,   62.54it/s]
#
#
#
#
#
#
#
#
#
# 100%|██████████| Fitting SlidingEstimator : 121/121 [00:00<00:00,  129.24it/s]
#  60%|█████▉    | Fitting SlidingEstimator : 72/121 [00:00<00:00,  118.70it/s]
#
#
#
#
#
#
#
#  23%|██▎       | Fitting SlidingEstimator : 28/121 [00:00<00:00,   95.41it/s]
#
#
#
#
#  79%|███████▊  | Fitting SlidingEstimator : 95/121 [00:00<00:00,  119.15it/s]
#
#
#
#
#
#
#  43%|████▎     | Fitting SlidingEstimator : 52/121 [00:00<00:00,  109.70it/s]
#
#
#
#
#
#
#
#
#   9%|▉         | Fitting SlidingEstimator : 11/121 [00:00<00:01,   71.35it/s]
#
#
#
#
#
#  63%|██████▎   | Fitting SlidingEstimator : 76/121 [00:00<00:00,  115.41it/s]
#
#
#
#
#
#
#
#  29%|██▉       | Fitting SlidingEstimator : 35/121 [00:00<00:00,  103.09it/s]
#
#
#
#
#
#
#  48%|████▊     | Fitting SlidingEstimator : 58/121 [00:00<00:00,  114.38it/s]
#
#
#
#
#
#
#
#
#  12%|█▏        | Fitting SlidingEstimator : 15/121 [00:00<00:01,   80.42it/s]
#
#
#
#
#  83%|████████▎ | Fitting SlidingEstimator : 100/121 [00:00<00:00,  119.16it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  68%|██████▊   | Fitting SlidingEstimator : 82/121 [00:00<00:00,  117.11it/s]
#
#
#
#
#
#
#  52%|█████▏    | Fitting SlidingEstimator : 63/121 [00:00<00:00,  116.53it/s]
#
#
#
#
#
#
#
#
#  17%|█▋        | Fitting SlidingEstimator : 20/121 [00:00<00:01,   91.12it/s]
#
#
#
#
#  85%|████████▌ | Fitting SlidingEstimator : 103/121 [00:00<00:00,  115.89it/s]
#
#
#
#
#
#
#
#  36%|███▋      | Fitting SlidingEstimator : 44/121 [00:00<00:00,  107.49it/s]
#
#
#
#
#
#  72%|███████▏  | Fitting SlidingEstimator : 87/121 [00:00<00:00,  117.84it/s]
#
#
#
#
#
#
#  55%|█████▍    | Fitting SlidingEstimator : 66/121 [00:00<00:00,  114.32it/s]
#
#
#
#
#
#
#
#
#  21%|██▏       | Fitting SlidingEstimator : 26/121 [00:00<00:00,  102.73it/s]
#
#
#
#
#  88%|████████▊ | Fitting SlidingEstimator : 106/121 [00:00<00:00,  113.64it/s]
#
#
#
#
#
#
#
#  40%|████      | Fitting SlidingEstimator : 49/121 [00:00<00:00,  110.84it/s]
#
#
#
#
#
#  74%|███████▍  | Fitting SlidingEstimator : 90/121 [00:00<00:00,  114.51it/s]
#
#
#
#
#
#
#
#
#  22%|██▏       | Fitting SlidingEstimator : 27/121 [00:00<00:01,   92.28it/s]
#
#
#
#
#
#
#  61%|██████    | Fitting SlidingEstimator : 74/121 [00:00<00:00,  119.51it/s]
#
#
#
#
#  94%|█████████▍| Fitting SlidingEstimator : 114/121 [00:00<00:00,  119.73it/s][Parallel(n_jobs=10)]: Done   3 out of  10 | elapsed:    1.8s remaining:    4.3s
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  81%|████████  | Fitting SlidingEstimator : 98/121 [00:00<00:00,  121.81it/s]
#
#
#
#
#  98%|█████████▊| Fitting SlidingEstimator : 118/121 [00:01<00:00,  119.64it/s]
#
#
#
#
#
#
#  62%|██████▏   | Fitting SlidingEstimator : 75/121 [00:00<00:00,  112.65it/s]
#
#
#
#
#
#
#
#
# 100%|██████████| Fitting SlidingEstimator : 121/121 [00:01<00:00,  119.00it/s][A
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  49%|████▉     | Fitting SlidingEstimator : 59/121 [00:00<00:00,  113.67it/s]
#
#
#
#
#
#
#
#
#  32%|███▏      | Fitting SlidingEstimator : 39/121 [00:00<00:00,  102.85it/s]
#
#
#
#
#
#
#  69%|██████▊   | Fitting SlidingEstimator : 83/121 [00:00<00:00,  117.18it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  86%|████████▌ | Fitting SlidingEstimator : 104/121 [00:00<00:00,  117.06it/s][A
#
#
#
#
#
#
#
#
#  36%|███▋      | Fitting SlidingEstimator : 44/121 [00:00<00:00,  107.06it/s]
#
#
#
#
#
#
#  75%|███████▌  | Fitting SlidingEstimator : 91/121 [00:00<00:00,  124.93it/s]
#
#
#
#
#
#
#
#  56%|█████▌    | Fitting SlidingEstimator : 68/121 [00:00<00:00,  115.58it/s]
#
#
#
#
#
#  93%|█████████▎| Fitting SlidingEstimator : 112/121 [00:00<00:00,  122.06it/s]
#
#
#
#
#
#
#
#
#  41%|████▏     | Fitting SlidingEstimator : 50/121 [00:00<00:00,  112.62it/s]
#
#
#
#
#
#
#
#  60%|██████    | Fitting SlidingEstimator : 73/121 [00:00<00:00,  118.05it/s]
#
#
#
#
#
#
#  78%|███████▊  | Fitting SlidingEstimator : 94/121 [00:00<00:00,  120.74it/s]
#
#
#
#
#
# 100%|██████████| Fitting SlidingEstimator : 121/121 [00:01<00:00,  120.62it/s]
#
#
#
#
#
#
#
#
#
#  46%|████▋     | Fitting SlidingEstimator : 56/121 [00:00<00:00,  117.35it/s]
#
#
#
#
#
#
#
#  64%|██████▎   | Fitting SlidingEstimator : 77/121 [00:00<00:00,  117.84it/s]
#
#
#
#
#
#
#  83%|████████▎ | Fitting SlidingEstimator : 101/121 [00:00<00:00,  126.05it/s]
#
#
#
#
#
#
#
#
#  51%|█████     | Fitting SlidingEstimator : 62/121 [00:00<00:00,  121.35it/s]
#
#
#
#
#
#
#
#  71%|███████   | Fitting SlidingEstimator : 86/121 [00:00<00:00,  126.77it/s]
#
#
#
#
#
#
#  90%|█████████ | Fitting SlidingEstimator : 109/121 [00:00<00:00,  131.66it/s]
#
#
#
#
#
#
#
#
#  57%|█████▋    | Fitting SlidingEstimator : 69/121 [00:00<00:00,  127.89it/s]
#
#
#
#
#
#
#  95%|█████████▌| Fitting SlidingEstimator : 115/121 [00:00<00:00,  134.44it/s]
#
#
#
#
#
#
#
#  76%|███████▌  | Fitting SlidingEstimator : 92/121 [00:00<00:00,  128.47it/s]
#
#
#
#
#
#
#
#
#  62%|██████▏   | Fitting SlidingEstimator : 75/121 [00:00<00:00,  130.84it/s]
#
#
#
#
#
#
# 100%|██████████| Fitting SlidingEstimator : 121/121 [00:00<00:00,  127.20it/s]
#
#
#
#
#
#
#
# 100%|██████████| Fitting SlidingEstimator : 121/121 [00:00<00:00,  127.14it/s]
#
#
#
#
#
#
#
#  82%|████████▏ | Fitting SlidingEstimator : 99/121 [00:00<00:00,  133.41it/s]
#
#
#
#
#
#
#
#
#  69%|██████▉   | Fitting SlidingEstimator : 84/121 [00:00<00:00,  140.82it/s]
#
#
#
#
#
#
#
#  90%|█████████ | Fitting SlidingEstimator : 109/121 [00:00<00:00,  143.07it/s]
#
#
#
#
#
#
#
#
#  77%|███████▋  | Fitting SlidingEstimator : 93/121 [00:00<00:00,  147.71it/s]
#
#
#
#
#
#
#
#  97%|█████████▋| Fitting SlidingEstimator : 117/121 [00:00<00:00,  148.52it/s]
#
#
#
#
#
#
#
# 100%|██████████| Fitting SlidingEstimator : 121/121 [00:00<00:00,  135.85it/s]
#
#
#
#
#
#
#
#
#
#  84%|████████▍ | Fitting SlidingEstimator : 102/121 [00:00<00:00,  153.76it/s]
#
#
#
#
#
#
#
#
#  92%|█████████▏| Fitting SlidingEstimator : 111/121 [00:00<00:00,  161.05it/s]
#
#
#
#
#
#
#
#
# 100%|██████████| Fitting SlidingEstimator : 121/121 [00:00<00:00,  153.67it/s]
# [Parallel(n_jobs=10)]: Done   6 out of  10 | elapsed:    2.4s remaining:    1.6s
# [Parallel(n_jobs=10)]: Done  10 out of  10 | elapsed:    2.6s finished
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# Best time point post-250ms: 0.655 seconds with score: 0.7193300350443208
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# ...
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]

# %%
plt.plot(post_erp[post_erp.attention == 'exo'].time, post_erp[post_erp.attention == 'exo'].score)
plt.plot(post_erp[post_erp.attention == 'endo'].time, post_erp[post_erp.attention == 'endo'].score)

# %%
post_erp.to_csv('files/B3_post_erp.csv')

# %% [markdown]
# ## Training on the end of the trial (control)

# %%
# Data preparation for training and prediction periods
tmin_training, tmax_training = 1.4, 2
# Take some time after training for plotting purposes 
tmin_prediction, tmax_prediction = -.2, .8
trial_end = pre_post_training(epochs, tmin_training, tmax_training, tmin_prediction, tmax_prediction)
# Out:
# /tmp/ipykernel_14765/132503421.py:7: RuntimeWarning: tmax is not in time interval. tmax is set to <class 'mne.epochs.EpochsFIF'>.tmax (1.995 s)
#   epochs_posttraining = epochs.copy().crop(tmin=tmin_training, tmax=tmax_training)
# /tmp/ipykernel_14765/132503421.py:11: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X = epochs_posttraining.copy().get_data()
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
#   9%|▉         | Fitting SlidingEstimator : 11/120 [00:00<00:00,  161.48it/s]
#  18%|█▊        | Fitting SlidingEstimator : 21/120 [00:00<00:00,  202.70it/s]
#  25%|██▌       | Fitting SlidingEstimator : 30/120 [00:00<00:00,  219.25it/s][A
#  33%|███▎      | Fitting SlidingEstimator : 40/120 [00:00<00:00,  231.36it/s]
#
#   0%|          | Fitting SlidingEstimator : 0/120 [00:00<?,       ?it/s]
#  41%|████      | Fitting SlidingEstimator : 49/120 [00:00<00:00,  235.26it/s]
#  48%|████▊     | Fitting SlidingEstimator : 58/120 [00:00<00:00,  236.46it/s]
#
#   8%|▊         | Fitting SlidingEstimator : 10/120 [00:00<00:00,  142.86it/s]
#  34%|███▍      | Fitting SlidingEstimator : 41/120 [00:00<00:00,  229.96it/s]
#
#
#   0%|          | Fitting SlidingEstimator : 0/120 [00:00<?,       ?it/s]
#
#  54%|█████▍    | Fitting SlidingEstimator : 65/120 [00:00<00:00,  228.36it/s]
#  60%|██████    | Fitting SlidingEstimator : 72/120 [00:00<00:00,  225.42it/s]
#
#  18%|█▊        | Fitting SlidingEstimator : 21/120 [00:00<00:00,  147.89it/s]
#  64%|██████▍   | Fitting SlidingEstimator : 77/120 [00:00<00:00,  215.68it/s]
#
#  25%|██▌       | Fitting SlidingEstimator : 30/120 [00:00<00:00,  172.59it/s]
#
#
#   6%|▌         | Fitting SlidingEstimator : 7/120 [00:00<00:01,   93.80it/s]
#  71%|███████   | Fitting SlidingEstimator : 85/120 [00:00<00:00,  217.40it/s]
#
#
#
#
#  10%|█         | Fitting SlidingEstimator : 12/120 [00:00<00:01,  106.98it/s]
#
#
#
#   0%|          | Fitting SlidingEstimator : 0/120 [00:00<?,       ?it/s]
#  75%|███████▌  | Fitting SlidingEstimator : 90/120 [00:00<00:00,  208.48it/s]
#
#
#  16%|█▌        | Fitting SlidingEstimator : 19/120 [00:00<00:00,  129.75it/s]
#
#  34%|███▍      | Fitting SlidingEstimator : 41/120 [00:00<00:00,  161.14it/s]
#  80%|████████  | Fitting SlidingEstimator : 96/120 [00:00<00:00,  200.58it/s]
#
#  40%|████      | Fitting SlidingEstimator : 48/120 [00:00<00:00,  165.67it/s]
#
#
#  20%|██        | Fitting SlidingEstimator : 24/120 [00:00<00:00,  129.93it/s]
#
#
#
#   3%|▎         | Fitting SlidingEstimator : 4/120 [00:00<00:02,   53.22it/s]
#  85%|████████▌ | Fitting SlidingEstimator : 102/120 [00:00<00:00,  195.30it/s][A
#
#
#  25%|██▌       | Fitting SlidingEstimator : 30/120 [00:00<00:00,  136.25it/s]
#
#  43%|████▎     | Fitting SlidingEstimator : 52/120 [00:00<00:00,  156.87it/s]
#
#
#
#   8%|▊         | Fitting SlidingEstimator : 10/120 [00:00<00:01,   88.44it/s]
#  70%|███████   | Fitting SlidingEstimator : 84/120 [00:00<00:00,  186.51it/s]
#
#
#
#
#  89%|████████▉ | Fitting SlidingEstimator : 107/120 [00:00<00:00,  191.17it/s]
#
#  48%|████▊     | Fitting SlidingEstimator : 58/120 [00:00<00:00,  158.31it/s]
#
#
#  29%|██▉       | Fitting SlidingEstimator : 35/120 [00:00<00:00,  134.98it/s]
#
#
#
#  11%|█         | Fitting SlidingEstimator : 13/120 [00:00<00:01,   85.77it/s]
#  92%|█████████▎| Fitting SlidingEstimator : 111/120 [00:00<00:00,  184.96it/s]
#
#  52%|█████▎    | Fitting SlidingEstimator : 63/120 [00:00<00:00,  155.92it/s]
#
#
#  33%|███▎      | Fitting SlidingEstimator : 40/120 [00:00<00:00,  135.61it/s]
#  98%|█████████▊| Fitting SlidingEstimator : 118/120 [00:00<00:00,  186.47it/s][A
#
#
#
#  18%|█▊        | Fitting SlidingEstimator : 22/120 [00:00<00:00,  104.65it/s]
#
#
#  37%|███▋      | Fitting SlidingEstimator : 44/120 [00:00<00:00,  132.19it/s]
#
#
#
#
# 100%|██████████| Fitting SlidingEstimator : 120/120 [00:00<00:00,  191.66it/s]A
#
#
#  58%|█████▊    | Fitting SlidingEstimator : 70/120 [00:00<00:00,  154.19it/s]
#  81%|████████  | Fitting SlidingEstimator : 97/120 [00:00<00:00,  164.92it/s]
#
#
#
#
#
#
#
#
#  22%|██▏       | Fitting SlidingEstimator : 26/120 [00:00<00:00,  103.71it/s]
#
#
#   5%|▌         | Fitting SlidingEstimator : 6/120 [00:00<00:02,   52.52it/s]
#
#  62%|██████▏   | Fitting SlidingEstimator : 74/120 [00:00<00:00,  147.82it/s]
#
#
#
#
#
#
#  85%|████████▌ | Fitting SlidingEstimator : 102/120 [00:00<00:00,  159.22it/s]
#
#
#
#  24%|██▍       | Fitting SlidingEstimator : 29/120 [00:00<00:00,  101.30it/s]
#
#
#  45%|████▌     | Fitting SlidingEstimator : 54/120 [00:00<00:00,  131.89it/s]
#
#
#
#
#  12%|█▏        | Fitting SlidingEstimator : 14/120 [00:00<00:01,   86.31it/s]
#
#  66%|██████▌   | Fitting SlidingEstimator : 79/120 [00:00<00:00,  145.79it/s]
#  89%|████████▉ | Fitting SlidingEstimator : 107/120 [00:00<00:00,  158.11it/s]
#
#
#
#  28%|██▊       | Fitting SlidingEstimator : 34/120 [00:00<00:00,  107.06it/s]
#
#
#  48%|████▊     | Fitting SlidingEstimator : 58/120 [00:00<00:00,  127.74it/s]
#
#
#
#
#  12%|█▎        | Fitting SlidingEstimator : 15/120 [00:00<00:01,   75.28it/s]
#
#
#
#
#
#
#
#   1%|          | Fitting SlidingEstimator : 1/120 [00:00<00:08,   14.28it/s]
#
#
#
#  72%|███████▏  | Fitting SlidingEstimator : 86/120 [00:00<00:00,  147.48it/s]
#  96%|█████████▌| Fitting SlidingEstimator : 115/120 [00:00<00:00,  159.88it/s]
#
#
#  52%|█████▎    | Fitting SlidingEstimator : 63/120 [00:00<00:00,  128.52it/s]
#
#
#
#
#  16%|█▌        | Fitting SlidingEstimator : 19/120 [00:00<00:01,   81.28it/s]
#
#
#
#
#
#
#
#
#
#   3%|▎         | Fitting SlidingEstimator : 4/120 [00:00<00:02,   38.85it/s]
# 100%|██████████| Fitting SlidingEstimator : 120/120 [00:00<00:00,  158.87it/s]
#
# 100%|██████████| Fitting SlidingEstimator : 120/120 [00:00<00:00,  167.06it/s][A
#
#
#
#  54%|█████▍    | Fitting SlidingEstimator : 65/120 [00:00<00:00,  122.21it/s]
#
#
#
#
#  20%|██        | Fitting SlidingEstimator : 24/120 [00:00<00:01,   88.55it/s]
#
#
#
#  38%|███▊      | Fitting SlidingEstimator : 46/120 [00:00<00:00,  109.35it/s]
#
#
#
#
#
#  10%|█         | Fitting SlidingEstimator : 12/120 [00:00<00:01,   85.02it/s]
#
#  76%|███████▌  | Fitting SlidingEstimator : 91/120 [00:00<00:00,  133.61it/s]
#
#
#  58%|█████▊    | Fitting SlidingEstimator : 70/120 [00:00<00:00,  124.34it/s]
#
#
#
#
#
#
#   0%|          | Fitting SlidingEstimator : 0/120 [00:00<?,       ?it/s]
#
#
#
#
#
#
#
#
#
#
#  12%|█▎        | Fitting SlidingEstimator : 15/120 [00:00<00:01,   85.63it/s]
#
#  23%|██▎       | Fitting SlidingEstimator : 28/120 [00:00<00:01,   89.40it/s]
#
#
#
#  42%|████▎     | Fitting SlidingEstimator : 51/120 [00:00<00:00,  109.85it/s]
#
#
#  80%|████████  | Fitting SlidingEstimator : 96/120 [00:00<00:00,  134.62it/s]
#
#
#
#
#
#  15%|█▌        | Fitting SlidingEstimator : 18/120 [00:00<00:01,   82.29it/s]
#
#
#
#  45%|████▌     | Fitting SlidingEstimator : 54/120 [00:00<00:00,  107.92it/s]
#
#
#
#
#  28%|██▊       | Fitting SlidingEstimator : 33/120 [00:00<00:00,   90.30it/s]
#
#
#  66%|██████▌   | Fitting SlidingEstimator : 79/120 [00:00<00:00,  123.60it/s]
#
#  87%|████████▋ | Fitting SlidingEstimator : 104/120 [00:00<00:00,  134.54it/s]
#
#
#
#
#
#
#   1%|          | Fitting SlidingEstimator : 1/120 [00:00<00:09,   11.95it/s]
#
#
#
#
#
#  18%|█▊        | Fitting SlidingEstimator : 22/120 [00:00<00:01,   86.15it/s]
#
#
#
#  48%|████▊     | Fitting SlidingEstimator : 57/120 [00:00<00:00,  104.18it/s]
#
#
#
#
#  32%|███▏      | Fitting SlidingEstimator : 38/120 [00:00<00:00,   95.66it/s]
#
#
#  71%|███████   | Fitting SlidingEstimator : 85/120 [00:00<00:00,  126.55it/s]
#
#  88%|████████▊ | Fitting SlidingEstimator : 105/120 [00:00<00:00,  126.59it/s]
#
#
#
#
#
#
#   5%|▌         | Fitting SlidingEstimator : 6/120 [00:00<00:02,   46.25it/s]
#
#
#
#
#
#  21%|██        | Fitting SlidingEstimator : 25/120 [00:00<00:01,   85.65it/s]
#
#
#
#
#  32%|███▎      | Fitting SlidingEstimator : 39/120 [00:00<00:00,   89.22it/s]
#
#
#
#  51%|█████     | Fitting SlidingEstimator : 61/120 [00:00<00:00,  105.03it/s]
#
#
#  72%|███████▎  | Fitting SlidingEstimator : 87/120 [00:00<00:00,  120.92it/s]
#
#
#
#
#
#
#
#   0%|          | Fitting SlidingEstimator : 0/120 [00:00<?,       ?it/s]
#
#  90%|█████████ | Fitting SlidingEstimator : 108/120 [00:00<00:00,  123.62it/s]
#
#
#
#
#
#
#
#
#  35%|███▌      | Fitting SlidingEstimator : 42/120 [00:00<00:00,   88.57it/s]
#
#
#  76%|███████▌  | Fitting SlidingEstimator : 91/120 [00:00<00:00,  119.08it/s]
#
#  52%|█████▎    | Fitting SlidingEstimator : 63/120 [00:00<00:00,  101.05it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   8%|▊         | Fitting SlidingEstimator : 9/120 [00:00<00:02,   42.75it/s]
#
#
#  79%|███████▉  | Fitting SlidingEstimator : 95/120 [00:00<00:00,  118.40it/s]
#
# 100%|██████████| Fitting SlidingEstimator : 120/120 [00:00<00:00,  129.98it/s]
#
#
#
# 100%|██████████| Fitting SlidingEstimator : 120/120 [00:00<00:00,  133.58it/s]
#  57%|█████▊    | Fitting SlidingEstimator : 69/120 [00:00<00:00,  101.34it/s]
#
#
#
#
#
#  28%|██▊       | Fitting SlidingEstimator : 33/120 [00:00<00:01,   81.35it/s]
#
#
#
#
#
#
#  17%|█▋        | Fitting SlidingEstimator : 20/120 [00:00<00:01,   79.86it/s]
#
#
#  84%|████████▍ | Fitting SlidingEstimator : 101/120 [00:00<00:00,  119.59it/s]
#
#
#
#
#  43%|████▎     | Fitting SlidingEstimator : 52/120 [00:00<00:00,   91.89it/s]
#
#
#
#  62%|██████▎   | Fitting SlidingEstimator : 75/120 [00:00<00:00,  103.14it/s]
#
#
#
#
#
#  31%|███       | Fitting SlidingEstimator : 37/120 [00:00<00:00,   84.64it/s]
#
#
#
#
#
#
#
#
#   0%|          | Fitting SlidingEstimator : 0/120 [00:00<?,       ?it/s]
#
#
#
#
#
#
#  20%|██        | Fitting SlidingEstimator : 24/120 [00:00<00:01,   83.26it/s]
#
#
#
#
#
#
#
#   1%|          | Fitting SlidingEstimator : 1/120 [00:00<00:17,    6.78it/s]
#
#
#  87%|████████▋ | Fitting SlidingEstimator : 104/120 [00:00<00:00,  117.17it/s]
#
#
#
#  65%|██████▌   | Fitting SlidingEstimator : 78/120 [00:00<00:00,  101.26it/s]
#
#
#
#
#
#
#
#
#
#
#  49%|████▉     | Fitting SlidingEstimator : 59/120 [00:00<00:00,   96.88it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   3%|▎         | Fitting SlidingEstimator : 4/120 [00:00<00:05,   22.70it/s]
#
#
#  90%|█████████ | Fitting SlidingEstimator : 108/120 [00:00<00:00,  116.68it/s]
#
#
#
#
#
#
#
#
#   1%|          | Fitting SlidingEstimator : 1/120 [00:00<00:08,   14.33it/s]
#
#
#
#  68%|██████▊   | Fitting SlidingEstimator : 81/120 [00:00<00:00,   98.99it/s]
#
#
#
#
#
#  36%|███▌      | Fitting SlidingEstimator : 43/120 [00:00<00:00,   82.94it/s]
#
#
#
#
#
#
#  25%|██▌       | Fitting SlidingEstimator : 30/120 [00:00<00:01,   83.73it/s]
#
#
#
#
#
#
#
#   8%|▊         | Fitting SlidingEstimator : 9/120 [00:00<00:02,   43.95it/s]
#
#
#  92%|█████████▎| Fitting SlidingEstimator : 111/120 [00:00<00:00,  114.87it/s]
#
#
#
#
#  52%|█████▎    | Fitting SlidingEstimator : 63/120 [00:00<00:00,   90.78it/s]
#
#
#
#
#
#
#
#
#   3%|▎         | Fitting SlidingEstimator : 4/120 [00:00<00:03,   38.63it/s]
#
#
#
#
#
#  38%|███▊      | Fitting SlidingEstimator : 46/120 [00:00<00:00,   82.96it/s]
#
#
#
#  72%|███████▎  | Fitting SlidingEstimator : 87/120 [00:00<00:00,  102.43it/s]
#
#
#  96%|█████████▌| Fitting SlidingEstimator : 115/120 [00:00<00:00,  114.64it/s]
#
#
#
#
#
#
#  29%|██▉       | Fitting SlidingEstimator : 35/120 [00:00<00:00,   87.76it/s]
#
#
#
#
#
#
#
#  11%|█         | Fitting SlidingEstimator : 13/120 [00:00<00:02,   52.44it/s]
#
#
#
#
#
#  42%|████▏     | Fitting SlidingEstimator : 50/120 [00:00<00:00,   85.76it/s]
#
#
#
#
#
#
#
#
#   5%|▌         | Fitting SlidingEstimator : 6/120 [00:00<00:02,   42.58it/s]
#
#
#
#
#  56%|█████▌    | Fitting SlidingEstimator : 67/120 [00:00<00:00,   90.87it/s]
#
#
#  99%|█████████▉| Fitting SlidingEstimator : 119/120 [00:01<00:00,  114.61it/s]
#
#
#
#  73%|███████▎  | Fitting SlidingEstimator : 88/120 [00:00<00:00,   95.70it/s]
#
#
#
#
#
#
#  32%|███▎      | Fitting SlidingEstimator : 39/120 [00:00<00:00,   88.72it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| Fitting SlidingEstimator : 120/120 [00:01<00:00,  116.40it/s][A
#
#
#
#
#
#
#
#
#  47%|████▋     | Fitting SlidingEstimator : 56/120 [00:00<00:00,   92.26it/s]
#
#
#
#
#  14%|█▍        | Fitting SlidingEstimator : 17/120 [00:00<00:01,   56.06it/s]
#
#
#
#  78%|███████▊  | Fitting SlidingEstimator : 94/120 [00:00<00:00,  100.35it/s]
#
#
#
#
#
#  49%|████▉     | Fitting SlidingEstimator : 59/120 [00:00<00:00,   91.29it/s]
#
#
#
#
#
#
#
#
#  12%|█▎        | Fitting SlidingEstimator : 15/120 [00:00<00:01,   72.53it/s]
#
#
#
#
#
#
#  38%|███▊      | Fitting SlidingEstimator : 46/120 [00:00<00:00,   93.31it/s]
#
#
#
#
#
#
#
#  18%|█▊        | Fitting SlidingEstimator : 22/120 [00:00<00:01,   63.73it/s]
#
#
#
#  84%|████████▍ | Fitting SlidingEstimator : 101/120 [00:00<00:00,  103.68it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  65%|██████▌   | Fitting SlidingEstimator : 78/120 [00:00<00:00,   93.15it/s]
#
#
#
#
#
#  54%|█████▍    | Fitting SlidingEstimator : 65/120 [00:00<00:00,   95.35it/s]
#
#
#
#
#
#
#
#  22%|██▏       | Fitting SlidingEstimator : 26/120 [00:00<00:01,   68.71it/s]
#
#
#
#  88%|████████▊ | Fitting SlidingEstimator : 106/120 [00:01<00:00,  106.19it/s]
#
#
#
#
#
#
#  43%|████▎     | Fitting SlidingEstimator : 52/120 [00:00<00:00,   92.22it/s]
#
#
#
#
#
#  56%|█████▌    | Fitting SlidingEstimator : 67/120 [00:00<00:00,   92.66it/s]
#
#
#
#
#
#
#
#
#  18%|█▊        | Fitting SlidingEstimator : 22/120 [00:00<00:01,   77.66it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#  68%|██████▊   | Fitting SlidingEstimator : 82/120 [00:00<00:00,   91.83it/s]
#
#
#
#  90%|█████████ | Fitting SlidingEstimator : 108/120 [00:01<00:00,  103.52it/s]
#
#
#
#
#
#
#
#
#  20%|██        | Fitting SlidingEstimator : 24/120 [00:00<00:01,   75.07it/s]
#
#
#
#
#
#
#  46%|████▌     | Fitting SlidingEstimator : 55/120 [00:00<00:00,   89.76it/s]
#
#
#
#
#
#  60%|██████    | Fitting SlidingEstimator : 72/120 [00:00<00:00,   94.23it/s]
#
#
#
#
#  72%|███████▏  | Fitting SlidingEstimator : 86/120 [00:00<00:00,   92.64it/s]
#
#
#
#
#
#
#
#  28%|██▊       | Fitting SlidingEstimator : 34/120 [00:00<00:01,   74.70it/s]
#
#
#
#  95%|█████████▌| Fitting SlidingEstimator : 114/120 [00:01<00:00,  107.35it/s]
#
#
#
#
#
#
#  51%|█████     | Fitting SlidingEstimator : 61/120 [00:00<00:00,   95.26it/s]
#
#
#
#
#
#
#
#
#  26%|██▌       | Fitting SlidingEstimator : 31/120 [00:00<00:01,   87.06it/s]
#
#
#
#
#
#  64%|██████▍   | Fitting SlidingEstimator : 77/120 [00:00<00:00,   97.14it/s]
#
#
#
#
#  77%|███████▋  | Fitting SlidingEstimator : 92/120 [00:00<00:00,   96.67it/s]
#
#
#
#
#
#
#
#
#
#
#
#  32%|███▏      | Fitting SlidingEstimator : 38/120 [00:00<00:01,   78.02it/s]
#
#
#
# 100%|██████████| Fitting SlidingEstimator : 120/120 [00:01<00:00,  105.25it/s]
#
#
#
#
#
#
#
#  53%|█████▎    | Fitting SlidingEstimator : 64/120 [00:00<00:00,   94.53it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  68%|██████▊   | Fitting SlidingEstimator : 82/120 [00:00<00:00,  100.00it/s]
#
#
#
#
#  28%|██▊       | Fitting SlidingEstimator : 34/120 [00:00<00:00,   86.08it/s]
#
#
#
#
#
#
#
#  38%|███▊      | Fitting SlidingEstimator : 45/120 [00:00<00:00,   85.23it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#  72%|███████▏  | Fitting SlidingEstimator : 86/120 [00:00<00:00,  101.06it/s]
#
#
#
#
#  85%|████████▌ | Fitting SlidingEstimator : 102/120 [00:01<00:00,  100.71it/s]
#
#
#
#
#
#
#
#
#  33%|███▎      | Fitting SlidingEstimator : 40/120 [00:00<00:00,   89.81it/s]
#
#
#
#
#
#
#
#  39%|███▉      | Fitting SlidingEstimator : 47/120 [00:00<00:00,   81.54it/s]
#
#
#
#
#
#
#  63%|██████▎   | Fitting SlidingEstimator : 76/120 [00:00<00:00,  102.80it/s]
#
#
#
#
#
#  75%|███████▌  | Fitting SlidingEstimator : 90/120 [00:00<00:00,  100.40it/s]
#
#
#
#
#  91%|█████████ | Fitting SlidingEstimator : 109/120 [00:01<00:00,  105.75it/s]
#
#
#
#
#
#
#
#
#  38%|███▊      | Fitting SlidingEstimator : 45/120 [00:00<00:00,   94.34it/s]
#
#
#
#
#
#
#
#  45%|████▌     | Fitting SlidingEstimator : 54/120 [00:00<00:00,   90.73it/s]
#
#
#
#
#
#
#  65%|██████▌   | Fitting SlidingEstimator : 78/120 [00:00<00:00,   99.96it/s]
#
#
#
#
#
#  78%|███████▊  | Fitting SlidingEstimator : 94/120 [00:00<00:00,  100.73it/s]
#
#
#
#
#  93%|█████████▎| Fitting SlidingEstimator : 112/120 [00:01<00:00,  103.98it/s]
#
#
#
#
#
#
#
#
#  44%|████▍     | Fitting SlidingEstimator : 53/120 [00:00<00:00,  104.98it/s][Parallel(n_jobs=10)]: Done   3 out of  10 | elapsed:    1.8s remaining:    4.2s
#
#
#
#
#
#
#
#
#  48%|████▊     | Fitting SlidingEstimator : 58/120 [00:00<00:00,   91.37it/s]
#
#
#
#
#
#
#  69%|██████▉   | Fitting SlidingEstimator : 83/120 [00:00<00:00,  103.01it/s]
#
#
#
#
#
#  84%|████████▍ | Fitting SlidingEstimator : 101/120 [00:01<00:00,  106.76it/s]
#
#
#
#
# 100%|██████████| Fitting SlidingEstimator : 120/120 [00:01<00:00,  102.59it/s]
#
#
#
#
#
#
#
#
#
#  48%|████▊     | Fitting SlidingEstimator : 58/120 [00:00<00:00,  107.03it/s]
#
#
#
#
#
#
#
#  52%|█████▎    | Fitting SlidingEstimator : 63/120 [00:00<00:00,   95.08it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#  74%|███████▍  | Fitting SlidingEstimator : 89/120 [00:00<00:00,  106.12it/s]
#
#
#
#
#
#
#
#
#  52%|█████▏    | Fitting SlidingEstimator : 62/120 [00:00<00:00,  107.90it/s]
#
#
#
#
#
#
#
#  57%|█████▋    | Fitting SlidingEstimator : 68/120 [00:00<00:00,   98.26it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#  78%|███████▊  | Fitting SlidingEstimator : 93/120 [00:00<00:00,  106.00it/s]
#
#
#
#
#
#
#
#
#  55%|█████▌    | Fitting SlidingEstimator : 66/120 [00:00<00:00,  108.47it/s]
#
#
#
#
#
#
#
#  63%|██████▎   | Fitting SlidingEstimator : 76/120 [00:00<00:00,  105.25it/s]
#
#
#
#
#
#  97%|█████████▋| Fitting SlidingEstimator : 116/120 [00:01<00:00,  111.97it/s]
#
#
#
#
#
#
#  84%|████████▍ | Fitting SlidingEstimator : 101/120 [00:00<00:00,  113.01it/s]
#
#
#
#
#
#
#
#
#  60%|██████    | Fitting SlidingEstimator : 72/120 [00:00<00:00,  113.33it/s]
#
#
#
#
#
# 100%|██████████| Fitting SlidingEstimator : 120/120 [00:01<00:00,  105.05it/s]
#
#
#
#
#
#
#
#
#  67%|██████▋   | Fitting SlidingEstimator : 80/120 [00:00<00:00,  104.18it/s]
#
#
#
#
#
#
#  89%|████████▉ | Fitting SlidingEstimator : 107/120 [00:01<00:00,  116.50it/s]
#
#
#
#
#
#
#
#
#  66%|██████▌   | Fitting SlidingEstimator : 79/120 [00:00<00:00,  118.07it/s]
#
#
#
#
#
#
#
#  73%|███████▎  | Fitting SlidingEstimator : 88/120 [00:00<00:00,  111.99it/s]
#
#
#
#
#
#
#  97%|█████████▋| Fitting SlidingEstimator : 116/120 [00:01<00:00,  123.86it/s]
#
#
#
#
#
#
#
#
#  72%|███████▎  | Fitting SlidingEstimator : 87/120 [00:00<00:00,  125.02it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| Fitting SlidingEstimator : 120/120 [00:01<00:00,  111.99it/s]
#  80%|████████  | Fitting SlidingEstimator : 96/120 [00:00<00:00,  119.46it/s]
#
#
#
#
#
#
#
#
#  82%|████████▏ | Fitting SlidingEstimator : 98/120 [00:00<00:00,  136.20it/s]
#
#
#
#
#
#
#
#  88%|████████▊ | Fitting SlidingEstimator : 106/120 [00:00<00:00,  128.53it/s]
#
#
#
#
#
#
#
#
#  86%|████████▌ | Fitting SlidingEstimator : 103/120 [00:00<00:00,  136.51it/s]
#
#
#
#
#
#
#
#  94%|█████████▍| Fitting SlidingEstimator : 113/120 [00:00<00:00,  133.05it/s]
#
#
#
#
#
#
#
#
#  93%|█████████▎| Fitting SlidingEstimator : 112/120 [00:00<00:00,  144.70it/s]
#
#
#
#
#
#
#
# 100%|██████████| Fitting SlidingEstimator : 120/120 [00:01<00:00,  116.86it/s]
#
#
#
#
#
#
#
#
#
# 100%|██████████| Fitting SlidingEstimator : 120/120 [00:00<00:00,  132.59it/s]
# [Parallel(n_jobs=10)]: Done   6 out of  10 | elapsed:    2.3s remaining:    1.5s
# [Parallel(n_jobs=10)]: Done  10 out of  10 | elapsed:    2.5s finished
# Best time point post-250ms: 1.88 seconds with score: 0.5876298701298701
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# ...
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_14765/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]

# %%
plt.plot(trial_end[trial_end.attention == 'exo'].time, trial_end[trial_end.attention == 'exo'].score)
plt.plot(trial_end[trial_end.attention == 'endo'].time, trial_end[trial_end.attention == 'endo'].score)

# %%
trial_end.to_csv('files/B3_trial_end.csv')
