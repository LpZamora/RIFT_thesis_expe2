# %%
data_path = '/home/lea/Documents/obsidian_notes/masterADS/ads_thesis_RIFT/my_code_expe2'
data_file = '/data/B3/data.mat'
epoch_file = '/data/B3/preprocessing/B3_EEG_epo.fif'

relevant_electrodes = ['O2','PO4','P4','P6','P2','P1','P3','P5','PO3','O1','Pz','POz','Oz','Iz']

# Dic to index trial_info matrix
info_colnames = {'reaction_times':0,'reaction_err':1, 'answer':2,'base_delay':3,\
                      'target_timings':4, 'flicker_sides':5, 'cued_side':6, 'orients_L':7, 'orients_R':8,\
                      'angle_magnitude':9, 'probe_sides':10, 'targets_binary':12, 'attention_type_block':13,\
                      'trial_num_my_rec':14}
info_colnumtonames = {v: k for k, v in info_colnames.items()}

# %%
import scipy.io as sio
import scipy
import numpy as np
import pandas as pd
import mne
from mne.time_frequency import EpochsTFRArray
import matplotlib.pyplot as plt
import copy
from collections import Counter
from frequency_tagging_funs import snr_spectrum, frequency_rescaling, ssvep_amplitudes

from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedKFold
from mne.decoding import SlidingEstimator, cross_val_multiscore

f = sio.loadmat(f'{data_path}{data_file}')

# Create pd df to pass to mne metadata
pd_info = {}
for i, column in enumerate(f['data'][0][0]):
    if i in info_colnames.values():
        # Remove practice trials
        column = column[4:,:]
        # Collapse to trial indexes
        original_shape = column.shape
        new_shape = (original_shape[0] * original_shape[1],) + original_shape[2:]
        column = np.reshape(column, new_shape)
        pd_info[info_colnumtonames[i]] = column
pd_info = pd.DataFrame(pd_info, columns=info_colnames.keys())
pd_info 

# Load eeg epochs .fif and add metadata
epochs = mne.read_epochs(f'{data_path}{epoch_file}')
epoch_good = [x for x,y in enumerate(epochs.drop_log) if len(y) == 0]
epochs.metadata = pd_info.iloc[epoch_good]
# Out:
# Reading /home/lea/Documents/obsidian_notes/masterADS/ads_thesis_RIFT/my_code_expe2/data/B3/preprocessing/B3_EEG_epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 510 matching events found
# No baseline correction applied
# 0 projection items activated
# Adding metadata with 14 columns

# %%
# Keep only trials where there was no target
epochs = epochs['targets_binary==0']
#Only keep EEG channels
epochs = epochs.pick_types(eeg=True)
# Out:
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).

# %% [markdown]
# # A. Endogeneous condition
# ## 1 FFT & SNR

# %%
# Simplify metadata
epochs.metadata['flicker_sides'] = epochs.metadata['flicker_sides'].replace({0: 6064, 1: 6460})
epochs.metadata['cued_side'] = epochs.metadata['cued_side'].replace({0: 'left', 1: 'right'})

condition_1 = ((epochs.metadata['flicker_sides'] == 6064.0) & (epochs.metadata['cued_side'] == 'left')) | \
    ((epochs.metadata['flicker_sides'] == 6460.0) & (epochs.metadata['cued_side'] == 'right'))
condition_2 = ((epochs.metadata['flicker_sides'] == 6064.0) & (epochs.metadata['cued_side'] == 'right')) | \
    ((epochs.metadata['flicker_sides'] == 6460.0) & (epochs.metadata['cued_side'] == 'left'))
epochs.metadata['cued_tag'] = np.where(condition_1, 60, np.where(condition_2, 64, np.nan))
epochs_endo = epochs['attention_type_block==1'].copy()
epochs_exo = epochs['attention_type_block==0'].copy()

# %%
# Fast Fourier Transform
# adapted from https://mne.tools/dev/auto_tutorials/time-freq/50_ssvep.html

sfreq = epochs.info["sfreq"]
tmin = 0 # Search in window starting from cue (when SSVEP is expected)
tmax = 2
fmin = 1.0
fmax = 90

# Spectrum of the signal averaged over trials
freqs_psd, psds_endo = ssvep_amplitudes(epochs_endo, epochs.info['ch_names'], tmin, tmax)
freqs_psd, psds_exo = ssvep_amplitudes(epochs_exo, epochs.info['ch_names'], tmin, tmax)

# Get bins to exlude from regularization (close neighbors ±0.5Hz)  
bin_size = np.diff(freqs_psd)[0]
skip_nei = int((0.5 - bin_size/2)//bin_size) 

# Get bins to include in regularization (neighbors within +/- 2-0.5Hz)
used_nei = int((2 - bin_size/2) // bin_size)  # Total bins within ±2 Hz
used_nei = used_nei - skip_nei # Bins within (0.5 Hz, 2 Hz]

snrs_endo = snr_spectrum(psds_endo, noise_n_neighbor_freqs=used_nei, noise_skip_neighbor_freqs = skip_nei)
snrs_exo = snr_spectrum(psds_exo, noise_n_neighbor_freqs=used_nei, noise_skip_neighbor_freqs = skip_nei)

fig, axes = plt.subplots(2, 2, sharex="all", sharey="none", figsize=(8, 5))
freq_range = range(
    np.where(np.floor(freqs_psd) == 1.0)[0][0], np.where(np.ceil(freqs_psd) == fmax - 1)[0][0]
)

psds_mean = psds_endo.mean(axis=(0))[freq_range]
psds_std = psds_endo.std(axis=(0))[freq_range]
axes[0,0].plot(freqs_psd[freq_range], psds_mean, color="b")
axes[0,0].fill_between(
    freqs_psd[freq_range], psds_mean - psds_std, psds_mean + psds_std, color="b", alpha=0.2
)
axes[0,0].set(title="PSD spectrum endogeneous", ylabel="Power Spectral Density")

psds_mean = psds_exo.mean(axis=(0))[freq_range]
psds_std = psds_exo.std(axis=(0))[freq_range]
axes[0,1].plot(freqs_psd[freq_range], psds_mean, color="b")
axes[0,1].fill_between(
    freqs_psd[freq_range], psds_mean - psds_std, psds_mean + psds_std, color="b", alpha=0.2
)
axes[0,1].set(title="PSD spectrum exogeneous", ylabel="Power Spectral Density")

# SNR spectrum
snr_mean = snrs_endo.mean(axis=(0))[freq_range]
snr_std = snrs_endo.std(axis=(0))[freq_range]

axes[1,0].plot(freqs_psd[freq_range], snr_mean, color="r")
axes[1,0].fill_between(
    freqs_psd[freq_range], snr_mean - snr_std, snr_mean + snr_std, color="r", alpha=0.2
)
axes[1,0].set(
    title="SNR spectrum endogeneous",
    xlabel="Frequency [Hz]",
    ylabel="SNR",
    ylim=[-2, 15],
    xlim=[fmin, fmax],
)
snr_mean = snrs_exo.mean(axis=(0))[freq_range]
snr_std = snrs_exo.std(axis=(0))[freq_range]

axes[1,1].plot(freqs_psd[freq_range], snr_mean, color="r")
axes[1,1].fill_between(
    freqs_psd[freq_range], snr_mean - snr_std, snr_mean + snr_std, color="r", alpha=0.2
)
axes[1,1].set(
    title="SNR spectrum exogeneous",
    xlabel="Frequency [Hz]",
    ylabel="SNR",
    ylim=[-2, 15],
    xlim=[fmin, fmax],
)
plt.tight_layout()
fig.show()

# Extract SNR values at the stimulation frequency
stim_freq1 = 60
stim_freq2 = 64

# find index of frequency bin closest to stimulation frequency
i_bin_1 = np.argmin(abs(freqs_psd - stim_freq1))
i_bin_2 = np.argmin(abs(freqs_psd - stim_freq2))

# Apply the subset
snrs_target1_endo = snrs_endo[:, i_bin_1]
snrs_target2_endo = snrs_endo[:, i_bin_2]
print(f'SNR at {stim_freq1}Hz in endogenous condition: {snrs_target1_endo.mean()}')
print(f'SNR at {stim_freq2}Hz in endogenous: {snrs_target2_endo.mean()}')
snrs_target1_exo = snrs_exo[:, i_bin_1]
snrs_target2_exo = snrs_exo[:, i_bin_2]
print(f'SNR at {stim_freq1}Hz in exogenous condition: {snrs_target1_exo.mean()}')
print(f'SNR at {stim_freq2}Hz in exogenous: {snrs_target2_exo.mean()}')
# Out:
# /tmp/ipykernel_27774/1712708323.py:76: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# SNR at 60Hz in endogenous condition: 6.021968053757581
# SNR at 64Hz in endogenous: 4.352228570427185
# SNR at 60Hz in exogenous condition: 7.019367420568832
# SNR at 64Hz in exogenous: 7.034279836013852

# %% [markdown]
# ## 1.2 Topography of the SNR

# %%
# plot SNR topography
fig, ax = plt.subplots(2,2)
mne.viz.plot_topomap(snrs_target1_endo, epochs.info, vlim=(1, None), axes=ax[0,0], show=False, extrapolate='local')
mne.viz.plot_topomap(snrs_target2_endo, epochs.info, vlim=(1, None), axes=ax[0,1], show=False, extrapolate='local')
mne.viz.plot_topomap(snrs_target1_exo, epochs.info, vlim=(1, None), axes=ax[1,0], show=False, extrapolate='local')
mne.viz.plot_topomap(snrs_target2_exo, epochs.info, vlim=(1, None), axes=ax[1,1], show=False, extrapolate='local')
ax[0,0].set_title('Endogeneous 60Hz')
ax[0,1].set_title('Exogeneous 60H')
ax[1,0].set_title('Endogeneous 64Hz')
ax[1,1].set_title('Exogeneous 64H')
plt.show()

# Channels with the highest SNR 
print(f'Channels with highest SNR for 60Hz endo {np.array(epochs.info['ch_names'])[np.argsort(snrs_target1_endo)[::-1]][:4]}')
print(f'Channels with highest SNR for 64Hz endo {np.array(epochs.info['ch_names'])[np.argsort(snrs_target2_endo)[::-1]][:4]}')
print(f'Channels with highest SNR for 60Hz exo {np.array(epochs.info['ch_names'])[np.argsort(snrs_target1_exo)[::-1]][:4]}')
print(f'Channels with highest SNR for 64Hz exo {np.array(epochs.info['ch_names'])[np.argsort(snrs_target2_exo)[::-1]][:4]}')
#select electrodes from 60 as the top electrodes are parietal and occipital
SNR_best_electrodes_60_endo = np.array(epochs.info['ch_names'])[np.argsort(snrs_target1_endo)[::-1]][:4]
SNR_best_electrodes_64_endo = np.array(epochs.info['ch_names'])[np.argsort(snrs_target2_endo)[::-1]][:4]
SNR_best_electrodes_60_exo = np.array(epochs.info['ch_names'])[np.argsort(snrs_target1_exo)[::-1]][:4]
SNR_best_electrodes_64_exo = np.array(epochs.info['ch_names'])[np.argsort(snrs_target2_exo)[::-1]][:4]
# Out:
# Channels with highest SNR for 60Hz endo ['PO4' 'P2' 'POz' 'PO3']
# Channels with highest SNR for 64Hz endo ['PO4' 'PO3' 'CP1' 'Pz']
# Channels with highest SNR for 60Hz exo ['POz' 'PO3' 'PO4' 'CP1']
# Channels with highest SNR for 64Hz exo ['O2' 'PO3' 'PO4' 'O1']

# %% [markdown]
# ## 1.3 Time frequency analysis of coherence by electrode
# Coherence is studied in the time window between trial start and onset of the stimuli (the post stimuli window is likely contaminated by attentional catching due to their onset).

# %% [markdown]
# ### Inter-trial coherence with Morlet estimation

# %%
# n_cylce: trade-off temporal vs frequency resolution (is how many cycles of the frequency to include in the Gaussian envelope). 
# Frequency resolution is emphasized by picking the maximum number of cycles to have the wavelets slightly shorter than the signal.


# time window from -.5 sec to 1 sec relative to cue
tmin, tmax = -.5, 1
# Define range of frequencies of interest +/- 5 to the tagged frequencies
freqs = np.arange(55, 70, step = 0.5)

_, itc_endo = epochs_endo.copy().crop(tmin, tmax).compute_tfr(
    method="morlet", freqs=freqs, n_cycles=freqs-10, return_itc=True, average=True
)
_, itc_exo = epochs_exo.copy().crop(tmin, tmax).compute_tfr(
    method="morlet", freqs=freqs, n_cycles=freqs-10, return_itc=True, average=True
)


fig, axes = plt.subplots(2, 7, figsize=(15, 5), sharey = True) 
axes = axes.flatten() 

channels = relevant_electrodes#Just plot in relevant electrodes to make it easier

# Plot each electrode
for e, (channel, ax) in enumerate(zip(channels, axes)):
    itc_endo.plot(
        picks=[channel],
        baseline=None,
        vlim=(0,1),
        axes=ax,
        colorbar=True,
        show=False 
    )
    ax.set_title(channel) 
    ax.axhline(y=60, color='r', linestyle='--', linewidth=1)
    ax.axhline(y=64, color='r', linestyle='--', linewidth=1)
    
plt.tight_layout()
plt.show()
fig, axes = plt.subplots(2, 7, figsize=(15, 5), sharey = True) 
axes = axes.flatten() 

# Plot each electrode
for e, (channel, ax) in enumerate(zip(channels, axes)):
    itc_exo.plot(
        picks=[channel],
        baseline=None,
        vlim=(0,1),
        axes=ax,
        colorbar=True,
        show=False 
    )
    ax.set_title(channel) 
    ax.axhline(y=60, color='r', linestyle='--', linewidth=1)
    ax.axhline(y=64, color='r', linestyle='--', linewidth=1)
    
plt.tight_layout()
plt.show()
# Out:
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:   12.8s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:   12.5s
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied

# %%
# Check whether the expected frequencies are indeed the highest
itc_arr, frex_idx = itc_endo.get_data(return_freqs=True)
print(f'Frequencies in endogeneous with the maximum coherence in descending order : {frex_idx[itc_arr.mean(axis=(0,2)).argsort()[::-1]][:4]}')
print(f'From best to 4th \nChannels with the highest coherence with 64 in endo:{np.array(epochs.info['ch_names'])[np.argsort(np.squeeze(itc_arr[:,np.where(frex_idx==60),:].max(axis = -1)))[::-1]][:4]} \
                        \nChannels with the highest coherence with 60 in endo:{np.array(epochs.info['ch_names'])[np.argsort(np.squeeze(itc_arr[:,np.where(frex_idx==64),:].max(axis = -1)))[::-1]][:4]}')
best_electrodes_coherence_morlet_60_endo = np.array(epochs.info['ch_names'])[np.argsort(np.squeeze(itc_arr[:,np.where(frex_idx==60),:].max(axis = -1)))[::-1]][:4]
best_electrodes_coherence_morlet_64_endo = np.array(epochs.info['ch_names'])[np.argsort(np.squeeze(itc_arr[:,np.where(frex_idx==64),:].max(axis = -1)))[::-1]][:4]

itc_arr, frex_idx = itc_exo.get_data(return_freqs=True)
print(f'Frequencies in exogeneous with the maximum coherence in descending order : {frex_idx[itc_arr.mean(axis=(0,2)).argsort()[::-1]][:4]}')
print(f'From best to 4th \nChannels with the highest coherence with 64 in exo:{np.array(epochs.info['ch_names'])[np.argsort(np.squeeze(itc_arr[:,np.where(frex_idx==60),:].max(axis = -1)))[::-1]][:4]} \
                        \nChannels with the highest coherence with 60 in enxxo:{np.array(epochs.info['ch_names'])[np.argsort(np.squeeze(itc_arr[:,np.where(frex_idx==64),:].max(axis = -1)))[::-1]][:4]}')
best_electrodes_coherence_morlet_60_exo = np.array(epochs.info['ch_names'])[np.argsort(np.squeeze(itc_arr[:,np.where(frex_idx==60),:].max(axis = -1)))[::-1]][:4]
best_electrodes_coherence_morlet_64_exo = np.array(epochs.info['ch_names'])[np.argsort(np.squeeze(itc_arr[:,np.where(frex_idx==64),:].max(axis = -1)))[::-1]][:4]
# Out:
# Frequencies in endogeneous with the maximum coherence in descending order : [64.  63.5 64.5 59.5]
# From best to 4th
# Channels with the highest coherence with 64 in endo:['PO4' 'CP1' 'O2' 'P2']
# Channels with the highest coherence with 60 in endo:['Pz' 'CP1' 'PO3' 'P1']
# Frequencies in exogeneous with the maximum coherence in descending order : [60.  63.5 60.5 59.5]
# From best to 4th
# Channels with the highest coherence with 64 in exo:['PO4' 'POz' 'O2' 'PO3']
# Channels with the highest coherence with 60 in enxxo:['POz' 'CP1' 'PO4' 'P1']

# %% [markdown]
# ## 1.4 Select electrodes based on previous analysis

# %%
print(f'Top 4 electrodes for SNR 60 endo {SNR_best_electrodes_60_endo}')
print(f'Top 4 electrodes for SNR 64 endo {SNR_best_electrodes_64_endo}')
print(f'Top 4 electrodes for SNR 60 exo {SNR_best_electrodes_60_exo}')
print(f'Top 4 electrodes for SNR 64 exo {SNR_best_electrodes_64_exo}')
print(f'Top 4 electrodes for ITC morlet 60 endo {best_electrodes_coherence_morlet_60_endo}')
print(f'Top 4 electrodes for ITC morlet 64 endo {best_electrodes_coherence_morlet_64_endo}')
print(f'Top 4 electrodes for ITC morlet 60 exo {best_electrodes_coherence_morlet_60_exo}')
print(f'Top 4 electrodes for ITC morlet 64 exo {best_electrodes_coherence_morlet_64_exo}')
# Out:
# Top 4 electrodes for SNR 60 endo ['PO4' 'P2' 'POz' 'PO3']
# Top 4 electrodes for SNR 64 endo ['PO4' 'PO3' 'CP1' 'Pz']
# Top 4 electrodes for SNR 60 exo ['POz' 'PO3' 'PO4' 'CP1']
# Top 4 electrodes for SNR 64 exo ['O2' 'PO3' 'PO4' 'O1']
# Top 4 electrodes for ITC morlet 60 endo ['PO4' 'CP1' 'O2' 'P2']
# Top 4 electrodes for ITC morlet 64 endo ['Pz' 'CP1' 'PO3' 'P1']
# Top 4 electrodes for ITC morlet 60 exo ['PO4' 'POz' 'O2' 'PO3']
# Top 4 electrodes for ITC morlet 64 exo ['POz' 'CP1' 'PO4' 'P1']

# %%
# Select top 3 electrodes that are the most often the best according to SNR and IT coherence
# First for 60Hz, then 64Hz
all_electrodes_60 = (list(SNR_best_electrodes_60_endo) + 
                  list(SNR_best_electrodes_60_exo) + 
                  list(best_electrodes_coherence_morlet_60_endo) + 
                  list(best_electrodes_coherence_morlet_60_exo))

# Count the occurrences of each electrode
electrode_counts = Counter(all_electrodes_60)

best_electrodes_60 = [electrode for electrode, count in electrode_counts.most_common(3)]

all_electrodes_64 = (
                  list(SNR_best_electrodes_64_endo) + 
                  list(SNR_best_electrodes_64_exo) + 
                  list(best_electrodes_coherence_morlet_64_endo) + 
                  list(best_electrodes_coherence_morlet_64_exo))

# Count the occurrences of each electrode
electrode_counts = Counter(all_electrodes_64)

best_electrodes_64 = [electrode for electrode, count in electrode_counts.most_common(3)]

print(f'selected electrodes for 60Hz: {best_electrodes_60}')
print(f'selected electrodes for 64Hz: {best_electrodes_64}')

best_electrodes = list(set(best_electrodes_60+best_electrodes_64))

# Remove all other electrodes
epochs = epochs.pick(best_electrodes)
epochs_endo = epochs_endo.pick(best_electrodes)
epochs_exo = epochs_exo.pick(best_electrodes)

# Store index for correct selection across 60 and 64
best_electrodes_60_idx = np.isin(epochs.info['ch_names'], best_electrodes_60)
best_electrodes_64_idx = np.isin(epochs.info['ch_names'], best_electrodes_64)
# Out:
# selected electrodes for 60Hz: ['PO4', 'POz', 'PO3']
# selected electrodes for 64Hz: ['PO4', 'PO3', 'CP1']

# %% [markdown]
# # 2 - Testing for an attentional effect
# ### Comparing SNR across cued conditions

# %%
queries = ["cued_tag == 60 & attention_type_block==0", "cued_tag == 64 & attention_type_block==0",
          "cued_tag == 60 & attention_type_block==1", "cued_tag == 64 & attention_type_block==1"]
vals = {}

tmin = 0 # Search in window starting from cue (when SSVEP is expected)
tmax = 1

for query in queries:
    # Spectrum averaged over all trials for all best electrodes
    freqs, amplitudes = ssvep_amplitudes(epochs[query], best_electrodes, tmin, tmax)

    # Transform to SNR
    snrs = snr_spectrum(amplitudes, noise_n_neighbor_freqs=used_nei, noise_skip_neighbor_freqs = skip_nei)

    # find index of frequency bin closest to stimulation frequency
    i_bin_60 = np.argmin(abs(freqs - 60))
    i_bin_64 = np.argmin(abs(freqs - 64))

    # Apply the subset, select the electrodes for 60Hz and 64, average over electrodes
    vals[str(60)+query] = copy.deepcopy(np.mean(snrs[best_electrodes_60_idx, i_bin_60], axis=0))
    vals[str(64)+query] = copy.deepcopy(np.mean(snrs[best_electrodes_64_idx, i_bin_64], axis=0))

# %%
fig, ax = plt.subplots(1,2, figsize=(6,3), sharex=True, sharey=True)
ax[0].plot([0,1], [vals['60cued_tag == 64 & attention_type_block==0'], vals['60cued_tag == 60 & attention_type_block==0']], 'o-', label='exo')
ax[1].plot([0,1], [vals['64cued_tag == 60 & attention_type_block==0'], vals['64cued_tag == 64 & attention_type_block==0']], 'o-', label='exo')
ax[0].plot([0,1], [vals['60cued_tag == 64 & attention_type_block==1'], vals['60cued_tag == 60 & attention_type_block==1']], 'o-', label='endo')
ax[1].plot([0,1], [vals['64cued_tag == 60 & attention_type_block==1'], vals['64cued_tag == 64 & attention_type_block==1']], 'o-', label='endo')

ax[0].set_title('SNR at 60Hz')
ax[1].set_title('SNR at 64Hz')
ax[0].set_ylabel('SNR')
ax[1].set_ylabel('SNR')
ax[0].set_xticks([0,1], ['Not cued', 'Cued'])
ax[1].set_xticks([0,1], ['Not cued', 'Cued'])
ax[1].set_xlim(-.5, 1.5)
plt.legend(bbox_to_anchor=(1,1))
plt.tight_layout()
plt.show()

# %%
def ami(unattended, attended):
    return (attended-unattended)/(attended+unattended)
    
cueing_60_exo = ami(vals['60cued_tag == 64 & attention_type_block==0'], vals['60cued_tag == 60 & attention_type_block==0'])
cueing_64_exo = ami(vals['64cued_tag == 60 & attention_type_block==0'], vals['64cued_tag == 64 & attention_type_block==0'])
cueing_60_endo = ami(vals['60cued_tag == 64 & attention_type_block==1'], vals['60cued_tag == 60 & attention_type_block==1'])
cueing_64_endo = ami(vals['64cued_tag == 60 & attention_type_block==1'], vals['64cued_tag == 64 & attention_type_block==1'])

ami_all = np.stack([cueing_60_exo,cueing_64_exo,cueing_60_endo,cueing_64_endo])
np.save('files/B3_ami.npy', ami_all)

# %% [markdown]
# ### Comparing inter-trial coherence across cued conditions

# %%
# time window from -1 sec to 1 sec relative to cue
tmin, tmax = -.5, 1


# Using a n_cycles of 42 to match the paper by Chota, Bruat, Stigchel & Strauch 2023
# THey used 7 for 10 and 13.333 Hz so an equivalent enveloppe is 42 cycles?


# Get inter-trial coherence with 60 and 64Hz by cued frequency 
freqs6064 = np.array([60, 64])
power_64_endo = epochs_endo['cued_tag == 64'].copy().crop(tmin, tmax).compute_tfr(
    method="morlet", freqs=freqs6064, n_cycles=42,return_itc=False, average=True
)

power_60_endo = epochs_endo['cued_tag == 60'].copy().crop(tmin, tmax).compute_tfr(
    method="morlet", freqs=freqs6064, n_cycles=42,return_itc=False, average=True
)
power_64_exo = epochs_exo['cued_tag == 64'].copy().crop(tmin, tmax).compute_tfr(
    method="morlet", freqs=freqs6064, n_cycles=42,return_itc=False, average=True
)

power_60_exo = epochs_exo['cued_tag == 60'].copy().crop(tmin, tmax).compute_tfr(
    method="morlet", freqs=freqs6064, n_cycles=42,return_itc=False, average=True
)


coherence = {}
power_64_arr, times_coh, freqs_idx = power_64_endo.get_data(return_freqs = True, return_times = True)
power_60_arr = power_60_endo.get_data()
coherence['with64_for64cued_endo'] = power_64_arr[best_electrodes_64_idx,1,:]
coherence['with60_for64cued_endo'] = power_64_arr[best_electrodes_60_idx,0,:]
coherence['with64_for60cued_endo'] = power_60_arr[best_electrodes_64_idx,1,:]
coherence['with60_for60cued_endo'] = power_60_arr[best_electrodes_60_idx,0,:]
power_64_arr, times_coh, freqs_idx = power_64_exo.get_data(return_freqs = True, return_times = True)
power_60_arr = power_60_exo.get_data()
coherence['with64_for64cued_exo'] = power_64_arr[best_electrodes_64_idx,1,:]
coherence['with60_for64cued_exo'] = power_64_arr[best_electrodes_60_idx,0,:]
coherence['with64_for60cued_exo'] = power_60_arr[best_electrodes_64_idx,1,:]
coherence['with60_for60cued_exo'] = power_60_arr[best_electrodes_60_idx,0,:]

# %%
fig, ax = plt.subplots(2,2, sharex=True, sharey=True, figsize=(10,5))
ax[0,0].plot(times_coh, coherence['with60_for60cued_endo'].T - coherence['with60_for64cued_endo'].T, label = np.array(epochs.info['ch_names'])[best_electrodes_60_idx])
ax[0,0].set_ylabel('Coherence 60Hz')
ax[0,0].set_title('Endogeneous difference 60Hz cued-uncued')
ax[1,0].plot(times_coh, coherence['with64_for64cued_endo'].T - coherence['with64_for60cued_endo'].T, label = np.array(epochs.info['ch_names'])[best_electrodes_64_idx])
ax[1,0].set_ylabel('Coherence 64Hz')
ax[1,0].set_title('Endogeneous difference 64Hz cued-uncued')
ax[0,1].plot(times_coh, coherence['with60_for60cued_exo'].T - coherence['with60_for64cued_exo'].T, label = np.array(epochs.info['ch_names'])[best_electrodes_60_idx])
ax[0,1].set_title('Exogeneous difference 60Hz cued-uncued')
ax[1,1].plot(times_coh, coherence['with64_for64cued_exo'].T - coherence['with64_for60cued_exo'].T, label =  np.array(epochs.info['ch_names'])[best_electrodes_64_idx])
ax[1,1].set_title('Exogeneous difference 64Hz cued-uncued')

# for axi in ax.flatten():
#     axi.vlines(0, -.4, .4, color='black')

plt.legend(bbox_to_anchor=(1,1))
ax[1,0].set_xlabel('Time from cue (second)')
ax[1,1].set_xlabel('Time from cue (second)')
plt.show()

# %%
# Export for group analysis, average over electrodes

def pd_coh(coherence_dic, cued, coh_with, condition, times):
    coherence = pd.DataFrame(coherence_dic[f'with{coh_with}_for{cued}cued_{condition}'])
    #First normalize electrodes, then average
    coherence = pd.DataFrame(coherence.apply(lambda x: (x - np.mean(x)) / np.std(x), axis=1).mean()).T
    coherence['cued'] = cued
    coherence['coh_with'] = coh_with
    coherence['condition'] = condition
    coherence = coherence.melt(id_vars=['cued','coh_with','condition'])
    coherence['time'] = times
    return coherence

coh64_cue64_endo = pd_coh(coherence, 64, 64, 'endo', times_coh)
coh64_cue60_endo = pd_coh(coherence, 60, 64, 'endo', times_coh)
coh60_cue64_endo = pd_coh(coherence, 64, 60, 'endo', times_coh)
coh60_cue60_endo = pd_coh(coherence, 60, 60, 'endo', times_coh)
coh64_cue64_exo = pd_coh(coherence, 64, 64, 'exo', times_coh)
coh64_cue60_exo = pd_coh(coherence, 60, 64, 'exo', times_coh)
coh60_cue64_exo = pd_coh(coherence, 64, 60, 'exo', times_coh)
coh60_cue60_exo = pd_coh(coherence, 60, 60, 'exo', times_coh)

ITcoh_B3 = pd.concat([coh60_cue60_endo, coh60_cue64_endo, coh64_cue60_endo, coh64_cue64_endo,
                     coh60_cue60_exo, coh60_cue64_exo, coh64_cue60_exo, coh64_cue64_exo])
ITcoh_B3.columns = ['cued', 'coh_with', 'condition', 'timepoint', 'ITcoherence', 'time']
ITcoh_B3.to_csv('files/ITcoh_B3.csv',index=False)

# %% [markdown]
# # 3 - Predict cued side with a classifier

# %%
def pre_post_training(epochs, tmin_training,tmax_training,tmin_prediction,tmax_prediction):
    '''
    Function to train on a given period and test on another.
    tmax_training and tmin_training are used for training the model
    tmax_prediciton and tmin_prediciton are used for prediction only based on the best training time
    '''
    epochs_posttraining = epochs.copy().crop(tmin=tmin_training, tmax=tmax_training)
    epochs_pretraining = epochs.copy().crop(tmin=tmin_prediction, tmax=tmax_prediction ).copy()
    
    # Data and label to train on (predicting side that was cued)
    X = epochs_posttraining.copy().get_data()
    y = epochs_posttraining.metadata['cued_side'].values
    
    # Model fitting with logistic regression, using 10 CV
    clf = make_pipeline(StandardScaler(), LogisticRegression(solver="liblinear"))
    time_decod = SlidingEstimator(clf, n_jobs=10, scoring="roc_auc", verbose=True)
    scores = cross_val_multiscore(time_decod, X, y, cv=10, n_jobs=10)
    
    # Find the best time point during training period, first average scores over splits and pick max score
    mean_scores = np.mean(scores, axis=0)
    best_time_idx = np.argmax(mean_scores)
    best_time = epochs_posttraining.times[best_time_idx]
    best_score = mean_scores[best_time_idx]
    print(f"Best time point post-250ms: {best_time} seconds with score: {best_score}")
    
    # Re-train the model on the best time during the training period only
    best_time_data = X[:, :, best_time_idx]
    clf_best = make_pipeline(StandardScaler(), LogisticRegression(solver="liblinear"))
    clf_best.fit(best_time_data, y)
    
    # Evaluate the model on data for each time point during prediction period separately for endo and exo
    exo = epochs_pretraining['attention_type_block==0'].copy()
    endo = epochs_pretraining['attention_type_block==1'].copy()
    # Automatically perform kfold
    skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
    cv_scores_pretraining_exo = []
    cv_scores_pretraining_endo = []
    
    # Iterate through each time point in the prediction period
    for t in range(len(exo.times)):
        X_pretraining_exo = exo.get_data()[:, :, t]
        X_pretraining_endo = endo.get_data()[:, :, t]
        y_exo = exo.metadata['cued_side'].values
        y_endo = endo.metadata['cued_side'].values
        fold_scores_exo = []
        fold_scores_endo = []
        
        # Iterate through each fold of cross-validation
        for train_index, test_index in skf.split(X_pretraining_exo, y_exo):
            X_train, X_test = X_pretraining_exo[train_index], X_pretraining_exo[test_index]
            y_train, y_test = y_exo[train_index], y_exo[test_index]
            
            # Use the previously trained model to predict the time point data in the prediction period
            predictions = clf_best.predict(X_pretraining_exo[test_index])
            score_exo = roc_auc_score(y_test, predictions)
            fold_scores_exo.append(score_exo)
        # Average score across folds for this time point
        avg_score_exo = np.mean(fold_scores_exo, axis=-1)
        cv_scores_pretraining_exo.append(avg_score_exo)
        
        # Same for endo
        for train_index, test_index in skf.split(X_pretraining_endo, y_endo):
            X_train, X_test = X_pretraining_endo[train_index], X_pretraining_endo[test_index]
            y_train, y_test = y_endo[train_index], y_endo[test_index]
            
            predictions = clf_best.predict(X_pretraining_endo[test_index])
            score_endo = roc_auc_score(y_test, predictions)
            fold_scores_endo.append(score_endo)
        
        avg_score_endo = np.mean(fold_scores_endo, axis=-1)
        cv_scores_pretraining_endo.append(avg_score_endo)

    cv_scores_pretraining_exo = np.array(cv_scores_pretraining_exo)
    cv_scores_pretraining_endo = np.array(cv_scores_pretraining_endo)
    
    # Make all scores > .50 as there are only two labels
    cv_scores_pretraining_exo = np.abs(cv_scores_pretraining_exo - cv_scores_pretraining_exo.mean())+.5
    cv_scores_pretraining_endo = np.abs(cv_scores_pretraining_endo - cv_scores_pretraining_endo.mean())+.5

    pd_prediction = pd.DataFrame({'exo':cv_scores_pretraining_exo,
                     'endo':cv_scores_pretraining_endo,
                     'time':epochs_pretraining.times})
    pd_prediction = pd_prediction.melt(id_vars='time')
    pd_prediction.columns = ['time', 'attention', 'score']
    pd_prediction['best_time'] = best_time
    return pd_prediction

# %%
# Load eeg epochs again to use all channels
epochs = mne.read_epochs(f'{data_path}{epoch_file}')
epoch_good = [x for x,y in enumerate(epochs.drop_log) if len(y) == 0]
epochs.metadata = pd_info.iloc[epoch_good]

# Remove trials where a target occured
epochs = epochs['targets_binary == 0']

# Downsample for speed
epochs.resample(200).pick_types(eeg=True)
# Out:
# Reading /home/lea/Documents/obsidian_notes/masterADS/ads_thesis_RIFT/my_code_expe2/data/B3/preprocessing/B3_EEG_epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 510 matching events found
# No baseline correction applied
# 0 projection items activated
# Adding metadata with 14 columns
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# <EpochsFIF |  414 events (all good), -1 – 1.995 s, baseline -1 – 0 s, ~121.4 MB, data loaded, with metadata,
#  '3': 414>

# %% [markdown]
# ## Training on the attention window (target onset period)

# %%
# Data preparation for training and prediction periods
tmin_training, tmax_training = .125, .8
# Take some time after training for plotting purposes 
tmin_prediction, tmax_prediction = -.2, .8
target_period = pre_post_training(epochs, tmin_training, tmax_training, tmin_prediction, tmax_prediction)
# Out:
# /tmp/ipykernel_27774/132503421.py:11: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X = epochs_posttraining.copy().get_data()
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
#  32%|███▏      | Fitting SlidingEstimator : 43/136 [00:00<00:00,  241.81it/s]
#  42%|████▏     | Fitting SlidingEstimator : 57/136 [00:00<00:00,  225.83it/s]
#  47%|████▋     | Fitting SlidingEstimator : 64/136 [00:00<00:00,  221.21it/s][A
#  54%|█████▎    | Fitting SlidingEstimator : 73/136 [00:00<00:00,  224.66it/s]
#  60%|█████▉    | Fitting SlidingEstimator : 81/136 [00:00<00:00,  225.07it/s]
#  65%|██████▍   | Fitting SlidingEstimator : 88/136 [00:00<00:00,  221.57it/s]
#  29%|██▊       | Fitting SlidingEstimator : 39/136 [00:00<00:00,  180.33it/s]
#
#  70%|██████▉   | Fitting SlidingEstimator : 95/136 [00:00<00:00,  217.36it/s]A
#  75%|███████▌  | Fitting SlidingEstimator : 102/136 [00:00<00:00,  216.22it/s][A
#  40%|████      | Fitting SlidingEstimator : 55/136 [00:00<00:00,  193.11it/s]
#
#  79%|███████▊  | Fitting SlidingEstimator : 107/136 [00:00<00:00,  207.68it/s]A
#  43%|████▎     | Fitting SlidingEstimator : 59/136 [00:00<00:00,  180.65it/s]
#
#  85%|████████▍ | Fitting SlidingEstimator : 115/136 [00:00<00:00,  207.06it/s]A
#  50%|█████     | Fitting SlidingEstimator : 68/136 [00:00<00:00,  185.42it/s]
#
#  89%|████████▉ | Fitting SlidingEstimator : 121/136 [00:00<00:00,  202.97it/s][A
#  54%|█████▎    | Fitting SlidingEstimator : 73/136 [00:00<00:00,  179.61it/s]
#
#  93%|█████████▎| Fitting SlidingEstimator : 127/136 [00:00<00:00,  198.53it/s][A
#  58%|█████▊    | Fitting SlidingEstimator : 79/136 [00:00<00:00,  177.71it/s]
#
# 100%|██████████| Fitting SlidingEstimator : 136/136 [00:00<00:00,  205.41it/s][A
#
#  62%|██████▏   | Fitting SlidingEstimator : 84/136 [00:00<00:00,  174.56it/s]
#
#  27%|██▋       | Fitting SlidingEstimator : 37/136 [00:00<00:00,  149.12it/s]
#  64%|██████▍   | Fitting SlidingEstimator : 87/136 [00:00<00:00,  166.07it/s]
#
#  31%|███       | Fitting SlidingEstimator : 42/136 [00:00<00:00,  148.19it/s]
#  71%|███████   | Fitting SlidingEstimator : 96/136 [00:00<00:00,  171.39it/s]
#
#  35%|███▍      | Fitting SlidingEstimator : 47/136 [00:00<00:00,  146.46it/s]
#
#
#   0%|          | Fitting SlidingEstimator : 0/136 [00:00<?,       ?it/s]
#  75%|███████▌  | Fitting SlidingEstimator : 102/136 [00:00<00:00,  163.90it/s]
#
#  42%|████▏     | Fitting SlidingEstimator : 57/136 [00:00<00:00,  156.63it/s]
#  80%|████████  | Fitting SlidingEstimator : 109/136 [00:00<00:00,  164.36it/s]
#
#  46%|████▌     | Fitting SlidingEstimator : 62/136 [00:00<00:00,  150.20it/s]
#
#
#   4%|▎         | Fitting SlidingEstimator : 5/136 [00:00<00:02,   63.90it/s]
#  82%|████████▏ | Fitting SlidingEstimator : 111/136 [00:00<00:00,  155.88it/s]
#
#  49%|████▊     | Fitting SlidingEstimator : 66/136 [00:00<00:00,  143.68it/s]
#
#
#   6%|▌         | Fitting SlidingEstimator : 8/136 [00:00<00:02,   60.29it/s]
#
#  52%|█████▏    | Fitting SlidingEstimator : 71/136 [00:00<00:00,  142.90it/s]
#  86%|████████▌ | Fitting SlidingEstimator : 117/136 [00:00<00:00,  150.05it/s]
#
#
#
#   0%|          | Fitting SlidingEstimator : 0/136 [00:00<?,       ?it/s]
#
#
#
#
#  57%|█████▋    | Fitting SlidingEstimator : 78/136 [00:00<00:00,  147.19it/s]
#  93%|█████████▎| Fitting SlidingEstimator : 126/136 [00:00<00:00,  154.65it/s]
#
#
#  15%|█▍        | Fitting SlidingEstimator : 20/136 [00:00<00:01,   91.91it/s]
#  97%|█████████▋| Fitting SlidingEstimator : 132/136 [00:00<00:00,  155.65it/s]
#
#  64%|██████▍   | Fitting SlidingEstimator : 87/136 [00:00<00:00,  150.05it/s]
#
#
#
#   1%|▏         | Fitting SlidingEstimator : 2/136 [00:00<00:05,   24.50it/s]
# 100%|██████████| Fitting SlidingEstimator : 136/136 [00:00<00:00,  158.87it/s]
#
#
#
#  18%|█▊        | Fitting SlidingEstimator : 25/136 [00:00<00:01,   98.46it/s]
#
#  66%|██████▌   | Fitting SlidingEstimator : 90/136 [00:00<00:00,  145.26it/s]
#
#
#
#   7%|▋         | Fitting SlidingEstimator : 9/136 [00:00<00:01,   79.29it/s]
#
#  71%|███████   | Fitting SlidingEstimator : 96/136 [00:00<00:00,  145.71it/s]
#
#
#  24%|██▎       | Fitting SlidingEstimator : 32/136 [00:00<00:00,  107.11it/s]
#
#
#
#   8%|▊         | Fitting SlidingEstimator : 11/136 [00:00<00:01,   71.86it/s]
#
#  75%|███████▌  | Fitting SlidingEstimator : 102/136 [00:00<00:00,  147.02it/s]
#
#
#  28%|██▊       | Fitting SlidingEstimator : 38/136 [00:00<00:00,  112.53it/s]
#
#
#
#  12%|█▎        | Fitting SlidingEstimator : 17/136 [00:00<00:01,   92.18it/s]
#
#  78%|███████▊  | Fitting SlidingEstimator : 106/136 [00:00<00:00,  144.40it/s]
#
#
#  34%|███▍      | Fitting SlidingEstimator : 46/136 [00:00<00:00,  122.96it/s]
#
#
#
#  15%|█▍        | Fitting SlidingEstimator : 20/136 [00:00<00:01,   86.86it/s]
#
#  82%|████████▏ | Fitting SlidingEstimator : 112/136 [00:00<00:00,  145.18it/s]
#
#
#  35%|███▌      | Fitting SlidingEstimator : 48/136 [00:00<00:00,  115.07it/s]
#
#
#
#  20%|█▉        | Fitting SlidingEstimator : 27/136 [00:00<00:01,  100.49it/s]
#
#  87%|████████▋ | Fitting SlidingEstimator : 118/136 [00:00<00:00,  146.95it/s]
#
#
#  42%|████▏     | Fitting SlidingEstimator : 57/136 [00:00<00:00,  127.60it/s]
#
#
#
#  23%|██▎       | Fitting SlidingEstimator : 31/136 [00:00<00:01,  101.88it/s]
#
#
#
#
#
#
#  89%|████████▉ | Fitting SlidingEstimator : 121/136 [00:00<00:00,  141.97it/s]
#
#
#  45%|████▍     | Fitting SlidingEstimator : 61/136 [00:00<00:00,  124.63it/s]
#
#
#
#  28%|██▊       | Fitting SlidingEstimator : 38/136 [00:00<00:00,  110.64it/s]
#
#  95%|█████████▍| Fitting SlidingEstimator : 129/136 [00:00<00:00,  146.53it/s]
#
#
#  49%|████▉     | Fitting SlidingEstimator : 67/136 [00:00<00:00,  127.98it/s]
#
#
#
#  31%|███       | Fitting SlidingEstimator : 42/136 [00:00<00:00,  111.27it/s]
#
# 100%|██████████| Fitting SlidingEstimator : 136/136 [00:00<00:00,  149.82it/s]
#
#
#
#
# 100%|██████████| Fitting SlidingEstimator : 136/136 [00:00<00:00,  146.92it/s]A
#
#
#
#  52%|█████▏    | Fitting SlidingEstimator : 71/136 [00:00<00:00,  124.95it/s]
#
#
#
#  35%|███▌      | Fitting SlidingEstimator : 48/136 [00:00<00:00,  117.52it/s]
#
#
#
#
#   4%|▍         | Fitting SlidingEstimator : 6/136 [00:00<00:02,   57.54it/s]
#
#
#
#  40%|███▉      | Fitting SlidingEstimator : 54/136 [00:00<00:00,  122.73it/s]
#
#
#
#
#
#
#
#   7%|▋         | Fitting SlidingEstimator : 10/136 [00:00<00:01,   72.92it/s]
#
#
#
#  45%|████▍     | Fitting SlidingEstimator : 61/136 [00:00<00:00,  129.24it/s]
#
#
#  62%|██████▏   | Fitting SlidingEstimator : 84/136 [00:00<00:00,  129.63it/s]
#
#
#
#
#  12%|█▎        | Fitting SlidingEstimator : 17/136 [00:00<00:01,   96.12it/s]
#
#
#
#
#
#   0%|          | Fitting SlidingEstimator : 0/136 [00:00<?,       ?it/s]
#
#
#
#  48%|████▊     | Fitting SlidingEstimator : 65/136 [00:00<00:00,  128.26it/s]
#
#
#  65%|██████▌   | Fitting SlidingEstimator : 89/136 [00:00<00:00,  129.82it/s]
#
#
#
#
#  17%|█▋        | Fitting SlidingEstimator : 23/136 [00:00<00:01,  107.84it/s]
#
#
#
#
#
#   1%|          | Fitting SlidingEstimator : 1/136 [00:00<00:04,   27.76it/s]
#
#
#  69%|██████▉   | Fitting SlidingEstimator : 94/136 [00:00<00:00,  130.48it/s]
#
#
#
#  53%|█████▎    | Fitting SlidingEstimator : 72/136 [00:00<00:00,  128.97it/s]
#
#
#
#
#  23%|██▎       | Fitting SlidingEstimator : 31/136 [00:00<00:00,  122.81it/s]
#
#
#
#
#
#   2%|▏         | Fitting SlidingEstimator : 3/136 [00:00<00:03,   43.21it/s]
#
#
#  72%|███████▏  | Fitting SlidingEstimator : 98/136 [00:00<00:00,  129.67it/s]
#
#
#
#  58%|█████▊    | Fitting SlidingEstimator : 79/136 [00:00<00:00,  133.39it/s]
#
#
#
#
#  27%|██▋       | Fitting SlidingEstimator : 37/136 [00:00<00:00,  127.20it/s]
#
#
#
#
#
#   7%|▋         | Fitting SlidingEstimator : 9/136 [00:00<00:01,   86.93it/s]
#
#
#  74%|███████▍  | Fitting SlidingEstimator : 101/136 [00:00<00:00,  126.88it/s]
#
#
#
#  62%|██████▎   | Fitting SlidingEstimator : 85/136 [00:00<00:00,  134.96it/s]
#
#
#
#
#  30%|███       | Fitting SlidingEstimator : 41/136 [00:00<00:00,  125.01it/s]
#
#
#
#
#
#  11%|█         | Fitting SlidingEstimator : 15/136 [00:00<00:01,  107.68it/s]
#
#
#
#
#
#
#
#
#
#
#
#  66%|██████▌   | Fitting SlidingEstimator : 90/136 [00:00<00:00,  134.67it/s]
#
#
#
#
#
#  14%|█▍        | Fitting SlidingEstimator : 19/136 [00:00<00:01,  108.95it/s]
#
#
#
#
#  38%|███▊      | Fitting SlidingEstimator : 51/136 [00:00<00:00,  128.21it/s]
#
#
#  85%|████████▌ | Fitting SlidingEstimator : 116/136 [00:00<00:00,  133.32it/s]
#
#
#
#  72%|███████▏  | Fitting SlidingEstimator : 98/136 [00:00<00:00,  139.38it/s]
#
#
#
#
#
#  18%|█▊        | Fitting SlidingEstimator : 25/136 [00:00<00:00,  116.72it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  88%|████████▊ | Fitting SlidingEstimator : 119/136 [00:00<00:00,  130.45it/s]
#
#
#
#
#
#
#
#
#
#  21%|██        | Fitting SlidingEstimator : 28/136 [00:00<00:00,  111.94it/s]
#
#
#  92%|█████████▏| Fitting SlidingEstimator : 125/136 [00:00<00:00,  133.25it/s]
#
#
#
#
#
#
#
#
#
#
#  48%|████▊     | Fitting SlidingEstimator : 65/136 [00:00<00:00,  138.32it/s]
#
#
#
#  79%|███████▊  | Fitting SlidingEstimator : 107/136 [00:00<00:00,  135.92it/s]
#
#
#  96%|█████████▋| Fitting SlidingEstimator : 131/136 [00:01<00:00,  135.48it/s]
#
#
#
#
#
#
#   1%|          | Fitting SlidingEstimator : 1/136 [00:00<00:09,   13.58it/s]
#
#
#
#
#  50%|█████     | Fitting SlidingEstimator : 68/136 [00:00<00:00,  133.32it/s]
#
#
#
#
#
#  28%|██▊       | Fitting SlidingEstimator : 38/136 [00:00<00:00,  118.20it/s]
#
#
#
#  83%|████████▎ | Fitting SlidingEstimator : 113/136 [00:00<00:00,  137.48it/s]
#
#
# 100%|██████████| Fitting SlidingEstimator : 136/136 [00:01<00:00,  129.92it/s]
#
#
#
#
#
#
#
#   6%|▌         | Fitting SlidingEstimator : 8/136 [00:00<00:01,   74.50it/s]
#
#
#
#
#  54%|█████▎    | Fitting SlidingEstimator : 73/136 [00:00<00:00,  134.15it/s]
#
#
#
#
#
#  32%|███▏      | Fitting SlidingEstimator : 43/136 [00:00<00:00,  120.95it/s]
#
#
#
#  87%|████████▋ | Fitting SlidingEstimator : 118/136 [00:00<00:00,  137.87it/s]
#
#
#
#
#
#
#  10%|▉         | Fitting SlidingEstimator : 13/136 [00:00<00:01,   90.36it/s]
#
#
#
#
#  59%|█████▉    | Fitting SlidingEstimator : 80/136 [00:00<00:00,  138.10it/s]
#
#
#
#  90%|█████████ | Fitting SlidingEstimator : 123/136 [00:00<00:00,  138.34it/s]
#
#
#
#
#
#  38%|███▊      | Fitting SlidingEstimator : 51/136 [00:00<00:00,  124.81it/s]
#
#
#
#
#  62%|██████▏   | Fitting SlidingEstimator : 84/136 [00:00<00:00,  136.16it/s]
#
#
#
#
#
#
#  15%|█▌        | Fitting SlidingEstimator : 21/136 [00:00<00:01,  114.26it/s]
#
#
#
#  96%|█████████▌| Fitting SlidingEstimator : 130/136 [00:00<00:00,  142.06it/s]
#
#
#
#
#
#  43%|████▎     | Fitting SlidingEstimator : 58/136 [00:00<00:00,  132.30it/s]
#
#
#
#
#
#
#
#   0%|          | Fitting SlidingEstimator : 0/136 [00:00<?,       ?it/s]
#
#
#
#
#  68%|██████▊   | Fitting SlidingEstimator : 92/136 [00:00<00:00,  143.21it/s]
#
#
#
# 100%|██████████| Fitting SlidingEstimator : 136/136 [00:01<00:00,  135.87it/s]
#
#
#
#
#
#
#
#  19%|█▉        | Fitting SlidingEstimator : 26/136 [00:00<00:00,  117.41it/s]
#
#
#
#
#
#  46%|████▋     | Fitting SlidingEstimator : 63/136 [00:00<00:00,  130.81it/s]
#
#
#
#
#  71%|███████   | Fitting SlidingEstimator : 96/136 [00:00<00:00,  140.53it/s]
#
#
#
#
#
#
#  24%|██▍       | Fitting SlidingEstimator : 33/136 [00:00<00:00,  128.68it/s]
#
#
#
#
#
#
#
#   1%|▏         | Fitting SlidingEstimator : 2/136 [00:00<00:04,   28.10it/s]
#
#
#
#
#
#  51%|█████▏    | Fitting SlidingEstimator : 70/136 [00:00<00:00,  136.42it/s]
#
#
#
#
#  75%|███████▌  | Fitting SlidingEstimator : 102/136 [00:00<00:00,  141.99it/s]
#
#
#
#
#
#
#  29%|██▊       | Fitting SlidingEstimator : 39/136 [00:00<00:00,  131.57it/s]
#
#
#
#
#
#  54%|█████▎    | Fitting SlidingEstimator : 73/136 [00:00<00:00,  132.33it/s]
#
#
#
#
#
#
#
#   4%|▍         | Fitting SlidingEstimator : 6/136 [00:00<00:02,   55.08it/s][Parallel(n_jobs=10)]: Done   3 out of  10 | elapsed:    3.2s remaining:    7.4s
#
#
#
#
#
#  78%|███████▊  | Fitting SlidingEstimator : 106/136 [00:00<00:00,  140.18it/s]
#
#
#
#
#
#
#  32%|███▏      | Fitting SlidingEstimator : 44/136 [00:00<00:00,  131.98it/s]
#
#
#
#
#
#  57%|█████▋    | Fitting SlidingEstimator : 77/136 [00:00<00:00,  130.22it/s]
#
#
#
#
#
#
#
#   9%|▉         | Fitting SlidingEstimator : 12/136 [00:00<00:01,   82.16it/s]
#
#
#
#
#  82%|████████▏ | Fitting SlidingEstimator : 112/136 [00:00<00:00,  142.17it/s]
#
#
#
#
#
#
#  35%|███▌      | Fitting SlidingEstimator : 48/136 [00:00<00:00,  128.69it/s]
#
#
#
#
#
#  61%|██████    | Fitting SlidingEstimator : 83/136 [00:00<00:00,  132.52it/s]
#
#
#
#
#
#
#
#  12%|█▎        | Fitting SlidingEstimator : 17/136 [00:00<00:01,   94.89it/s]
#
#
#
#
#  88%|████████▊ | Fitting SlidingEstimator : 119/136 [00:00<00:00,  145.32it/s]
#
#
#
#
#
#
#  40%|████      | Fitting SlidingEstimator : 55/136 [00:00<00:00,  133.80it/s]
#
#
#
#
#
#
#
#
#   0%|          | Fitting SlidingEstimator : 0/136 [00:00<?,       ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  17%|█▋        | Fitting SlidingEstimator : 23/136 [00:00<00:01,  107.70it/s]
#
#
#
#
#  92%|█████████▏| Fitting SlidingEstimator : 125/136 [00:00<00:00,  146.83it/s]
#
#
#
#
#
#
#  45%|████▍     | Fitting SlidingEstimator : 61/136 [00:00<00:00,  137.86it/s]
#
#
#
#
#
#
#
#  22%|██▏       | Fitting SlidingEstimator : 30/136 [00:00<00:00,  118.78it/s]
#
#
#
#
#
#  71%|███████   | Fitting SlidingEstimator : 96/136 [00:00<00:00,  137.14it/s]
#
#
#
#
#  97%|█████████▋| Fitting SlidingEstimator : 132/136 [00:00<00:00,  150.15it/s]
#
#
#
#
# 100%|██████████| Fitting SlidingEstimator : 136/136 [00:00<00:00,  143.91it/s]
#
#
#
#
#
#
#
#  50%|█████     | Fitting SlidingEstimator : 68/136 [00:00<00:00,  140.82it/s]
#
#
#
#
#
#
#
#
#   1%|▏         | Fitting SlidingEstimator : 2/136 [00:00<00:05,   26.35it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  26%|██▋       | Fitting SlidingEstimator : 36/136 [00:00<00:00,  125.41it/s]
#
#
#
#
#
#
#  55%|█████▌    | Fitting SlidingEstimator : 75/136 [00:00<00:00,  146.09it/s]
#
#
#
#
#
#
#
#
#   7%|▋         | Fitting SlidingEstimator : 10/136 [00:00<00:01,   90.46it/s]
#
#
#
#
#
#  79%|███████▊  | Fitting SlidingEstimator : 107/136 [00:00<00:00,  139.20it/s]
#
#
#
#
#
#
#
#  32%|███▏      | Fitting SlidingEstimator : 43/136 [00:00<00:00,  131.92it/s]
#
#
#
#
#
#
#  59%|█████▉    | Fitting SlidingEstimator : 80/136 [00:00<00:00,  144.65it/s]
#
#
#
#
#
#
#
#
#  12%|█▎        | Fitting SlidingEstimator : 17/136 [00:00<00:01,  115.78it/s]
#
#
#
#
#
#  83%|████████▎ | Fitting SlidingEstimator : 113/136 [00:00<00:00,  140.91it/s]
#
#
#
#
#
#
#
#  35%|███▍      | Fitting SlidingEstimator : 47/136 [00:00<00:00,  129.30it/s]
#
#
#
#
#
#
#  65%|██████▍   | Fitting SlidingEstimator : 88/136 [00:00<00:00,  150.52it/s]
#
#
#
#
#
#
#
#
#  15%|█▌        | Fitting SlidingEstimator : 21/136 [00:00<00:00,  116.26it/s]
#
#
#
#
#
#  90%|████████▉ | Fitting SlidingEstimator : 122/136 [00:00<00:00,  148.16it/s]
#
#
#
#
#
#
#
#  42%|████▏     | Fitting SlidingEstimator : 57/136 [00:00<00:00,  139.08it/s]
#
#
#
#
#
#
#  68%|██████▊   | Fitting SlidingEstimator : 93/136 [00:00<00:00,  150.10it/s]
#
#
#
#
#
#
#
#
#  20%|█▉        | Fitting SlidingEstimator : 27/136 [00:00<00:00,  121.55it/s]
#
#
#
#
#
#  95%|█████████▍| Fitting SlidingEstimator : 129/136 [00:00<00:00,  151.03it/s]
#
#
#
#
#
#
#
#  44%|████▍     | Fitting SlidingEstimator : 60/136 [00:00<00:00,  132.73it/s]
#
#
#
#
#
#
#  71%|███████▏  | Fitting SlidingEstimator : 97/136 [00:00<00:00,  147.01it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  24%|██▍       | Fitting SlidingEstimator : 33/136 [00:00<00:00,  127.64it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| Fitting SlidingEstimator : 136/136 [00:00<00:00,  141.07it/s][A
#
#
#
#
#
#
#
#  77%|███████▋  | Fitting SlidingEstimator : 105/136 [00:00<00:00,  150.80it/s]
#
#
#
#
#
#
#
#
#  30%|███       | Fitting SlidingEstimator : 41/136 [00:00<00:00,  134.60it/s]
#
#
#
#
#
#
#
#  53%|█████▎    | Fitting SlidingEstimator : 72/136 [00:00<00:00,  138.72it/s]
#
#
#
#
#
#
#  83%|████████▎ | Fitting SlidingEstimator : 113/136 [00:00<00:00,  156.17it/s]
#
#
#
#
#
#
#
#
#  35%|███▌      | Fitting SlidingEstimator : 48/136 [00:00<00:00,  141.93it/s]
#
#
#
#
#
#
#
#  60%|█████▉    | Fitting SlidingEstimator : 81/136 [00:00<00:00,  146.83it/s]
#
#
#
#
#
#
#  87%|████████▋ | Fitting SlidingEstimator : 118/136 [00:00<00:00,  155.42it/s]
#
#
#
#
#
#
#
#
#  41%|████      | Fitting SlidingEstimator : 56/136 [00:00<00:00,  150.96it/s]
#
#
#
#
#
#
#  92%|█████████▏| Fitting SlidingEstimator : 125/136 [00:00<00:00,  158.76it/s]
#
#
#
#
#
#
#
#  65%|██████▌   | Fitting SlidingEstimator : 89/136 [00:00<00:00,  152.41it/s]
#
#
#
#
#
#
#
#
#  45%|████▍     | Fitting SlidingEstimator : 61/136 [00:00<00:00,  148.49it/s]
#
#
#
#
#
#
#  99%|█████████▊| Fitting SlidingEstimator : 134/136 [00:00<00:00,  165.81it/s]
#
#
#
#
#
#
#
# 100%|██████████| Fitting SlidingEstimator : 136/136 [00:00<00:00,  155.99it/s][A
#
#
#
#
#
#
#
#
#
#  51%|█████     | Fitting SlidingEstimator : 69/136 [00:00<00:00,  156.65it/s]
#
#
#
#
#
#
#
#  76%|███████▋  | Fitting SlidingEstimator : 104/136 [00:00<00:00,  159.37it/s]
#
#
#
#
#
#
#
#
#  58%|█████▊    | Fitting SlidingEstimator : 79/136 [00:00<00:00,  167.49it/s]
#
#
#
#
#
#
#
#  85%|████████▍ | Fitting SlidingEstimator : 115/136 [00:00<00:00,  169.30it/s]
#
#
#
#
#
#
#
#
#  63%|██████▎   | Fitting SlidingEstimator : 86/136 [00:00<00:00,  170.47it/s]
#
#
#
#
#
#
#
#  90%|█████████ | Fitting SlidingEstimator : 123/136 [00:00<00:00,  173.35it/s]
#
#
#
#
#
#
#
#
#  71%|███████▏  | Fitting SlidingEstimator : 97/136 [00:00<00:00,  181.76it/s]
#
#
#
#
#
#
#
# 100%|██████████| Fitting SlidingEstimator : 136/136 [00:00<00:00,  168.02it/s]
#
#
#
#
#
#
#
#
#
#  78%|███████▊  | Fitting SlidingEstimator : 106/136 [00:00<00:00,  188.18it/s]
#
#
#
#
#
#
#
#
#  88%|████████▊ | Fitting SlidingEstimator : 119/136 [00:00<00:00,  201.69it/s][Parallel(n_jobs=10)]: Done   6 out of  10 | elapsed:    3.9s remaining:    2.6s
#
#
#
#
#
#
#
#
#
# 100%|██████████| Fitting SlidingEstimator : 136/136 [00:00<00:00,  197.81it/s]
# [Parallel(n_jobs=10)]: Done  10 out of  10 | elapsed:    4.3s finished
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# Best time point post-250ms: 0.18500000000000005 seconds with score: 0.9045047412904555
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
# ...
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]

# %%
plt.plot(target_period[target_period.attention == 'exo'].time, target_period[target_period.attention == 'exo'].score)
plt.plot(target_period[target_period.attention == 'endo'].time, target_period[target_period.attention == 'endo'].score)

# %%
target_period.to_csv('files/B3_target_period.csv')

# %% [markdown]
# ## Training on the period after the ERP

# %%
# First plotting ERP for exogeneous attention, for eahc cued side
epochs["attention_type_block==0 & cued_side == 0"].copy().crop(tmin=-.1, tmax=.7).pick(relevant_electrodes).average().plot_joint(times=[.1,.15,.2,.3]);
epochs["attention_type_block==0 & cued_side == 1"].copy().crop(tmin=-.1, tmax=.7).pick(relevant_electrodes).average().plot_joint(times=[.1,.15,.2,.3]);
# Out:
# No projector specified for this dataset. Please consider the method self.add_proj.
# No projector specified for this dataset. Please consider the method self.add_proj.

# %%
# First plotting ERP for endogeneous attention, for eahc cued side
epochs["attention_type_block==1 & cued_side == 0"].copy().crop(tmin=-.1, tmax=.7).pick(relevant_electrodes).average().plot_joint(times=[.1,.15,.2,.3]);
epochs["attention_type_block==1 & cued_side == 1"].copy().crop(tmin=-.1, tmax=.7).pick(relevant_electrodes).average().plot_joint(times=[.1,.15,.2,.3]);
# Out:
# No projector specified for this dataset. Please consider the method self.add_proj.
# No projector specified for this dataset. Please consider the method self.add_proj.

# %%
# Extract all averaged ERPs for all relevant electrodes for cued_side and attention blocks
queries = ["attention_type_block==0 & cued_side == 0", "attention_type_block==0 & cued_side == 1", "attention_type_block==1 & cued_side == 0", "attention_type_block==1 & cued_side == 1"]
erp = {}
# Baseline for the ERP
tmin = -.1
for query in queries:
    erp[query] = epochs[query].copy().crop(tmin=tmin, tmax=.7).pick(relevant_electrodes).average().get_data()

# Export for group analysis
def pd_erp(erp_dic, attention, cued_side):
    erp = pd.DataFrame(erp_dic[f'attention_type_block=={attention} & cued_side == {cued_side}'])
    erp['channel'] = relevant_electrodes
    erp['attention'] = attention
    erp['cued_side'] = cued_side
    erp = erp.melt(id_vars=['channel','attention','cued_side'])
    erp['time'] = erp['variable']*(1/epochs.info['sfreq']) + tmin
    return erp

exo_left = pd_erp(erp, 0, 0)
exo_right = pd_erp(erp, 0, 1)
endo_left = pd_erp(erp, 1, 0)
endo_right = pd_erp(erp, 1, 1)

erp_B3 = pd.concat([exo_left, exo_right, endo_left, endo_right])
erp_B3.columns = ['channel', 'attention', 'cued_side', 'timepoint', 'erp', 'time']
erp_B3.to_csv('files/erp_B3.csv',index=False)

# %%
# Data preparation for training and prediction periods
tmin_training, tmax_training = .5, 1.1
# Take some time after training for plotting purposes 
tmin_prediction, tmax_prediction = -.2, .8
post_erp = pre_post_training(epochs, tmin_training, tmax_training, tmin_prediction, tmax_prediction)
# Out:
# /tmp/ipykernel_27774/132503421.py:11: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X = epochs_posttraining.copy().get_data()
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
#  24%|██▍       | Fitting SlidingEstimator : 29/121 [00:00<00:00,  281.52it/s]
#  34%|███▍      | Fitting SlidingEstimator : 41/121 [00:00<00:00,  291.98it/s]
#  40%|████      | Fitting SlidingEstimator : 49/121 [00:00<00:00,  280.16it/s][A
#  49%|████▉     | Fitting SlidingEstimator : 59/121 [00:00<00:00,  277.14it/s]
#
#   0%|          | Fitting SlidingEstimator : 0/121 [00:00<?,       ?it/s]
#  57%|█████▋    | Fitting SlidingEstimator : 69/121 [00:00<00:00,  276.10it/s]
#  65%|██████▌   | Fitting SlidingEstimator : 79/121 [00:00<00:00,  277.51it/s]
#
#   9%|▉         | Fitting SlidingEstimator : 11/121 [00:00<00:00,  155.10it/s]
#  71%|███████   | Fitting SlidingEstimator : 86/121 [00:00<00:00,  267.55it/s]
#
#  13%|█▎        | Fitting SlidingEstimator : 16/121 [00:00<00:00,  150.76it/s]
#  38%|███▊      | Fitting SlidingEstimator : 46/121 [00:00<00:00,  210.57it/s]
#
#
#  74%|███████▍  | Fitting SlidingEstimator : 90/121 [00:00<00:00,  248.04it/s]A
#
#  19%|█▉        | Fitting SlidingEstimator : 23/121 [00:00<00:00,  163.77it/s]
#  81%|████████  | Fitting SlidingEstimator : 98/121 [00:00<00:00,  245.52it/s]
#
#  25%|██▍       | Fitting SlidingEstimator : 30/121 [00:00<00:00,  172.26it/s]
#  49%|████▉     | Fitting SlidingEstimator : 59/121 [00:00<00:00,  205.73it/s]
#
#
#  87%|████████▋ | Fitting SlidingEstimator : 105/121 [00:00<00:00,  240.09it/s]A
#
#  31%|███       | Fitting SlidingEstimator : 37/121 [00:00<00:00,  176.85it/s]
#  55%|█████▌    | Fitting SlidingEstimator : 67/121 [00:00<00:00,  206.09it/s]
#
#
#  93%|█████████▎| Fitting SlidingEstimator : 112/121 [00:00<00:00,  236.83it/s]A
#
#  36%|███▋      | Fitting SlidingEstimator : 44/121 [00:00<00:00,  178.86it/s]
#  99%|█████████▉| Fitting SlidingEstimator : 120/121 [00:00<00:00,  236.87it/s]
#
#
# 100%|██████████| Fitting SlidingEstimator : 121/121 [00:00<00:00,  239.69it/s][A
#
#
#
#
#   0%|          | Fitting SlidingEstimator : 0/121 [00:00<?,       ?it/s]
#
#  42%|████▏     | Fitting SlidingEstimator : 51/121 [00:00<00:00,  175.07it/s]
#  67%|██████▋   | Fitting SlidingEstimator : 81/121 [00:00<00:00,  198.97it/s]
#
#
#  21%|██        | Fitting SlidingEstimator : 25/121 [00:00<00:00,  136.21it/s]
#
#  48%|████▊     | Fitting SlidingEstimator : 58/121 [00:00<00:00,  177.29it/s]
#  72%|███████▏  | Fitting SlidingEstimator : 87/121 [00:00<00:00,  194.17it/s]
#
#
#
#   3%|▎         | Fitting SlidingEstimator : 4/121 [00:00<00:02,   57.51it/s]
#
#  53%|█████▎    | Fitting SlidingEstimator : 64/121 [00:00<00:00,  176.20it/s]
#
#
#  26%|██▋       | Fitting SlidingEstimator : 32/121 [00:00<00:00,  142.08it/s]
#
#
#
#   8%|▊         | Fitting SlidingEstimator : 10/121 [00:00<00:01,   97.60it/s]
#  78%|███████▊  | Fitting SlidingEstimator : 94/121 [00:00<00:00,  192.91it/s]
#
#
#
#
#  57%|█████▋    | Fitting SlidingEstimator : 69/121 [00:00<00:00,  170.57it/s]
#  83%|████████▎ | Fitting SlidingEstimator : 100/121 [00:00<00:00,  190.89it/s]
#
#
#
#  13%|█▎        | Fitting SlidingEstimator : 16/121 [00:00<00:00,  116.16it/s]
#
#
#  36%|███▌      | Fitting SlidingEstimator : 43/121 [00:00<00:00,  145.76it/s]
#
#
#
#
#
#
#  63%|██████▎   | Fitting SlidingEstimator : 76/121 [00:00<00:00,  172.26it/s]A
#
#
#
#
#  18%|█▊        | Fitting SlidingEstimator : 22/121 [00:00<00:00,  129.19it/s]
#
#  66%|██████▌   | Fitting SlidingEstimator : 80/121 [00:00<00:00,  166.27it/s]
#
#
#  40%|███▉      | Fitting SlidingEstimator : 48/121 [00:00<00:00,  140.24it/s]
#
#
#
#  22%|██▏       | Fitting SlidingEstimator : 27/121 [00:00<00:00,  130.27it/s]
#  93%|█████████▎| Fitting SlidingEstimator : 112/121 [00:00<00:00,  185.45it/s]
#
#  73%|███████▎  | Fitting SlidingEstimator : 88/121 [00:00<00:00,  170.17it/s]
#
#
#  43%|████▎     | Fitting SlidingEstimator : 52/121 [00:00<00:00,  137.42it/s]
#
#
#
#
#   2%|▏         | Fitting SlidingEstimator : 3/121 [00:00<00:03,   37.72it/s]
#
#
#
#  26%|██▌       | Fitting SlidingEstimator : 31/121 [00:00<00:00,  126.94it/s]
#  99%|█████████▉| Fitting SlidingEstimator : 120/121 [00:00<00:00,  189.40it/s]
#
#  76%|███████▌  | Fitting SlidingEstimator : 92/121 [00:00<00:00,  164.99it/s]
#
#
#  48%|████▊     | Fitting SlidingEstimator : 58/121 [00:00<00:00,  139.82it/s]
# 100%|██████████| Fitting SlidingEstimator : 121/121 [00:00<00:00,  187.09it/s]
#
#
#
#
#
#  10%|▉         | Fitting SlidingEstimator : 12/121 [00:00<00:01,  104.45it/s]
#
#
#
#  32%|███▏      | Fitting SlidingEstimator : 39/121 [00:00<00:00,  139.40it/s]
#
#  80%|████████  | Fitting SlidingEstimator : 97/121 [00:00<00:00,  162.03it/s]
#
#
#  52%|█████▏    | Fitting SlidingEstimator : 63/121 [00:00<00:00,  140.61it/s]
#
#
#
#
#  12%|█▏        | Fitting SlidingEstimator : 15/121 [00:00<00:01,   97.53it/s]
#
#
#
#
#
#   0%|          | Fitting SlidingEstimator : 0/121 [00:00<?,       ?it/s]
#
#
#
#  35%|███▍      | Fitting SlidingEstimator : 42/121 [00:00<00:00,  132.63it/s]
#
#  83%|████████▎ | Fitting SlidingEstimator : 100/121 [00:00<00:00,  156.26it/s]
#
#
#  57%|█████▋    | Fitting SlidingEstimator : 69/121 [00:00<00:00,  142.14it/s]
#
#
#
#
#  18%|█▊        | Fitting SlidingEstimator : 22/121 [00:00<00:00,  111.95it/s]
#
#
#
#  40%|███▉      | Fitting SlidingEstimator : 48/121 [00:00<00:00,  133.51it/s]
#
#  89%|████████▉ | Fitting SlidingEstimator : 108/121 [00:00<00:00,  160.55it/s]
#
#
#  60%|█████▉    | Fitting SlidingEstimator : 72/121 [00:00<00:00,  136.85it/s]
#
#
#
#
#
#   3%|▎         | Fitting SlidingEstimator : 4/121 [00:00<00:02,   55.54it/s]
#
#
#
#
#  24%|██▍       | Fitting SlidingEstimator : 29/121 [00:00<00:00,  124.35it/s]
#
#
#
#  43%|████▎     | Fitting SlidingEstimator : 52/121 [00:00<00:00,  131.72it/s]
#
#  93%|█████████▎| Fitting SlidingEstimator : 112/121 [00:00<00:00,  156.15it/s]
#
#
#  62%|██████▏   | Fitting SlidingEstimator : 75/121 [00:00<00:00,  131.42it/s]
#
#
#
#
#
#   4%|▍         | Fitting SlidingEstimator : 5/121 [00:00<00:02,   44.88it/s]
#
#
#
#
#  26%|██▌       | Fitting SlidingEstimator : 31/121 [00:00<00:00,  113.97it/s]
#
#
#
#  45%|████▌     | Fitting SlidingEstimator : 55/121 [00:00<00:00,  125.01it/s]
#
#  98%|█████████▊| Fitting SlidingEstimator : 118/121 [00:00<00:00,  157.67it/s]
#
#
#  67%|██████▋   | Fitting SlidingEstimator : 81/121 [00:00<00:00,  134.39it/s]
#
#
#
#
#
#   8%|▊         | Fitting SlidingEstimator : 10/121 [00:00<00:01,   70.55it/s]
#
# 100%|██████████| Fitting SlidingEstimator : 121/121 [00:00<00:00,  160.76it/s]
#
#
#
#
#
#  31%|███▏      | Fitting SlidingEstimator : 38/121 [00:00<00:00,  121.47it/s]
#
#
#
#  50%|████▉     | Fitting SlidingEstimator : 60/121 [00:00<00:00,  126.51it/s]
#
#
#
#
#
#
#
#
#
#   0%|          | Fitting SlidingEstimator : 0/121 [000:00<00:00,  135.45it/s]0:00<?,       ?it/s]
#
#
#
#
#
#  13%|█▎        | Fitting SlidingEstimator : 16/121 [00:00<00:01,   87.59it/s]
#
#
#
#
#  36%|███▌      | Fitting SlidingEstimator : 43/121 [00:00<00:00,  120.85it/s]
#
#
#
#  54%|█████▎    | Fitting SlidingEstimator : 65/121 [00:00<00:00,  124.18it/s]
#
#
#  77%|███████▋  | Fitting SlidingEstimator : 93/121 [00:00<00:00,  137.19it/s]
#
#
#
#
#
#  17%|█▋        | Fitting SlidingEstimator : 20/121 [00:00<00:01,   92.25it/s]
#
#
#
#
#  40%|███▉      | Fitting SlidingEstimator : 48/121 [00:00<00:00,  123.31it/s]
#
#
#
#
#
#
#   2%|▏         | Fitting SlidingEstimator : 3/121 [00:00<00:02,   41.19it/s]
#
#
#
#  58%|█████▊    | Fitting SlidingEstimator : 70/121 [00:00<00:00,  126.00it/s]
#
#
#  80%|████████  | Fitting SlidingEstimator : 97/121 [00:00<00:00,  134.95it/s]
#
#
#
#
#
#  21%|██        | Fitting SlidingEstimator : 25/121 [00:00<00:00,  100.28it/s]
#
#
#
#
#  43%|████▎     | Fitting SlidingEstimator : 52/121 [00:00<00:00,  122.67it/s]
#
#
#
#
#
#
#   5%|▍         | Fitting SlidingEstimator : 6/121 [00:00<00:02,   55.94it/s]
#
#
#
#
#
#
#  83%|████████▎ | Fitting SlidingEstimator : 101/121 [00:00<00:00,  133.14it/s]
#
#
#
#
#
#  62%|██████▏   | Fitting SlidingEstimator : 75/121 [00:00<00:00,  124.86it/s]
#
#
#
#
#  45%|████▌     | Fitting SlidingEstimator : 55/121 [00:00<00:00,  119.00it/s]
#
#
#
#
#
#
#
#   0%|          | Fitting SlidingEstimator : 0/121 [00:00<?,       ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#  28%|██▊       | Fitting SlidingEstimator : 34/121 [00:00<00:00,  106.35it/s]
#
#
#
#
#
#
#  67%|██████▋   | Fitting SlidingEstimator : 81/121 [00:00<00:00,  124.98it/s]
#
#
#
#
#  50%|█████     | Fitting SlidingEstimator : 61/121 [00:00<00:00,  120.01it/s]
#
#
#  93%|█████████▎| Fitting SlidingEstimator : 113/121 [00:00<00:00,  134.84it/s]
#
#
#
#
#
#
#
#
#
#  69%|██████▉   | Fitting SlidingEstimator : 84/121 [00:00<00:00,  121.52it/s]
#
#
#
#
#
#
#  12%|█▏        | Fitting SlidingEstimator : 15/121 [00:00<00:01,   73.48it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#  54%|█████▎    | Fitting SlidingEstimator : 65/121 [00:00<00:00,  119.10it/s][A
#
#
#  98%|█████████▊| Fitting SlidingEstimator : 119/121 [00:00<00:00,  136.81it/s]
#
#
#
#
#
#  35%|███▍      | Fitting SlidingEstimator : 42/121 [00:00<00:00,  105.02it/s]
#
#
#
#  74%|███████▍  | Fitting SlidingEstimator : 90/121 [00:00<00:00,  123.94it/s]
#
#
#
#
#
#
# 100%|██████████| Fitting SlidingEstimator : 121/121 [00:00<00:00,  136.03it/s][A
#
#
#
#
#
#
#
#
#   4%|▍         | Fitting SlidingEstimator : 5/121 [00:00<00:02,   46.31it/s]
#
#
#
#
#  59%|█████▊    | Fitting SlidingEstimator : 71/121 [00:00<00:00,  120.71it/s]
#
#
#
#
#
#  39%|███▉      | Fitting SlidingEstimator : 47/121 [00:00<00:00,  109.06it/s]
#
#
#
#
#
#
#  21%|██        | Fitting SlidingEstimator : 25/121 [00:00<00:01,   90.89it/s]
#
#
#
#  78%|███████▊  | Fitting SlidingEstimator : 94/121 [00:00<00:00,  121.34it/s]
#
#
#
#
#
#
#
#   7%|▋         | Fitting SlidingEstimator : 9/121 [00:00<00:01,   58.34it/s]
#
#
#
#
#
#
#
#
#   0%|          | Fitting SlidingEstimator : 0/121 [00:00<?,       ?it/s]
#
#
#
#
#  61%|██████    | Fitting SlidingEstimator : 74/121 [00:00<00:00,  115.36it/s]
#
#
#
#
#
#  40%|████      | Fitting SlidingEstimator : 49/121 [00:00<00:00,  103.72it/s]
#
#
#
#  81%|████████  | Fitting SlidingEstimator : 98/121 [00:00<00:00,  119.24it/s]
#
#
#
#
#
#
#
#  12%|█▏        | Fitting SlidingEstimator : 14/121 [00:00<00:01,   73.18it/s]
#
#
#
#
#  64%|██████▍   | Fitting SlidingEstimator : 78/121 [00:00<00:00,  114.59it/s]
#
#
#
#
#
#
#
#
#   1%|          | Fitting SlidingEstimator : 1/121 [00:00<00:05,   23.93it/s]
#
#
#
#
#
#  45%|████▍     | Fitting SlidingEstimator : 54/121 [00:00<00:00,  106.23it/s]
#
#
#
#
#
#
#  30%|██▉       | Fitting SlidingEstimator : 36/121 [00:00<00:00,  104.05it/s]
#
#
#
#  83%|████████▎ | Fitting SlidingEstimator : 100/121 [00:00<00:00,  114.58it/s]
#
#
#
#
#
#
#
#  17%|█▋        | Fitting SlidingEstimator : 21/121 [00:00<00:01,   92.56it/s]
#
#
#
#
#  69%|██████▉   | Fitting SlidingEstimator : 84/121 [00:00<00:00,  118.25it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  46%|████▋     | Fitting SlidingEstimator : 56/121 [00:00<00:00,  100.87it/s][A
#
#
#
#
#
#
#  33%|███▎      | Fitting SlidingEstimator : 40/121 [00:00<00:00,  103.92it/s]
#
#
#
#  86%|████████▌ | Fitting SlidingEstimator : 104/121 [00:00<00:00,  114.81it/s]
#
#
#
#
#  74%|███████▎  | Fitting SlidingEstimator : 89/121 [00:00<00:00,  120.04it/s]
#
#
#
#
#
#
#
#  19%|█▉        | Fitting SlidingEstimator : 23/121 [00:00<00:01,   85.50it/s]
#
#
#
#
#
#
#
#
#   8%|▊         | Fitting SlidingEstimator : 10/121 [00:00<00:01,   85.85it/s]
#
#
#
#
#
#  52%|█████▏    | Fitting SlidingEstimator : 63/121 [00:00<00:00,  105.52it/s]
#
#
#
#  89%|████████▉ | Fitting SlidingEstimator : 108/121 [00:00<00:00,  111.84it/s]
#
#
#
#
#
#
#
#
#
#
#
#  38%|███▊      | Fitting SlidingEstimator : 46/121 [00:00<00:00,  105.33it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  12%|█▏        | Fitting SlidingEstimator : 14/121 [00:00<00:01,   92.60it/s]
#
#
#
#
#
#  55%|█████▌    | Fitting SlidingEstimator : 67/121 [00:00<00:00,  105.97it/s]
#
#
#
#  94%|█████████▍| Fitting SlidingEstimator : 114/121 [00:00<00:00,  115.76it/s]
#
#
#
#
#
#
#  40%|████      | Fitting SlidingEstimator : 49/121 [00:00<00:00,  102.21it/s]
#
#
#
#
#
#
#
#
#  16%|█▌        | Fitting SlidingEstimator : 19/121 [00:00<00:01,  100.21it/s]
#
#
#
#
#  82%|████████▏ | Fitting SlidingEstimator : 99/121 [00:00<00:00,  118.91it/s]
#
#
#
#
#
#  60%|██████    | Fitting SlidingEstimator : 73/121 [00:00<00:00,  111.25it/s]
#
#
#
#
#
#
#
#  27%|██▋       | Fitting SlidingEstimator : 33/121 [00:00<00:00,   93.66it/s]
#
#
#
#  98%|█████████▊| Fitting SlidingEstimator : 118/121 [00:00<00:00,  115.81it/s]
#
#
#
#
#
#
#  45%|████▌     | Fitting SlidingEstimator : 55/121 [00:00<00:00,  108.17it/s]
#
#
#
# 100%|██████████| Fitting SlidingEstimator : 121/121 [00:01<00:00,  119.24it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  86%|████████▌ | Fitting SlidingEstimator : 104/121 [00:00<00:00,  119.83it/s][A
#
#
#
#
#
#
#
#
#  21%|██▏       | Fitting SlidingEstimator : 26/121 [00:00<00:00,  111.37it/s]
#
#
#
#
#
#  64%|██████▍   | Fitting SlidingEstimator : 78/121 [00:00<00:00,  112.59it/s]
#
#
#
#
#
#
#  48%|████▊     | Fitting SlidingEstimator : 58/121 [00:00<00:00,  106.02it/s]
#
#
#
#
#
#
#
#  36%|███▌      | Fitting SlidingEstimator : 43/121 [00:00<00:00,  103.76it/s]
#
#
#
#
#  93%|█████████▎| Fitting SlidingEstimator : 112/121 [00:00<00:00,  126.09it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  67%|██████▋   | Fitting SlidingEstimator : 81/121 [00:00<00:00,  110.21it/s]
#
#
#
#
#
#
#  23%|██▎       | Fitting SlidingEstimator : 28/121 [00:00<00:00,  101.99it/s]
#
#
#
#
#  97%|█████████▋| Fitting SlidingEstimator : 117/121 [00:00<00:00,  126.95it/s][Parallel(n_jobs=10)]: Done   3 out of  10 | elapsed:    1.7s remaining:    4.1s
#
#
#
#
#
#
#
#
#  40%|███▉      | Fitting SlidingEstimator : 48/121 [00:00<00:00,  105.46it/s]
#
#
#
#
#
# 100%|██████████| Fitting SlidingEstimator : 121/121 [00:00<00:00,  125.66it/s][A
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  55%|█████▌    | Fitting SlidingEstimator : 67/121 [00:00<00:00,  107.91it/s]
#
#
#
#
#
#
#
#  45%|████▍     | Fitting SlidingEstimator : 54/121 [00:00<00:00,  110.03it/s]
#
#
#
#
#
#  76%|███████▌  | Fitting SlidingEstimator : 92/121 [00:00<00:00,  113.75it/s]
#
#
#
#
#
#
#
#
#  35%|███▍      | Fitting SlidingEstimator : 42/121 [00:00<00:00,  117.54it/s]
#
#
#
#
#
#
#  59%|█████▊    | Fitting SlidingEstimator : 71/121 [00:00<00:00,  106.13it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  49%|████▉     | Fitting SlidingEstimator : 59/121 [00:00<00:00,  113.04it/s]
#
#
#
#
#
#
#
#
#  42%|████▏     | Fitting SlidingEstimator : 51/121 [00:00<00:00,  131.50it/s]
#
#
#
#
#
#
#  65%|██████▌   | Fitting SlidingEstimator : 79/121 [00:00<00:00,  114.51it/s]
#
#
#
#
#
#  88%|████████▊ | Fitting SlidingEstimator : 106/121 [00:00<00:00,  123.36it/s]
#
#
#
#
#
#
#
#  53%|█████▎    | Fitting SlidingEstimator : 64/121 [00:00<00:00,  112.49it/s]
#
#
#
#
#
#
#
#
#  44%|████▍     | Fitting SlidingEstimator : 53/121 [00:00<00:00,  123.81it/s]
#
#
#
#
#
#
#  70%|███████   | Fitting SlidingEstimator : 85/121 [00:00<00:00,  117.25it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  93%|█████████▎| Fitting SlidingEstimator : 113/121 [00:00<00:00,  127.87it/s][A
#
#
#
#
#
#
#
#
#  50%|████▉     | Fitting SlidingEstimator : 60/121 [00:00<00:00,  129.69it/s]
#
#
#
#
#
#
#  76%|███████▌  | Fitting SlidingEstimator : 92/121 [00:00<00:00,  122.58it/s]
#
#
#
#
#
#  99%|█████████▉| Fitting SlidingEstimator : 120/121 [00:00<00:00,  132.68it/s]
#
#
#
#
#
#
#
# 100%|██████████| Fitting SlidingEstimator : 121/121 [00:00<00:00,  122.37it/s][A
#
#
#
#
#
#
#
#
#
#  55%|█████▍    | Fitting SlidingEstimator : 66/121 [00:00<00:00,  132.73it/s]
#
#
#
#
#
#
#  80%|████████  | Fitting SlidingEstimator : 97/121 [00:00<00:00,  123.52it/s]
#
#
#
#
#
#
#
#  68%|██████▊   | Fitting SlidingEstimator : 82/121 [00:00<00:00,  124.78it/s]
#
#
#
#
#
#
#
#
#  61%|██████    | Fitting SlidingEstimator : 74/121 [00:00<00:00,  139.89it/s]
#
#
#
#
#
#
#  88%|████████▊ | Fitting SlidingEstimator : 106/121 [00:00<00:00,  132.41it/s]
#
#
#
#
#
#
#
#  74%|███████▎  | Fitting SlidingEstimator : 89/121 [00:00<00:00,  127.12it/s]
#
#
#
#
#
#
#
#
#  68%|██████▊   | Fitting SlidingEstimator : 82/121 [00:00<00:00,  146.33it/s]
#
#
#
#
#
#
#  93%|█████████▎| Fitting SlidingEstimator : 113/121 [00:00<00:00,  136.93it/s]
#
#
#
#
#
#
#
#  80%|████████  | Fitting SlidingEstimator : 97/121 [00:00<00:00,  134.19it/s]
#
#
#
#
#
#
#
#
#  74%|███████▎  | Fitting SlidingEstimator : 89/121 [00:00<00:00,  150.86it/s]
#
#
#
#
#
#
# 100%|██████████| Fitting SlidingEstimator : 121/121 [00:00<00:00,  128.79it/s]
#
#
#
#
#
#
#
#
#  88%|████████▊ | Fitting SlidingEstimator : 107/121 [00:00<00:00,  144.36it/s]
#
#
#
#
#
#
#
#
#  81%|████████  | Fitting SlidingEstimator : 98/121 [00:00<00:00,  159.31it/s]
#
#
#
#
#
#
#
#  97%|█████████▋| Fitting SlidingEstimator : 117/121 [00:00<00:00,  153.45it/s]
#
#
#
#
#
#
#
#
# 100%|██████████| Fitting SlidingEstimator : 121/121 [00:00<00:00,  138.71it/s]
#
#
#
#
#
#
#
#
#
# 100%|██████████| Fitting SlidingEstimator : 121/121 [00:00<00:00,  161.00it/s]
# [Parallel(n_jobs=10)]: Done   6 out of  10 | elapsed:    2.2s remaining:    1.5s
# [Parallel(n_jobs=10)]: Done  10 out of  10 | elapsed:    2.5s finished
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# Best time point post-250ms: 0.655 seconds with score: 0.7193300350443208
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# ...
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]

# %%
plt.plot(post_erp[post_erp.attention == 'exo'].time, post_erp[post_erp.attention == 'exo'].score)
plt.plot(post_erp[post_erp.attention == 'endo'].time, post_erp[post_erp.attention == 'endo'].score)

# %%
post_erp.to_csv('files/B3_post_erp.csv')

# %% [markdown]
# ## Training on the end of the trial (control)

# %%
# Data preparation for training and prediction periods
tmin_training, tmax_training = 1.4, 2
# Take some time after training for plotting purposes 
tmin_prediction, tmax_prediction = -.2, .8
trial_end = pre_post_training(epochs, tmin_training, tmax_training, tmin_prediction, tmax_prediction)
# Out:
# /tmp/ipykernel_27774/132503421.py:7: RuntimeWarning: tmax is not in time interval. tmax is set to <class 'mne.epochs.EpochsFIF'>.tmax (1.995 s)
#   epochs_posttraining = epochs.copy().crop(tmin=tmin_training, tmax=tmax_training)
# /tmp/ipykernel_27774/132503421.py:11: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X = epochs_posttraining.copy().get_data()
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
#   2%|▏         | Fitting SlidingEstimator : 2/120 [00:00<00:02,   56.83it/s]
#  11%|█         | Fitting SlidingEstimator : 13/120 [00:00<00:00,  183.53it/s]
#  18%|█▊        | Fitting SlidingEstimator : 22/120 [00:00<00:00,  208.29it/s][A
#  30%|███       | Fitting SlidingEstimator : 36/120 [00:00<00:00,  249.13it/s]
#
#   0%|          | Fitting SlidingEstimator : 0/120 [00:00<?,       ?it/s]
#  38%|███▊      | Fitting SlidingEstimator : 45/120 [00:00<00:00,  245.74it/s]
#  29%|██▉       | Fitting SlidingEstimator : 35/120 [00:00<00:00,  233.83it/s]
#
#   8%|▊         | Fitting SlidingEstimator : 10/120 [00:00<00:00,  141.15it/s]
#
#
#   0%|          | Fitting SlidingEstimator : 0/120 [00:00<?,       ?it/s]
#
#  16%|█▌        | Fitting SlidingEstimator : 19/120 [00:00<00:00,  181.15it/s]
#  57%|█████▋    | Fitting SlidingEstimator : 68/120 [00:00<00:00,  234.62it/s]
#  42%|████▏     | Fitting SlidingEstimator : 50/120 [00:00<00:00,  225.67it/s]
#
#  22%|██▏       | Fitting SlidingEstimator : 26/120 [00:00<00:00,  182.21it/s]
#
#
#   4%|▍         | Fitting SlidingEstimator : 5/120 [00:00<00:01,   70.44it/s]
#  62%|██████▎   | Fitting SlidingEstimator : 75/120 [00:00<00:00,  227.20it/s]
#
#  28%|██▊       | Fitting SlidingEstimator : 34/120 [00:00<00:00,  189.00it/s]
#
#
#   8%|▊         | Fitting SlidingEstimator : 10/120 [00:00<00:01,   94.96it/s]
#  51%|█████     | Fitting SlidingEstimator : 61/120 [00:00<00:00,  206.79it/s]
#
#  32%|███▏      | Fitting SlidingEstimator : 38/120 [00:00<00:00,  173.46it/s]
#
#
#
#   0%|          | Fitting SlidingEstimator : 0/120 [00:00<?,       ?it/s]
#
#
#  13%|█▎        | Fitting SlidingEstimator : 16/120 [00:00<00:00,  114.70it/s]
#  56%|█████▌    | Fitting SlidingEstimator : 67/120 [00:00<00:00,  200.43it/s]
#
#  39%|███▉      | Fitting SlidingEstimator : 47/120 [00:00<00:00,  183.40it/s]
#
#
#
#  78%|███████▊  | Fitting SlidingEstimator : 93/120 [00:00<00:00,  211.91it/s][A
#
#
#  18%|█▊        | Fitting SlidingEstimator : 22/120 [00:00<00:00,  125.23it/s]
#  60%|██████    | Fitting SlidingEstimator : 72/120 [00:00<00:00,  194.36it/s]
#
#  42%|████▏     | Fitting SlidingEstimator : 50/120 [00:00<00:00,  168.91it/s]
#
#
#
#   2%|▎         | Fitting SlidingEstimator : 3/120 [00:00<00:02,   42.12it/s]
#  81%|████████  | Fitting SlidingEstimator : 97/120 [00:00<00:00,  200.48it/s]
#
#
#  24%|██▍       | Fitting SlidingEstimator : 29/120 [00:00<00:00,  131.79it/s]
#
#  47%|████▋     | Fitting SlidingEstimator : 56/120 [00:00<00:00,  170.01it/s]
#
#
#
#  86%|████████▌ | Fitting SlidingEstimator : 103/120 [00:00<00:00,  197.64it/s][A
#  70%|███████   | Fitting SlidingEstimator : 84/120 [00:00<00:00,  184.43it/s]
#
#
#  28%|██▊       | Fitting SlidingEstimator : 33/120 [00:00<00:00,  127.35it/s]
#
#
#
#
#   0%|          | Fitting SlidingEstimator : 0/120 [00:00<?,       ?it/s]
#
#  49%|████▉     | Fitting SlidingEstimator : 59/120 [00:00<00:00,  157.89it/s]
#
#
#
#  91%|█████████ | Fitting SlidingEstimator : 109/120 [00:00<00:00,  193.98it/s][A
#  76%|███████▌  | Fitting SlidingEstimator : 91/120 [00:00<00:00,  184.72it/s]
#
#
#  32%|███▎      | Fitting SlidingEstimator : 39/120 [00:00<00:00,  132.91it/s]
#
#  55%|█████▌    | Fitting SlidingEstimator : 66/120 [00:00<00:00,  156.51it/s]
#
#
#
#  96%|█████████▌| Fitting SlidingEstimator : 115/120 [00:00<00:00,  192.55it/s][A
#  78%|███████▊  | Fitting SlidingEstimator : 94/120 [00:00<00:00,  175.87it/s]
#
#
#
#
#
#
#
#  37%|███▋      | Fitting SlidingEstimator : 44/120 [00:00<00:00,  131.81it/s][A
#
#  59%|█████▉    | Fitting SlidingEstimator : 71/120 [00:00<00:00,  155.13it/s]
#
#
#
# 100%|██████████| Fitting SlidingEstimator : 120/120 [00:00<00:00,  194.12it/s][A
#
#  83%|████████▎ | Fitting SlidingEstimator : 100/120 [00:00<00:00,  173.83it/s]
#
#
#
#
#   6%|▌         | Fitting SlidingEstimator : 7/120 [00:00<00:01,   65.28it/s]
#
#
#  40%|████      | Fitting SlidingEstimator : 48/120 [00:00<00:00,  128.61it/s]
#
#  62%|██████▎   | Fitting SlidingEstimator : 75/120 [00:00<00:00,  150.65it/s]
#
#
#
#  23%|██▎       | Fitting SlidingEstimator : 28/120 [00:00<00:00,  105.87it/s]
#
#
#
#
#
#   0%|          | Fitting SlidingEstimator : 0/120 [00:00<?,       ?it/s]
#  87%|████████▋ | Fitting SlidingEstimator : 104/120 [00:00<00:00,  168.46it/s]
#
#
#  45%|████▌     | Fitting SlidingEstimator : 54/120 [00:00<00:00,  131.52it/s]
#
#
#
#
#   9%|▉         | Fitting SlidingEstimator : 11/120 [00:00<00:01,   72.39it/s]
#
#  68%|██████▊   | Fitting SlidingEstimator : 81/120 [00:00<00:00,  151.61it/s]
#
#
#
#
#  22%|█████████▏| Fitting SlidingEstimator : 110/120 [00:00<00:00,  167.71it/s]9%|██▉       | Fitting SlidingEstimator : 35/120 [00:00<00:00,  113.52it/s]
#
#
#  48%|████▊     | Fitting SlidingEstimator : 58/120 [00:00<00:00,  130.21it/s]
#
#
#
#
#  12%|█▎        | Fitting SlidingEstimator : 15/120 [00:00<00:01,   80.44it/s]
#
#  71%|███████   | Fitting SlidingEstimator : 85/120 [00:00<00:00,  146.11it/s]
#  96%|█████████▌| Fitting SlidingEstimator : 115/120 [00:00<00:00,  165.29it/s]
#
#
#
#  34%|███▍      | Fitting SlidingEstimator : 41/120 [00:00<00:00,  116.96it/s]
#
#
#  53%|█████▎    | Fitting SlidingEstimator : 64/120 [00:00<00:00,  133.24it/s]
#
#
#
#
#  18%|█▊        | Fitting SlidingEstimator : 22/120 [00:00<00:00,  101.28it/s]
#
#  74%|███████▍  | Fitting SlidingEstimator : 89/120 [00:00<00:00,  143.27it/s]
#
#
#
#
#
#   3%|▎         | Fitting SlidingEstimator : 4/120 [00:00<00:03,   35.98it/s]
# 100%|██████████| Fitting SlidingEstimator : 120/120 [00:00<00:00,  171.38it/s]
#
#
#
#  54%|█████▍    | Fitting SlidingEstimator : 65/120 [00:00<00:00,  123.94it/s]
#
#
#
#
#  19%|█▉        | Fitting SlidingEstimator : 23/120 [00:00<00:01,   89.58it/s]
#
#
#
#  38%|███▊      | Fitting SlidingEstimator : 46/120 [00:00<00:00,  115.44it/s]
#
#  76%|███████▌  | Fitting SlidingEstimator : 91/120 [00:00<00:00,  135.94it/s]
#
#
#
#
#
#   7%|▋         | Fitting SlidingEstimator : 8/120 [00:00<00:02,   55.06it/s]
#
#
#
#
#
#
#   0%|          | Fitting SlidingEstimator : 0/120 [00:00<?,       ?it/s]
#
#
#  58%|█████▊    | Fitting SlidingEstimator : 70/120 [00:00<00:00,  123.23it/s]
#
#
#
#
#  24%|██▍       | Fitting SlidingEstimator : 29/120 [00:00<00:00,   98.31it/s]
#
#
#
#  42%|████▏     | Fitting SlidingEstimator : 50/120 [00:00<00:00,  114.80it/s]
#
#  82%|████████▏ | Fitting SlidingEstimator : 98/120 [00:00<00:00,  140.44it/s]
#
#
#
#
#
#   8%|▊         | Fitting SlidingEstimator : 10/120 [00:00<00:02,   51.54it/s]
#
#
#
#  45%|████▌     | Fitting SlidingEstimator : 54/120 [00:00<00:00,  114.19it/s]
#
#
#
#
#  26%|██▌       | Fitting SlidingEstimator : 31/120 [00:00<00:00,   91.93it/s]
#
#
#  63%|██████▎   | Fitting SlidingEstimator : 76/120 [00:00<00:00,  120.71it/s]
#
#
#
#
#
#
#   2%|▏         | Fitting SlidingEstimator : 2/120 [00:00<00:04,   23.75it/s]
#
#  88%|████████▊ | Fitting SlidingEstimator : 105/120 [00:00<00:00,  136.69it/s]
#
#
#
#
#
#
#
#
#  28%|██▊       | Fitting SlidingEstimator : 33/120 [00:00<00:00,   87.41it/s]
#
#
#
#
#
#
#
#
#  16%|█▌        | Fitting SlidingEstimator : 19/120 [00:00<00:01,   76.19it/s]
#
#
#
#
#
#
#
#
#  91%|█████████ | Fitting SlidingEstimator : 109/120 [00:00<00:00,  135.31it/s]A
#
#
#
#
#
#
#
#
#
#
#  68%|██████▊   | Fitting SlidingEstimator : 82/120 [00:00<00:00,  114.39it/s]A
#
#
#
#
#
#  18%|█▊        | Fitting SlidingEstimator : 22/120 [00:00<00:01,   75.01it/s]
#
#
#
#
#  33%|███▎      | Fitting SlidingEstimator : 40/120 [00:00<00:00,   93.28it/s]
#
#
#
#
#
#
#   8%|▊         | Fitting SlidingEstimator : 9/120 [00:00<00:01,   58.46it/s]
#
#  96%|█████████▌| Fitting SlidingEstimator : 115/120 [00:00<00:00,  137.28it/s]
#
#
#
#  51%|█████     | Fitting SlidingEstimator : 61/120 [00:00<00:00,   98.68it/s]
#
#
#  73%|███████▎  | Fitting SlidingEstimator : 88/120 [00:00<00:00,  118.80it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#  20%|██        | Fitting SlidingEstimator : 24/120 [00:00<00:01,   72.75it/s]
#
#
#
#
#   8%|▊         | Fitting SlidingEstimator : 10/120 [00:00<00:02,   52.83it/s]
#
# 100%|██████████| Fitting SlidingEstimator : 120/120 [00:00<00:00,  141.40it/s]
#
#
#
#
#
#
#
#
#
#
#  27%|██▋       | Fitting SlidingEstimator : 32/120 [00:00<00:00,   88.02it/s]
#
#
#
#
#
#
#  12%|█▎        | Fitting SlidingEstimator : 15/120 [00:00<00:01,   66.51it/s]
#
#
#
#
#  41%|████      | Fitting SlidingEstimator : 49/120 [00:00<00:00,   97.36it/s]
#
#
#
#
#
#
#
#  56%|█████▌    | Fitting SlidingEstimator : 67/120 [00:00<00:00,  101.52it/s]
#
#
#  78%|███████▊  | Fitting SlidingEstimator : 94/120 [00:00<00:00,  117.73it/s]
#
#
#
#
#
#  28%|██▊       | Fitting SlidingEstimator : 34/120 [00:00<00:01,   84.44it/s]
#
#
#
#
#
#
#
#
#
#  16%|█▌        | Fitting SlidingEstimator : 19/120 [00:00<00:01,   70.74it/s]
#
#
#
#  61%|██████    | Fitting SlidingEstimator : 73/120 [00:00<00:00,  103.70it/s]
#
#
#
#
#  45%|████▌     | Fitting SlidingEstimator : 54/120 [00:00<00:00,   95.77it/s]
#
#
#
#
#
#
#
#   3%|▎         | Fitting SlidingEstimator : 4/120 [00:00<00:04,   27.61it/s]
#
#
#
#
#
#  29%|██▉       | Fitting SlidingEstimator : 35/120 [00:00<00:01,   78.63it/s]
#
#
#
#
#
#
#  81%|████████  | Fitting SlidingEstimator : 97/120 [00:00<00:00,  107.91it/s]
#
#
#
#
#
#
#  18%|█▊        | Fitting SlidingEstimator : 22/120 [00:00<00:01,   71.24it/s]
#
#
#
#
#
#
#
#
#   0%|          | Fitting SlidingEstimator : 0/120 [00:00<?,       ?it/s]
#
#
#
#
#  47%|████▋     | Fitting SlidingEstimator : 56/120 [00:00<00:00,   91.61it/s]
#
#
#
#
#
#
#
#   7%|▋         | Fitting SlidingEstimator : 8/120 [00:00<00:02,   44.48it/s]
#
#
#
#
#
#  33%|███▎      | Fitting SlidingEstimator : 40/120 [00:00<00:00,   83.93it/s]
#
#
#  86%|████████▌ | Fitting SlidingEstimator : 103/120 [00:00<00:00,  112.00it/s]
#
#
#
#  68%|██████▊   | Fitting SlidingEstimator : 82/120 [00:00<00:00,  106.82it/s]
#
#
#
#
#
#
#  24%|██▍       | Fitting SlidingEstimator : 29/120 [00:00<00:01,   83.74it/s]
#
#
#
#
#
#  35%|███▌      | Fitting SlidingEstimator : 42/120 [00:00<00:00,   81.80it/s]
#
#
#
#
#
#
#
#   9%|▉         | Fitting SlidingEstimator : 11/120 [00:00<00:02,   49.58it/s]
#
#
#  90%|█████████ | Fitting SlidingEstimator : 108/120 [00:00<00:00,  114.18it/s]
#
#
#
#
#  50%|█████     | Fitting SlidingEstimator : 60/120 [00:00<00:00,   90.62it/s]
#
#
#
#
#
#
#
#
#   2%|▎         | Fitting SlidingEstimator : 3/120 [00:00<00:02,   43.43it/s]
#
#
#
#
#
#
#
#
#
#
#  72%|███████▏  | Fitting SlidingEstimator : 86/120 [00:00<00:00,  104.76it/s]
#
#
#  96%|█████████▌| Fitting SlidingEstimator : 115/120 [00:00<00:00,  119.64it/s]
#
#
#
#
#  53%|█████▎    | Fitting SlidingEstimator : 64/120 [00:00<00:00,   92.56it/s]
#
#
#
#
#
#
#
#  12%|█▏        | Fitting SlidingEstimator : 14/120 [00:00<00:01,   53.79it/s]
#
#
#
#
#
#  39%|███▉      | Fitting SlidingEstimator : 47/120 [00:00<00:00,   85.14it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#   5%|▌         | Fitting SlidingEstimator : 6/120 [00:00<00:02,   56.82it/s]
#
#
#
#
#
#
#  28%|██▊       | Fitting SlidingEstimator : 34/120 [00:00<00:01,   80.63it/s]
#
#
#  98%|█████████▊| Fitting SlidingEstimator : 118/120 [00:00<00:00,  117.78it/s]
#
#
#
#
#  57%|█████▋    | Fitting SlidingEstimator : 68/120 [00:00<00:00,   93.60it/s]
#
#
#
#
#
#
#
# 100%|██████████| Fitting SlidingEstimator : 120/120 [00:01<00:00,  119.39it/s][A
#
#
#
#
#
#
#  42%|████▎     | Fitting SlidingEstimator : 51/120 [00:00<00:00,   86.09it/s]
#
#
#
#
#
#
#
#
#
#
#  78%|███████▊  | Fitting SlidingEstimator : 94/120 [00:00<00:00,  104.72it/s]
#
#
#
#
#
#
#
#
#  32%|███▎      | Fitting SlidingEstimator : 39/120 [00:00<00:00,   86.44it/s][A
#
#
#
#
#  62%|██████▏   | Fitting SlidingEstimator : 74/120 [00:00<00:00,   98.83it/s]
#
#
#
#
#
#
#
#  18%|█▊        | Fitting SlidingEstimator : 22/120 [00:00<00:01,   67.68it/s]
#
#
#
#
#
#  46%|████▌     | Fitting SlidingEstimator : 55/120 [00:00<00:00,   86.87it/s]
#
#
#
#
#
#
#  36%|███▌      | Fitting SlidingEstimator : 43/120 [00:00<00:00,   87.95it/s]
#
#
#
#
#
#
#
#
#  12%|█▏        | Fitting SlidingEstimator : 14/120 [00:00<00:01,   74.70it/s]
#
#
#
#  82%|████████▎ | Fitting SlidingEstimator : 99/120 [00:00<00:00,  104.60it/s]
#
#
#
#
#  65%|██████▌   | Fitting SlidingEstimator : 78/120 [00:00<00:00,   99.30it/s]
#
#
#
#
#
#
#
#  23%|██▎       | Fitting SlidingEstimator : 28/120 [00:00<00:01,   75.52it/s]
#
#
#
#
#
#  48%|████▊     | Fitting SlidingEstimator : 58/120 [00:00<00:00,   85.44it/s]
#
#
#
#
#
#
#
#
#  13%|█▎        | Fitting SlidingEstimator : 16/120 [00:00<00:01,   70.28it/s]
#
#
#
#  87%|████████▋ | Fitting SlidingEstimator : 104/120 [00:00<00:00,  107.05it/s]
#
#
#
#
#
#
#  41%|████      | Fitting SlidingEstimator : 49/120 [00:00<00:00,   90.90it/s]
#
#
#
#
#  67%|██████▋   | Fitting SlidingEstimator : 80/120 [00:00<00:00,   95.64it/s]
#
#
#
#
#
#
#
#  28%|██▊       | Fitting SlidingEstimator : 34/120 [00:00<00:01,   83.47it/s]
#
#
#
#  89%|████████▉ | Fitting SlidingEstimator : 107/120 [00:01<00:00,  105.85it/s]
#
#
#
#
#
#
#
#
#  19%|█▉        | Fitting SlidingEstimator : 23/120 [00:00<00:01,   89.17it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#  44%|████▍     | Fitting SlidingEstimator : 53/120 [00:00<00:00,   93.04it/s]
#
#
#
#
#  55%|█████▌    | Fitting SlidingEstimator : 66/120 [00:00<00:00,   94.47it/s]
#
#
#
#  94%|█████████▍| Fitting SlidingEstimator : 113/120 [00:01<00:00,  109.88it/s]
#
#
#
#
#
#
#
#  29%|██▉       | Fitting SlidingEstimator : 35/120 [00:00<00:01,   77.45it/s]
#
#
#
#
#
#
#
#
#  22%|██▏       | Fitting SlidingEstimator : 26/120 [00:00<00:01,   89.08it/s]
#
#
#
#
#  75%|███████▌  | Fitting SlidingEstimator : 90/120 [00:00<00:00,  101.62it/s]
#
#
#
#
#
#
#  49%|████▉     | Fitting SlidingEstimator : 59/120 [00:00<00:00,   96.60it/s]
#
#
#
#  99%|█████████▉| Fitting SlidingEstimator : 119/120 [00:01<00:00,  113.67it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  33%|███▎      | Fitting SlidingEstimator : 40/120 [00:00<00:00,   82.47it/s]
#
#
#
#
#
#
#
#
#  60%|██████    | Fitting SlidingEstimator : 72/120 [00:00<00:00,   92.45it/s]
#
#
#
#
#  78%|███████▊  | Fitting SlidingEstimator : 94/120 [00:00<00:00,  101.32it/s]
#
#
#
# 100%|██████████| Fitting SlidingEstimator : 120/120 [00:01<00:00,  108.82it/s]
#
#
#
#
#
#
#
#  53%|█████▎    | Fitting SlidingEstimator : 64/120 [00:00<00:00,   98.79it/s]
#
#
#
#
#
#
#
#
#  30%|███       | Fitting SlidingEstimator : 36/120 [00:00<00:00,   99.88it/s]
#
#
#
#
#
#
#
#  38%|███▊      | Fitting SlidingEstimator : 46/120 [00:00<00:00,   89.70it/s]
#
#
#
#
#
#  65%|██████▌   | Fitting SlidingEstimator : 78/120 [00:00<00:00,   94.91it/s]
#
#
#
#
#  84%|████████▍ | Fitting SlidingEstimator : 101/120 [00:00<00:00,  106.75it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  33%|███▎      | Fitting SlidingEstimator : 40/120 [00:00<00:00,  101.33it/s]
#
#
#
#
#
#
#
#  42%|████▎     | Fitting SlidingEstimator : 51/120 [00:00<00:00,   91.83it/s]
#
#
#
#
#
#  68%|██████▊   | Fitting SlidingEstimator : 81/120 [00:00<00:00,   93.59it/s]
#
#
#
#
#  57%|█████▋    | Fitting SlidingEstimator : 68/120 [00:00<00:00,  100.11it/s]
#
#
#
#
#
#
#
#
#  38%|███▊      | Fitting SlidingEstimator : 45/120 [00:00<00:00,  104.50it/s]
#
#
#
#
#
#
#
#  48%|████▊     | Fitting SlidingEstimator : 57/120 [00:00<00:00,   97.02it/s]
#
#
#
#
#
#  72%|███████▏  | Fitting SlidingEstimator : 86/120 [00:00<00:00,   96.55it/s]
#
#
#
#
#  92%|█████████▏| Fitting SlidingEstimator : 110/120 [00:01<00:00,  108.10it/s]
#
#
#
#
#
#
#  64%|██████▍   | Fitting SlidingEstimator : 77/120 [00:00<00:00,  103.12it/s]
#
#
#
#
#
#
#
#
#  40%|████      | Fitting SlidingEstimator : 48/120 [00:00<00:00,  103.02it/s]
#
#
#
#
#
#  76%|███████▌  | Fitting SlidingEstimator : 91/120 [00:00<00:00,   99.25it/s]
#
#
#
#
#  98%|█████████▊| Fitting SlidingEstimator : 117/120 [00:01<00:00,  113.57it/s]
#
#
#
#
#
#
#
#  52%|█████▏    | Fitting SlidingEstimator : 62/120 [00:00<00:00,   99.15it/s]
#
#
#
#
#
#
#  67%|██████▋   | Fitting SlidingEstimator : 80/120 [00:00<00:00,  102.18it/s]
#
#
#
#
#
#
#
#
#  45%|████▌     | Fitting SlidingEstimator : 54/120 [00:00<00:00,  109.28it/s]
#
#
#
#
# 100%|██████████| Fitting SlidingEstimator : 120/120 [00:01<00:00,  106.55it/s]
# [Parallel(n_jobs=10)]: Done   3 out of  10 | elapsed:    1.8s remaining:    4.1s
#
#
#
#
#
#
#  81%|████████  | Fitting SlidingEstimator : 97/120 [00:01<00:00,  103.45it/s]
#
#
#
#
#
#
#
#  56%|█████▌    | Fitting SlidingEstimator : 67/120 [00:00<00:00,  101.58it/s]
#
#
#
#
#
#
#  74%|███████▍  | Fitting SlidingEstimator : 89/120 [00:00<00:00,  110.66it/s]
#
#
#
#
#
#
#
#
#  48%|████▊     | Fitting SlidingEstimator : 57/120 [00:00<00:00,  107.17it/s]
#
#
#
#
#
#  86%|████████▌ | Fitting SlidingEstimator : 103/120 [00:01<00:00,  107.12it/s]
#
#
#
#
#
#
#
#  59%|█████▉    | Fitting SlidingEstimator : 71/120 [00:00<00:00,  101.60it/s]
#
#
#
#
#
#
#  77%|███████▋  | Fitting SlidingEstimator : 92/120 [00:00<00:00,  109.23it/s]
#
#
#
#
#
#
#
#
#  53%|█████▎    | Fitting SlidingEstimator : 64/120 [00:00<00:00,  114.53it/s]
#
#
#
#
#
#  89%|████████▉ | Fitting SlidingEstimator : 107/120 [00:01<00:00,  106.94it/s]
#
#
#
#
#
#
#
#  64%|██████▍   | Fitting SlidingEstimator : 77/120 [00:00<00:00,  106.61it/s]
#
#
#
#
#
#
#  84%|████████▍ | Fitting SlidingEstimator : 101/120 [00:00<00:00,  118.08it/s]
#
#
#
#
#
#
#
#
#  57%|█████▊    | Fitting SlidingEstimator : 69/120 [00:00<00:00,  116.00it/s]
#
#
#
#
#
#  94%|█████████▍| Fitting SlidingEstimator : 113/120 [00:01<00:00,  110.51it/s]
#
#
#
#
#
#
#  88%|████████▊ | Fitting SlidingEstimator : 105/120 [00:00<00:00,  117.97it/s]
#
#
#
#
#
#
#
#  70%|███████   | Fitting SlidingEstimator : 84/120 [00:00<00:00,  110.91it/s]
#
#
#
#
#
#
#
#
#  63%|██████▎   | Fitting SlidingEstimator : 76/120 [00:00<00:00,  122.35it/s]
#
#
#
#
#
# 100%|██████████| Fitting SlidingEstimator : 120/120 [00:01<00:00,  104.11it/s]
#
#
#
#
#
#
#
#  95%|█████████▌| Fitting SlidingEstimator : 114/120 [00:01<00:00,  126.54it/s]
#
#
#
#
#
#
#
#  76%|███████▌  | Fitting SlidingEstimator : 91/120 [00:00<00:00,  116.63it/s]
#
#
#
#
#
#
#
#
#  68%|██████▊   | Fitting SlidingEstimator : 81/120 [00:00<00:00,  124.21it/s]
#
#
#
#
#
#
#  99%|█████████▉| Fitting SlidingEstimator : 119/120 [00:01<00:00,  127.57it/s]
#
#
#
#
#
#
#
# 100%|██████████| Fitting SlidingEstimator : 120/120 [00:01<00:00,  113.45it/s][A
#
#
#
#
#
#
#
#
#
#  75%|███████▌  | Fitting SlidingEstimator : 90/120 [00:00<00:00,  133.33it/s]
#
#
#
#
#
#
#
#  88%|████████▊ | Fitting SlidingEstimator : 105/120 [00:00<00:00,  126.75it/s]
#
#
#
#
#
#
#
#
#  81%|████████  | Fitting SlidingEstimator : 97/120 [00:00<00:00,  137.45it/s]
#
#
#
#
#
#
#
#  94%|█████████▍| Fitting SlidingEstimator : 113/120 [00:00<00:00,  133.01it/s]
#
#
#
#
#
#
#
#
#  89%|████████▉ | Fitting SlidingEstimator : 107/120 [00:00<00:00,  146.86it/s]
#
#
#
#
#
#
#
# 100%|██████████| Fitting SlidingEstimator : 120/120 [00:00<00:00,  120.33it/s]
#
#
#
#
#
#
#
#
#
# 100%|██████████| Fitting SlidingEstimator : 120/120 [00:00<00:00,  139.66it/s]
# [Parallel(n_jobs=10)]: Done   6 out of  10 | elapsed:    2.2s remaining:    1.5s
# [Parallel(n_jobs=10)]: Done  10 out of  10 | elapsed:    2.4s finished
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# Best time point post-250ms: 1.88 seconds with score: 0.5876298701298701
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# ...
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:41: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_27774/132503421.py:42: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pretraining_endo = endo.get_data()[:, :, t]

# %%
plt.plot(trial_end[trial_end.attention == 'exo'].time, trial_end[trial_end.attention == 'exo'].score)
plt.plot(trial_end[trial_end.attention == 'endo'].time, trial_end[trial_end.attention == 'endo'].score)

# %%
trial_end.to_csv('files/B3_trial_end.csv')
