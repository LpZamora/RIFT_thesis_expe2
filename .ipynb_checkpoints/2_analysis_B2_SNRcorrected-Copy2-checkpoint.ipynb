# %%
data_path = '/home/lea/Documents/obsidian_notes/masterADS/ads_thesis_RIFT/my_code_expe2'
data_file = '/data/B2/data.mat'
epoch_file = '/data/B2/preprocessing/B2_EEG_epo.fif'

relevant_electrodes = ['O2','PO4','PO8','P8','P4','P6','P2','P1','P3','P5','P7','PO7','PO3','O1','Pz','POz','Oz','Iz']

# Dic to index trial_info matrix
info_colnames = {'reaction_times':0,'reaction_err':1, 'answer':2,'base_delay':3,\
                      'target_timings':4, 'flicker_sides':5, 'cued_side':6, 'orients_L':7, 'orients_R':8,\
                      'angle_magnitude':9, 'probe_sides':10, 'targets_binary':12, 'attention_type_block':13,\
                      'trial_num_my_rec':14}
info_colnumtonames = {v: k for k, v in info_colnames.items()}

# %%
import scipy.io as sio
import scipy
import numpy as np
import pandas as pd
import mne
from mne.time_frequency import EpochsTFRArray
import matplotlib.pyplot as plt
import copy
from collections import Counter
from frequency_tagging_funs import snr_spectrum, frequency_rescaling

from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from mne.decoding import (
    CSP,
    GeneralizingEstimator,
    LinearModel,
    Scaler,
    SlidingEstimator,
    Vectorizer,
    cross_val_multiscore,
    get_coef,
)

f = sio.loadmat(f'{data_path}{data_file}')

# Create pd df to pass to mne metadata
pd_info = {}
for i, column in enumerate(f['data'][0][0]):
    if i in info_colnames.values():
        # Remove practice trials
        column = column[4:,:]
        # Collapse to trial indexes
        original_shape = column.shape
        new_shape = (original_shape[0] * original_shape[1],) + original_shape[2:]
        column = np.reshape(column, new_shape)
        pd_info[info_colnumtonames[i]] = column
pd_info = pd.DataFrame(pd_info, columns=info_colnames.keys())
pd_info 

# Load eeg epochs .fif and add metadata
epochs = mne.read_epochs(f'{data_path}{epoch_file}')
epoch_good = [x for x,y in enumerate(epochs.drop_log) if len(y) == 0]
epochs.metadata = pd_info.iloc[epoch_good]
# Out:
# Reading /home/lea/Documents/obsidian_notes/masterADS/ads_thesis_RIFT/my_code_expe2/data/B2/preprocessing/B2_EEG_epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 555 matching events found
# No baseline correction applied
# 0 projection items activated
# Adding metadata with 14 columns

# %%
# Keep only posterior electrodes
epochs.pick_channels(relevant_electrodes)
# Out:
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# <EpochsFIF |  555 events (all good), -1 – 2 s, baseline -1 – 0 s, ~468.4 MB, data loaded, with metadata,
#  '3': 555>

# %%
# Keep only trials where there was no target
epochs = epochs['targets_binary==0']

# %% [markdown]
# # A. Endogeneous condition
# ## 1 FFT & SNR

# %%
# Simplify metadata
epochs.metadata['flicker_sides'] = epochs.metadata['flicker_sides'].replace({0: 6064, 1: 6460})
epochs.metadata['cued_side'] = epochs.metadata['cued_side'].replace({0: 'left', 1: 'right'})

condition_1 = ((epochs.metadata['flicker_sides'] == 6064.0) & (epochs.metadata['cued_side'] == 'left')) | \
    ((epochs.metadata['flicker_sides'] == 6460.0) & (epochs.metadata['cued_side'] == 'right'))
condition_2 = ((epochs.metadata['flicker_sides'] == 6064.0) & (epochs.metadata['cued_side'] == 'right')) | \
    ((epochs.metadata['flicker_sides'] == 6460.0) & (epochs.metadata['cued_side'] == 'left'))
epochs.metadata['cued_tag'] = np.where(condition_1, 60, np.where(condition_2, 64, np.nan))
epochs_endo = epochs['attention_type_block==1'].copy()
epochs_exo = epochs['attention_type_block==0'].copy()

# %%
# Fast Fourier Transform
# adapted from https://mne.tools/dev/auto_tutorials/time-freq/50_ssvep.html

sfreq = epochs.info["sfreq"]
tmin = 0 # Search in window starting from cue (when SSVEP is expected)
tmax = 2
fmin = 1.0
fmax = 90

# Spectrum of the signal averaged over trials
spectrum_endo = epochs_endo.copy().average().compute_psd(
    "welch",
    n_fft=int(sfreq * (tmax - tmin)),
    n_overlap=0,
    n_per_seg=None,
    tmin=tmin,
    tmax=tmax,
    fmin=fmin,
    fmax=fmax,
    window="hamming",
    verbose=False,
)
psds_endo, freqs_psd = spectrum_endo.get_data(return_freqs=True)
spectrum_exo = epochs_exo.copy().average().compute_psd(
    "welch",
    n_fft=int(sfreq * (tmax - tmin)),
    n_overlap=0,
    n_per_seg=None,
    tmin=tmin,
    tmax=tmax,
    fmin=fmin,
    fmax=fmax,
    window="hamming",
    verbose=False,
)
psds_exo, freqs_psd = spectrum_exo.get_data(return_freqs=True)


# Get bins to exlude from regularization (close neighbors ±0.5Hz)  
bin_size = np.diff(freqs_psd)[0]
skip_nei = int((0.5 - bin_size/2)//bin_size) 

# Get bins to include in regularization (neighbors within +/- 2-0.5Hz)
used_nei = int((2 - bin_size/2) // bin_size)  # Total bins within ±2 Hz
used_nei = used_nei - skip_nei # Bins within (0.5 Hz, 2 Hz]

snrs_endo = snr_spectrum(psds_endo, noise_n_neighbor_freqs=used_nei, noise_skip_neighbor_freqs = skip_nei)
snrs_exo = snr_spectrum(psds_exo, noise_n_neighbor_freqs=used_nei, noise_skip_neighbor_freqs = skip_nei)

fig, axes = plt.subplots(2, 2, sharex="all", sharey="none", figsize=(8, 5))
freq_range = range(
    np.where(np.floor(freqs_psd) == 1.0)[0][0], np.where(np.ceil(freqs_psd) == fmax - 1)[0][0]
)

psds_plot = 10 * np.log10(psds_endo)
psds_mean = psds_plot.mean(axis=(0))[freq_range]
psds_std = psds_plot.std(axis=(0))[freq_range]
axes[0,0].plot(freqs_psd[freq_range], psds_mean, color="b")
axes[0,0].fill_between(
    freqs_psd[freq_range], psds_mean - psds_std, psds_mean + psds_std, color="b", alpha=0.2
)
axes[0,0].set(title="PSD spectrum endogeneous", ylabel="Power Spectral Density [dB]")
psds_plot = 10 * np.log10(psds_exo)
psds_mean = psds_plot.mean(axis=(0))[freq_range]
psds_std = psds_plot.std(axis=(0))[freq_range]
axes[0,1].plot(freqs_psd[freq_range], psds_mean, color="b")
axes[0,1].fill_between(
    freqs_psd[freq_range], psds_mean - psds_std, psds_mean + psds_std, color="b", alpha=0.2
)
axes[0,1].set(title="PSD spectrum exogeneous", ylabel="Power Spectral Density [dB]")

# SNR spectrum
snr_mean = snrs_endo.mean(axis=(0))[freq_range]
snr_std = snrs_endo.std(axis=(0))[freq_range]

axes[1,0].plot(freqs_psd[freq_range], snr_mean, color="r")
axes[1,0].fill_between(
    freqs_psd[freq_range], snr_mean - snr_std, snr_mean + snr_std, color="r", alpha=0.2
)
axes[1,0].set(
    title="SNR spectrum endogeneous",
    xlabel="Frequency [Hz]",
    ylabel="SNR",
    ylim=[-2, 15],
    xlim=[fmin, fmax],
)
snr_mean = snrs_exo.mean(axis=(0))[freq_range]
snr_std = snrs_exo.std(axis=(0))[freq_range]

axes[1,1].plot(freqs_psd[freq_range], snr_mean, color="r")
axes[1,1].fill_between(
    freqs_psd[freq_range], snr_mean - snr_std, snr_mean + snr_std, color="r", alpha=0.2
)
axes[1,1].set(
    title="SNR spectrum exogeneous",
    xlabel="Frequency [Hz]",
    ylabel="SNR",
    ylim=[-2, 15],
    xlim=[fmin, fmax],
)
plt.tight_layout()
fig.show()

# Extract SNR values at the stimulation frequency
stim_freq1 = 60
stim_freq2 = 64

# find index of frequency bin closest to stimulation frequency
i_bin_1 = np.argmin(abs(freqs_psd - stim_freq1))
i_bin_2 = np.argmin(abs(freqs_psd - stim_freq2))

# Apply the subset
snrs_target1_endo = snrs_endo[:, i_bin_1]
snrs_target2_endo = snrs_endo[:, i_bin_2]
print(f'SNR at {stim_freq1}Hz in endogenous condition: {snrs_target1_endo.mean()}')
print(f'SNR at {stim_freq2}Hz in endogenous: {snrs_target2_endo.mean()}')
snrs_target1_exo = snrs_exo[:, i_bin_1]
snrs_target2_exo = snrs_exo[:, i_bin_2]
print(f'SNR at {stim_freq1}Hz in exogenous condition: {snrs_target1_exo.mean()}')
print(f'SNR at {stim_freq2}Hz in exogenous: {snrs_target2_exo.mean()}')
# Out:
# /tmp/ipykernel_57947/4082944448.py:102: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# SNR at 60Hz in endogenous condition: 12.137198530518289
# SNR at 64Hz in endogenous: 11.59807696123856
# SNR at 60Hz in exogenous condition: 12.732660582804835
# SNR at 64Hz in exogenous: 11.800482148536705

# %% [markdown]
# ## 1.2 Topography of the SNR

# %%
# plot SNR topography
fig, ax = plt.subplots(2,2)
mne.viz.plot_topomap(snrs_target1_endo, epochs.info, vlim=(1, None), axes=ax[0,0], show=False, extrapolate='local')
mne.viz.plot_topomap(snrs_target2_endo, epochs.info, vlim=(1, None), axes=ax[0,1], show=False, extrapolate='local')
mne.viz.plot_topomap(snrs_target1_exo, epochs.info, vlim=(1, None), axes=ax[1,0], show=False, extrapolate='local')
mne.viz.plot_topomap(snrs_target2_exo, epochs.info, vlim=(1, None), axes=ax[1,1], show=False, extrapolate='local')
ax[0,0].set_title('Endogeneous 60Hz')
ax[0,1].set_title('Exogeneous 60H')
ax[1,0].set_title('Endogeneous 64Hz')
ax[1,1].set_title('Exogeneous 64H')
plt.show()

# Channels with the highest SNR 
print(f'Channels with highest SNR for 60Hz endo {np.array(epochs.info['ch_names'])[np.argsort(snrs_target1_endo)[::-1]][:6]}')
print(f'Channels with highest SNR for 64Hz endo{np.array(epochs.info['ch_names'])[np.argsort(snrs_target2_endo)[::-1]][:6]}')
print(f'Channels with highest SNR for 60Hz exo {np.array(epochs.info['ch_names'])[np.argsort(snrs_target1_exo)[::-1]][:6]}')
print(f'Channels with highest SNR for 64Hz exo {np.array(epochs.info['ch_names'])[np.argsort(snrs_target2_exo)[::-1]][:6]}')
#select electrodes from 60 as the top electrodes are parietal and occipital
SNR_best_electrodes_60_endo = np.array(epochs.info['ch_names'])[np.argsort(snrs_target1_endo)[::-1]][:6]
SNR_best_electrodes_64_endo = np.array(epochs.info['ch_names'])[np.argsort(snrs_target2_endo)[::-1]][:6]
SNR_best_electrodes_60_exo = np.array(epochs.info['ch_names'])[np.argsort(snrs_target1_exo)[::-1]][:6]
SNR_best_electrodes_64_exo = np.array(epochs.info['ch_names'])[np.argsort(snrs_target2_exo)[::-1]][:6]
# Out:
# Channels with highest SNR for 60Hz endo ['PO4' 'P1' 'POz' 'P4' 'Pz' 'O1']
# Channels with highest SNR for 64Hz endo['POz' 'P1' 'PO8' 'P2' 'P4' 'O2']
# Channels with highest SNR for 60Hz exo ['P2' 'POz' 'P4' 'Oz' 'P1' 'O1']
# Channels with highest SNR for 64Hz exo ['P2' 'POz' 'PO4' 'Pz' 'P1' 'O2']

# %% [markdown]
# ## 1.3 Time frequency analysis of coherence by electrode
# Coherence is studied in the time window between trial start and onset of the stimuli (the post stimuli window is likely contaminated by attentional catching due to their onset).

# %%
# # time window from -1 sec to 1 sec relative to cue
# tmin, tmax = -1, 1
# # Define range of frequencies of interest
# freqs = np.arange(55, 75, step = 0.5)

# %% [markdown]
# ### Magnitude squared coherence with Hilbert transform

# %%
# def coherence_kabir(signalX, pick, freq_of_interest):

#     #get info from EEG
#     min_time = signalX.times[0]
#     max_time = signalX.times[-1]
#     sampling_rate = signalX.info['sfreq']
    
#     # Band-pass EEG (+/-1.9Hz) and apply hilbert
#     signalX = signalX.copy().pick(pick).filter(l_freq=freq_of_interest - 1.9, h_freq=freq_of_interest + 1.9,
#         method='iir', iir_params=dict(order=4, ftype='butter'), phase='zero', fir_window='hamming', verbose = False)
#     #filter(l_freq = freq_of_interest - 1.9, h_freq = freq_of_interest + 1.9, verbose=True)
    
#     signalX = np.squeeze(signalX.get_data(copy=False)).T
#     signalXh =  scipy.signal.hilbert(signalX, axis=1)
#     n = signalXh.shape[1]  # number of trials

#     #Create sine wave
#     t = np.linspace(min_time, max_time, int(sampling_rate * (np.abs(min_time) + max_time))+1, endpoint=False)
#     signalY = np.sin(2 * np.pi * freq_of_interest * t)
#     signalY = np.tile(signalY, (n,1)).T #repeat over trials
#     # Hilbert transform
#     signalYh = scipy.signal.hilbert(signalY.T, axis=1)

#     # Magnitude
#     mX = np.abs(signalXh).T
#     mY = np.abs(signalYh)

#     # Phase difference
#     phase_diff = np.angle(signalXh).T - np.angle(signalYh)

#     coh = np.zeros(signalY.shape[0])
#     for t in range(signalY.shape[0]):
#         num = ((np.abs(np.sum(mX[:, t] * mY[:, t] * np.exp(1j * phase_diff[:, t])) / n)) ** 2)
#         denom = (np.sum((mX[:, t]**2) * (mY[:, t]**2)) / n)
#         coh[t] = num/denom
        
#     return coh

# # time window from -1 sec to 1 sec relative to cue
# tmin, tmax = -1, 1
# # Define range of frequencies of interest
# freqs = np.arange(55, 75, step = 0.5)

# channels = epochs_endo.info['ch_names']

# epochs_endo_cropped = epochs_endo.copy().crop(tmin, tmax)

# coherence_mat = np.zeros((len(channels), freqs.size, len(epochs_endo_cropped.times)))

# for e, channel in enumerate(channels):
#     for i, freq in enumerate(freqs):
#         coherence_mat[e,i,:] = coherence_kabir(epochs_endo_cropped, [channel], freq)

# coherence_hilbert = mne.time_frequency.EpochsTFRArray(epochs_endo_cropped.info, np.array([coherence_mat]), epochs_endo_cropped.times, freqs)

# # Baseline (-1 to 0s) correction
# coherence_hilbert = coherence_hilbert.apply_baseline(baseline=(tmin, 0))

# fig, axes = plt.subplots(3, 6, figsize=(18, 6))  
# axes = axes.flatten() 

# # Plot each channel
# for e, (channel, ax) in enumerate(zip(channels, axes)):
#     coherence_hilbert.plot(
#         picks=[channel],
#         baseline= None,
#         axes=ax,
#         colorbar=False,
#         show=False 
#     )
#     ax.set_title(channel)  

# plt.tight_layout()
# plt.show()



# # Channels with the highest coherence with the cued frequency
# print(f'From best to 5th \nChannels with the highest coherence with 60:{np.array(epochs.info['ch_names'])[np.argsort(np.squeeze(coherence_mat[:,np.where(freqs == 60),:].max(axis = -1)))[::-1]][:6]} \
#                         \nChannels with the highest coherence with 64:{np.array(epochs.info['ch_names'])[np.argsort(np.squeeze(coherence_mat[:,np.where(freqs == 64),:].max(axis = -1)))[::-1]][:6]}')
# best_electrodes_coherence_60 = np.array(epochs.info['ch_names'])[np.argsort(np.squeeze(coherence_mat[:,np.where(freqs == 60),:].max(axis = -1)))[::-1]][:6]
# best_electrodes_coherence_64 = np.array(epochs.info['ch_names'])[np.argsort(np.squeeze(coherence_mat[:,np.where(freqs == 64),:].max(axis = -1)))[::-1]][:6]

# %% [markdown]
# ### Inter-trial coherence with stockwell estimation

# %%
# n_cylce: trade-off temporal vs frequency resolution (is how many cycles of the frequency to include in the Gaussian envelope). 
# Frequency resolution is emphasized.

# time window from -1 sec to 1 sec relative to cue
tmin, tmax = -1, 1
# Define range of frequencies of interest
freqs = np.arange(55, 75, step = 0.5)

_, itc_endo = epochs_endo.copy().crop(tmin, tmax).compute_tfr(
    method="morlet", freqs=freqs, n_cycles=freqs/2,return_itc=True, average=True
)
_, itc_exo = epochs_exo.copy().crop(tmin, tmax).compute_tfr(
    method="morlet", freqs=freqs, n_cycles=freqs/2,return_itc=True, average=True
)

# Baseline (-1 to 0s) correction
itc_endo = itc_endo.apply_baseline(baseline=(tmin, 0))
itc_exo = itc_exo.apply_baseline(baseline=(tmin, 0))

fig, axes = plt.subplots(3, 6, figsize=(18, 9), sharey = True) 
axes = axes.flatten() 

channels = epochs.info['ch_names']

# Plot each electrode
for e, (channel, ax) in enumerate(zip(channels, axes)):
    itc_endo.plot(
        picks=[channel],
        baseline=None,
        vlim=(-.4, .4),
        axes=ax,
        colorbar=False,
        show=False 
    )
    ax.set_title(channel) 
    ax.axhline(y=60, color='r', linestyle='--', linewidth=1)
    ax.axhline(y=64, color='r', linestyle='--', linewidth=1)
    
plt.tight_layout()
plt.show()
fig, axes = plt.subplots(3, 6, figsize=(18, 9), sharey = True) 
axes = axes.flatten() 

channels = epochs.info['ch_names']

# Plot each electrode
for e, (channel, ax) in enumerate(zip(channels, axes)):
    itc_exo.plot(
        picks=[channel],
        baseline=None,
        vlim=(-.4, .4),
        axes=ax,
        colorbar=False,
        show=False 
    )
    ax.set_title(channel) 
    ax.axhline(y=60, color='r', linestyle='--', linewidth=1)
    ax.axhline(y=64, color='r', linestyle='--', linewidth=1)
    
plt.tight_layout()
plt.show()
# Out:
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:   20.7s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:   20.5s
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied

# %%
# Check whether the expected frequencies are indeed the highest
itc_arr, frex_idx = itc_endo.get_data(return_freqs=True)
print(f'Frequencies in endogeneous with the maximum coherence in descending order : {frex_idx[itc_arr.mean(axis=(0,2)).argsort()[::-1]][:4]}')
print(f'From best to 6th \nChannels with the highest coherence with 64 in endo:{np.array(epochs.info['ch_names'])[np.argsort(np.squeeze(itc_arr[:,np.where(frex_idx==60),:].max(axis = -1)))[::-1]][:6]} \
                        \nChannels with the highest coherence with 60 in endo:{np.array(epochs.info['ch_names'])[np.argsort(np.squeeze(itc_arr[:,np.where(frex_idx==64),:].max(axis = -1)))[::-1]][:6]}')
best_electrodes_coherence_stockwell_60_endo = np.array(epochs.info['ch_names'])[np.argsort(np.squeeze(itc_arr[:,np.where(frex_idx==60),:].max(axis = -1)))[::-1]][:6]
best_electrodes_coherence_stockwell_64_endo = np.array(epochs.info['ch_names'])[np.argsort(np.squeeze(itc_arr[:,np.where(frex_idx==64),:].max(axis = -1)))[::-1]][:6]

itc_arr, frex_idx = itc_exo.get_data(return_freqs=True)
print(f'Frequencies in exogeneous with the maximum coherence in descending order : {frex_idx[itc_arr.mean(axis=(0,2)).argsort()[::-1]][:4]}')
print(f'From best to 6th \nChannels with the highest coherence with 64 in exo:{np.array(epochs.info['ch_names'])[np.argsort(np.squeeze(itc_arr[:,np.where(frex_idx==60),:].max(axis = -1)))[::-1]][:6]} \
                        \nChannels with the highest coherence with 60 in enxxo:{np.array(epochs.info['ch_names'])[np.argsort(np.squeeze(itc_arr[:,np.where(frex_idx==64),:].max(axis = -1)))[::-1]][:6]}')
best_electrodes_coherence_stockwell_60_exo = np.array(epochs.info['ch_names'])[np.argsort(np.squeeze(itc_arr[:,np.where(frex_idx==60),:].max(axis = -1)))[::-1]][:6]
best_electrodes_coherence_stockwell_64_exo = np.array(epochs.info['ch_names'])[np.argsort(np.squeeze(itc_arr[:,np.where(frex_idx==64),:].max(axis = -1)))[::-1]][:6]
# Out:
# Frequencies in endogeneous with the maximum coherence in descending order : [60.  60.5 59.5 64. ]
# From best to 6th
# Channels with the highest coherence with 64 in endo:['POz' 'P2' 'PO4' 'P1' 'Pz' 'PO3']
# Channels with the highest coherence with 60 in endo:['POz' 'PO3' 'Pz' 'P1' 'O1' 'PO4']
# Frequencies in exogeneous with the maximum coherence in descending order : [63.5 60.  59.5 64. ]
# From best to 6th
# Channels with the highest coherence with 64 in exo:['POz' 'Pz' 'P1' 'PO3' 'PO4' 'P2']
# Channels with the highest coherence with 60 in enxxo:['POz' 'PO4' 'O1' 'PO3' 'Pz' 'P2']

# %% [markdown]
# ## 1.4 Select electrodes based on previous analysis

# %%
print(f'Top 6 electrodes for SNR 60 endo {SNR_best_electrodes_60_endo}')
print(f'Top 6 electrodes for SNR 64 endo {SNR_best_electrodes_64_endo}')
print(f'Top 6 electrodes for SNR 60 exo {SNR_best_electrodes_60_exo}')
print(f'Top 6 electrodes for SNR 64 exo {SNR_best_electrodes_64_exo}')
# print(f'Top 6 electrodes for Coherence 60 {best_electrodes_coherence_60}')
# print(f'Top 6 electrodes for Coherence 64 {best_electrodes_coherence_64}')
print(f'Top 6 electrodes for ITC stockwell 60 endo {best_electrodes_coherence_stockwell_60_endo}')
print(f'Top 6 electrodes for ITC stockwell 64 endo {best_electrodes_coherence_stockwell_64_endo}')

print(f'Top 6 electrodes for ITC stockwell 60 exo {best_electrodes_coherence_stockwell_60_exo}')
print(f'Top 6 electrodes for ITC stockwell 64 exo {best_electrodes_coherence_stockwell_64_exo}')
# Out:
# Top 6 electrodes for SNR 60 endo ['PO4' 'P1' 'POz' 'P4' 'Pz' 'O1']
# Top 6 electrodes for SNR 64 endo ['POz' 'P1' 'PO8' 'P2' 'P4' 'O2']
# Top 6 electrodes for SNR 60 exo ['P2' 'POz' 'P4' 'Oz' 'P1' 'O1']
# Top 6 electrodes for SNR 64 exo ['P2' 'POz' 'PO4' 'Pz' 'P1' 'O2']
# Top 6 electrodes for ITC stockwell 60 endo ['POz' 'P2' 'PO4' 'P1' 'Pz' 'PO3']
# Top 6 electrodes for ITC stockwell 64 endo ['POz' 'PO3' 'Pz' 'P1' 'O1' 'PO4']
# Top 6 electrodes for ITC stockwell 60 exo ['POz' 'Pz' 'P1' 'PO3' 'PO4' 'P2']
# Top 6 electrodes for ITC stockwell 64 exo ['POz' 'PO4' 'O1' 'PO3' 'Pz' 'P2']

# %%
# Select top 6 electrodes that are the most often the best according to SNR, IT coherence and MS coherence
all_electrodes = (list(SNR_best_electrodes_60_endo) + 
                  list(SNR_best_electrodes_64_endo) + 
                  list(SNR_best_electrodes_60_exo) + 
                  list(SNR_best_electrodes_64_exo) + 
                  # list(best_electrodes_coherence_60) + 
                  # list(best_electrodes_coherence_64) + 
                  list(best_electrodes_coherence_stockwell_60_endo) + 
                  list(best_electrodes_coherence_stockwell_64_endo) + 
                  list(best_electrodes_coherence_stockwell_60_exo) + 
                  list(best_electrodes_coherence_stockwell_64_exo))

# Count the occurrences of each electrode
electrode_counts = Counter(all_electrodes)

best_electrodes = [electrode for electrode, count in electrode_counts.most_common(6)]

print(f'selected electrodes: {best_electrodes}')
# Out:
# selected electrodes: ['POz', 'P1', 'PO4', 'Pz', 'P2', 'O1']

# %% [markdown]
# # 2 - Testing for an attentional effect
# ### Comparing SNR across cued conditions

# %%
queries = ["cued_tag == 60 & attention_type_block==0", "cued_tag == 64 & attention_type_block==0",
          "cued_tag == 60 & attention_type_block==1", "cued_tag == 64 & attention_type_block==1"]
vals = {}
stim_freq1 = 60
stim_freq2 = 64

sfreq = epochs_endo.info['sfreq']
tmin = 0 # Search in window starting from cue (when SSVEP is expected)
tmax = 2
fmin = 1.0
fmax = 90.0

for query in queries:
    # Spectrum averaged over all trials
    spectrum = epochs[query].copy().pick(best_electrodes).compute_psd(
        "welch",
        n_fft=int(sfreq * (tmax - tmin)),
        n_overlap=0,
        n_per_seg=None,
        tmin=tmin,
        tmax=tmax,
        fmin=fmin,
        fmax=fmax,
        window="hamming",
        verbose=False,
    )
    psds, freqs_psd = spectrum.get_data(return_freqs=True)

    # find index of frequency bin closest to stimulation frequency
    i_bin_1 = np.argmin(abs(freqs_psd - stim_freq1))
    i_bin_2 = np.argmin(abs(freqs_psd - stim_freq2))
    
    # Apply the subset
    vals[str(int(stim_freq1))+query] = copy.deepcopy(np.mean(psds,axis=0)[:, i_bin_1])
    vals[str(int(stim_freq2))+query] = copy.deepcopy(np.mean(psds,axis=0)[:, i_bin_2])

# %%
fig, ax = plt.subplots(2,2, figsize=(7,6), sharex=True, sharey=True)
for e, elec in enumerate(best_electrodes):
    ax[0,0].plot([0,1], [vals['60cued_tag == 64 & attention_type_block==0'][e], vals['60cued_tag == 60 & attention_type_block==0'][e]], 'o-', label=elec)
    ax[1,0].plot([0,1], [vals['64cued_tag == 60 & attention_type_block==0'][e], vals['64cued_tag == 64 & attention_type_block==0'][e]], 'o-', label=elec)
    ax[0,1].plot([0,1], [vals['60cued_tag == 64 & attention_type_block==1'][e], vals['60cued_tag == 60 & attention_type_block==1'][e]], 'o-', label=elec)
    ax[1,1].plot([0,1], [vals['64cued_tag == 60 & attention_type_block==1'][e], vals['64cued_tag == 64 & attention_type_block==1'][e]], 'o-', label=elec)

ax[0,0].set_title('PSD at 60Hz endogeneous')
ax[0,1].set_title('PSD at 60Hz exogeneous')
ax[1,0].set_title('PSD at 64Hz endogeneous')
ax[1,1].set_title('PSD at 64Hz exogeneous')
ax[0,0].set_ylabel('PSD at 60Hz')
ax[1,0].set_ylabel('PSD at 64Hz')
ax[1,0].set_xticks([0,1], ['Not cued', 'Cued'])
ax[1,1].set_xticks([0,1], ['Not cued', 'Cued'])
ax[1,1].set_xlim(-.5, 1.5)
plt.legend(bbox_to_anchor=(1,1))
plt.tight_layout()
plt.show()

# %%
# Normalize the frequency amplitudes as in Adamian & Andersen, 2024
npsd56 = frequency_rescaling(np.vstack([vals['60cued_tag == 60 & attention_type_block==0'],\
                                        vals['60cued_tag == 64 & attention_type_block==0'],
                                        vals['60cued_tag == 60 & attention_type_block==1'],
                                        vals['60cued_tag == 64 & attention_type_block==1'],]).T)
npsd60 = frequency_rescaling(np.vstack([vals['64cued_tag == 64 & attention_type_block==0'],\
                                        vals['64cued_tag == 60 & attention_type_block==0'],
                                        vals['64cued_tag == 64 & attention_type_block==1'],
                                        vals['64cued_tag == 60 & attention_type_block==1'],]).T)
npsds = np.concatenate([npsd56,npsd60])

# Average over electrodes
# npsds = npsds.mean(axis=0)
# np.save('files/B2_normalizes_psds.npy', npsds)

# %% [markdown]
# ### Comparing inter-trial coherence across cued conditions

# %%
# time window from -1 sec to 1 sec relative to cue
tmin, tmax = -1, 1

# Get inter-trial coherence with 60 and 64Hz by cued frequency 
freqs6064 = np.array([60, 64])
_, itc_64_endo = epochs_endo['cued_tag == 64'].copy().crop(tmin, tmax).compute_tfr(
    method="morlet", freqs=freqs6064, n_cycles=freqs6064/2,return_itc=True, average=True
)

_, itc_60_endo = epochs_endo['cued_tag == 60'].copy().crop(tmin, tmax).compute_tfr(
    method="morlet", freqs=freqs6064, n_cycles=freqs6064/2,return_itc=True, average=True
)
_, itc_64_exo = epochs_exo['cued_tag == 64'].copy().crop(tmin, tmax).compute_tfr(
    method="morlet", freqs=freqs6064, n_cycles=freqs6064/2,return_itc=True, average=True
)

_, itc_60_exo = epochs_exo['cued_tag == 60'].copy().crop(tmin, tmax).compute_tfr(
    method="morlet", freqs=freqs6064, n_cycles=freqs6064/2,return_itc=True, average=True
)

elec_idx = np.where(np.isin(epochs.info['ch_names'], best_electrodes))[0]

coherence = {}
itc_64_arr, times_coh, freqs_idx = itc_64_endo.get_data(return_freqs = True, return_times = True)
itc_60_arr = itc_60_endo.get_data()
coherence['with64_for64cued_endo'] = itc_64_arr[elec_idx,1,:]
coherence['with60_for64cued_endo'] = itc_64_arr[elec_idx,0,:]
coherence['with64_for60cued_endo'] = itc_60_arr[elec_idx,1,:]
coherence['with60_for60cued_endo'] = itc_60_arr[elec_idx,0,:]
itc_64_arr, times_coh, freqs_idx = itc_64_exo.get_data(return_freqs = True, return_times = True)
itc_60_arr = itc_60_exo.get_data()
coherence['with64_for64cued_exo'] = itc_64_arr[elec_idx,1,:]
coherence['with60_for64cued_exo'] = itc_64_arr[elec_idx,0,:]
coherence['with64_for60cued_exo'] = itc_60_arr[elec_idx,1,:]
coherence['with60_for60cued_exo'] = itc_60_arr[elec_idx,0,:]
# Out:
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.6s

# %%
fig, ax = plt.subplots(2,2, sharex=True, sharey=True, figsize=(10,5))
ax[0,0].plot(times_coh, coherence['with60_for60cued_endo'].T - coherence['with60_for64cued_endo'].T, label = best_electrodes)
ax[0,0].set_ylabel('Coherence 60Hz')
ax[0,0].set_title('Endogeneous difference 60Hz cued-uncued')
ax[1,0].plot(times_coh, coherence['with64_for64cued_endo'].T - coherence['with64_for60cued_endo'].T, label = best_electrodes)
ax[1,0].set_ylabel('Coherence 64Hz')
ax[1,0].set_title('Endogeneous difference 64Hz cued-uncued')
ax[0,1].plot(times_coh, coherence['with60_for60cued_exo'].T - coherence['with60_for64cued_exo'].T, label = best_electrodes)
ax[0,1].set_title('Exogeneous difference 60Hz cued-uncued')
ax[1,1].plot(times_coh, coherence['with64_for64cued_exo'].T - coherence['with64_for60cued_exo'].T, label = best_electrodes)
ax[1,1].set_title('Exogeneous difference 64Hz cued-uncued')

# for axi in ax.flatten():
#     axi.vlines(0, -.4, .4, color='black')

plt.legend(bbox_to_anchor=(1,1))
ax[1,0].set_xlabel('Time from cue (second)')
ax[1,1].set_xlabel('Time from cue (second)')
plt.show()

# %%
# Export for group analysis

def pd_coh(coherence_dic, cued, coh_with, condition):
    coherence = pd.DataFrame(coherence_dic[f'with{coh_with}_for{cued}cued_{condition}'])
    coherence['channel'] = best_electrodes
    coherence['cued'] = cued
    coherence['coh_with'] = coh_with
    coherence['condition'] = condition
    coherence = coherence.melt(id_vars=['channel','cued','coh_with','condition'])
    coherence['time'] = coherence['variable']*(1/epochs_endo.info['sfreq']) + tmin
    return coherence

coh64_cue64_endo = pd_coh(coherence, 64, 64, 'endo')
coh64_cue60_endo = pd_coh(coherence, 60, 64, 'endo')
coh60_cue64_endo = pd_coh(coherence, 64, 60, 'endo')
coh60_cue60_endo = pd_coh(coherence, 60, 60, 'endo')
coh64_cue64_exo = pd_coh(coherence, 64, 64, 'exo')
coh64_cue60_exo = pd_coh(coherence, 60, 64, 'exo')
coh60_cue64_exo = pd_coh(coherence, 64, 60, 'exo')
coh60_cue60_exo = pd_coh(coherence, 60, 60, 'exo')

ITcoh_B2 = pd.concat([coh60_cue60_endo, coh60_cue64_endo, coh64_cue60_endo, coh64_cue64_endo,
                     coh60_cue60_exo, coh60_cue64_exo, coh64_cue60_exo, coh64_cue64_exo])
ITcoh_B2.columns = ['channel', 'cued', 'coh_with', 'condition', 'timepoint', 'ITcoherence', 'time']
ITcoh_B2.to_csv('files/ITcoh_B2.csv',index=False)

# %% [markdown]
# ### Comparing MS coherence across cued conditions

# %%
# # time window from -1 sec to 1 sec relative to cue
# tmin, tmax = -1, 1
# # Define range of frequencies of interest
# freqs = np.array([60, 64])

# epochs_endo_cropped = epochs_endo['cued_tag == 64'].copy().pick(best_electrodes).crop(tmin, tmax)
# coherence_mat = np.zeros((len(best_electrodes), freqs.size, len(epochs_endo_cropped.times)))
# for e, channel in enumerate(best_electrodes):
#     for i, freq in enumerate(freqs):
#         coherence_mat[e,i,:] = coherence_kabir(epochs_endo_cropped, [channel], freq)
# coherence_hilbert_64 = mne.time_frequency.EpochsTFRArray(epochs_endo_cropped.info, np.array([coherence_mat]), epochs_endo_cropped.times, freqs)

# epochs_endo_cropped = epochs_endo['cued_tag == 60'].copy().pick(best_electrodes).crop(tmin, tmax)
# coherence_mat = np.zeros((len(best_electrodes), freqs.size, len(epochs_endo_cropped.times)))
# for e, channel in enumerate(best_electrodes):
#     for i, freq in enumerate(freqs):
#         coherence_mat[e,i,:] = coherence_kabir(epochs_endo_cropped, [channel], freq)
# coherence_hilbert_60 = mne.time_frequency.EpochsTFRArray(epochs_endo_cropped.info, np.array([coherence_mat]), epochs_endo_cropped.times, freqs)

# coherence_hilbert_64, times_coh, freqs_idx = coherence_hilbert_64.get_data(return_freqs = True, return_times = True)
# coherence_hilbert_60 = coherence_hilbert_60.get_data()

# %%
# coherence_hilbert = {}
# coherence_hilbert['with64_for64cued'] = np.squeeze(coherence_hilbert_64)[:,1,:]
# coherence_hilbert['with60_for64cued'] = np.squeeze(coherence_hilbert_64)[:,0,:]
# coherence_hilbert['with64_for60cued'] = np.squeeze(coherence_hilbert_60)[:,1,:]
# coherence_hilbert['with60_for60cued'] = np.squeeze(coherence_hilbert_60)[:,0,:]

# plt.plot(times_coh, coherence_hilbert['with64_for64cued'].T - coherence_hilbert['with64_for60cued'].T, label = best_electrodes)
# plt.vlines(0,-0.35,0.3, color = 'black')
# plt.legend()
# plt.title('Coherence with 64Hz when 64 cued - coherence with 64 when 64 not cued')
# plt.xlabel('Time from cue')
# plt.ylabel('Coherence contrast cued/uncued')
# plt.show()

# plt.plot(times_coh, coherence_hilbert['with60_for60cued'].T - coherence_hilbert['with60_for64cued'].T, label = best_electrodes)
# plt.vlines(0,-0.35,0.3, color = 'black')
# plt.legend()
# plt.title('Coherence with 60Hz when 60 cued - coherence with 60 when 60 not cued')
# plt.xlabel('Time from cue')
# plt.ylabel('Coherence contrast cued/uncued')

# %%
# # Export for group analysis
# coh64_cue64 = pd_coh(coherence_hilbert, 64, 64)
# coh64_cue60 = pd_coh(coherence_hilbert, 60, 64)
# coh60_cue64 = pd_coh(coherence_hilbert, 64, 60)
# coh60_cue60 = pd_coh(coherence_hilbert, 60, 60)

# MScoh_B2 = pd.concat([coh60_cue60, coh60_cue64, coh64_cue60, coh64_cue64])
# MScoh_B2.columns = ['channel', 'cued', 'coh_with', 'timepoint', 'MScoherence', 'time']
# MScoh_B2.to_csv('files/MScoh_B2.csv',index=False)

# %% [markdown]
# # 3 - Predict cued tag with a classifier

# %%
# Load eeg epochs again to use all channels
epochs = mne.read_epochs(f'{data_path}{epoch_file}')
epoch_good = [x for x,y in enumerate(epochs.drop_log) if len(y) == 0]
epochs.metadata = pd_info.iloc[epoch_good]

# Remove trials where a target occured
epochs = epochs['targets_binary == 0']

# Crop to after the latest target onset possibility
epochs.crop(-.2, 2)

# Downsample for speed
epochs.resample(500).pick_types(eeg=True)
# Out:
# Reading /home/lea/Documents/obsidian_notes/masterADS/ads_thesis_RIFT/my_code_expe2/data/B2/preprocessing/B2_EEG_epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 555 matching events found
# No baseline correction applied
# 0 projection items activated
# Adding metadata with 14 columns
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# <EpochsFIF |  448 events (all good), -0.200195 – 1.9978 s, baseline -1 – 0 s (baseline period was cropped after baseline correction), ~240.7 MB, data loaded, with metadata,
#  '3': 448>

# %%
# Data preparation for post-250ms
epochs_post_250ms = epochs.copy().crop(tmin=.2)
epochs_pre_250ms = epochs.copy().crop(tmax=0.5).copy()

# Data and class to predict for post-250ms
X = epochs_post_250ms.copy().get_data()
y = epochs_post_250ms.metadata['cued_side'].values


# Model fitting for post-250ms
clf = make_pipeline(StandardScaler(), LogisticRegression(solver="liblinear"))
time_decod = SlidingEstimator(clf, n_jobs=5, scoring="roc_auc", verbose=True)
scores = cross_val_multiscore(time_decod, X, y, cv=10, n_jobs=5)

# Mean scores across cross-validation splits for post-250ms
mean_scores = np.mean(scores, axis=0)

# Find the best time point after 250ms
best_time_idx = np.argmax(mean_scores)
best_time = epochs_post_250ms.times[best_time_idx]
best_score = mean_scores[best_time_idx]
print(f"Best time point post-250ms: {best_time} seconds with score: {best_score}")

# Train the model on the best time point after 250ms
best_time_data = X[:, :, best_time_idx]
clf_best = make_pipeline(StandardScaler(), LogisticRegression(solver="liblinear"))
clf_best.fit(best_time_data, y)


# Evaluate the model on pre-250ms data for each time point separately for endo and exo
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import StratifiedKFold
# Automatically perform kfold
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

# Initialize cross-validation scores list
cv_scores_pre_250ms_exo = []
cv_scores_pre_250ms_endo = []

exo = epochs_pre_250ms['attention_type_block==0'].copy()
endo = epochs_pre_250ms['attention_type_block==1'].copy()

# Iterate through each time point in pre-250ms data
for t in range(len(exo.times)):
    X_pre_250ms_exo = exo.get_data()[:, :, t]
    X_pre_250ms_endo = endo.get_data()[:, :, t]
    y_exo = exo.metadata['cued_side'].values
    y_endo = endo.metadata['cued_side'].values
    fold_scores_exo = []
    fold_scores_endo = []
    
    # Iterate through each fold of cross-validation
    for train_index, test_index in skf.split(X_pre_250ms_exo, y_exo):
        X_train, X_test = X_pre_250ms_exo[train_index], X_pre_250ms_exo[test_index]
        y_train, y_test = y_exo[train_index], y_exo[test_index]
        
        # Use the previously trained model to predict on pre-250ms data
        predictions = clf_best.predict(X_pre_250ms_exo[test_index])
        score_exo = roc_auc_score(y_test, predictions)
        fold_scores_exo.append(score_exo)
    # Average score across folds for this time point
    avg_score_exo = np.mean(fold_scores_exo, axis=-1)
    cv_scores_pre_250ms_exo.append(avg_score_exo)
    
    # Iterate through each fold of cross-validation
    for train_index, test_index in skf.split(X_pre_250ms_endo, y_endo):
        X_train, X_test = X_pre_250ms_endo[train_index], X_pre_250ms_endo[test_index]
        y_train, y_test = y_endo[train_index], y_endo[test_index]
        
        # Use the previously trained model to predict on pre-250ms data
        predictions = clf_best.predict(X_pre_250ms_endo[test_index])
        score_endo = roc_auc_score(y_test, predictions)
        fold_scores_endo.append(score_endo)
    
    # Average score across folds for this time point
    avg_score_endo = np.mean(fold_scores_endo, axis=-1)
    cv_scores_pre_250ms_endo.append(avg_score_endo)

# %%
cv_scores_pre_250ms_endo_arr = np.array(cv_scores_pre_250ms_endo)
cv_scores_pre_250ms_endo_arr = np.abs(cv_scores_pre_250ms_endo_arr-cv_scores_pre_250ms_endo_arr.mean()) + .5
cv_scores_pre_250ms_exo_arr = np.array(cv_scores_pre_250ms_exo)
cv_scores_pre_250ms_exo_arr = np.abs(cv_scores_pre_250ms_exo_arr-cv_scores_pre_250ms_exo_arr.mean()) + .5
plt.plot(exo.times, cv_scores_pre_250ms_endo_arr)
plt.plot(exo.times, cv_scores_pre_250ms_exo_arr)

# %%
np.save('files/B2_decoding.npy', np.vstack([cv_scores_pre_250ms_endo_arr, cv_scores_pre_250ms_exo_arr]))
np.save('files/decoding_times.npy', exo.times)

# %%
# Initialize cross-validation scores list
cv_scores_pre_250ms_attention = []

# Iterate through each time point in pre-250ms data
for t in range(len(epochs_pre_250ms.times)):
    X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
    y_attention = epochs_pre_250ms.metadata['attention_type_block'].values
    fold_scores_attention = []
    
    # Iterate through each fold of cross-validation
    for train_index, test_index in skf.split(X_pre_250ms_attention, y_attention):
        X_train, X_test = X_pre_250ms_attention[train_index], X_pre_250ms_attention[test_index]
        y_train, y_test = y_attention[train_index], y_attention[test_index]
        
        # Use the previously trained model to predict on pre-250ms data
        predictions = clf_best.predict(X_pre_250ms_attention[test_index])
        score_attention = roc_auc_score(y_test, predictions)
        fold_scores_attention.append(score_attention)
    # Average score across folds for this time point
    avg_score_attention = np.mean(fold_scores_attention, axis=-1)
    cv_scores_pre_250ms_attention.append(avg_score_attention)
# Out:
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
# ...
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_127397/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]

# %%
plt.plot(exo.times, cv_scores_pre_250ms_attention)

# %%
# Data preparation for post-250ms
epochs_post_250ms = epochs.copy().crop(tmin=-.2)
epochs_pre_250ms = epochs.copy().crop(tmax=0.6).copy()

# Data and class to predict for post-250ms
X = epochs_post_250ms.copy().get_data()
y = epochs_post_250ms.metadata['cued_side'].values


# Model fitting for post-250ms
clf = make_pipeline(StandardScaler(), LogisticRegression(solver="liblinear"))
time_decod = SlidingEstimator(clf, n_jobs=5, scoring="roc_auc", verbose=True)
scores = cross_val_multiscore(time_decod, X, y, cv=10, n_jobs=5)

# Mean scores across cross-validation splits for post-250ms
mean_scores = np.mean(scores, axis=0)

# Find the best time point after 250ms
best_time_idx = np.argmax(mean_scores)
best_time = epochs_post_250ms.times[best_time_idx]
best_score = mean_scores[best_time_idx]
print(f"Best time point post-250ms: {best_time} seconds with score: {best_score}")

# Train the model on the best time point after 250ms
best_time_data = X[:, :, best_time_idx]
clf_best = make_pipeline(StandardScaler(), LogisticRegression(solver="liblinear"))
clf_best.fit(best_time_data, y)


# Evaluate the model on pre-250ms data for each time point separately for endo and exo
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import StratifiedKFold
# Automatically perform kfold
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

# Initialize cross-validation scores list
cv_scores_pre_250ms_exo = []
cv_scores_pre_250ms_endo = []

exo = epochs_pre_250ms['attention_type_block==0'].copy()
endo = epochs_pre_250ms['attention_type_block==1'].copy()

# Iterate through each time point in pre-250ms data
for t in range(len(exo.times)):
    X_pre_250ms_exo = exo.get_data()[:, :, t]
    X_pre_250ms_endo = endo.get_data()[:, :, t]
    y_exo = exo.metadata['cued_side'].values
    y_endo = endo.metadata['cued_side'].values
    fold_scores_exo = []
    fold_scores_endo = []
    
    # Iterate through each fold of cross-validation
    for train_index, test_index in skf.split(X_pre_250ms_exo, y_exo):
        X_train, X_test = X_pre_250ms_exo[train_index], X_pre_250ms_exo[test_index]
        y_train, y_test = y_exo[train_index], y_exo[test_index]
        
        # Use the previously trained model to predict on pre-250ms data
        predictions = clf_best.predict(X_pre_250ms_exo[test_index])
        score_exo = roc_auc_score(y_test, predictions)
        fold_scores_exo.append(score_exo)
    # Average score across folds for this time point
    avg_score_exo = np.mean(fold_scores_exo, axis=-1)
    cv_scores_pre_250ms_exo.append(avg_score_exo)
    
    # Iterate through each fold of cross-validation
    for train_index, test_index in skf.split(X_pre_250ms_endo, y_endo):
        X_train, X_test = X_pre_250ms_endo[train_index], X_pre_250ms_endo[test_index]
        y_train, y_test = y_endo[train_index], y_endo[test_index]
        
        # Use the previously trained model to predict on pre-250ms data
        predictions = clf_best.predict(X_pre_250ms_endo[test_index])
        score_endo = roc_auc_score(y_test, predictions)
        fold_scores_endo.append(score_endo)
    
    # Average score across folds for this time point
    avg_score_endo = np.mean(fold_scores_endo, axis=-1)
    cv_scores_pre_250ms_endo.append(avg_score_endo)
# Out:
# /tmp/ipykernel_127397/2399489850.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X = epochs_post_250ms.copy().get_data()
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
#  58%|█████▊    | Fitting SlidingEstimator : 634/1100 [00:04<00:03,  150.49it/s]s]
#  59%|█████▊    | Fitting SlidingEstimator : 646/1100 [00:04<00:02,  152.23it/s]
#  59%|█████▉    | Fitting SlidingEstimator : 651/1100 [00:04<00:02,  151.93it/s]A
#  60%|█████▉    | Fitting SlidingEstimator : 656/1100 [00:04<00:02,  151.39it/s][A
#  60%|██████    | Fitting SlidingEstimator : 660/1100 [00:04<00:02,  149.77it/s][A
#  60%|██████    | Fitting SlidingEstimator : 665/1100 [00:04<00:02,  149.05it/s][A
#  61%|██████    | Fitting SlidingEstimator : 669/1100 [00:04<00:02,  147.55it/s][A
#  61%|██████    | Fitting SlidingEstimator : 673/1100 [00:04<00:02,  145.02it/s][A
#  62%|██████▏   | Fitting SlidingEstimator : 677/1100 [00:04<00:02,  143.36it/s][A
#  62%|██████▏   | Fitting SlidingEstimator : 680/1100 [00:04<00:02,  140.72it/s][A
#  62%|██████▏   | Fitting SlidingEstimator : 685/1100 [00:04<00:02,  140.61it/s][A
#  63%|██████▎   | Fitting SlidingEstimator : 689/1100 [00:04<00:02,  139.32it/s][A
#  63%|██████▎   | Fitting SlidingEstimator : 695/1100 [00:04<00:02,  140.96it/s][A
#  64%|██████▎   | Fitting SlidingEstimator : 699/1100 [00:04<00:02,  139.73it/s][A
#  64%|██████▍   | Fitting SlidingEstimator : 705/1100 [00:04<00:02,  140.87it/s][A
#  64%|██████▍   | Fitting SlidingEstimator : 709/1100 [00:04<00:02,  139.78it/s][A
#  65%|██████▍   | Fitting SlidingEstimator : 713/1100 [00:04<00:02,  138.77it/s][A
#  65%|██████▌   | Fitting SlidingEstimator : 718/1100 [00:04<00:02,  139.20it/s][A
#  66%|██████▌   | Fitting SlidingEstimator : 723/1100 [00:04<00:02,  139.24it/s][A
#  66%|██████▌   | Fitting SlidingEstimator : 727/1100 [00:04<00:02,  138.10it/s][A
#  67%|██████▋   | Fitting SlidingEstimator : 732/1100 [00:04<00:02,  138.41it/s][A
#  67%|██████▋   | Fitting SlidingEstimator : 736/1100 [00:04<00:02,  137.36it/s][A
#  67%|██████▋   | Fitting SlidingEstimator : 741/1100 [00:04<00:02,  137.49it/s][A
#  68%|██████▊   | Fitting SlidingEstimator : 745/1100 [00:04<00:02,  136.09it/s]
#  68%|██████▊   | Fitting SlidingEstimator : 751/1100 [00:05<00:02,  136.67it/s]
#  69%|██████▊   | Fitting SlidingEstimator : 755/1100 [00:05<00:02,  135.04it/s]
#  69%|██████▉   | Fitting SlidingEstimator : 758/1100 [00:05<00:02,  132.82it/s]
#  69%|██████▉   | Fitting SlidingEstimator : 764/1100 [00:05<00:02,  134.67it/s]
#  70%|███████   | Fitting SlidingEstimator : 770/1100 [00:05<00:02,  136.10it/s]
#  70%|███████   | Fitting SlidingEstimator : 774/1100 [00:05<00:02,  133.71it/s]
#  71%|███████   | Fitting SlidingEstimator : 778/1100 [00:05<00:02,  132.69it/s]
#  71%|███████▏  | Fitting SlidingEstimator : 784/1100 [00:05<00:02,  134.72it/s]
#  72%|███████▏  | Fitting SlidingEstimator : 789/1100 [00:05<00:02,  135.08it/s]
#  72%|███████▏  | Fitting SlidingEstimator : 793/1100 [00:05<00:02,  133.52it/s]
#  73%|███████▎  | Fitting SlidingEstimator : 798/1100 [00:05<00:02,  133.98it/s]
#  73%|███████▎  | Fitting SlidingEstimator : 804/1100 [00:05<00:02,  135.40it/s]
#  73%|███████▎  | Fitting SlidingEstimator : 808/1100 [00:05<00:02,  134.43it/s]
#  74%|███████▍  | Fitting SlidingEstimator : 815/1100 [00:05<00:02,  137.15it/s]
#  75%|███████▍  | Fitting SlidingEstimator : 820/1100 [00:05<00:02,  136.19it/s]
#  75%|███████▌  | Fitting SlidingEstimator : 826/1100 [00:05<00:02,  136.85it/s]
#  75%|███████▌  | Fitting SlidingEstimator : 829/1100 [00:05<00:02,  134.29it/s]
#  76%|███████▌  | Fitting SlidingEstimator : 834/1100 [00:05<00:01,  133.99it/s]
#  76%|███████▌  | Fitting SlidingEstimator : 838/1100 [00:05<00:01,  132.42it/s]
#  77%|███████▋  | Fitting SlidingEstimator : 843/1100 [00:05<00:01,  132.88it/s]
#  77%|███████▋  | Fitting SlidingEstimator : 850/1100 [00:05<00:01,  136.24it/s]
#  78%|███████▊  | Fitting SlidingEstimator : 853/1100 [00:05<00:01,  133.98it/s]
#  78%|███████▊  | Fitting SlidingEstimator : 859/1100 [00:05<00:01,  134.80it/s]
#  79%|███████▊  | Fitting SlidingEstimator : 864/1100 [00:05<00:01,  134.77it/s]
#  79%|███████▉  | Fitting SlidingEstimator : 870/1100 [00:05<00:01,  135.90it/s]
#  79%|███████▉  | Fitting SlidingEstimator : 873/1100 [00:05<00:01,  133.66it/s]
#  80%|████████  | Fitting SlidingEstimator : 881/1100 [00:05<00:01,  136.74it/s]
#  81%|████████  | Fitting SlidingEstimator : 886/1100 [00:06<00:01,  136.76it/s]
#  81%|████████  | Fitting SlidingEstimator : 888/1100 [00:06<00:01,  132.60it/s]
#  81%|████████  | Fitting SlidingEstimator : 893/1100 [00:06<00:01,  133.26it/s]
#  82%|████████▏ | Fitting SlidingEstimator : 897/1100 [00:06<00:01,  132.55it/s]
#  82%|████████▏ | Fitting SlidingEstimator : 902/1100 [00:06<00:01,  132.66it/s]
#  82%|████████▏ | Fitting SlidingEstimator : 905/1100 [00:06<00:01,  130.26it/s]
#  83%|████████▎ | Fitting SlidingEstimator : 910/1100 [00:06<00:01,  131.06it/s]
#  83%|████████▎ | Fitting SlidingEstimator : 915/1100 [00:06<00:01,  131.77it/s]
#  84%|████████▎ | Fitting SlidingEstimator : 921/1100 [00:06<00:01,  133.85it/s]
#  84%|████████▍ | Fitting SlidingEstimator : 925/1100 [00:06<00:01,  132.89it/s]
#  85%|████████▍ | Fitting SlidingEstimator : 930/1100 [00:06<00:01,  133.23it/s]
#  85%|████████▌ | Fitting SlidingEstimator : 936/1100 [00:06<00:01,  134.12it/s]
#  86%|████████▌ | Fitting SlidingEstimator : 941/1100 [00:06<00:01,  134.56it/s]
#  86%|████████▌ | Fitting SlidingEstimator : 947/1100 [00:06<00:01,  136.19it/s]
#  87%|████████▋ | Fitting SlidingEstimator : 952/1100 [00:06<00:01,  136.70it/s]
#  87%|████████▋ | Fitting SlidingEstimator : 957/1100 [00:06<00:01,  136.70it/s]
#  88%|████████▊ | Fitting SlidingEstimator : 964/1100 [00:06<00:00,  140.00it/s]
#  88%|████████▊ | Fitting SlidingEstimator : 970/1100 [00:06<00:00,  140.95it/s]
#  89%|████████▊ | Fitting SlidingEstimator : 974/1100 [00:06<00:00,  139.82it/s]
#  89%|████████▉ | Fitting SlidingEstimator : 980/1100 [00:06<00:00,  141.57it/s]
#  90%|████████▉ | Fitting SlidingEstimator : 985/1100 [00:06<00:00,  141.86it/s]
#  90%|█████████ | Fitting SlidingEstimator : 990/1100 [00:06<00:00,  141.45it/s]
#  91%|█████████ | Fitting SlidingEstimator : 996/1100 [00:06<00:00,  143.16it/s]
#  91%|█████████ | Fitting SlidingEstimator : 1002/1100 [00:06<00:00,  144.00it/s][A
#  92%|█████████▏| Fitting SlidingEstimator : 1008/1100 [00:06<00:00,  145.50it/s][A
#  92%|█████████▏| Fitting SlidingEstimator : 1013/1100 [00:06<00:00,  145.57it/s][A
#  93%|█████████▎| Fitting SlidingEstimator : 1018/1100 [00:06<00:00,  145.43it/s][A
#  93%|█████████▎| Fitting SlidingEstimator : 1023/1100 [00:06<00:00,  145.31it/s][A
#  93%|█████████▎| Fitting SlidingEstimator : 1028/1100 [00:07<00:00,  145.41it/s][A
#  94%|█████████▍| Fitting SlidingEstimator : 1034/1100 [00:07<00:00,  146.47it/s][A
#  94%|█████████▍| Fitting SlidingEstimator : 1039/1100 [00:07<00:00,  146.28it/s][A
#  95%|█████████▌| Fitting SlidingEstimator : 1045/1100 [00:07<00:00,  147.46it/s][A
#  95%|█████████▌| Fitting SlidingEstimator : 1050/1100 [00:07<00:00,  147.29it/s][A
#  96%|█████████▌| Fitting SlidingEstimator : 1054/1100 [00:07<00:00,  145.64it/s][A
#  96%|█████████▋| Fitting SlidingEstimator : 1059/1100 [00:07<00:00,  145.74it/s][A
#  97%|█████████▋| Fitting SlidingEstimator : 1066/1100 [00:07<00:00,  147.87it/s][A
#  97%|█████████▋| Fitting SlidingEstimator : 1071/1100 [00:07<00:00,  146.98it/s][A
#  98%|█████████▊| Fitting SlidingEstimator : 1077/1100 [00:07<00:00,  148.39it/s][A
#  98%|█████████▊| Fitting SlidingEstimator : 1083/1100 [00:07<00:00,  149.58it/s][A
#  99%|█████████▉| Fitting SlidingEstimator : 1087/1100 [00:07<00:00,  147.86it/s][A
#  99%|█████████▉| Fitting SlidingEstimator : 1092/1100 [00:07<00:00,  147.78it/s][A
# 100%|█████████▉| Fitting SlidingEstimator : 1098/1100 [00:07<00:00,  149.20it/s][A
# 100%|██████████| Fitting SlidingEstimator : 1100/1100 [00:07<00:00,  146.72it/s][A
#
#  41%|████      | Fitting SlidingEstimator : 448/1100 [00:03<00:04,  139.36it/s]
#  41%|████      | Fitting SlidingEstimator : 452/1100 [00:03<00:04,  138.06it/s]
#  42%|████▏     | Fitting SlidingEstimator : 458/1100 [00:03<00:04,  138.08it/s]
#  42%|████▏     | Fitting SlidingEstimator : 461/1100 [00:03<00:04,  135.74it/s]
#  42%|████▏     | Fitting SlidingEstimator : 466/1100 [00:03<00:04,  135.90it/s]
#  43%|████▎     | Fitting SlidingEstimator : 470/1100 [00:03<00:04,  134.04it/s]
#  43%|████▎     | Fitting SlidingEstimator : 476/1100 [00:03<00:04,  135.01it/s]
#  44%|████▎     | Fitting SlidingEstimator : 480/1100 [00:03<00:04,  134.19it/s]
#  44%|████▍     | Fitting SlidingEstimator : 485/1100 [00:03<00:04,  134.81it/s]
#  45%|████▍     | Fitting SlidingEstimator : 490/1100 [00:03<00:04,  135.23it/s]
#  45%|████▌     | Fitting SlidingEstimator : 495/1100 [00:03<00:04,  134.46it/s]
#  45%|████▌     | Fitting SlidingEstimator : 500/1100 [00:03<00:04,  134.82it/s]
#  46%|████▌     | Fitting SlidingEstimator : 504/1100 [00:03<00:04,  133.69it/s]
#  46%|████▌     | Fitting SlidingEstimator : 506/1100 [00:03<00:04,  130.16it/s]
#  46%|████▋     | Fitting SlidingEstimator : 510/1100 [00:03<00:04,  129.10it/s]
#  47%|████▋     | Fitting SlidingEstimator : 514/1100 [00:03<00:04,  128.36it/s]
#  47%|████▋     | Fitting SlidingEstimator : 518/1100 [00:03<00:04,  127.02it/s]
#  47%|████▋     | Fitting SlidingEstimator : 521/1100 [00:04<00:04,  124.61it/s]
#  48%|████▊     | Fitting SlidingEstimator : 524/1100 [00:04<00:04,  121.90it/s]
#  48%|████▊     | Fitting SlidingEstimator : 529/1100 [00:04<00:04,  122.71it/s]
#
#   0%|          | Fitting SlidingEstimator : 0/1100 [00:00<?,       ?it/s]
#  49%|████▊     | Fitting SlidingEstimator : 534/1100 [00:04<00:04,  123.58it/s]
#  49%|████▉     | Fitting SlidingEstimator : 539/1100 [00:04<00:04,  124.66it/s]
#
#   0%|          | Fitting SlidingEstimator : 4/1100 [00:00<00:21,   51.00it/s]
#  49%|████▉     | Fitting SlidingEstimator : 543/1100 [00:04<00:04,  124.27it/s]
#
#   1%|          | Fitting SlidingEstimator : 8/1100 [00:00<00:15,   69.74it/s]
#  50%|████▉     | Fitting SlidingEstimator : 547/1100 [00:04<00:04,  122.45it/s]
#
#   1%|          | Fitting SlidingEstimator : 13/1100 [00:00<00:12,   87.44it/s]
#  50%|█████     | Fitting SlidingEstimator : 550/1100 [00:04<00:04,  120.86it/s]
#
#   1%|▏         | Fitting SlidingEstimator : 16/1100 [00:00<00:12,   86.91it/s]
#  50%|█████     | Fitting SlidingEstimator : 555/1100 [00:04<00:04,  122.10it/s]
#
#   2%|▏         | Fitting SlidingEstimator : 22/1100 [00:00<00:10,   99.95it/s]
#  51%|█████     | Fitting SlidingEstimator : 560/1100 [00:04<00:04,  121.97it/s]
#
#   2%|▏         | Fitting SlidingEstimator : 24/1100 [00:00<00:11,   93.73it/s]
#  51%|█████     | Fitting SlidingEstimator : 563/1100 [00:04<00:04,  120.06it/s]
#
#   3%|▎         | Fitting SlidingEstimator : 30/1100 [00:00<00:10,  103.78it/s]
#  52%|█████▏    | Fitting SlidingEstimator : 567/1100 [00:04<00:04,  119.76it/s]
#
#   3%|▎         | Fitting SlidingEstimator : 35/1100 [00:00<00:09,  107.97it/s]
#  52%|█████▏    | Fitting SlidingEstimator : 571/1100 [00:04<00:04,  119.40it/s]
#
#   4%|▎         | Fitting SlidingEstimator : 39/1100 [00:00<00:09,  108.84it/s]
#  52%|█████▏    | Fitting SlidingEstimator : 575/1100 [00:04<00:04,  119.34it/s]
#
#   4%|▍         | Fitting SlidingEstimator : 43/1100 [00:00<00:09,  108.10it/s]
#  53%|█████▎    | Fitting SlidingEstimator : 578/1100 [00:04<00:04,  116.72it/s]
#
#   4%|▍         | Fitting SlidingEstimator : 47/1100 [00:00<00:09,  107.21it/s]
#  53%|█████▎    | Fitting SlidingEstimator : 582/1100 [00:04<00:04,  116.40it/s]
#
#   5%|▍         | Fitting SlidingEstimator : 51/1100 [00:00<00:09,  107.79it/s]
#  53%|█████▎    | Fitting SlidingEstimator : 588/1100 [00:04<00:04,  118.57it/s]
#
#   5%|▌         | Fitting SlidingEstimator : 55/1100 [00:00<00:09,  108.44it/s]
#  54%|█████▎    | Fitting SlidingEstimator : 591/1100 [00:04<00:04,  116.82it/s]
#
#   5%|���         | Fitting SlidingEstimator : 60/1100 [00:00<00:09,  111.19it/s]
#  54%|█████▍    | Fitting SlidingEstimator : 594/1100 [00:04<00:04,  115.45it/s]
#
#   6%|▌         | Fitting SlidingEstimator : 64/1100 [00:00<00:09,  111.51it/s]
#  54%|█████▍    | Fitting SlidingEstimator : 599/1100 [00:04<00:04,  116.73it/s]
#
#   6%|▌         | Fitting SlidingEstimator : 68/1100 [00:00<00:09,  111.54it/s]
#  55%|█████▍    | Fitting SlidingEstimator : 603/1100 [00:04<00:04,  116.79it/s]
#
#   7%|▋         | Fitting SlidingEstimator : 74/1100 [00:00<00:09,  113.64it/s]
#  55%|█████▌    | Fitting SlidingEstimator : 607/1100 [00:04<00:04,  116.62it/s]
#
#   7%|▋         | Fitting SlidingEstimator : 78/1100 [00:00<00:09,  112.34it/s]
#  56%|█████▌    | Fitting SlidingEstimator : 613/1100 [00:04<00:04,  118.90it/s]
#
#   8%|▊         | Fitting SlidingEstimator : 84/1100 [00:00<00:08,  115.70it/s]
#  56%|█████▌    | Fitting SlidingEstimator : 618/1100 [00:04<00:04,  119.42it/s]
#
#   8%|▊         | Fitting SlidingEstimator : 87/1100 [00:00<00:08,  112.80it/s]
#  56%|█████▋    | Fitting SlidingEstimator : 621/1100 [00:04<00:04,  117.87it/s]
#
#
#   8%|▊         | Fitting SlidingEstimator : 91/1100 [00:00<00:08,  112.70it/s]
#  57%|█████▋    | Fitting SlidingEstimator : 630/1100 [00:04<00:03,  118.75it/s]
#
#   9%|▊         | Fitting SlidingEstimator : 96/1100 [00:00<00:08,  114.13it/s]
#  58%|█████▊    | Fitting SlidingEstimator : 634/1100 [00:04<00:03,  118.70it/s]
#
#   9%|▉         | Fitting SlidingEstimator : 100/1100 [00:00<00:08,  113.79it/s]
#  58%|█████▊    | Fitting SlidingEstimator : 637/1100 [00:05<00:03,  116.84it/s]
#
#   9%|▉         | Fitting SlidingEstimator : 103/1100 [00:00<00:08,  111.99it/s]
#
#  10%|▉         | Fitting SlidingEstimator : 108/1100 [00:00<00:08,  114.09it/s]
#  58%|█████▊    | Fitting SlidingEstimator : 642/1100 [00:05<00:03,  117.45it/s]
#
#
#  10%|█         | Fitting SlidingEstimator : 110/1100 [00:01<00:08,  110.59it/s]
#  59%|█████▉    | Fitting SlidingEstimator : 651/1100 [00:05<00:03,  117.54it/s]
#
#  11%|█         | Fitting SlidingEstimator : 116/1100 [00:01<00:08,  112.67it/s]
#  60%|█████▉    | Fitting SlidingEstimator : 656/1100 [00:05<00:03,  118.66it/s]
#
#  11%|█         | Fitting SlidingEstimator : 120/1100 [00:01<00:08,  112.47it/s]
#  60%|█████▉    | Fitting SlidingEstimator : 658/1100 [00:05<00:03,  115.81it/s]
#
#  11%|█▏        | Fitting SlidingEstimator : 124/1100 [00:01<00:08,  112.38it/s]
#  60%|██████    | Fitting SlidingEstimator : 663/1100 [00:05<00:03,  116.92it/s]
#
#  12%|█▏        | Fitting SlidingEstimator : 130/1100 [00:01<00:08,  115.01it/s]
#  61%|██████    | Fitting SlidingEstimator : 668/1100 [00:05<00:03,  118.36it/s]
#
#  12%|█▏        | Fitting SlidingEstimator : 135/1100 [00:01<00:08,  116.62it/s]
#  61%|██████    | Fitting SlidingEstimator : 673/1100 [00:05<00:03,  119.45it/s]
#
#  13%|█▎        | Fitting SlidingEstimator : 140/1100 [00:01<00:08,  118.17it/s]
#  62%|██████▏   | Fitting SlidingEstimator : 678/1100 [00:05<00:03,  120.55it/s]
#
#  13%|█▎        | Fitting SlidingEstimator : 145/1100 [00:01<00:08,  119.05it/s]
#  62%|██████▏   | Fitting SlidingEstimator : 684/1100 [00:05<00:03,  122.55it/s]
#
#  14%|█▎        | Fitting SlidingEstimator : 150/1100 [00:01<00:07,  119.32it/s]
#  62%|██████▏   | Fitting SlidingEstimator : 687/1100 [00:05<00:03,  120.46it/s]
#
#  14%|█▍        | Fitting SlidingEstimator : 155/1100 [00:01<00:07,  120.64it/s]
#  63%|██████▎   | Fitting SlidingEstimator : 693/1100 [00:05<00:03,  122.32it/s]
#
#  15%|█▍        | Fitting SlidingEstimator : 160/1100 [00:01<00:07,  121.38it/s]
#  64%|██████▎   | Fitting SlidingEstimator : 700/1100 [00:05<00:03,  125.45it/s]
#
#  15%|█▌        | Fitting SlidingEstimator : 165/1100 [00:01<00:07,  122.15it/s]
#  64%|██████▍   | Fitting SlidingEstimator : 705/1100 [00:05<00:03,  126.26it/s]
#
#  16%|█▌        | Fitting SlidingEstimator : 171/1100 [00:01<00:07,  125.07it/s]
#  65%|██████▍   | Fitting SlidingEstimator : 711/1100 [00:05<00:03,  128.23it/s]
#
#  16%|█▌        | Fitting SlidingEstimator : 177/1100 [00:01<00:07,  127.47it/s]
#  65%|██████▌   | Fitting SlidingEstimator : 715/1100 [00:05<00:03,  127.61it/s]
#
#  17%|█▋        | Fitting SlidingEstimator : 183/1100 [00:01<00:07,  129.73it/s]
#  65%|██████▌   | Fitting SlidingEstimator : 720/1100 [00:05<00:02,  128.45it/s]
#
#  17%|█▋        | Fitting SlidingEstimator : 189/1100 [00:01<00:06,  131.50it/s]
#  66%|██████▌   | Fitting SlidingEstimator : 726/1100 [00:05<00:02,  130.53it/s]
#
#  18%|█▊        | Fitting SlidingEstimator : 193/1100 [00:01<00:06,  130.57it/s]
#  67%|██████▋   | Fitting SlidingEstimator : 732/1100 [00:05<00:02,  132.33it/s]
#
#  18%|█▊        | Fitting SlidingEstimator : 199/1100 [00:01<00:06,  132.98it/s]
#  67%|██████▋   | Fitting SlidingEstimator : 737/1100 [00:05<00:02,  132.86it/s]
#
#  19%|█▊        | Fitting SlidingEstimator : 204/1100 [00:01<00:06,  133.54it/s]
#  67%|██████▋   | Fitting SlidingEstimator : 742/1100 [00:05<00:02,  133.43it/s]
#
#  19%|█▉        | Fitting SlidingEstimator : 210/1100 [00:01<00:06,  135.00it/s]
#  68%|██████▊   | Fitting SlidingEstimator : 748/1100 [00:05<00:02,  135.07it/s]
#
#  20%|█▉        | Fitting SlidingEstimator : 216/1100 [00:01<00:06,  136.96it/s]
#  69%|██████▊   | Fitting SlidingEstimator : 754/1100 [00:05<00:02,  136.68it/s]
#
#  20%|██        | Fitting SlidingEstimator : 222/1100 [00:01<00:06,  138.81it/s]
#  69%|██████▉   | Fitting SlidingEstimator : 758/1100 [00:05<00:02,  135.18it/s]
#
#  21%|██        | Fitting SlidingEstimator : 227/1100 [00:01<00:06,  139.05it/s]
#  69%|██████▉   | Fitting SlidingEstimator : 763/1100 [00:05<00:02,  135.73it/s]
#
#  21%|██        | Fitting SlidingEstimator : 232/1100 [00:01<00:06,  139.36it/s]
#  70%|██████▉   | Fitting SlidingEstimator : 768/1100 [00:05<00:02,  136.05it/s]
#
#  22%|██▏       | Fitting SlidingEstimator : 237/1100 [00:01<00:06,  139.30it/s]
#  70%|███████   | Fitting SlidingEstimator : 775/1100 [00:06<00:02,  138.99it/s]
#
#  22%|██▏       | Fitting SlidingEstimator : 243/1100 [00:01<00:06,  140.38it/s]
#  71%|███████   | Fitting SlidingEstimator : 782/1100 [00:06<00:02,  141.09it/s]
#
#  23%|██▎       | Fitting SlidingEstimator : 248/1100 [00:01<00:06,  140.70it/s]
#  72%|███████▏  | Fitting SlidingEstimator : 787/1100 [00:06<00:02,  141.30it/s]
#
#  23%|██▎       | Fitting SlidingEstimator : 254/1100 [00:01<00:05,  141.69it/s]
#  72%|███████▏  | Fitting SlidingEstimator : 794/1100 [00:06<00:02,  144.10it/s]
#
#  23%|██▎       | Fitting SlidingEstimator : 258/1100 [00:02<00:06,  140.31it/s]
#  73%|███████▎  | Fitting SlidingEstimator : 799/1100 [00:06<00:02,  144.21it/s]
#
#  24%|██▍       | Fitting SlidingEstimator : 264/1100 [00:02<00:05,  142.16it/s]
#  73%|███████▎  | Fitting SlidingEstimator : 803/1100 [00:06<00:02,  142.37it/s]
#
#  25%|██▍       | Fitting SlidingEstimator : 271/1100 [00:02<00:05,  145.18it/s]
#  74%|███████▎  | Fitting SlidingEstimator : 809/1100 [00:06<00:02,  143.66it/s]
#
#  25%|██▌       | Fitting SlidingEstimator : 275/1100 [00:02<00:05,  143.16it/s]
#  74%|███████▍  | Fitting SlidingEstimator : 814/1100 [00:06<00:01,  143.82it/s]
#
#  26%|██▌       | Fitting SlidingEstimator : 281/1100 [00:02<00:05,  144.80it/s]
#  75%|███████▍  | Fitting SlidingEstimator : 821/1100 [00:06<00:01,  146.15it/s]
#
#  26%|██▌       | Fitting SlidingEstimator : 286/1100 [00:02<00:05,  144.75it/s]
#  75%|███████▌  | Fitting SlidingEstimator : 826/1100 [00:06<00:01,  145.74it/s]
#
#  26%|██▋       | Fitting SlidingEstimator : 291/1100 [00:02<00:05,  144.27it/s]
#  75%|███████▌  | Fitting SlidingEstimator : 830/1100 [00:06<00:01,  144.06it/s]
#
#  27%|██▋       | Fitting SlidingEstimator : 297/1100 [00:02<00:05,  145.10it/s]
#  76%|███████▌  | Fitting SlidingEstimator : 835/1100 [00:06<00:01,  144.17it/s]
#
#  27%|██▋       | Fitting SlidingEstimator : 302/1100 [00:02<00:05,  144.97it/s]
#  77%|███████▋  | Fitting SlidingEstimator : 842/1100 [00:06<00:01,  146.40it/s]
#
#  28%|██▊       | Fitting SlidingEstimator : 308/1100 [00:02<00:05,  146.19it/s]
#  77%|███████▋  | Fitting SlidingEstimator : 847/1100 [00:06<00:01,  145.57it/s]
#
#  29%|██▊       | Fitting SlidingEstimator : 314/1100 [00:02<00:05,  146.77it/s]
#  78%|███████▊  | Fitting SlidingEstimator : 854/1100 [00:06<00:01,  147.18it/s]
#
#  29%|██▉       | Fitting SlidingEstimator : 318/1100 [00:02<00:05,  144.95it/s]
#
#  29%|██▉       | Fitting SlidingEstimator : 324/1100 [00:02<00:05,  146.53it/s]
#  78%|███████▊  | Fitting SlidingEstimator : 859/1100 [00:06<00:01,  146.53it/s]
#
#  30%|██▉       | Fitting SlidingEstimator : 329/1100 [00:02<00:05,  146.52it/s]
#  79%|███████▊  | Fitting SlidingEstimator : 864/1100 [00:06<00:01,  146.46it/s]
#
#  30%|███       | Fitting SlidingEstimator : 335/1100 [00:02<00:05,  147.54it/s]
#  79%|███████▉  | Fitting SlidingEstimator : 869/1100 [00:06<00:01,  146.46it/s]
#  79%|███████▉  | Fitting SlidingEstimator : 874/1100 [00:06<00:01,  146.46it/s]
#
#  31%|███       | Fitting SlidingEstimator : 341/1100 [00:02<00:05,  148.74it/s]
#  80%|████████  | Fitting SlidingEstimator : 881/1100 [00:06<00:01,  149.24it/s]
#
#  32%|███▏      | Fitting SlidingEstimator : 347/1100 [00:02<00:05,  149.04it/s]
#  81%|████████  | Fitting SlidingEstimator : 886/1100 [00:06<00:01,  148.78it/s]
#
#  32%|███▏      | Fitting SlidingEstimator : 353/1100 [00:02<00:04,  150.12it/s]
#  81%|████████  | Fitting SlidingEstimator : 892/1100 [00:06<00:01,  149.30it/s]
#
#  33%|███▎      | Fitting SlidingEstimator : 359/1100 [00:02<00:04,  151.39it/s]
#  82%|████████▏ | Fitting SlidingEstimator : 898/1100 [00:06<00:01,  150.59it/s]
#
#  33%|█��█▎      | Fitting SlidingEstimator : 365/1100 [00:02<00:04,  152.36it/s]
#  82%|████████▏ | Fitting SlidingEstimator : 903/1100 [00:06<00:01,  150.13it/s]
#
#  34%|███▎      | Fitting SlidingEstimator : 370/1100 [00:02<00:04,  152.02it/s]
#  82%|████████▏ | Fitting SlidingEstimator : 907/1100 [00:06<00:01,  148.27it/s]
#
#  34%|███▍      | Fitting SlidingEstimator : 375/1100 [00:02<00:04,  150.94it/s]
#  83%|████████▎ | Fitting SlidingEstimator : 912/1100 [00:06<00:01,  148.07it/s]
#
#  35%|███▍      | Fitting SlidingEstimator : 380/1100 [00:02<00:04,  150.66it/s]
#  83%|████████▎ | Fitting SlidingEstimator : 918/1100 [00:06<00:01,  149.38it/s]
#
#  35%|███▌      | Fitting SlidingEstimator : 386/1100 [00:02<00:04,  151.70it/s]
#  84%|████████▍ | Fitting SlidingEstimator : 923/1100 [00:06<00:01,  149.07it/s]
#
#  36%|███▌      | Fitting SlidingEstimator : 392/1100 [00:02<00:04,  152.77it/s]
#  84%|████████▍ | Fitting SlidingEstimator : 928/1100 [00:06<00:01,  148.75it/s]
#
#  36%|███▌      | Fitting SlidingEstimator : 397/1100 [00:02<00:04,  152.27it/s]
#  85%|████████▍ | Fitting SlidingEstimator : 934/1100 [00:07<00:01,  149.60it/s]
#
#  37%|███▋      | Fitting SlidingEstimator : 402/1100 [00:02<00:04,  152.07it/s]
#
#
#  37%|███▋      | Fitting SlidingEstimator : 408/1100 [00:02<00:04,  153.21it/s]
#
#  38%|███▊      | Fitting SlidingEstimator : 413/1100 [00:03<00:04,  152.77it/s]
#  86%|████████▌ | Fitting SlidingEstimator : 943/1100 [00:07<00:01,  147.58it/s]
#
#  38%|███▊      | Fitting SlidingEstimator : 418/1100 [00:03<00:04,  152.49it/s]
#  86%|████████▋ | Fitting SlidingEstimator : 950/1100 [00:07<00:01,  148.82it/s]
#
#  38%|███▊      | Fitting SlidingEstimator : 421/1100 [00:03<00:04,  149.39it/s]
#  87%|████████▋ | Fitting SlidingEstimator : 956/1100 [00:07<00:00,  149.65it/s]
#
#  39%|███▊      | Fitting SlidingEstimator : 426/1100 [00:03<00:04,  149.18it/s]
#  87%|████████▋ | Fitting SlidingEstimator : 961/1100 [00:07<00:00,  148.93it/s]
#
#  39%|███▉      | Fitting SlidingEstimator : 432/1100 [00:03<00:04,  150.12it/s]
#  88%|████████▊ | Fitting SlidingEstimator : 967/1100 [00:07<00:00,  149.62it/s]
#
#  40%|███▉      | Fitting SlidingEstimator : 437/1100 [00:03<00:04,  149.37it/s]
#  88%|████████▊ | Fitting SlidingEstimator : 971/1100 [00:07<00:00,  147.90it/s]
#
#  40%|████      | Fitting SlidingEstimator : 442/1100 [00:03<00:04,  148.56it/s]
#  89%|████████▊ | Fitting SlidingEstimator : 976/1100 [00:07<00:00,  146.90it/s]
#
#  41%|████      | Fitting SlidingEstimator : 447/1100 [00:03<00:04,  148.49it/s]
#  89%|████████▉ | Fitting SlidingEstimator : 981/1100 [00:07<00:00,  145.63it/s]
#
#  41%|████      | Fitting SlidingEstimator : 450/1100 [00:03<00:04,  144.90it/s]
#  90%|████████▉ | Fitting SlidingEstimator : 985/1100 [00:07<00:00,  144.25it/s]
#
#  41%|████▏     | Fitting SlidingEstimator : 455/1100 [00:03<00:04,  144.97it/s]
#  90%|████████▉ | Fitting SlidingEstimator : 989/1100 [00:07<00:00,  143.02it/s]
#
#  42%|████▏     | Fitting SlidingEstimator : 460/1100 [00:03<00:04,  144.60it/s]
#  90%|█████████ | Fitting SlidingEstimator : 993/1100 [00:07<00:00,  141.54it/s]
#
#  42%|████▏     | Fitting SlidingEstimator : 465/1100 [00:03<00:04,  144.43it/s]
#  91%|█████████ | Fitting SlidingEstimator : 999/1100 [00:07<00:00,  141.31it/s]
#
#  43%|████▎     | Fitting SlidingEstimator : 469/1100 [00:03<00:04,  143.03it/s]
#  91%|█████████▏| Fitting SlidingEstimator : 1004/1100 [00:07<00:00,  141.34it/s]
#
#  43%|████▎     | Fitting SlidingEstimator : 474/1100 [00:03<00:04,  142.95it/s]
#  92%|█████████▏| Fitting SlidingEstimator : 1009/1100 [00:07<00:00,  141.58it/s]
#
#  43%|████▎     | Fitting SlidingEstimator : 478/1100 [00:03<00:04,  141.70it/s]
#  92%|█████████▏| Fitting SlidingEstimator : 1014/1100 [00:07<00:00,  141.57it/s]
#
#  44%|████▍     | Fitting SlidingEstimator : 484/1100 [00:03<00:04,  143.41it/s]
#  93%|█████████▎| Fitting SlidingEstimator : 1019/1100 [00:07<00:00,  141.68it/s]
#
#  44%|████▍     | Fitting SlidingEstimator : 489/1100 [00:03<00:04,  142.58it/s]
#  93%|█████████▎| Fitting SlidingEstimator : 1023/1100 [00:07<00:00,  140.44it/s]
#
#  45%|████▍     | Fitting SlidingEstimator : 493/1100 [00:03<00:04,  141.10it/s]
#  93%|█████████▎| Fitting SlidingEstimator : 1026/1100 [00:07<00:00,  136.65it/s]
#
#  45%|████▌     | Fitting SlidingEstimator : 497/1100 [00:03<00:04,  139.92it/s]
#
#
#  94%|█████████▎| Fitting SlidingEstimator : 1030/1100 [00:07<00:00,  134.35it/s][A
#
#
#  46%|████▌     | Fitting SlidingEstimator : 507/1100 [00:03<00:04,  139.78it/s]
#  95%|█████████▍| Fitting SlidingEstimator : 1040/1100 [00:07<00:00,  134.80it/s]
#
#  46%|████▋     | Fitting SlidingEstimator : 511/1100 [00:03<00:04,  138.39it/s]
#
#
#  47%|████▋     | Fitting SlidingEstimator : 516/1100 [00:03<00:04,  138.55it/s]
#
#  47%|████▋     | Fitting SlidingEstimator : 521/1100 [00:03<00:04,  138.81it/s]
#  95%|█████████▌| Fitting SlidingEstimator : 1050/1100 [00:07<00:00,  135.19it/s]
#
#  48%|████▊     | Fitting SlidingEstimator : 526/1100 [00:03<00:04,  139.17it/s]
#  96%|█████████▌| Fitting SlidingEstimator : 1055/1100 [00:07<00:00,  135.65it/s]
#
#
#  48%|████▊     | Fitting SlidingEstimator : 531/1100 [00:03<00:04,  139.25it/s]
#  97%|█████████▋| Fitting SlidingEstimator : 1064/1100 [00:08<00:00,  134.79it/s]
#
#  49%|████▊     | Fitting SlidingEstimator : 534/1100 [00:03<00:04,  136.17it/s]
#  97%|█���███████▋| Fitting SlidingEstimator : 1067/1100 [00:08<00:00,  132.47it/s]
#
#  49%|████▉     | Fitting SlidingEstimator : 537/1100 [00:03<00:04,  133.65it/s]
#  98%|█████████▊| Fitting SlidingEstimator : 1073/1100 [00:08<00:00,  134.34it/s]
#
#  49%|████▉     | Fitting SlidingEstimator : 541/1100 [00:04<00:04,  132.62it/s]
#  98%|█████████▊| Fitting SlidingEstimator : 1076/1100 [00:08<00:00,  132.12it/s]
#
#  50%|████▉     | Fitting SlidingEstimator : 546/1100 [00:04<00:04,  133.05it/s]
#  98%|█████████▊| Fitting SlidingEstimator : 1081/1100 [00:08<00:00,  132.72it/s]
#
#  50%|█████     | Fitting SlidingEstimator : 550/1100 [00:04<00:04,  132.12it/s]
#  99%|█████████▉| Fitting SlidingEstimator : 1087/1100 [00:08<00:00,  134.55it/s]
#
#  50%|█████     | Fitting SlidingEstimator : 554/1100 [00:04<00:04,  130.65it/s]
#  99%|█████████▉| Fitting SlidingEstimator : 1090/1100 [00:08<00:00,  132.15it/s]
#
#  51%|█████     | Fitting SlidingEstimator : 558/1100 [00:04<00:04,  129.81it/s]
# 100%|█████████▉| Fitting SlidingEstimator : 1095/1100 [00:08<00:00,  132.77it/s]
#
#  51%|█████     | Fitting SlidingEstimator : 562/1100 [00:04<00:04,  128.75it/s]
# 100%|█████████▉| Fitting SlidingEstimator : 1097/1100 [00:08<00:00,  128.86it/s]
#
#  52%|█████▏    | Fitting SlidingEstimator : 567/1100 [00:04<00:04,  129.15it/s]
# 100%|█████████▉| Fitting SlidingEstimator : 1099/1100 [00:08<00:00,  125.53it/s]
#
#  52%|█████▏    | Fitting SlidingEstimator : 572/1100 [00:04<00:04,  129.32it/s]
# 100%|██████████| Fitting SlidingEstimator : 1100/1100 [00:08<00:00,  131.59it/s]
#
#
#  52%|█████▏    | Fitting SlidingEstimator : 575/1100 [00:04<00:04,  127.01it/s]
#
#
#   0%|          | Fitting SlidingEstimator : 0/1100 [00:00<?,       ?it/s]
#
#  53%|█████▎    | Fitting SlidingEstimator : 581/1100 [00:04<00:04,  129.18it/s]
#
#  53%|█████▎    | Fitting SlidingEstimator : 585/1100 [00:04<00:04,  128.32it/s]
#
#
#   1%|          | Fitting SlidingEstimator : 6/1100 [00:00<00:13,   79.82it/s]
#
#  54%|█████▎    | Fitting SlidingEstimator : 591/1100 [00:04<00:03,  130.35it/s]
#
#
#   1%|          | Fitting SlidingEstimator : 10/1100 [00:00<00:12,   89.50it/s]
#
#  54%|█████▍    | Fitting SlidingEstimator : 595/1100 [00:04<00:03,  129.77it/s]
#
#
#   1%|▏         | Fitting SlidingEstimator : 16/1100 [00:00<00:09,  109.15it/s]
#
#  55%|█████▍    | Fitting SlidingEstimator : 601/1100 [00:04<00:03,  132.03it/s]
#
#
#   2%|▏         | Fitting SlidingEstimator : 21/1100 [00:00<00:09,  115.11it/s]
#
#  55%|█████▌    | Fitting SlidingEstimator : 607/1100 [00:04<00:03,  133.97it/s]
#
#
#   3%|▎         | Fitting SlidingEstimator : 28/1100 [00:00<00:08,  128.51it/s]
#
#  56%|█████▌    | Fitting SlidingEstimator : 611/1100 [00:04<00:03,  132.46it/s]
#
#
#   3%|▎         | Fitting SlidingEstimator : 31/1100 [00:00<00:08,  120.47it/s]
#
#  56%|█████▌    | Fitting SlidingEstimator : 617/1100 [00:04<00:03,  134.27it/s]
#
#
#   3%|▎         | Fitting SlidingEstimator : 36/1100 [00:00<00:08,  123.80it/s]
#
#  56%|█████▋    | Fitting SlidingEstimator : 621/1100 [00:04<00:03,  133.27it/s]
#
#
#   4%|▎         | Fitting SlidingEstimator : 41/1100 [00:00<00:08,  126.37it/s]
#
#  57%|█████▋    | Fitting SlidingEstimator : 626/1100 [00:04<00:03,  133.61it/s]
#
#
#   4%|▍         | Fitting SlidingEstimator : 46/1100 [00:00<00:08,  127.02it/s]
#
#  57%|█████▋    | Fitting SlidingEstimator : 632/1100 [00:04<00:03,  135.63it/s]
#
#
#   5%|▍         | Fitting SlidingEstimator : 53/1100 [00:00<00:07,  135.46it/s]
#
#  58%|█████▊    | Fitting SlidingEstimator : 639/1100 [00:04<00:03,  137.16it/s]
#
#
#   5%|▌         | Fitting SlidingEstimator : 57/1100 [00:00<00:07,  132.86it/s]
#
#  59%|█████▊    | Fitting SlidingEstimator : 644/1100 [00:04<00:03,  136.87it/s]
#
#
#   6%|▌         | Fitting SlidingEstimator : 61/1100 [00:00<00:07,  131.15it/s]
#
#  59%|█████▉    | Fitting SlidingEstimator : 649/1100 [00:04<00:03,  137.25it/s]
#
#
#   6%|▌         | Fitting SlidingEstimator : 66/1100 [00:00<00:07,  132.66it/s]
#
#  59%|█████▉    | Fitting SlidingEstimator : 653/1100 [00:04<00:03,  136.31it/s]
#
#
#   7%|▋         | Fitting SlidingEstimator : 72/1100 [00:00<00:07,  136.14it/s]
#
#  60%|██████    | Fitting SlidingEstimator : 661/1100 [00:04<00:03,  139.61it/s]
#
#
#   7%|▋         | Fitting SlidingEstimator : 77/1100 [00:00<00:07,  137.13it/s]
#
#  60%|██████    | Fitting SlidingEstimator : 665/1100 [00:04<00:03,  138.53it/s]
#
#
#   8%|▊         | Fitting SlidingEstimator : 83/1100 [00:00<00:07,  140.35it/s]
#
#  61%|██████    | Fitting SlidingEstimator : 670/1100 [00:04<00:03,  138.97it/s]
#
#
#   8%|▊         | Fitting SlidingEstimator : 87/1100 [00:00<00:07,  137.63it/s]
#
#  61%|██████▏   | Fitting SlidingEstimator : 674/1100 [00:04<00:03,  137.85it/s]
#
#
#   8%|▊         | Fitting SlidingEstimator : 92/1100 [00:00<00:07,  138.07it/s]
#
#  62%|██████▏   | Fitting SlidingEstimator : 679/1100 [00:05<00:03,  138.15it/s]
#
#
#   9%|▉         | Fitting SlidingEstimator : 97/1100 [00:00<00:07,  138.62it/s]
#
#  62%|████���█▏   | Fitting SlidingEstimator : 684/1100 [00:05<00:03,  138.44it/s]
#
#
#   9%|▉         | Fitting SlidingEstimator : 103/1100 [00:00<00:07,  140.85it/s]
#
#  63%|██████▎   | Fitting SlidingEstimator : 690/1100 [00:05<00:02,  139.84it/s]
#
#
#  10%|▉         | Fitting SlidingEstimator : 108/1100 [00:00<00:07,  140.39it/s]
#
#  63%|██████▎   | Fitting SlidingEstimator : 696/1100 [00:05<00:02,  140.95it/s]
#
#
#  10%|█         | Fitting SlidingEstimator : 113/1100 [00:00<00:07,  140.29it/s]
#
#  64%|██████▍   | Fitting SlidingEstimator : 702/1100 [00:05<00:02,  142.55it/s]
#
#
#  11%|█         | Fitting SlidingEstimator : 118/1100 [00:00<00:06,  140.66it/s]
#
#  64%|██████▍   | Fitting SlidingEstimator : 708/1100 [00:05<00:02,  143.42it/s]
#
#
#  11%|█         | Fitting SlidingEstimator : 123/1100 [00:00<00:06,  140.75it/s]
#
#  65%|██████▍   | Fitting SlidingEstimator : 714/1100 [00:05<00:02,  145.01it/s]
#
#
#  12%|█▏        | Fitting SlidingEstimator : 129/1100 [00:00<00:06,  141.92it/s]
#
#  65%|██████▌   | Fitting SlidingEstimator : 719/1100 [00:05<00:02,  144.97it/s]
#
#
#  12%|█▏        | Fitting SlidingEstimator : 135/1100 [00:00<00:06,  144.03it/s]
#
#  66%|██████▌   | Fitting SlidingEstimator : 724/1100 [00:05<00:02,  144.33it/s]
#
#
#  13%|█▎        | Fitting SlidingEstimator : 141/1100 [00:01<00:06,  146.08it/s]
#
#  66%|██████▋   | Fitting SlidingEstimator : 729/1100 [00:05<00:02,  144.42it/s]
#
#
#  13%|█▎        | Fitting SlidingEstimator : 147/1100 [00:01<00:06,  146.98it/s]
#
#  67%|██████▋   | Fitting SlidingEstimator : 734/1100 [00:05<00:02,  144.03it/s]
#
#
#  14%|█▍        | Fitting SlidingEstimator : 152/1100 [00:01<00:06,  146.96it/s]
#
#  67%|██████▋   | Fitting SlidingEstimator : 739/1100 [00:05<00:02,  144.20it/s]
#
#
#  14%|█▍        | Fitting SlidingEstimator : 157/1100 [00:01<00:06,  146.30it/s]
#
#  68%|██████▊   | Fitting SlidingEstimator : 745/1100 [00:05<00:02,  145.42it/s]
#
#
#  15%|█▍        | Fitting SlidingEstimator : 162/1100 [00:01<00:06,  146.16it/s]
#
#  68%|██████▊   | Fitting SlidingEstimator : 751/1100 [00:05<00:02,  146.31it/s]
#
#
#  15%|█▌        | Fitting SlidingEstimator : 168/1100 [00:01<00:06,  147.45it/s]
#
#  69%|██████▉   | Fitting SlidingEstimator : 758/1100 [00:05<00:02,  148.00it/s]
#
#
#  16%|█▌        | Fitting SlidingEstimator : 173/1100 [00:01<00:06,  146.99it/s]
#
#  69%|██████▉   | Fitting SlidingEstimator : 764/1100 [00:05<00:02,  149.33it/s]
#
#
#  16%|█▌        | Fitting SlidingEstimator : 178/1100 [00:01<00:06,  146.93it/s]
#
#  70%|██████▉   | Fitting SlidingEstimator : 769/1100 [00:05<00:02,  149.13it/s]
#
#
#  17%|█▋        | Fitting SlidingEstimator : 183/1100 [00:01<00:06,  146.70it/s]
#
#  70%|███████   | Fitting SlidingEstimator : 774/1100 [00:05<00:02,  148.82it/s]
#
#
#  17%|█▋        | Fitting SlidingEstimator : 190/1100 [00:01<00:06,  148.76it/s]
#
#  71%|███████   | Fitting SlidingEstimator : 779/1100 [00:05<00:02,  148.40it/s]
#
#
#  18%|█▊        | Fitting SlidingEstimator : 195/1100 [00:01<00:06,  148.42it/s]
#
#  71%|███████▏  | Fitting SlidingEstimator : 785/1100 [00:05<00:02,  149.20it/s]
#
#
#  18%|█▊        | Fitting SlidingEstimator : 200/1100 [00:01<00:06,  148.07it/s]
#
#  72%|███████▏  | Fitting SlidingEstimator : 791/1100 [00:05<00:02,  150.44it/s]
#
#
#  19%|█▉        | Fitting SlidingEstimator : 207/1100 [00:01<00:05,  151.18it/s]
#
#  72%|███████▏  | Fitting SlidingEstimator : 796/1100 [00:05<00:02,  150.25it/s]
#
#
#  19%|█▉        | Fitting SlidingEstimator : 211/1100 [00:01<00:05,  149.04it/s]
#
#  73%|███████▎  | Fitting SlidingEstimator : 803/1100 [00:05<00:01,  152.76it/s]
#
#
#  20%|█▉        | Fitting SlidingEstimator : 216/1100 [00:01<00:05,  148.93it/s]
#
#  73%|███████▎  | Fitting SlidingEstimator : 807/1100 [00:05<00:01,  150.91it/s]
#
#
#  20%|██        | Fitting SlidingEstimator : 222/1100 [00:01<00:05,  150.33it/s]
#
#  74%|███████▍  | Fitting SlidingEstimator : 813/1100 [00:05<00:01,  151.80it/s]
#
#
#  21%|██        | Fitting SlidingEstimator : 228/1100 [00:01<00:05,  151.70it/s]
#
#  74%|███████▍  | Fitting SlidingEstimator : 818/1100 [00:05<00:01,  151.36it/s]
#
#
#  21%|██        | Fitting SlidingEstimator : 233/1100 [00:01<00:05,  151.35it/s]
#
#  75%|███████▍  | Fitting SlidingEstimator : 822/1100 [00:05<00:01,  149.03it/s]
#
#
#  22%|██▏       | Fitting SlidingEstimator : 238/1100 [00:01<00:05,  148.53it/s]
#
#  75%|███████▌  | Fitting SlidingEstimator : 827/1100 [00:05<00:01,  148.69it/s]
#
#
#  22%|██▏       | Fitting SlidingEstimator : 244/1100 [00:01<00:05,  149.66it/s]
#
#  76%|███████▌  | Fitting SlidingEstimator : 832/1100 [00:06<00:01,  148.35it/s]
#
#
#  23%|██▎       | Fitting SlidingEstimator : 250/1100 [00:01<00:05,  151.02it/s]
#
#  76%|███████▌  | Fitting SlidingEstimator : 837/1100 [00:06<00:01,  147.83it/s]
#
#
#  23%|██▎       | Fitting SlidingEstimator : 257/1100 [00:01<00:05,  153.18it/s]
#
#  77%|███████▋  | Fitting SlidingEstimator : 842/1100 [00:06<00:01,  147.73it/s]
#
#
#  24%|██▍       | Fitting SlidingEstimator : 263/1100 [00:01<00:05,  154.40it/s]
#
#  77%|███████▋  | Fitting SlidingEstimator : 847/1100 [00:06<00:01,  147.39it/s]
#
#
#  24%|██▍       | Fitting SlidingEstimator : 267/1100 [00:01<00:05,  152.33it/s]
#
#  77%|███████▋  | Fitting SlidingEstimator : 851/1100 [00:06<00:01,  146.01it/s]
#
#
#  25%|██▍       | Fitting SlidingEstimator : 273/1100 [00:01<00:05,  153.14it/s]
#
#  78%|███████▊  | Fitting SlidingEstimator : 856/1100 [00:06<00:01,  146.07it/s]
#
#
#  25%|██▌       | Fitting SlidingEstimator : 279/1100 [00:01<00:05,  154.15it/s]
#
#  78%|███████▊  | Fitting SlidingEstimator : 862/1100 [00:06<00:01,  146.83it/s]
#
#
#  26%|██▌       | Fitting SlidingEstimator : 283/1100 [00:01<00:05,  152.16it/s]
#
#  79%|███████▉  | Fitting SlidingEstimator : 868/1100 [00:06<00:01,  147.42it/s]
#
#
#  26%|██▋       | Fitting SlidingEstimator : 290/1100 [00:01<00:05,  154.42it/s]
#
#  79%|███████▉  | Fitting SlidingEstimator : 873/1100 [00:06<00:01,  147.31it/s]
#
#
#  27%|██▋       | Fitting SlidingEstimator : 293/1100 [00:01<00:05,  150.67it/s]
#
#  80%|███████▉  | Fitting SlidingEstimator : 879/1100 [00:06<00:01,  148.10it/s]
#
#
#  27%|██▋       | Fitting SlidingEstimator : 298/1100 [00:02<00:05,  150.48it/s]
#
#  80%|████████  | Fitting SlidingEstimator : 884/1100 [00:06<00:01,  147.72it/s]
#
#
#  27%|██▋       | Fitting SlidingEstimator : 302/1100 [00:02<00:05,  148.34it/s]
#
#  81%|████████  | Fitting SlidingEstimator : 889/1100 [00:06<00:01,  147.69it/s]
#
#
#  28%|██▊       | Fitting SlidingEstimator : 306/1100 [00:02<00:05,  146.58it/s]
#
#  81%|████████  | Fitting SlidingEstimator : 893/1100 [00:06<00:01,  144.92it/s]
#
#
#  28%|██▊       | Fitting SlidingEstimator : 310/1100 [00:02<00:05,  144.33it/s]
#
#  82%|████████▏ | Fitting SlidingEstimator : 898/1100 [00:06<00:01,  144.05it/s]
#
#
#  29%|██▊       | Fitting SlidingEstimator : 315/1100 [00:02<00:05,  144.38it/s]
#
#  82%|████████▏ | Fitting SlidingEstimator : 902/1100 [00:06<00:01,  142.69it/s]
#
#
#  29%|██▉       | Fitting SlidingEstimator : 319/1100 [00:02<00:05,  142.23it/s]
#
#  82%|████████▏ | Fitting SlidingEstimator : 907/1100 [00:06<00:01,  142.83it/s]
#
#
#  29%|██▉       | Fitting SlidingEstimator : 324/1100 [00:02<00:05,  142.42it/s]
#
#  83%|████████▎ | Fitting SlidingEstimator : 912/1100 [00:06<00:01,  142.96it/s]
#
#
#  30%|██▉       | Fitting SlidingEstimator : 329/1100 [00:02<00:05,  141.87it/s]
#
#  83%|████████▎ | Fitting SlidingEstimator : 916/1100 [00:06<00:01,  141.14it/s]
#
#
#  31%|███       | Fitting SlidingEstimator : 336/1100 [00:02<00:05,  144.81it/s]
#
#  84%|████████▎ | Fitting SlidingEstimator : 921/1100 [00:06<00:01,  141.23it/s]
#
#
#  31%|███       | Fitting SlidingEstimator : 339/1100 [00:02<00:05,  141.93it/s]
#
#  84%|████████▍ | Fitting SlidingEstimator : 925/1100 [00:06<00:01,  139.23it/s]
#
#
#  31%|███       | Fitting SlidingEstimator : 343/1100 [00:02<00:05,  140.47it/s]
#
#  85%|████████▍ | Fitting SlidingEstimator : 931/1100 [00:06<00:01,  140.32it/s]
#
#
#  32%|███▏      | Fitting SlidingEstimator : 348/1100 [00:02<00:05,  140.24it/s]
#
#  85%|████████▌ | Fitting SlidingEstimator : 935/1100 [00:06<00:01,  139.26it/s]
#
#
#  32%|███▏      | Fitting SlidingEstimator : 353/1100 [00:02<00:05,  140.09it/s]
#
#  86%|████████▌ | Fitting SlidingEstimator : 941/1100 [00:06<00:01,  139.83it/s]
#
#
#  32%|███▏      | Fitting SlidingEstimator : 356/1100 [00:02<00:05,  137.50it/s]
#
#  86%|████████▌ | Fitting SlidingEstimator : 944/1100 [00:06<00:01,  136.36it/s]
#
#
#  33%|███▎      | Fitting SlidingEstimator : 361/1100 [00:02<00:05,  137.77it/s]
#
#  86%|████████▌ | Fitting SlidingEstimator : 948/1100 [00:06<00:01,  135.41it/s]
#
#
#  33%|███▎      | Fitting SlidingEstimator : 366/1100 [00:02<00:05,  137.70it/s]
#
#  87%|███████���▋ | Fitting SlidingEstimator : 952/1100 [00:06<00:01,  134.16it/s]
#
#
#  34%|███▍      | Fitting SlidingEstimator : 372/1100 [00:02<00:05,  139.02it/s]
#
#  87%|████████▋ | Fitting SlidingEstimator : 957/1100 [00:06<00:01,  134.41it/s]
#
#
#  34%|███▍      | Fitting SlidingEstimator : 375/1100 [00:02<00:05,  136.44it/s]
#
#  87%|████████▋ | Fitting SlidingEstimator : 960/1100 [00:06<00:01,  131.27it/s]
#
#
#  35%|███▍      | Fitting SlidingEstimator : 381/1100 [00:02<00:05,  137.53it/s]
#
#
#  35%|███▍      | Fitting SlidingEstimator : 384/1100 [00:02<00:05,  135.15it/s]
#
#  88%|████████▊ | Fitting SlidingEstimator : 967/1100 [00:07<00:00,  133.54it/s]
#
#
#  35%|███▌      | Fitting SlidingEstimator : 390/1100 [00:02<00:05,  137.02it/s]
#
#  88%|████████▊ | Fitting SlidingEstimator : 971/1100 [00:07<00:00,  130.37it/s]
#
#
#  36%|███▌      | Fitting SlidingEstimator : 394/1100 [00:02<00:05,  135.97it/s]
#
#  89%|████████▊ | Fitting SlidingEstimator : 976/1100 [00:07<00:00,  130.63it/s]
#
#
#  36%|███▋      | Fitting SlidingEstimator : 399/1100 [00:02<00:05,  136.07it/s]
#
#  89%|████████▉ | Fitting SlidingEstimator : 980/1100 [00:07<00:00,  129.29it/s]
#
#
#  37%|███▋      | Fitting SlidingEstimator : 403/1100 [00:02<00:05,  135.11it/s]
#
#  89%|████████▉ | Fitting SlidingEstimator : 984/1100 [00:07<00:00,  128.70it/s]
#
#
#  37%|███▋      | Fitting SlidingEstimator : 409/1100 [00:02<00:05,  135.62it/s]
#
#  90%|████████▉ | Fitting SlidingEstimator : 987/1100 [00:07<00:00,  126.87it/s]
#
#
#  38%|███▊      | Fitting SlidingEstimator : 413/1100 [00:02<00:05,  134.02it/s]
#
#  90%|█████████ | Fitting SlidingEstimator : 993/1100 [00:07<00:00,  127.96it/s]
#
#
#  38%|███▊      | Fitting SlidingEstimator : 417/1100 [00:02<00:05,  132.79it/s]
#
#  91%|█████████ | Fitting SlidingEstimator : 999/1100 [00:07<00:00,  128.46it/s]
#
#
#  38%|███▊      | Fitting SlidingEstimator : 422/1100 [00:03<00:05,  133.32it/s]
#
#  91%|█████████ | Fitting SlidingEstimator : 1002/1100 [00:07<00:00,  126.19it/s]
#
#
#  39%|███▉      | Fitting SlidingEstimator : 427/1100 [00:03<00:05,  133.67it/s]
#
#  92%|█████████▏| Fitting SlidingEstimator : 1008/1100 [00:07<00:00,  128.26it/s]
#
#
#  39%|███▉      | Fitting SlidingEstimator : 432/1100 [00:03<00:04,  134.31it/s]
#
#  92%|█████████▏| Fitting SlidingEstimator : 1013/1100 [00:07<00:00,  129.03it/s]
#
#
#  40%|███▉      | Fitting SlidingEstimator : 436/1100 [00:03<00:04,  133.40it/s]
#
#  92%|█████████▏| Fitting SlidingEstimator : 1017/1100 [00:07<00:00,  128.53it/s]
#
#
#  40%|████      | Fitting SlidingEstimator : 442/1100 [00:03<00:04,  134.86it/s]
#
#  93%|█████████▎| Fitting SlidingEstimator : 1022/1100 [00:07<00:00,  129.37it/s]
#
#
#  41%|████      | Fitting SlidingEstimator : 447/1100 [00:03<00:04,  134.80it/s]
#
#  93%|█████████▎| Fitting SlidingEstimator : 1028/1100 [00:07<00:00,  131.28it/s]
#
#
#  41%|████      | Fitting SlidingEstimator : 452/1100 [00:03<00:04,  134.75it/s]
#
#  94%|█████████▍| Fitting SlidingEstimator : 1033/1100 [00:07<00:00,  132.03it/s]
#
#
#  42%|████▏     | Fitting SlidingEstimator : 457/1100 [00:03<00:04,  134.67it/s]
#
#  94%|█████████▍| Fitting SlidingEstimator : 1039/1100 [00:07<00:00,  133.40it/s]
#
#
#  42%|████▏     | Fitting SlidingEstimator : 461/1100 [00:03<00:04,  133.64it/s]
#
#  95%|█████████▍| Fitting SlidingEstimator : 1041/1100 [00:07<00:00,  129.84it/s]
#
#
#  42%|████▏     | Fitting SlidingEstimator : 465/1100 [00:03<00:04,  132.36it/s]
#
#  95%|█████████▌| Fitting SlidingEstimator : 1047/1100 [00:07<00:00,  131.64it/s]
#
#
#  42%|████▏     | Fitting SlidingEstimator : 467/1100 [00:03<00:04,  128.74it/s]
#
#  96%|█████████▌| Fitting SlidingEstimator : 1052/1100 [00:07<00:00,  132.00it/s]
#
#
#  43%|████▎     | Fitting SlidingEstimator : 472/1100 [00:03<00:04,  128.97it/s]
#
#  96%|█████████▌| Fitting SlidingEstimator : 1056/1100 [00:07<00:00,  131.21it/s]
#
#
#  43%|████▎     | Fitting SlidingEstimator : 476/1100 [00:03<00:04,  128.22it/s]
#
#  96%|█████████▌| Fitting SlidingEstimator : 1058/1100 [00:07<00:00,  127.51it/s]
#
#
#  44%|████▎     | Fitting SlidingEstimator : 480/1100 [00:03<00:04,  126.40it/s]
#
#  97%|█████████▋| Fitting SlidingEstimator : 1063/1100 [00:07<00:00,  128.21it/s]
#
#
#  44%|████▍     | Fitting SlidingEstimator : 483/1100 [00:03<00:04,  124.54it/s]
#
#  97%|█████████▋| Fitting SlidingEstimator : 1068/1100 [00:07<00:00,  128.69it/s]
#
#
#  44%|████▍     | Fitting SlidingEstimator : 489/1100 [00:03<00:04,  126.54it/s]
#
#  97%|█████████▋| Fitting SlidingEstimator : 1072/1100 [00:07<00:00,  127.85it/s]
#
#
#  45%|████▍     | Fitting SlidingEstimator : 492/1100 [00:03<00:04,  124.05it/s]
#
#  98%|█████████▊| Fitting SlidingEstimator : 1078/1100 [00:07<00:00,  129.45it/s]
#
#
#  45%|████▌     | Fitting SlidingEstimator : 496/1100 [00:03<00:04,  123.30it/s]
#
#  98%|█████████▊| Fitting SlidingEstimator : 1083/1100 [00:07<00:00,  130.01it/s]
#
#
#  45%|████▌     | Fitting SlidingEstimator : 500/1100 [00:03<00:04,  122.51it/s]
#
#  99%|█████████▉| Fitting SlidingEstimator : 1088/1100 [00:07<00:00,  130.29it/s]
#
#
#  46%|████▌     | Fitting SlidingEstimator : 504/1100 [00:03<00:04,  122.16it/s]
#
#  99%|█████████▉| Fitting SlidingEstimator : 1093/1100 [00:08<00:00,  131.06it/s]
#
#
#  46%|████▋     | Fitting SlidingEstimator : 510/1100 [00:03<00:04,  124.47it/s]
#
# 100%|█████████▉| Fitting SlidingEstimator : 1096/1100 [00:08<00:00,  128.88it/s]
#
# 100%|██████████| Fitting SlidingEstimator : 1100/1100 [00:08<00:00,  128.32it/s]
#
#
# 100%|██████████| Fitting SlidingEstimator : 1100/1100 [00:08<00:00,  136.06it/s][A
#
#
#
#  47%|████▋     | Fitting SlidingEstimator : 520/1100 [00:03<00:04,  125.06it/s]
#
#
#  48%|████▊     | Fitting SlidingEstimator : 525/1100 [00:03<00:04,  124.67it/s]
#
#
#  48%|████▊     | Fitting SlidingEstimator : 531/1100 [00:03<00:04,  126.70it/s]
#
#
#  49%|████▊     | Fitting SlidingEstimator : 536/1100 [00:03<00:04,  126.97it/s]
#
#
#  49%|████▉     | Fitting SlidingEstimator : 540/1100 [00:03<00:04,  125.82it/s]
#
#
#  49%|████▉     | Fitting SlidingEstimator : 544/1100 [00:03<00:04,  124.92it/s]
#
#
#  50%|████▉     | Fitting SlidingEstimator : 548/1100 [00:04<00:04,  124.54it/s]
#
#
#  50%|█████     | Fitting SlidingEstimator : 551/1100 [00:04<00:04,  122.73it/s]
#
#
#
#   0%|          | Fitting SlidingEstimator : 0/1100 [00:00<?,       ?it/s]
#
#
#  50%|█████     | Fitting SlidingEstimator : 553/1100 [00:04<00:04,  119.69it/s]
#
#
#
#   0%|          | Fitting SlidingEstimator : 1/1100 [00:00<00:38,   28.29it/s]
#
#
#  51%|█████     | Fitting SlidingEstimator : 560/1100 [00:04<00:04,  121.48it/s]
#
#
#
#   1%|          | Fitting SlidingEstimator : 6/1100 [00:00<00:13,   82.55it/s]
#
#
#  51%|█████▏    | Fitting SlidingEstimator : 565/1100 [00:04<00:04,  121.81it/s]
#
#
#
#   1%|          | Fitting SlidingEstimator : 10/1100 [00:00<00:11,   94.28it/s]
#
#
#  52%|█████▏    | Fitting SlidingEstimator : 570/1100 [00:04<00:04,  122.77it/s]
#
#
#
#   1%|▏         | Fitting SlidingEstimator : 15/1100 [00:00<00:10,  107.34it/s]
#
#
#
#
#
#
#  52%|█████▏    | Fitting SlidingEstimator : 575/1100 [00:04<00:04,  123.42it/s][A
#
#
#  53%|█████▎    | Fitting SlidingEstimator : 580/1100 [00:04<00:04,  124.23it/s]
#
#
#
#   2%|▏         | Fitting SlidingEstimator : 25/1100 [00:00<00:09,  117.66it/s]
#
#
#  53%|█████▎    | Fitting SlidingEstimator : 583/1100 [00:04<00:04,  122.49it/s]
#
#
#
#   3%|▎         | Fitting SlidingEstimator : 28/1100 [00:00<00:09,  112.85it/s]
#
#
#  53%|█████▎    | Fitting SlidingEstimator : 588/1100 [00:04<00:04,  123.56it/s]
#
#
#
#   3%|▎         | Fitting SlidingEstimator : 34/1100 [00:00<00:08,  119.12it/s]
#
#
#  54%|█████▍    | Fitting SlidingEstimator : 592/1100 [00:04<00:04,  122.65it/s]
#
#
#
#   3%|▎         | Fitting SlidingEstimator : 38/1100 [00:00<00:08,  118.79it/s]
#
#
#  54%|█████▍    | Fitting SlidingEstimator : 595/1100 [00:04<00:04,  121.01it/s]
#
#
#
#   4%|▍         | Fitting SlidingEstimator : 42/1100 [00:00<00:09,  117.46it/s]
#
#
#  54%|█████▍    | Fitting SlidingEstimator : 598/1100 [00:04<00:04,  119.03it/s]
#
#
#
#   4%|▍         | Fitting SlidingEstimator : 47/1100 [00:00<00:08,  117.71it/s]
#
#
#  55%|█████▍    | Fitting SlidingEstimator : 602/1100 [00:04<00:04,  118.73it/s]
#
#
#
#   5%|▍         | Fitting SlidingEstimator : 50/1100 [00:00<00:09,  114.48it/s]
#
#
#  55%|█████▌    | Fitting SlidingEstimator : 605/1100 [00:04<00:04,  117.26it/s]
#
#
#
# ...
# /tmp/ipykernel_127397/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_127397/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]

# %%
cv_scores_pre_250ms_endo_arr = np.array(cv_scores_pre_250ms_endo)
cv_scores_pre_250ms_endo_arr = np.abs(cv_scores_pre_250ms_endo_arr-cv_scores_pre_250ms_endo_arr.mean()) + .5
cv_scores_pre_250ms_exo_arr = np.array(cv_scores_pre_250ms_exo)
cv_scores_pre_250ms_exo_arr = np.abs(cv_scores_pre_250ms_exo_arr-cv_scores_pre_250ms_exo_arr.mean()) + .5
plt.plot(exo.times, cv_scores_pre_250ms_endo_arr)
plt.plot(exo.times, cv_scores_pre_250ms_exo_arr)

# %%
np.save('files/B2_decoding.npy', np.vstack([cv_scores_pre_250ms_endo_arr, cv_scores_pre_250ms_exo_arr]))
np.save('files/decoding_times.npy', exo.times)
