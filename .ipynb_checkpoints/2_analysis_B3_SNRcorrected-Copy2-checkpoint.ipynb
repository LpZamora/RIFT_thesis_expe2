# %%
data_path = '/home/lea/Documents/obsidian_notes/masterADS/ads_thesis_RIFT/my_code_expe2'
data_file = '/data/B3/data.mat'
epoch_file = '/data/B3/preprocessing/B3_EEG_epo.fif'

relevant_electrodes = ['O2','PO4','PO8','P8','P4','P6','P2','P1','P3','P5','P7','PO7','PO3','O1','Pz','POz','Oz','Iz']

# Dic to index trial_info matrix
info_colnames = {'reaction_times':0,'reaction_err':1, 'answer':2,'base_delay':3,\
                      'target_timings':4, 'flicker_sides':5, 'cued_side':6, 'orients_L':7, 'orients_R':8,\
                      'angle_magnitude':9, 'probe_sides':10, 'targets_binary':12, 'attention_type_block':13,\
                      'trial_num_my_rec':14}
info_colnumtonames = {v: k for k, v in info_colnames.items()}

# %%
import scipy.io as sio
import scipy
import numpy as np
import pandas as pd
import mne
from mne.time_frequency import EpochsTFRArray
import matplotlib.pyplot as plt
import copy
from collections import Counter
from frequency_tagging_funs import snr_spectrum, frequency_rescaling

from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from mne.decoding import (
    CSP,
    GeneralizingEstimator,
    LinearModel,
    Scaler,
    SlidingEstimator,
    Vectorizer,
    cross_val_multiscore,
    get_coef,
)

f = sio.loadmat(f'{data_path}{data_file}')

# Create pd df to pass to mne metadata
pd_info = {}
for i, column in enumerate(f['data'][0][0]):
    if i in info_colnames.values():
        # Remove practice trials
        column = column[4:,:]
        # Collapse to trial indexes
        original_shape = column.shape
        new_shape = (original_shape[0] * original_shape[1],) + original_shape[2:]
        column = np.reshape(column, new_shape)
        pd_info[info_colnumtonames[i]] = column
pd_info = pd.DataFrame(pd_info, columns=info_colnames.keys())
pd_info 

# Load eeg epochs .fif and add metadata
epochs = mne.read_epochs(f'{data_path}{epoch_file}')
epoch_good = [x for x,y in enumerate(epochs.drop_log) if len(y) == 0]
epochs.metadata = pd_info.iloc[epoch_good]
# Out:
# Reading /home/lea/Documents/obsidian_notes/masterADS/ads_thesis_RIFT/my_code_expe2/data/B3/preprocessing/B3_EEG_epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 510 matching events found
# No baseline correction applied
# 0 projection items activated
# Adding metadata with 14 columns

# %%
# Keep only posterior electrodes
epochs.pick_channels(relevant_electrodes)
# Out:
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# <EpochsFIF |  510 events (all good), -1 – 2 s, baseline -1 – 0 s, ~430.4 MB, data loaded, with metadata,
#  '3': 510>

# %%
# Keep only trials where there was no target
epochs = epochs['targets_binary==0']

# %% [markdown]
# # A. Endogeneous condition
# ## 1 FFT & SNR

# %%
# Simplify metadata
epochs.metadata['flicker_sides'] = epochs.metadata['flicker_sides'].replace({0: 6064, 1: 6460})
epochs.metadata['cued_side'] = epochs.metadata['cued_side'].replace({0: 'left', 1: 'right'})

condition_1 = ((epochs.metadata['flicker_sides'] == 6064.0) & (epochs.metadata['cued_side'] == 'left')) | \
    ((epochs.metadata['flicker_sides'] == 6460.0) & (epochs.metadata['cued_side'] == 'right'))
condition_2 = ((epochs.metadata['flicker_sides'] == 6064.0) & (epochs.metadata['cued_side'] == 'right')) | \
    ((epochs.metadata['flicker_sides'] == 6460.0) & (epochs.metadata['cued_side'] == 'left'))
epochs.metadata['cued_tag'] = np.where(condition_1, 60, np.where(condition_2, 64, np.nan))
epochs_endo = epochs['attention_type_block==1'].copy()
epochs_exo = epochs['attention_type_block==0'].copy()

# %%
# Fast Fourier Transform
# adapted from https://mne.tools/dev/auto_tutorials/time-freq/50_ssvep.html

sfreq = epochs.info["sfreq"]
tmin = 0 # Search in window starting from cue (when SSVEP is expected)
tmax = 2
fmin = 1.0
fmax = 90

# Spectrum of the signal averaged over trials
spectrum_endo = epochs_endo.copy().average().compute_psd(
    "welch",
    n_fft=int(sfreq * (tmax - tmin)),
    n_overlap=0,
    n_per_seg=None,
    tmin=tmin,
    tmax=tmax,
    fmin=fmin,
    fmax=fmax,
    window="hamming",
    verbose=False,
)
psds_endo, freqs_psd = spectrum_endo.get_data(return_freqs=True)
spectrum_exo = epochs_exo.copy().average().compute_psd(
    "welch",
    n_fft=int(sfreq * (tmax - tmin)),
    n_overlap=0,
    n_per_seg=None,
    tmin=tmin,
    tmax=tmax,
    fmin=fmin,
    fmax=fmax,
    window="hamming",
    verbose=False,
)
psds_exo, freqs_psd = spectrum_exo.get_data(return_freqs=True)


# Get bins to exlude from regularization (close neighbors ±0.5Hz)  
bin_size = np.diff(freqs_psd)[0]
skip_nei = int((0.5 - bin_size/2)//bin_size) 

# Get bins to include in regularization (neighbors within +/- 2-0.5Hz)
used_nei = int((2 - bin_size/2) // bin_size)  # Total bins within ±2 Hz
used_nei = used_nei - skip_nei # Bins within (0.5 Hz, 2 Hz]

snrs_endo = snr_spectrum(psds_endo, noise_n_neighbor_freqs=used_nei, noise_skip_neighbor_freqs = skip_nei)
snrs_exo = snr_spectrum(psds_exo, noise_n_neighbor_freqs=used_nei, noise_skip_neighbor_freqs = skip_nei)

fig, axes = plt.subplots(2, 2, sharex="all", sharey="none", figsize=(8, 5))
freq_range = range(
    np.where(np.floor(freqs_psd) == 1.0)[0][0], np.where(np.ceil(freqs_psd) == fmax - 1)[0][0]
)

psds_plot = 10 * np.log10(psds_endo)
psds_mean = psds_plot.mean(axis=(0))[freq_range]
psds_std = psds_plot.std(axis=(0))[freq_range]
axes[0,0].plot(freqs_psd[freq_range], psds_mean, color="b")
axes[0,0].fill_between(
    freqs_psd[freq_range], psds_mean - psds_std, psds_mean + psds_std, color="b", alpha=0.2
)
axes[0,0].set(title="PSD spectrum endogeneous", ylabel="Power Spectral Density [dB]")
psds_plot = 10 * np.log10(psds_exo)
psds_mean = psds_plot.mean(axis=(0))[freq_range]
psds_std = psds_plot.std(axis=(0))[freq_range]
axes[0,1].plot(freqs_psd[freq_range], psds_mean, color="b")
axes[0,1].fill_between(
    freqs_psd[freq_range], psds_mean - psds_std, psds_mean + psds_std, color="b", alpha=0.2
)
axes[0,1].set(title="PSD spectrum exogeneous", ylabel="Power Spectral Density [dB]")

# SNR spectrum
snr_mean = snrs_endo.mean(axis=(0))[freq_range]
snr_std = snrs_endo.std(axis=(0))[freq_range]

axes[1,0].plot(freqs_psd[freq_range], snr_mean, color="r")
axes[1,0].fill_between(
    freqs_psd[freq_range], snr_mean - snr_std, snr_mean + snr_std, color="r", alpha=0.2
)
axes[1,0].set(
    title="SNR spectrum endogeneous",
    xlabel="Frequency [Hz]",
    ylabel="SNR",
    ylim=[-2, 15],
    xlim=[fmin, fmax],
)
snr_mean = snrs_exo.mean(axis=(0))[freq_range]
snr_std = snrs_exo.std(axis=(0))[freq_range]

axes[1,1].plot(freqs_psd[freq_range], snr_mean, color="r")
axes[1,1].fill_between(
    freqs_psd[freq_range], snr_mean - snr_std, snr_mean + snr_std, color="r", alpha=0.2
)
axes[1,1].set(
    title="SNR spectrum exogeneous",
    xlabel="Frequency [Hz]",
    ylabel="SNR",
    ylim=[-2, 15],
    xlim=[fmin, fmax],
)
plt.tight_layout()
fig.show()

# Extract SNR values at the stimulation frequency
stim_freq1 = 60
stim_freq2 = 64

# find index of frequency bin closest to stimulation frequency
i_bin_1 = np.argmin(abs(freqs_psd - stim_freq1))
i_bin_2 = np.argmin(abs(freqs_psd - stim_freq2))

# Apply the subset
snrs_target1_endo = snrs_endo[:, i_bin_1]
snrs_target2_endo = snrs_endo[:, i_bin_2]
print(f'SNR at {stim_freq1}Hz in endogenous condition: {snrs_target1_endo.mean()}')
print(f'SNR at {stim_freq2}Hz in endogenous: {snrs_target2_endo.mean()}')
snrs_target1_exo = snrs_exo[:, i_bin_1]
snrs_target2_exo = snrs_exo[:, i_bin_2]
print(f'SNR at {stim_freq1}Hz in exogenous condition: {snrs_target1_exo.mean()}')
print(f'SNR at {stim_freq2}Hz in exogenous: {snrs_target2_exo.mean()}')
# Out:
# /tmp/ipykernel_59131/4082944448.py:102: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# SNR at 60Hz in endogenous condition: 6.536632662167375
# SNR at 64Hz in endogenous: 6.19255216969936
# SNR at 60Hz in exogenous condition: 6.902983220094555
# SNR at 64Hz in exogenous: 8.743468433164644

# %% [markdown]
# ## 1.2 Topography of the SNR

# %%
# plot SNR topography
fig, ax = plt.subplots(2,2)
mne.viz.plot_topomap(snrs_target1_endo, epochs.info, vlim=(1, None), axes=ax[0,0], show=False, extrapolate='local')
mne.viz.plot_topomap(snrs_target2_endo, epochs.info, vlim=(1, None), axes=ax[0,1], show=False, extrapolate='local')
mne.viz.plot_topomap(snrs_target1_exo, epochs.info, vlim=(1, None), axes=ax[1,0], show=False, extrapolate='local')
mne.viz.plot_topomap(snrs_target2_exo, epochs.info, vlim=(1, None), axes=ax[1,1], show=False, extrapolate='local')
ax[0,0].set_title('Endogeneous 60Hz')
ax[0,1].set_title('Exogeneous 60H')
ax[1,0].set_title('Endogeneous 64Hz')
ax[1,1].set_title('Exogeneous 64H')
plt.show()

# Channels with the highest SNR 
print(f'Channels with highest SNR for 60Hz endo {np.array(epochs.info['ch_names'])[np.argsort(snrs_target1_endo)[::-1]][:6]}')
print(f'Channels with highest SNR for 64Hz endo{np.array(epochs.info['ch_names'])[np.argsort(snrs_target2_endo)[::-1]][:6]}')
print(f'Channels with highest SNR for 60Hz exo {np.array(epochs.info['ch_names'])[np.argsort(snrs_target1_exo)[::-1]][:6]}')
print(f'Channels with highest SNR for 64Hz exo {np.array(epochs.info['ch_names'])[np.argsort(snrs_target2_exo)[::-1]][:6]}')
#select electrodes from 60 as the top electrodes are parietal and occipital
SNR_best_electrodes_60_endo = np.array(epochs.info['ch_names'])[np.argsort(snrs_target1_endo)[::-1]][:6]
SNR_best_electrodes_64_endo = np.array(epochs.info['ch_names'])[np.argsort(snrs_target2_endo)[::-1]][:6]
SNR_best_electrodes_60_exo = np.array(epochs.info['ch_names'])[np.argsort(snrs_target1_exo)[::-1]][:6]
SNR_best_electrodes_64_exo = np.array(epochs.info['ch_names'])[np.argsort(snrs_target2_exo)[::-1]][:6]
# Out:
# Channels with highest SNR for 60Hz endo ['P2' 'PO4' 'O2' 'POz' 'P1' 'PO3']
# Channels with highest SNR for 64Hz endo['Pz' 'PO3' 'PO4' 'POz' 'P2' 'P1']
# Channels with highest SNR for 60Hz exo ['P2' 'PO4' 'O2' 'POz' 'P1' 'Pz']
# Channels with highest SNR for 64Hz exo ['P1' 'POz' 'O2' 'P3' 'P2' 'PO3']

# %% [markdown]
# ## 1.3 Time frequency analysis of coherence by electrode
# Coherence is studied in the time window between trial start and onset of the stimuli (the post stimuli window is likely contaminated by attentional catching due to their onset).

# %%
# # time window from -1 sec to 1 sec relative to cue
# tmin, tmax = -1, 1
# # Define range of frequencies of interest
# freqs = np.arange(55, 75, step = 0.5)

# %% [markdown]
# ### Magnitude squared coherence with Hilbert transform

# %%
# def coherence_kabir(signalX, pick, freq_of_interest):

#     #get info from EEG
#     min_time = signalX.times[0]
#     max_time = signalX.times[-1]
#     sampling_rate = signalX.info['sfreq']
    
#     # Band-pass EEG (+/-1.9Hz) and apply hilbert
#     signalX = signalX.copy().pick(pick).filter(l_freq=freq_of_interest - 1.9, h_freq=freq_of_interest + 1.9,
#         method='iir', iir_params=dict(order=4, ftype='butter'), phase='zero', fir_window='hamming', verbose = False)
#     #filter(l_freq = freq_of_interest - 1.9, h_freq = freq_of_interest + 1.9, verbose=True)
    
#     signalX = np.squeeze(signalX.get_data(copy=False)).T
#     signalXh =  scipy.signal.hilbert(signalX, axis=1)
#     n = signalXh.shape[1]  # number of trials

#     #Create sine wave
#     t = np.linspace(min_time, max_time, int(sampling_rate * (np.abs(min_time) + max_time))+1, endpoint=False)
#     signalY = np.sin(2 * np.pi * freq_of_interest * t)
#     signalY = np.tile(signalY, (n,1)).T #repeat over trials
#     # Hilbert transform
#     signalYh = scipy.signal.hilbert(signalY.T, axis=1)

#     # Magnitude
#     mX = np.abs(signalXh).T
#     mY = np.abs(signalYh)

#     # Phase difference
#     phase_diff = np.angle(signalXh).T - np.angle(signalYh)

#     coh = np.zeros(signalY.shape[0])
#     for t in range(signalY.shape[0]):
#         num = ((np.abs(np.sum(mX[:, t] * mY[:, t] * np.exp(1j * phase_diff[:, t])) / n)) ** 2)
#         denom = (np.sum((mX[:, t]**2) * (mY[:, t]**2)) / n)
#         coh[t] = num/denom
        
#     return coh

# # time window from -1 sec to 1 sec relative to cue
# tmin, tmax = -1, 1
# # Define range of frequencies of interest
# freqs = np.arange(55, 75, step = 0.5)

# channels = epochs_endo.info['ch_names']

# epochs_endo_cropped = epochs_endo.copy().crop(tmin, tmax)

# coherence_mat = np.zeros((len(channels), freqs.size, len(epochs_endo_cropped.times)))

# for e, channel in enumerate(channels):
#     for i, freq in enumerate(freqs):
#         coherence_mat[e,i,:] = coherence_kabir(epochs_endo_cropped, [channel], freq)

# coherence_hilbert = mne.time_frequency.EpochsTFRArray(epochs_endo_cropped.info, np.array([coherence_mat]), epochs_endo_cropped.times, freqs)

# # Baseline (-1 to 0s) correction
# coherence_hilbert = coherence_hilbert.apply_baseline(baseline=(tmin, 0))

# fig, axes = plt.subplots(3, 6, figsize=(18, 6))  
# axes = axes.flatten() 

# # Plot each channel
# for e, (channel, ax) in enumerate(zip(channels, axes)):
#     coherence_hilbert.plot(
#         picks=[channel],
#         baseline= None,
#         axes=ax,
#         colorbar=False,
#         show=False 
#     )
#     ax.set_title(channel)  

# plt.tight_layout()
# plt.show()



# # Channels with the highest coherence with the cued frequency
# print(f'From best to 5th \nChannels with the highest coherence with 60:{np.array(epochs.info['ch_names'])[np.argsort(np.squeeze(coherence_mat[:,np.where(freqs == 60),:].max(axis = -1)))[::-1]][:6]} \
#                         \nChannels with the highest coherence with 64:{np.array(epochs.info['ch_names'])[np.argsort(np.squeeze(coherence_mat[:,np.where(freqs == 64),:].max(axis = -1)))[::-1]][:6]}')
# best_electrodes_coherence_60 = np.array(epochs.info['ch_names'])[np.argsort(np.squeeze(coherence_mat[:,np.where(freqs == 60),:].max(axis = -1)))[::-1]][:6]
# best_electrodes_coherence_64 = np.array(epochs.info['ch_names'])[np.argsort(np.squeeze(coherence_mat[:,np.where(freqs == 64),:].max(axis = -1)))[::-1]][:6]

# %% [markdown]
# ### Inter-trial coherence with stockwell estimation

# %%
# n_cylce: trade-off temporal vs frequency resolution (is how many cycles of the frequency to include in the Gaussian envelope). 
# Frequency resolution is emphasized.

# time window from -1 sec to 1 sec relative to cue
tmin, tmax = -1, 1
# Define range of frequencies of interest
freqs = np.arange(55, 75, step = 0.5)

_, itc_endo = epochs_endo.copy().crop(tmin, tmax).compute_tfr(
    method="morlet", freqs=freqs, n_cycles=freqs/2,return_itc=True, average=True
)
_, itc_exo = epochs_exo.copy().crop(tmin, tmax).compute_tfr(
    method="morlet", freqs=freqs, n_cycles=freqs/2,return_itc=True, average=True
)

# Baseline (-1 to 0s) correction
itc_endo = itc_endo.apply_baseline(baseline=(tmin, 0))
itc_exo = itc_exo.apply_baseline(baseline=(tmin, 0))

fig, axes = plt.subplots(3, 6, figsize=(18, 9), sharey = True) 
axes = axes.flatten() 

channels = epochs.info['ch_names']

# Plot each electrode
for e, (channel, ax) in enumerate(zip(channels, axes)):
    itc_endo.plot(
        picks=[channel],
        baseline=None,
        vlim=(-.4, .4),
        axes=ax,
        colorbar=False,
        show=False 
    )
    ax.set_title(channel) 
    ax.axhline(y=60, color='r', linestyle='--', linewidth=1)
    ax.axhline(y=64, color='r', linestyle='--', linewidth=1)
    
plt.tight_layout()
plt.show()
fig, axes = plt.subplots(3, 6, figsize=(18, 9), sharey = True) 
axes = axes.flatten() 

channels = epochs.info['ch_names']

# Plot each electrode
for e, (channel, ax) in enumerate(zip(channels, axes)):
    itc_exo.plot(
        picks=[channel],
        baseline=None,
        vlim=(-.4, .4),
        axes=ax,
        colorbar=False,
        show=False 
    )
    ax.set_title(channel) 
    ax.axhline(y=60, color='r', linestyle='--', linewidth=1)
    ax.axhline(y=64, color='r', linestyle='--', linewidth=1)
    
plt.tight_layout()
plt.show()
# Out:
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:   16.3s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:   16.1s
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied

# %%
# Check whether the expected frequencies are indeed the highest
itc_arr, frex_idx = itc_endo.get_data(return_freqs=True)
print(f'Frequencies in endogeneous with the maximum coherence in descending order : {frex_idx[itc_arr.mean(axis=(0,2)).argsort()[::-1]][:4]}')
print(f'From best to 6th \nChannels with the highest coherence with 64 in endo:{np.array(epochs.info['ch_names'])[np.argsort(np.squeeze(itc_arr[:,np.where(frex_idx==60),:].max(axis = -1)))[::-1]][:6]} \
                        \nChannels with the highest coherence with 60 in endo:{np.array(epochs.info['ch_names'])[np.argsort(np.squeeze(itc_arr[:,np.where(frex_idx==64),:].max(axis = -1)))[::-1]][:6]}')
best_electrodes_coherence_stockwell_60_endo = np.array(epochs.info['ch_names'])[np.argsort(np.squeeze(itc_arr[:,np.where(frex_idx==60),:].max(axis = -1)))[::-1]][:6]
best_electrodes_coherence_stockwell_64_endo = np.array(epochs.info['ch_names'])[np.argsort(np.squeeze(itc_arr[:,np.where(frex_idx==64),:].max(axis = -1)))[::-1]][:6]

itc_arr, frex_idx = itc_exo.get_data(return_freqs=True)
print(f'Frequencies in exogeneous with the maximum coherence in descending order : {frex_idx[itc_arr.mean(axis=(0,2)).argsort()[::-1]][:4]}')
print(f'From best to 6th \nChannels with the highest coherence with 64 in exo:{np.array(epochs.info['ch_names'])[np.argsort(np.squeeze(itc_arr[:,np.where(frex_idx==60),:].max(axis = -1)))[::-1]][:6]} \
                        \nChannels with the highest coherence with 60 in enxxo:{np.array(epochs.info['ch_names'])[np.argsort(np.squeeze(itc_arr[:,np.where(frex_idx==64),:].max(axis = -1)))[::-1]][:6]}')
best_electrodes_coherence_stockwell_60_exo = np.array(epochs.info['ch_names'])[np.argsort(np.squeeze(itc_arr[:,np.where(frex_idx==60),:].max(axis = -1)))[::-1]][:6]
best_electrodes_coherence_stockwell_64_exo = np.array(epochs.info['ch_names'])[np.argsort(np.squeeze(itc_arr[:,np.where(frex_idx==64),:].max(axis = -1)))[::-1]][:6]
# Out:
# Frequencies in endogeneous with the maximum coherence in descending order : [64.  63.5 64.5 59.5]
# From best to 6th
# Channels with the highest coherence with 64 in endo:['PO4' 'O2' 'P2' 'PO3' 'POz' 'Pz']
# Channels with the highest coherence with 60 in endo:['PO3' 'P1' 'PO4' 'P2' 'O2' 'POz']
# Frequencies in exogeneous with the maximum coherence in descending order : [59.5 60.  59.  60.5]
# From best to 6th
# Channels with the highest coherence with 64 in exo:['O2' 'PO4' 'P2' 'Pz' 'PO3' 'POz']
# Channels with the highest coherence with 60 in enxxo:['Pz' 'POz' 'PO4' 'O2' 'P2' 'P1']

# %% [markdown]
# ## 1.4 Select electrodes based on previous analysis

# %%
print(f'Top 6 electrodes for SNR 60 endo {SNR_best_electrodes_60_endo}')
print(f'Top 6 electrodes for SNR 64 endo {SNR_best_electrodes_64_endo}')
print(f'Top 6 electrodes for SNR 60 exo {SNR_best_electrodes_60_exo}')
print(f'Top 6 electrodes for SNR 64 exo {SNR_best_electrodes_64_exo}')
# print(f'Top 6 electrodes for Coherence 60 {best_electrodes_coherence_60}')
# print(f'Top 6 electrodes for Coherence 64 {best_electrodes_coherence_64}')
print(f'Top 6 electrodes for ITC stockwell 60 endo {best_electrodes_coherence_stockwell_60_endo}')
print(f'Top 6 electrodes for ITC stockwell 64 endo {best_electrodes_coherence_stockwell_64_endo}')

print(f'Top 6 electrodes for ITC stockwell 60 exo {best_electrodes_coherence_stockwell_60_exo}')
print(f'Top 6 electrodes for ITC stockwell 64 exo {best_electrodes_coherence_stockwell_64_exo}')
# Out:
# Top 6 electrodes for SNR 60 endo ['P2' 'PO4' 'O2' 'POz' 'P1' 'PO3']
# Top 6 electrodes for SNR 64 endo ['Pz' 'PO3' 'PO4' 'POz' 'P2' 'P1']
# Top 6 electrodes for SNR 60 exo ['P2' 'PO4' 'O2' 'POz' 'P1' 'Pz']
# Top 6 electrodes for SNR 64 exo ['P1' 'POz' 'O2' 'P3' 'P2' 'PO3']
# Top 6 electrodes for ITC stockwell 60 endo ['PO4' 'O2' 'P2' 'PO3' 'POz' 'Pz']
# Top 6 electrodes for ITC stockwell 64 endo ['PO3' 'P1' 'PO4' 'P2' 'O2' 'POz']
# Top 6 electrodes for ITC stockwell 60 exo ['O2' 'PO4' 'P2' 'Pz' 'PO3' 'POz']
# Top 6 electrodes for ITC stockwell 64 exo ['Pz' 'POz' 'PO4' 'O2' 'P2' 'P1']

# %%
# Select top 6 electrodes that are the most often the best according to SNR, IT coherence and MS coherence
all_electrodes = (list(SNR_best_electrodes_60_endo) + 
                  list(SNR_best_electrodes_64_endo) + 
                  list(SNR_best_electrodes_60_exo) + 
                  list(SNR_best_electrodes_64_exo) + 
                  # list(best_electrodes_coherence_60) + 
                  # list(best_electrodes_coherence_64) + 
                  list(best_electrodes_coherence_stockwell_60_endo) + 
                  list(best_electrodes_coherence_stockwell_64_endo) + 
                  list(best_electrodes_coherence_stockwell_60_exo) + 
                  list(best_electrodes_coherence_stockwell_64_exo))

# Count the occurrences of each electrode
electrode_counts = Counter(all_electrodes)

best_electrodes = [electrode for electrode, count in electrode_counts.most_common(6)]

print(f'selected electrodes: {best_electrodes}')
# Out:
# selected electrodes: ['P2', 'POz', 'PO4', 'O2', 'P1', 'PO3']

# %% [markdown]
# # 2 - Testing for an attentional effect
# ### Comparing SNR across cued conditions

# %%
queries = ["cued_tag == 60 & attention_type_block==0", "cued_tag == 64 & attention_type_block==0",
          "cued_tag == 60 & attention_type_block==1", "cued_tag == 64 & attention_type_block==1"]
vals = {}
stim_freq1 = 60
stim_freq2 = 64

sfreq = epochs_endo.info['sfreq']
tmin = 0 # Search in window starting from cue (when SSVEP is expected)
tmax = 2
fmin = 1.0
fmax = 90.0

for query in queries:
    # Spectrum averaged over all trials
    spectrum = epochs[query].copy().pick(best_electrodes).compute_psd(
        "welch",
        n_fft=int(sfreq * (tmax - tmin)),
        n_overlap=0,
        n_per_seg=None,
        tmin=tmin,
        tmax=tmax,
        fmin=fmin,
        fmax=fmax,
        window="hamming",
        verbose=False,
    )
    psds, freqs_psd = spectrum.get_data(return_freqs=True)

    # find index of frequency bin closest to stimulation frequency
    i_bin_1 = np.argmin(abs(freqs_psd - stim_freq1))
    i_bin_2 = np.argmin(abs(freqs_psd - stim_freq2))
    
    # Apply the subset
    vals[str(int(stim_freq1))+query] = copy.deepcopy(np.mean(psds,axis=0)[:, i_bin_1])
    vals[str(int(stim_freq2))+query] = copy.deepcopy(np.mean(psds,axis=0)[:, i_bin_2])

# %%
fig, ax = plt.subplots(2,2, figsize=(7,6), sharex=True, sharey=True)
for e, elec in enumerate(best_electrodes):
    ax[0,0].plot([0,1], [vals['60cued_tag == 64 & attention_type_block==0'][e], vals['60cued_tag == 60 & attention_type_block==0'][e]], 'o-', label=elec)
    ax[1,0].plot([0,1], [vals['64cued_tag == 60 & attention_type_block==0'][e], vals['64cued_tag == 64 & attention_type_block==0'][e]], 'o-', label=elec)
    ax[0,1].plot([0,1], [vals['60cued_tag == 64 & attention_type_block==1'][e], vals['60cued_tag == 60 & attention_type_block==1'][e]], 'o-', label=elec)
    ax[1,1].plot([0,1], [vals['64cued_tag == 60 & attention_type_block==1'][e], vals['64cued_tag == 64 & attention_type_block==1'][e]], 'o-', label=elec)

ax[0,0].set_title('PSD at 60Hz endogeneous')
ax[0,1].set_title('PSD at 60Hz exogeneous')
ax[1,0].set_title('PSD at 64Hz endogeneous')
ax[1,1].set_title('PSD at 64Hz exogeneous')
ax[0,0].set_ylabel('PSD at 60Hz')
ax[1,0].set_ylabel('PSD at 64Hz')
ax[1,0].set_xticks([0,1], ['Not cued', 'Cued'])
ax[1,1].set_xticks([0,1], ['Not cued', 'Cued'])
ax[1,1].set_xlim(-.5, 1.5)
plt.legend(bbox_to_anchor=(1,1))
plt.tight_layout()
plt.show()

# %%
# Normalize the frequency amplitudes as in Adamian & Andersen, 2024
npsd56 = frequency_rescaling(np.vstack([vals['60cued_tag == 60 & attention_type_block==0'],\
                                        vals['60cued_tag == 64 & attention_type_block==0'],
                                        vals['60cued_tag == 60 & attention_type_block==1'],
                                        vals['60cued_tag == 64 & attention_type_block==1'],]).T)
npsd60 = frequency_rescaling(np.vstack([vals['64cued_tag == 64 & attention_type_block==0'],\
                                        vals['64cued_tag == 60 & attention_type_block==0'],
                                        vals['64cued_tag == 64 & attention_type_block==1'],
                                        vals['64cued_tag == 60 & attention_type_block==1'],]).T)
npsds = np.concatenate([npsd56,npsd60])

# Average over electrodes
# npsds = npsds.mean(axis=0)
# np.save('files/B3_normalizes_psds.npy', npsds)

# %% [markdown]
# ### Comparing inter-trial coherence across cued conditions

# %%
# time window from -1 sec to 1 sec relative to cue
tmin, tmax = -1, 1

# Get inter-trial coherence with 60 and 64Hz by cued frequency 
freqs6064 = np.array([60, 64])
_, itc_64_endo = epochs_endo['cued_tag == 64'].copy().crop(tmin, tmax).compute_tfr(
    method="morlet", freqs=freqs6064, n_cycles=freqs6064/2,return_itc=True, average=True
)

_, itc_60_endo = epochs_endo['cued_tag == 60'].copy().crop(tmin, tmax).compute_tfr(
    method="morlet", freqs=freqs6064, n_cycles=freqs6064/2,return_itc=True, average=True
)
_, itc_64_exo = epochs_exo['cued_tag == 64'].copy().crop(tmin, tmax).compute_tfr(
    method="morlet", freqs=freqs6064, n_cycles=freqs6064/2,return_itc=True, average=True
)

_, itc_60_exo = epochs_exo['cued_tag == 60'].copy().crop(tmin, tmax).compute_tfr(
    method="morlet", freqs=freqs6064, n_cycles=freqs6064/2,return_itc=True, average=True
)

elec_idx = np.where(np.isin(epochs.info['ch_names'], best_electrodes))[0]

coherence = {}
itc_64_arr, times_coh, freqs_idx = itc_64_endo.get_data(return_freqs = True, return_times = True)
itc_60_arr = itc_60_endo.get_data()
coherence['with64_for64cued_endo'] = itc_64_arr[elec_idx,1,:]
coherence['with60_for64cued_endo'] = itc_64_arr[elec_idx,0,:]
coherence['with64_for60cued_endo'] = itc_60_arr[elec_idx,1,:]
coherence['with60_for60cued_endo'] = itc_60_arr[elec_idx,0,:]
itc_64_arr, times_coh, freqs_idx = itc_64_exo.get_data(return_freqs = True, return_times = True)
itc_60_arr = itc_60_exo.get_data()
coherence['with64_for64cued_exo'] = itc_64_arr[elec_idx,1,:]
coherence['with60_for64cued_exo'] = itc_64_arr[elec_idx,0,:]
coherence['with64_for60cued_exo'] = itc_60_arr[elec_idx,1,:]
coherence['with60_for60cued_exo'] = itc_60_arr[elec_idx,0,:]
# Out:
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.4s

# %%
fig, ax = plt.subplots(2,2, sharex=True, sharey=True, figsize=(10,5))
ax[0,0].plot(times_coh, coherence['with60_for60cued_endo'].T - coherence['with60_for64cued_endo'].T, label = best_electrodes)
ax[0,0].set_ylabel('Coherence 60Hz')
ax[0,0].set_title('Endogeneous difference 60Hz cued-uncued')
ax[1,0].plot(times_coh, coherence['with64_for64cued_endo'].T - coherence['with64_for60cued_endo'].T, label = best_electrodes)
ax[1,0].set_ylabel('Coherence 64Hz')
ax[1,0].set_title('Endogeneous difference 64Hz cued-uncued')
ax[0,1].plot(times_coh, coherence['with60_for60cued_exo'].T - coherence['with60_for64cued_exo'].T, label = best_electrodes)
ax[0,1].set_title('Exogeneous difference 60Hz cued-uncued')
ax[1,1].plot(times_coh, coherence['with64_for64cued_exo'].T - coherence['with64_for60cued_exo'].T, label = best_electrodes)
ax[1,1].set_title('Exogeneous difference 64Hz cued-uncued')

# for axi in ax.flatten():
#     axi.vlines(0, -.4, .4, color='black')

plt.legend(bbox_to_anchor=(1,1))
ax[1,0].set_xlabel('Time from cue (second)')
ax[1,1].set_xlabel('Time from cue (second)')
plt.show()

# %%
# Export for group analysis

def pd_coh(coherence_dic, cued, coh_with, condition):
    coherence = pd.DataFrame(coherence_dic[f'with{coh_with}_for{cued}cued_{condition}'])
    coherence['channel'] = best_electrodes
    coherence['cued'] = cued
    coherence['coh_with'] = coh_with
    coherence['condition'] = condition
    coherence = coherence.melt(id_vars=['channel','cued','coh_with','condition'])
    coherence['time'] = coherence['variable']*(1/epochs_endo.info['sfreq']) + tmin
    return coherence

coh64_cue64_endo = pd_coh(coherence, 64, 64, 'endo')
coh64_cue60_endo = pd_coh(coherence, 60, 64, 'endo')
coh60_cue64_endo = pd_coh(coherence, 64, 60, 'endo')
coh60_cue60_endo = pd_coh(coherence, 60, 60, 'endo')
coh64_cue64_exo = pd_coh(coherence, 64, 64, 'exo')
coh64_cue60_exo = pd_coh(coherence, 60, 64, 'exo')
coh60_cue64_exo = pd_coh(coherence, 64, 60, 'exo')
coh60_cue60_exo = pd_coh(coherence, 60, 60, 'exo')

ITcoh_B3 = pd.concat([coh60_cue60_endo, coh60_cue64_endo, coh64_cue60_endo, coh64_cue64_endo,
                     coh60_cue60_exo, coh60_cue64_exo, coh64_cue60_exo, coh64_cue64_exo])
ITcoh_B3.columns = ['channel', 'cued', 'coh_with', 'condition', 'timepoint', 'ITcoherence', 'time']
ITcoh_B3.to_csv('files/ITcoh_B3.csv',index=False)

# %% [markdown]
# ### Comparing MS coherence across cued conditions

# %%
# # time window from -1 sec to 1 sec relative to cue
# tmin, tmax = -1, 1
# # Define range of frequencies of interest
# freqs = np.array([60, 64])

# epochs_endo_cropped = epochs_endo['cued_tag == 64'].copy().pick(best_electrodes).crop(tmin, tmax)
# coherence_mat = np.zeros((len(best_electrodes), freqs.size, len(epochs_endo_cropped.times)))
# for e, channel in enumerate(best_electrodes):
#     for i, freq in enumerate(freqs):
#         coherence_mat[e,i,:] = coherence_kabir(epochs_endo_cropped, [channel], freq)
# coherence_hilbert_64 = mne.time_frequency.EpochsTFRArray(epochs_endo_cropped.info, np.array([coherence_mat]), epochs_endo_cropped.times, freqs)

# epochs_endo_cropped = epochs_endo['cued_tag == 60'].copy().pick(best_electrodes).crop(tmin, tmax)
# coherence_mat = np.zeros((len(best_electrodes), freqs.size, len(epochs_endo_cropped.times)))
# for e, channel in enumerate(best_electrodes):
#     for i, freq in enumerate(freqs):
#         coherence_mat[e,i,:] = coherence_kabir(epochs_endo_cropped, [channel], freq)
# coherence_hilbert_60 = mne.time_frequency.EpochsTFRArray(epochs_endo_cropped.info, np.array([coherence_mat]), epochs_endo_cropped.times, freqs)

# coherence_hilbert_64, times_coh, freqs_idx = coherence_hilbert_64.get_data(return_freqs = True, return_times = True)
# coherence_hilbert_60 = coherence_hilbert_60.get_data()

# %%
# coherence_hilbert = {}
# coherence_hilbert['with64_for64cued'] = np.squeeze(coherence_hilbert_64)[:,1,:]
# coherence_hilbert['with60_for64cued'] = np.squeeze(coherence_hilbert_64)[:,0,:]
# coherence_hilbert['with64_for60cued'] = np.squeeze(coherence_hilbert_60)[:,1,:]
# coherence_hilbert['with60_for60cued'] = np.squeeze(coherence_hilbert_60)[:,0,:]

# plt.plot(times_coh, coherence_hilbert['with64_for64cued'].T - coherence_hilbert['with64_for60cued'].T, label = best_electrodes)
# plt.vlines(0,-0.35,0.3, color = 'black')
# plt.legend()
# plt.title('Coherence with 64Hz when 64 cued - coherence with 64 when 64 not cued')
# plt.xlabel('Time from cue')
# plt.ylabel('Coherence contrast cued/uncued')
# plt.show()

# plt.plot(times_coh, coherence_hilbert['with60_for60cued'].T - coherence_hilbert['with60_for64cued'].T, label = best_electrodes)
# plt.vlines(0,-0.35,0.3, color = 'black')
# plt.legend()
# plt.title('Coherence with 60Hz when 60 cued - coherence with 60 when 60 not cued')
# plt.xlabel('Time from cue')
# plt.ylabel('Coherence contrast cued/uncued')

# %%
# # Export for group analysis
# coh64_cue64 = pd_coh(coherence_hilbert, 64, 64)
# coh64_cue60 = pd_coh(coherence_hilbert, 60, 64)
# coh60_cue64 = pd_coh(coherence_hilbert, 64, 60)
# coh60_cue60 = pd_coh(coherence_hilbert, 60, 60)

# MScoh_B3 = pd.concat([coh60_cue60, coh60_cue64, coh64_cue60, coh64_cue64])
# MScoh_B3.columns = ['channel', 'cued', 'coh_with', 'timepoint', 'MScoherence', 'time']
# MScoh_B3.to_csv('files/MScoh_B3.csv',index=False)

# %% [markdown]
# # 3 - Predict cued tag with a classifier

# %%
# Load eeg epochs again to use all channels
epochs = mne.read_epochs(f'{data_path}{epoch_file}')
epoch_good = [x for x,y in enumerate(epochs.drop_log) if len(y) == 0]
epochs.metadata = pd_info.iloc[epoch_good]

# Remove trials where a target occured
epochs = epochs['targets_binary == 0']

# Crop to after the latest target onset possibility
epochs.crop(-.2, 2)

# Downsample for speed
epochs.resample(500).pick_types(eeg=True)
# Out:
# Reading /home/lea/Documents/obsidian_notes/masterADS/ads_thesis_RIFT/my_code_expe2/data/B3/preprocessing/B3_EEG_epo.fif ...
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 510 matching events found
# No baseline correction applied
# 0 projection items activated
# Adding metadata with 14 columns
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# <EpochsFIF |  414 events (all good), -0.200195 – 1.9978 s, baseline -1 – 0 s (baseline period was cropped after baseline correction), ~222.4 MB, data loaded, with metadata,
#  '3': 414>

# %%
# Data preparation for post-250ms
epochs_post_250ms = epochs.copy().crop(tmin=.2)
epochs_pre_250ms = epochs.copy().crop(tmax=0.5).copy()

# Data and class to predict for post-250ms
X = epochs_post_250ms.copy().get_data()
y = epochs_post_250ms.metadata['cued_side'].values


# Model fitting for post-250ms
clf = make_pipeline(StandardScaler(), LogisticRegression(solver="liblinear"))
time_decod = SlidingEstimator(clf, n_jobs=5, scoring="roc_auc", verbose=True)
scores = cross_val_multiscore(time_decod, X, y, cv=10, n_jobs=5)

# Mean scores across cross-validation splits for post-250ms
mean_scores = np.mean(scores, axis=0)

# Find the best time point after 250ms
best_time_idx = np.argmax(mean_scores)
best_time = epochs_post_250ms.times[best_time_idx]
best_score = mean_scores[best_time_idx]
print(f"Best time point post-250ms: {best_time} seconds with score: {best_score}")

# Train the model on the best time point after 250ms
best_time_data = X[:, :, best_time_idx]
clf_best = make_pipeline(StandardScaler(), LogisticRegression(solver="liblinear"))
clf_best.fit(best_time_data, y)


# Evaluate the model on pre-250ms data for each time point separately for endo and exo
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import StratifiedKFold
# Automatically perform kfold
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

# Initialize cross-validation scores list
cv_scores_pre_250ms_exo = []
cv_scores_pre_250ms_endo = []

exo = epochs_pre_250ms['attention_type_block==0'].copy()
endo = epochs_pre_250ms['attention_type_block==1'].copy()

# Iterate through each time point in pre-250ms data
for t in range(len(exo.times)):
    X_pre_250ms_exo = exo.get_data()[:, :, t]
    X_pre_250ms_endo = endo.get_data()[:, :, t]
    y_exo = exo.metadata['cued_side'].values
    y_endo = endo.metadata['cued_side'].values
    fold_scores_exo = []
    fold_scores_endo = []
    
    # Iterate through each fold of cross-validation
    for train_index, test_index in skf.split(X_pre_250ms_exo, y_exo):
        X_train, X_test = X_pre_250ms_exo[train_index], X_pre_250ms_exo[test_index]
        y_train, y_test = y_exo[train_index], y_exo[test_index]
        
        # Use the previously trained model to predict on pre-250ms data
        predictions = clf_best.predict(X_pre_250ms_exo[test_index])
        score_exo = roc_auc_score(y_test, predictions)
        fold_scores_exo.append(score_exo)
    # Average score across folds for this time point
    avg_score_exo = np.mean(fold_scores_exo, axis=-1)
    cv_scores_pre_250ms_exo.append(avg_score_exo)
    
    # Iterate through each fold of cross-validation
    for train_index, test_index in skf.split(X_pre_250ms_endo, y_endo):
        X_train, X_test = X_pre_250ms_endo[train_index], X_pre_250ms_endo[test_index]
        y_train, y_test = y_endo[train_index], y_endo[test_index]
        
        # Use the previously trained model to predict on pre-250ms data
        predictions = clf_best.predict(X_pre_250ms_endo[test_index])
        score_endo = roc_auc_score(y_test, predictions)
        fold_scores_endo.append(score_endo)
    
    # Average score across folds for this time point
    avg_score_endo = np.mean(fold_scores_endo, axis=-1)
    cv_scores_pre_250ms_endo.append(avg_score_endo)
# Out:
# /tmp/ipykernel_107845/2671821630.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X = epochs_post_250ms.copy().get_data()
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
#  51%|█████▏    | Fitting SlidingEstimator : 154/300 [00:00<00:00,  261.37it/s]
#  55%|█████▍    | Fitting SlidingEstimator : 164/300 [00:00<00:00,  264.19it/s]
#  57%|█████▋    | Fitting SlidingEstimator : 170/300 [00:00<00:00,  257.35it/s]A
#  59%|█████▊    | Fitting SlidingEstimator : 176/300 [00:00<00:00,  251.01it/s][A
#  61%|██████    | Fitting SlidingEstimator : 183/300 [00:00<00:00,  247.73it/s][A
#  63%|██████▎   | Fitting SlidingEstimator : 190/300 [00:00<00:00,  244.67it/s][A
#  66%|██████▌   | Fitting SlidingEstimator : 198/300 [00:00<00:00,  243.97it/s][A
#  69%|██████▊   | Fitting SlidingEstimator : 206/300 [00:00<00:00,  242.98it/s][A
#  71%|███████▏  | Fitting SlidingEstimator : 214/300 [00:00<00:00,  242.05it/s][A
#  74%|███████▎  | Fitting SlidingEstimator : 221/300 [00:00<00:00,  239.43it/s][A
#  76%|███████▋  | Fitting SlidingEstimator : 229/300 [00:00<00:00,  238.77it/s][A
#  79%|███████▉  | Fitting SlidingEstimator : 237/300 [00:00<00:00,  237.88it/s][A
#  81%|████████▏ | Fitting SlidingEstimator : 244/300 [00:01<00:00,  235.93it/s][A
#  84%|████████▍ | Fitting SlidingEstimator : 252/300 [00:01<00:00,  235.20it/s][A
#  87%|████████▋ | Fitting SlidingEstimator : 260/300 [00:01<00:00,  234.86it/s][A
#  89%|████████▉ | Fitting SlidingEstimator : 268/300 [00:01<00:00,  234.28it/s][A
#  91%|█████████▏| Fitting SlidingEstimator : 274/300 [00:01<00:00,  230.39it/s]
#  94%|█████████▍| Fitting SlidingEstimator : 282/300 [00:01<00:00,  230.48it/s]
#  97%|█████████▋| Fitting SlidingEstimator : 290/300 [00:01<00:00,  230.60it/s]
#  99%|█████████▉| Fitting SlidingEstimator : 297/300 [00:01<00:00,  229.20it/s]
# 100%|██████████| Fitting SlidingEstimator : 300/300 [00:01<00:00,  235.44it/s]
#
#  48%|████▊     | Fitting SlidingEstimator : 143/300 [00:00<00:00,  210.17it/s]
#
#   0%|          | Fitting SlidingEstimator : 0/300 [00:00<?,       ?it/s]
#  50%|█████     | Fitting SlidingEstimator : 151/300 [00:00<00:00,  211.70it/s]
#
#   0%|          | Fitting SlidingEstimator : 1/300 [00:00<00:10,   29.21it/s]
#  53%|█████▎    | Fitting SlidingEstimator : 158/300 [00:00<00:00,  211.03it/s]
#
#   3%|▎         | Fitting SlidingEstimator : 8/300 [00:00<00:02,  119.63it/s]
#  55%|█████▌    | Fitting SlidingEstimator : 166/300 [00:00<00:00,  211.18it/s]
#
#   6%|▌         | Fitting SlidingEstimator : 17/300 [00:00<00:01,  166.77it/s]
#  57%|█████▋    | Fitting SlidingEstimator : 172/300 [00:00<00:00,  208.73it/s]
#
#   8%|▊         | Fitting SlidingEstimator : 24/300 [00:00<00:01,  174.66it/s]
#  60%|█████▉    | Fitting SlidingEstimator : 179/300 [00:00<00:00,  208.57it/s]
#
#  10%|█         | Fitting SlidingEstimator : 30/300 [00:00<00:01,  174.31it/s]
#  62%|██████▏   | Fitting SlidingEstimator : 187/300 [00:00<00:00,  209.96it/s]
#
#  12%|█▏        | Fitting SlidingEstimator : 35/300 [00:00<00:01,  168.93it/s]
#  65%|██████▍   | Fitting SlidingEstimator : 194/300 [00:00<00:00,  209.51it/s]
#
#  15%|█▌        | Fitting SlidingEstimator : 45/300 [00:00<00:01,  188.48it/s]
#  67%|██████▋   | Fitting SlidingEstimator : 201/300 [00:00<00:00,  208.73it/s]
#
#  17%|█▋        | Fitting SlidingEstimator : 52/300 [00:00<00:01,  190.90it/s]
#  70%|██████▉   | Fitting SlidingEstimator : 209/300 [00:01<00:00,  209.95it/s]
#
#  19%|█▉        | Fitting SlidingEstimator : 58/300 [00:00<00:01,  188.86it/s]
#  72%|███████▏  | Fitting SlidingEstimator : 216/300 [00:01<00:00,  208.02it/s]
#
#  22%|██▏       | Fitting SlidingEstimator : 65/300 [00:00<00:01,  189.51it/s]
#  75%|███████▍  | Fitting SlidingEstimator : 224/300 [00:01<00:00,  209.70it/s]
#
#  25%|██▍       | Fitting SlidingEstimator : 74/300 [00:00<00:01,  197.45it/s]
#  77%|███████▋  | Fitting SlidingEstimator : 231/300 [00:01<00:00,  209.53it/s]
#
#  27%|██▋       | Fitting SlidingEstimator : 81/300 [00:00<00:01,  198.12it/s]
#  80%|███████▉  | Fitting SlidingEstimator : 239/300 [00:01<00:00,  210.59it/s]
#
#  29%|██▉       | Fitting SlidingEstimator : 87/300 [00:00<00:01,  195.40it/s]
#  83%|████████▎ | Fitting SlidingEstimator : 248/300 [00:01<00:00,  213.60it/s]
#
#  31%|███▏      | Fitting SlidingEstimator : 94/300 [00:00<00:01,  196.41it/s]
#  84%|████████▍ | Fitting SlidingEstimator : 253/300 [00:01<00:00,  209.44it/s]
#
#  34%|███▍      | Fitting SlidingEstimator : 102/300 [00:00<00:00,  199.43it/s]
#  86%|████████▌ | Fitting SlidingEstimator : 258/300 [00:01<00:00,  205.79it/s]
#
#  37%|███▋      | Fitting SlidingEstimator : 110/300 [00:00<00:00,  201.48it/s]
#  88%|████████▊ | Fitting SlidingEstimator : 265/300 [00:01<00:00,  205.37it/s]
#
#  39%|███▉      | Fitting SlidingEstimator : 117/300 [00:00<00:00,  201.59it/s]
#  91%|█████████▏| Fitting SlidingEstimator : 274/300 [00:01<00:00,  208.55it/s]
#
#  42%|████▏     | Fitting SlidingEstimator : 125/300 [00:00<00:00,  204.19it/s]
#  93%|█████████▎| Fitting SlidingEstimator : 280/300 [00:01<00:00,  206.76it/s]
#
#  44%|████▍     | Fitting SlidingEstimator : 132/300 [00:00<00:00,  203.97it/s]
#  95%|█████████▌| Fitting SlidingEstimator : 286/300 [00:01<00:00,  204.85it/s]
#
#
#   0%|          | Fitting SlidingEstimator : 0/300 [00:00<?,       ?it/s]
#
#  47%|████▋     | Fitting SlidingEstimator : 140/300 [00:00<00:00,  206.10it/s]
#  98%|█████████▊| Fitting SlidingEstimator : 294/300 [00:01<00:00,  205.85it/s]
#
#  49%|████▊     | Fitting SlidingEstimator : 146/300 [00:00<00:00,  203.58it/s]
# 100%|██████████| Fitting SlidingEstimator : 300/300 [00:01<00:00,  204.18it/s]
#
#
# 100%|██████████| Fitting SlidingEstimator : 300/300 [00:01<00:00,  204.52it/s]A
#
#
#  51%|█████     | Fitting SlidingEstimator : 153/300 [00:00<00:00,  202.03it/s]
#
#
#   5%|▌         | Fitting SlidingEstimator : 16/300 [00:00<00:01,  157.65it/s]
#
#  53%|█████▎    | Fitting SlidingEstimator : 158/300 [00:00<00:00,  197.88it/s]
#
#
#   8%|▊         | Fitting SlidingEstimator : 24/300 [00:00<00:01,  177.11it/s]
#
#  55%|█████▌    | Fitting SlidingEstimator : 166/300 [00:00<00:00,  200.37it/s]
#
#
#  11%|█         | Fitting SlidingEstimator : 32/300 [00:00<00:01,  185.72it/s]
#
#  58%|█████▊    | Fitting SlidingEstimator : 174/300 [00:00<00:00,  202.58it/s]
#
#
#  13%|█▎        | Fitting SlidingEstimator : 40/300 [00:00<00:01,  194.92it/s]
#
#  60%|██████    | Fitting SlidingEstimator : 181/300 [00:00<00:00,  202.35it/s]
#
#
#  16%|█▌        | Fitting SlidingEstimator : 47/300 [00:00<00:01,  196.33it/s]
#
#  63%|██████▎   | Fitting SlidingEstimator : 188/300 [00:00<00:00,  202.08it/s]
#
#
#  18%|█▊        | Fitting SlidingEstimator : 55/300 [00:00<00:01,  200.82it/s]
#
#  65%|██████▌   | Fitting SlidingEstimator : 196/300 [00:00<00:00,  203.66it/s]
#
#
#  20%|██        | Fitting SlidingEstimator : 61/300 [00:00<00:01,  197.05it/s]
#
#  68%|██████▊   | Fitting SlidingEstimator : 205/300 [00:01<00:00,  207.32it/s]
#
#
#  22%|██▏       | Fitting SlidingEstimator : 67/300 [00:00<00:01,  194.04it/s]
#
#  70%|███████   | Fitting SlidingEstimator : 210/300 [00:01<00:00,  203.47it/s]
#
#
#  25%|██▍       | Fitting SlidingEstimator : 74/300 [00:00<00:01,  195.07it/s]
#
#  72%|███████▏  | Fitting SlidingEstimator : 217/300 [00:01<00:00,  203.11it/s]
#
#
#  27%|██▋       | Fitting SlidingEstimator : 80/300 [00:00<00:01,  193.14it/s]
#
#  75%|███████▌  | Fitting SlidingEstimator : 226/300 [00:01<00:00,  205.87it/s]
#
#
#  29%|██▉       | Fitting SlidingEstimator : 87/300 [00:00<00:01,  194.46it/s]
#
#  77%|███████▋  | Fitting SlidingEstimator : 232/300 [00:01<00:00,  203.88it/s]
#
#
#  32%|███▏      | Fitting SlidingEstimator : 97/300 [00:00<00:00,  203.71it/s]
#
#  80%|███████▉  | Fitting SlidingEstimator : 239/300 [00:01<00:00,  203.70it/s]
#
#
#  34%|███▍      | Fitting SlidingEstimator : 103/300 [00:00<00:00,  199.94it/s]
#
#  83%|████████▎ | Fitting SlidingEstimator : 248/300 [00:01<00:00,  207.09it/s]
#
#
#  37%|███▋      | Fitting SlidingEstimator : 111/300 [00:00<00:00,  202.49it/s]
#
#  85%|████████▍ | Fitting SlidingEstimator : 254/300 [00:01<00:00,  205.18it/s]
#
#
#  39%|███▉      | Fitting SlidingEstimator : 117/300 [00:00<00:00,  199.26it/s]
#
#
#
#   0%|          | Fitting SlidingEstimator : 0/300 [00:00<?,       ?it/s]
#
#  87%|████████▋ | Fitting SlidingEstimator : 260/300 [00:01<00:00,  203.45it/s]
#
#
#  42%|████▏     | Fitting SlidingEstimator : 125/300 [00:00<00:00,  201.74it/s]
#
#  89%|████████▉ | Fitting SlidingEstimator : 268/300 [00:01<00:00,  203.97it/s]
#
#
#  44%|████▍     | Fitting SlidingEstimator : 132/300 [00:00<00:00,  200.41it/s]
#
#
#
#   2%|▏         | Fitting SlidingEstimator : 7/300 [00:00<00:03,   94.53it/s]
#
#  92%|█████████▏| Fitting SlidingEstimator : 275/300 [00:01<00:00,  203.11it/s]
#
#
#  46%|████▌     | Fitting SlidingEstimator : 138/300 [00:00<00:00,  197.89it/s]
#
#
#
#   5%|▌         | Fitting SlidingEstimator : 15/300 [00:00<00:02,  132.30it/s]
#
#  94%|█████████▍| Fitting SlidingEstimator : 282/300 [00:01<00:00,  202.09it/s]
#
#
#  48%|████▊     | Fitting SlidingEstimator : 145/300 [00:00<00:00,  197.36it/s]
#
#
#
#   7%|▋         | Fitting SlidingEstimator : 22/300 [00:00<00:01,  147.68it/s]
#
#  96%|█████████▌| Fitting SlidingEstimator : 287/300 [00:01<00:00,  198.54it/s]
#
#
#  50%|█████     | Fitting SlidingEstimator : 151/300 [00:00<00:00,  194.79it/s]
#
#
#
#   9%|▉         | Fitting SlidingEstimator : 28/300 [00:00<00:01,  151.70it/s]
#
#  98%|█████████▊| Fitting SlidingEstimator : 294/300 [00:01<00:00,  198.50it/s]
#
#
#  53%|█████▎    | Fitting SlidingEstimator : 158/300 [00:00<00:00,  192.99it/s]
#
#
#
#  11%|█         | Fitting SlidingEstimator : 33/300 [00:00<00:01,  150.50it/s]
#
#  99%|█████████▉| Fitting SlidingEstimator : 298/300 [00:01<00:00,  194.08it/s]
#
#
#  55%|█████▍    | Fitting SlidingEstimator : 164/300 [00:00<00:00,  191.93it/s]
#
#
#
#
#
# 100%|██████████| Fitting SlidingEstimator : 300/300 [00:01<00:00,  195.11it/s]
#  14%|█▎        | Fitting SlidingEstimator : 41/300 [00:00<00:01,  161.38it/s]
#
#
#  57%|█████▋    | Fitting SlidingEstimator : 172/300 [00:00<00:00,  194.67it/s]
#
#
#
#  16%|█▌        | Fitting SlidingEstimator : 48/300 [00:00<00:01,  166.97it/s]
#
#
#  60%|█████▉    | Fitting SlidingEstimator : 179/300 [00:00<00:00,  194.98it/s]
#
#
#
#  19%|█▊        | Fitting SlidingEstimator : 56/300 [00:00<00:01,  172.81it/s]
#
#
#  62%|██████▏   | Fitting SlidingEstimator : 186/300 [00:00<00:00,  195.24it/s]
#
#
#
#  21%|██▏       | Fitting SlidingEstimator : 64/300 [00:00<00:01,  179.74it/s]
#
#
#  64%|██████▍   | Fitting SlidingEstimator : 193/300 [00:00<00:00,  194.35it/s]
#
#
#
#  23%|██▎       | Fitting SlidingEstimator : 70/300 [00:00<00:01,  179.16it/s]
#
#
#  66%|██████▌   | Fitting SlidingEstimator : 198/300 [00:01<00:00,  191.19it/s]
#
#
#
#  25%|██▌       | Fitting SlidingEstimator : 76/300 [00:00<00:01,  177.88it/s]
#
#
#  68%|██████▊   | Fitting SlidingEstimator : 204/300 [00:01<00:00,  189.71it/s]
#
#
#
#  28%|██▊       | Fitting SlidingEstimator : 83/300 [00:00<00:01,  180.26it/s]
#
#
#  70%|███████   | Fitting SlidingEstimator : 211/300 [00:01<00:00,  190.49it/s]
#
#
#
#  30%|███       | Fitting SlidingEstimator : 90/300 [00:00<00:01,  182.72it/s]
#
#
#  73%|███████▎  | Fitting SlidingEstimator : 219/300 [00:01<00:00,  193.09it/s]
#
#
#
#  33%|███▎      | Fitting SlidingEstimator : 99/300 [00:00<00:01,  188.99it/s]
#
#
#  75%|███████▍  | Fitting SlidingEstimator : 224/300 [00:01<00:00,  190.40it/s]
#
#
#
#  35%|███▌      | Fitting SlidingEstimator : 106/300 [00:00<00:01,  190.39it/s]
#
#
#  76%|███████▋  | Fitting SlidingEstimator : 229/300 [00:01<00:00,  187.81it/s]
#
#
#
#  38%|███▊      | Fitting SlidingEstimator : 113/300 [00:00<00:00,  189.25it/s]
#
#
#   0%|          | Fitting SlidingEstimator : 0/300 [00:00<?,       ?it/s]8it/s]
#
#
#
#  39%|███▉      | Fitting SlidingEstimator : 118/300 [00:00<00:00,  185.90it/s]
#
#
#  80%|████████  | Fitting SlidingEstimator : 241/300 [00:01<00:00,  185.72it/s]
#
#
#
#  42%|████▏     | Fitting SlidingEstimator : 125/300 [00:00<00:00,  186.83it/s]
#
#
#   2%|▏         | Fitting SlidingEstimator : 7/300 [00:00<00:02,  103.30it/s]s]
#
#
#
#  43%|████▎     | Fitting SlidingEstimator : 130/300 [00:00<00:00,  183.64it/s]
#
#
#   5%|▍         | Fitting SlidingEstimator : 14/300 [00:00<00:02,  135.84it/s]]
#
#
#
#  46%|████▌     | Fitting SlidingEstimator : 137/300 [00:00<00:00,  184.31it/s]
#
#
#   6%|▋         | Fitting SlidingEstimator : 19/300 [00:00<00:02,  138.27it/s]]
#
#
#
#  48%|████▊     | Fitting SlidingEstimator : 143/300 [00:00<00:00,  183.05it/s]
#
#
#   8%|▊         | Fitting SlidingEstimator : 24/300 [00:00<00:01,  139.27it/s]]
#
#
#
#  50%|████▉     | Fitting SlidingEstimator : 149/300 [00:00<00:00,  181.18it/s]
#
#
#  10%|█         | Fitting SlidingEstimator : 30/300 [00:00<00:01,  145.69it/s]]
#
#
#
#  52%|█████▏    | Fitting SlidingEstimator : 156/300 [00:00<00:00,  179.59it/s]
#
#
#  12%|█▏        | Fitting SlidingEstimator : 36/300 [00:00<00:01,  150.71it/s]]
#
#
#
#  54%|█████▎    | Fitting SlidingEstimator : 161/300 [00:00<00:00,  177.04it/s]
#
#
#  14%|█▍        | Fitting SlidingEstimator : 42/300 [00:00<00:01,  153.24it/s]]
#
#
#
#  56%|█████▌    | Fitting SlidingEstimator : 168/300 [00:00<00:00,  177.86it/s]
#
#
#  16%|█▌        | Fitting SlidingEstimator : 48/300 [00:00<00:01,  156.36it/s]]
#
#
#
#  58%|█████▊    | Fitting SlidingEstimator : 173/300 [00:00<00:00,  175.89it/s]
#
#
#  18%|█▊        | Fitting SlidingEstimator : 55/300 [00:00<00:01,  162.33it/s]]
#
#
#
#
#
#
#  20%|██        | Fitting SlidingEstimator : 61/300 [00:00<00:01,  163.10it/s]]
#
#
# 100%|██████████| Fitting SlidingEstimator : 300/300 [00:01<00:00,  183.59it/s]
#
#
#
#
#  22%|██▏       | Fitting SlidingEstimator : 66/300 [00:00<00:01,  160.33it/s]]
#
#
#
#  24%|██▍       | Fitting SlidingEstimator : 73/300 [00:00<00:01,  164.47it/s]]
#
#
#
#  27%|██▋       | Fitting SlidingEstimator : 81/300 [00:00<00:01,  171.18it/s]]
#
#
#
#  29%|██▉       | Fitting SlidingEstimator : 88/300 [00:00<00:01,  174.38it/s]]
#
#
#
#  32%|███▏      | Fitting SlidingEstimator : 96/300 [00:00<00:01,  179.45it/s]]
#
#
#
#  35%|███▌      | Fitting SlidingEstimator : 105/300 [00:00<00:01,  185.76it/s]
#
#
#
#  78%|███████▊  | Fitting SlidingEstimator : 233/300 [00:01<00:00,  189.37it/s]
#
#
#
#  40%|███▉      | Fitting SlidingEstimator : 119/300 [00:00<00:00,  187.52it/s]
#
#
#
#  42%|████▏     | Fitting SlidingEstimator : 126/300 [00:00<00:00,  188.25it/s]
#
#
#
#  44%|████▍     | Fitting SlidingEstimator : 133/300 [00:00<00:00,  188.97it/s]
#
#
#
#  48%|████▊     | Fitting SlidingEstimator : 145/300 [00:00<00:00,  187.34it/s]
#
#
#
#  89%|████████▉ | Fitting SlidingEstimator : 267/300 [00:01<00:00,  190.45it/s]
#
#
#
#  53%|█████▎    | Fitting SlidingEstimator : 160/300 [00:00<00:00,  191.03it/s]
#
#
#
#  93%|█████████▎| Fitting SlidingEstimator : 278/300 [00:01<00:00,  186.97it/s]
#   0%|          | Fitting SlidingEstimator : 0/300 [00:00<?,       ?it/s]
#
#
#
#  55%|█████▌    | Fitting SlidingEstimator : 166/300 [00:00<00:00,  189.32it/s]
#   0%|          | Fitting SlidingEstimator : 1/300 [00:00<00:10,   28.91it/s]
#
#
#
#  57%|█████▋    | Fitting SlidingEstimator : 171/300 [00:00<00:00,  186.21it/s]
#   2%|▏         | Fitting SlidingEstimator : 7/300 [00:00<00:02,  103.51it/s]
#
#
#
#  59%|█████▉    | Fitting SlidingEstimator : 177/300 [00:00<00:00,  185.42it/s]
# 100%|██████████| Fitting SlidingEstimator : 300/300 [00:01<00:00,  183.84it/s][A
#  61%|██████▏   | Fitting SlidingEstimator : 184/300 [00:01<00:00,  186.46it/s]
#  64%|██████▎   | Fitting SlidingEstimator : 191/300 [00:01<00:00,  187.69it/s][A
#  66%|██████▌   | Fitting SlidingEstimator : 198/300 [00:01<00:00,  188.70it/s][A
#  69%|██████▊   | Fitting SlidingEstimator : 206/300 [00:01<00:00,  191.55it/s][A
#  71%|███████▏  | Fitting SlidingEstimator : 214/300 [00:01<00:00,  193.42it/s][A
#  74%|███████▍  | Fitting SlidingEstimator : 222/300 [00:01<00:00,  195.86it/s][A
#  76%|███████▋  | Fitting SlidingEstimator : 229/300 [00:01<00:00,  196.12it/s][A
#  78%|███████▊  | Fitting SlidingEstimator : 235/300 [00:01<00:00,  194.74it/s][A
#  81%|████████  | Fitting SlidingEstimator : 242/300 [00:01<00:00,  195.45it/s][A
#  84%|████████▍ | Fitting SlidingEstimator : 252/300 [00:01<00:00,  200.17it/s][A
#  86%|████████▋ | Fitting SlidingEstimator : 259/300 [00:01<00:00,  200.44it/s][A
#  89%|████████▊ | Fitting SlidingEstimator : 266/300 [00:01<00:00,  200.35it/s]
#  91%|█████████ | Fitting SlidingEstimator : 273/300 [00:01<00:00,  200.04it/s]
#  94%|█████████▍| Fitting SlidingEstimator : 282/300 [00:01<00:00,  202.71it/s]
#  96%|█████████▌| Fitting SlidingEstimator : 288/300 [00:01<00:00,  201.37it/s]
#  98%|█████████▊| Fitting SlidingEstimator : 293/300 [00:01<00:00,  198.31it/s]
# 100%|██████████| Fitting SlidingEstimator : 300/300 [00:01<00:00,  192.07it/s]
#
#  49%|████▊     | Fitting SlidingEstimator : 146/300 [00:00<00:00,  210.60it/s]
#  52%|█████▏    | Fitting SlidingEstimator : 156/300 [00:00<00:00,  216.79it/s]
#
#   0%|          | Fitting SlidingEstimator : 0/300 [00:00<?,       ?it/s]
#  54%|█████▍    | Fitting SlidingEstimator : 162/300 [00:00<00:00,  213.15it/s]
#
#   1%|          | Fitting SlidingEstimator : 2/300 [00:00<00:05,   58.15it/s]
#  57%|█████▋    | Fitting SlidingEstimator : 170/300 [00:00<00:00,  214.37it/s]
#
#   3%|▎         | Fitting SlidingEstimator : 10/300 [00:00<00:01,  148.81it/s]
#  59%|█████▉    | Fitting SlidingEstimator : 178/300 [00:00<00:00,  215.83it/s]
#
#   5%|▌         | Fitting SlidingEstimator : 16/300 [00:00<00:01,  158.67it/s]
#  62%|██████▏   | Fitting SlidingEstimator : 185/300 [00:00<00:00,  215.21it/s][Parallel(n_jobs=5)]: Done   4 out of  10 | elapsed:    6.4s remaining:    9.6s
#
#
#   8%|▊         | Fitting SlidingEstimator : 25/300 [00:00<00:01,  187.25it/s]
#  64%|██████▍   | Fitting SlidingEstimator : 193/300 [00:00<00:00,  215.69it/s]
#
#  11%|█         | Fitting SlidingEstimator : 32/300 [00:00<00:01,  191.56it/s]
#  67%|██████▋   | Fitting SlidingEstimator : 200/300 [00:00<00:00,  214.32it/s]
#
#  13%|█▎        | Fitting SlidingEstimator : 39/300 [00:00<00:01,  193.72it/s]
#  69%|██████▉   | Fitting SlidingEstimator : 208/300 [00:00<00:00,  214.86it/s]
#
#  16%|█▌        | Fitting SlidingEstimator : 47/300 [00:00<00:01,  200.38it/s]
#  72%|███████▏  | Fitting SlidingEstimator : 215/300 [00:01<00:00,  213.62it/s]
#
#  18%|█▊        | Fitting SlidingEstimator : 54/300 [00:00<00:01,  201.11it/s]
#  74%|███████▍  | Fitting SlidingEstimator : 222/300 [00:01<00:00,  212.51it/s]
#
#  20%|██        | Fitting SlidingEstimator : 61/300 [00:00<00:01,  201.30it/s]
#  76%|███████▋  | Fitting SlidingEstimator : 229/300 [00:01<00:00,  211.81it/s]
#
#  23%|██▎       | Fitting SlidingEstimator : 70/300 [00:00<00:01,  207.63it/s]
#  79%|███████▉  | Fitting SlidingEstimator : 238/300 [00:01<00:00,  214.56it/s]
#
#  26%|██▌       | Fitting SlidingEstimator : 77/300 [00:00<00:01,  206.55it/s]
#  81%|████████▏ | Fitting SlidingEstimator : 244/300 [00:01<00:00,  212.37it/s]
#
#  27%|██▋       | Fitting SlidingEstimator : 82/300 [00:00<00:01,  200.01it/s]
#  84%|████████▎ | Fitting SlidingEstimator : 251/300 [00:01<00:00,  211.72it/s]
#
#  29%|██▉       | Fitting SlidingEstimator : 88/300 [00:00<00:01,  196.30it/s]
#  86%|████████▋ | Fitting SlidingEstimator : 259/300 [00:01<00:00,  213.09it/s]
#
#  33%|███▎      | Fitting SlidingEstimator : 98/300 [00:00<00:00,  205.55it/s]
#  89%|████████▊ | Fitting SlidingEstimator : 266/300 [00:01<00:00,  212.60it/s]
#
#  35%|███▌      | Fitting SlidingEstimator : 105/300 [00:00<00:00,  205.09it/s]
#  91%|█████████ | Fitting SlidingEstimator : 272/300 [00:01<00:00,  210.49it/s]
#
#  37%|███▋      | Fitting SlidingEstimator : 110/300 [00:00<00:00,  200.09it/s]
#  93%|█████████▎| Fitting SlidingEstimator : 280/300 [00:01<00:00,  211.51it/s]
#
#  39%|███▉      | Fitting SlidingEstimator : 118/300 [00:00<00:00,  201.51it/s]
#  96%|█████���███▌| Fitting SlidingEstimator : 287/300 [00:01<00:00,  211.08it/s]
#
#  42%|████▏     | Fitting SlidingEstimator : 125/300 [00:00<00:00,  200.37it/s]
#
#
#   0%|          | Fitting SlidingEstimator : 0/300 [00:00<?,       ?it/s]
#  97%|█████████▋| Fitting SlidingEstimator : 292/300 [00:01<00:00,  207.45it/s]
#
#  44%|████▎     | Fitting SlidingEstimator : 131/300 [00:00<00:00,  198.35it/s]
# 100%|█████████▉| Fitting SlidingEstimator : 299/300 [00:01<00:00,  207.42it/s]
# 100%|██████████| Fitting SlidingEstimator : 300/300 [00:01<00:00,  206.73it/s]
#
#
#  46%|████▌     | Fitting SlidingEstimator : 138/300 [00:00<00:00,  198.83it/s]
#
#
#   2%|▏         | Fitting SlidingEstimator : 6/300 [00:00<00:03,   88.49it/s]
#
#  48%|████▊     | Fitting SlidingEstimator : 143/300 [00:00<00:00,  194.78it/s]
#
#
#   5%|▌         | Fitting SlidingEstimator : 15/300 [00:00<00:01,  148.88it/s]
#
#  50%|█████     | Fitting SlidingEstimator : 151/300 [00:00<00:00,  196.83it/s]
#
#
#   7%|▋         | Fitting SlidingEstimator : 21/300 [00:00<00:01,  154.32it/s]
#
#  53%|█████▎    | Fitting SlidingEstimator : 159/300 [00:00<00:00,  198.13it/s]
#
#
#   9%|▉         | Fitting SlidingEstimator : 27/300 [00:00<00:01,  158.82it/s]
#
#  55%|█████▌    | Fitting SlidingEstimator : 166/300 [00:00<00:00,  198.20it/s]
#
#
#  11%|█▏        | Fitting SlidingEstimator : 34/300 [00:00<00:01,  167.63it/s]
#
#  58%|█████▊    | Fitting SlidingEstimator : 174/300 [00:00<00:00,  200.72it/s]
#
#
#  14%|█▍        | Fitting SlidingEstimator : 42/300 [00:00<00:01,  176.78it/s]
#
#  61%|██████    | Fitting SlidingEstimator : 182/300 [00:00<00:00,  202.41it/s]
#
#
#  17%|█▋        | Fitting SlidingEstimator : 50/300 [00:00<00:01,  183.78it/s]
#
#  64%|██████▎   | Fitting SlidingEstimator : 191/300 [00:00<00:00,  205.65it/s]
#
#
#  20%|█▉        | Fitting SlidingEstimator : 59/300 [00:00<00:01,  193.31it/s]
#
#  66%|██████▌   | Fitting SlidingEstimator : 198/300 [00:00<00:00,  205.65it/s]
#
#
#  23%|██▎       | Fitting SlidingEstimator : 69/300 [00:00<00:01,  203.30it/s]
#
#  68%|██████▊   | Fitting SlidingEstimator : 204/300 [00:01<00:00,  203.23it/s]
#
#
#  25%|██▌       | Fitting SlidingEstimator : 76/300 [00:00<00:01,  203.42it/s]
#
#  71%|███████▏  | Fitting SlidingEstimator : 214/300 [00:01<00:00,  207.59it/s]
#
#
#  28%|██▊       | Fitting SlidingEstimator : 83/300 [00:00<00:01,  202.76it/s]
#
#  74%|███████▎  | Fitting SlidingEstimator : 221/300 [00:01<00:00,  207.02it/s]
#
#
#  31%|███       | Fitting SlidingEstimator : 92/300 [00:00<00:00,  208.76it/s]
#
#  76%|███████▋  | Fitting SlidingEstimator : 229/300 [00:01<00:00,  208.59it/s]
#
#
#  32%|███▏      | Fitting SlidingEstimator : 97/300 [00:00<00:01,  200.94it/s]
#
#  79%|███████▉  | Fitting SlidingEstimator : 237/300 [00:01<00:00,  209.09it/s]
#
#
#  35%|███▌      | Fitting SlidingEstimator : 105/300 [00:00<00:00,  204.02it/s]
#
#  81%|████████  | Fitting SlidingEstimator : 242/300 [00:01<00:00,  205.52it/s]
#
#
#  38%|███▊      | Fitting SlidingEstimator : 113/300 [00:00<00:00,  206.78it/s]
#
#  83%|████████▎ | Fitting SlidingEstimator : 249/300 [00:01<00:00,  205.53it/s]
#
#
#  40%|████      | Fitting SlidingEstimator : 121/300 [00:00<00:00,  208.29it/s]
#
#  86%|████████▌ | Fitting SlidingEstimator : 258/300 [00:01<00:00,  208.46it/s]
#
#
#  42%|████▏     | Fitting SlidingEstimator : 127/300 [00:00<00:00,  205.72it/s]
#
#
#
#   0%|          | Fitting SlidingEstimator : 0/300 [00:00<?,       ?it/s]
#
#
#
#
#  45%|████▍     | Fitting SlidingEstimator : 134/300 [00:00<00:00,  205.32it/s]
#
#  90%|█████████ | Fitting SlidingEstimator : 270/300 [00:01<00:00,  203.54it/s]
#
#
#  47%|████▋     | Fitting SlidingEstimator : 141/300 [00:00<00:00,  203.19it/s]
#
#
#
#   2%|▏         | Fitting SlidingEstimator : 7/300 [00:00<00:02,  101.42it/s]
#
#  92%|█████████▏| Fitting SlidingEstimator : 276/300 [00:01<00:00,  201.94it/s]
#
#
#  50%|████▉     | Fitting SlidingEstimator : 149/300 [00:00<00:00,  205.56it/s]
#
#
#
#   5%|▌         | Fitting SlidingEstimator : 15/300 [00:00<00:01,  145.33it/s]
#
#  95%|█████████▌| Fitting SlidingEstimator : 285/300 [00:01<00:00,  203.88it/s]
#
#
#  52%|█████▏    | Fitting SlidingEstimator : 155/300 [00:00<00:00,  201.62it/s]
#
#
#
#   7%|▋         | Fitting SlidingEstimator : 21/300 [00:00<00:01,  151.12it/s]
#
#  98%|█████████▊| Fitting SlidingEstimator : 294/300 [00:01<00:00,  206.46it/s]
#
#
#  54%|█████▍    | Fitting SlidingEstimator : 163/300 [00:00<00:00,  203.70it/s]
#
#
#
#   9%|▉         | Fitting SlidingEstimator : 27/300 [00:00<00:01,  154.63it/s]
#
# 100%|█████████▉| Fitting SlidingEstimator : 299/300 [00:01<00:00,  203.28it/s]
#
#
# 100%|██████████| Fitting SlidingEstimator : 300/300 [00:01<00:00,  202.16it/s]
#
#
#
#
#  11%|█         | Fitting SlidingEstimator : 33/300 [00:00<00:01,  157.78it/s]
#
#
#  59%|█████▉    | Fitting SlidingEstimator : 178/300 [00:00<00:00,  204.45it/s]
#
#
#
#  14%|█▍        | Fitting SlidingEstimator : 42/300 [00:00<00:01,  173.65it/s]
#
#
#  63%|██████▎   | Fitting SlidingEstimator : 188/300 [00:00<00:00,  209.78it/s]
#
#
#
#  16%|█▋        | Fitting SlidingEstimator : 49/300 [00:00<00:01,  177.84it/s]
#
#
#  65%|██████▌   | Fitting SlidingEstimator : 195/300 [00:00<00:00,  209.58it/s]
#
#
#
#  20%|█▉        | Fitting SlidingEstimator : 59/300 [00:00<00:01,  191.93it/s]
#
#
#  68%|██████▊   | Fitting SlidingEstimator : 204/300 [00:00<00:00,  212.79it/s]
#
#
#
#  22%|██▏       | Fitting SlidingEstimator : 66/300 [00:00<00:01,  192.96it/s]
#
#
#  71%|███████   | Fitting SlidingEstimator : 212/300 [00:01<00:00,  214.25it/s]
#
#
#
#  25%|██▌       | Fitting SlidingEstimator : 75/300 [00:00<00:01,  199.82it/s]
#
#
#  73%|███████▎  | Fitting SlidingEstimator : 218/300 [00:01<00:00,  211.23it/s]
#
#
#
#  28%|██▊       | Fitting SlidingEstimator : 83/300 [00:00<00:01,  202.94it/s]
#
#
#  75%|███████▌  | Fitting SlidingEstimator : 226/300 [00:01<00:00,  212.44it/s]
#
#
#
#  31%|███       | Fitting SlidingEstimator : 92/300 [00:00<00:00,  208.49it/s]
#
#
#  78%|███████▊  | Fitting SlidingEstimator : 234/300 [00:01<00:00,  212.67it/s]
#
#
#
#  33%|███▎      | Fitting SlidingEstimator : 100/300 [00:00<00:00,  209.17it/s]
#
#
#  81%|████████  | Fitting SlidingEstimator : 243/300 [00:01<00:00,  214.51it/s]
#
#
#
#  37%|███▋      | Fitting SlidingEstimator : 110/300 [00:00<00:00,  215.67it/s]
#
#
#  84%|████████▍ | Fitting SlidingEstimator : 252/300 [00:01<00:00,  217.11it/s]
#
#
#
#  40%|███▉      | Fitting SlidingEstimator : 119/300 [00:00<00:00,  217.91it/s]
#
#
#  87%|████████▋ | Fitting SlidingEstimator : 261/300 [00:01<00:00,  219.17it/s]
#
#
#
#  42%|████▏     | Fitting SlidingEstimator : 127/300 [00:00<00:00,  219.36it/s]
#
#
#  90%|█████████ | Fitting SlidingEstimator : 270/300 [00:01<00:00,  220.96it/s]
#
#
#
#  45%|████▌     | Fitting SlidingEstimator : 136/300 [00:00<00:00,  221.99it/s]
#
#
#  92%|█████████▏| Fitting SlidingEstimator : 277/300 [00:01<00:00,  219.63it/s]
#
#
#
#  48%|████▊     | Fitting SlidingEstimator : 143/300 [00:00<00:00,  220.21it/s]
#
#
#  96%|█████████▌| Fitting SlidingEstimator : 287/300 [00:01<00:00,  223.82it/s]
#
#
#
#  51%|█████▏    | Fitting SlidingEstimator : 154/300 [00:00<00:00,  226.78it/s]
#
#
#  98%|█████████▊| Fitting SlidingEstimator : 293/300 [00:01<00:00,  221.24it/s]
#
#
#
#  54%|█████▎    | Fitting SlidingEstimator : 161/300 [00:00<00:00,  224.74it/s][Parallel(n_jobs=5)]: Done   7 out of  10 | elapsed:    8.3s remaining:    3.6s
#
#
#
# 100%|██████████| Fitting SlidingEstimator : 300/300 [00:01<00:00,  212.62it/s]
#
#
#
#
#  57%|█████▋    | Fitting SlidingEstimator : 171/300 [00:00<00:00,  229.61it/s]
#
#
#
#  61%|██████    | Fitting SlidingEstimator : 183/300 [00:00<00:00,  238.16it/s]
#
#
#
#  65%|██████▍   | Fitting SlidingEstimator : 194/300 [00:00<00:00,  243.88it/s]
#
#
#
#  68%|██████▊   | Fitting SlidingEstimator : 205/300 [00:00<00:00,  248.28it/s]
#
#
#
#  72%|███████▏  | Fitting SlidingEstimator : 215/300 [00:00<00:00,  251.34it/s]
#
#
#
#  75%|███████▌  | Fitting SlidingEstimator : 226/300 [00:00<00:00,  256.15it/s]
#
#
#
#  80%|███████▉  | Fitting SlidingEstimator : 239/300 [00:00<00:00,  263.80it/s]
#
#
#
#  84%|████████▍ | Fitting SlidingEstimator : 252/300 [00:01<00:00,  270.20it/s]
#
#
#
#  87%|████████▋ | Fitting SlidingEstimator : 261/300 [00:01<00:00,  269.96it/s]
#
#
#
#  90%|█████████ | Fitting SlidingEstimator : 271/300 [00:01<00:00,  271.58it/s]
#
#
#
#  94%|█████████▍| Fitting SlidingEstimator : 283/300 [00:01<00:00,  275.92it/s]
#
#
#
#  98%|█████████▊| Fitting SlidingEstimator : 295/300 [00:01<00:00,  280.56it/s]
#
#
#
# 100%|██████████| Fitting SlidingEstimator : 300/300 [00:01<00:00,  254.55it/s]
# [Parallel(n_jobs=5)]: Done  10 out of  10 | elapsed:    9.5s finished
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# Best time point post-250ms: 0.20380468750000003 seconds with score: 0.8629602143887857
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# ...
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2671821630.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]

# %%
cv_scores_pre_250ms_endo_arr = np.array(cv_scores_pre_250ms_endo)
cv_scores_pre_250ms_endo_arr = np.abs(cv_scores_pre_250ms_endo_arr-cv_scores_pre_250ms_endo_arr.mean()) + .5
cv_scores_pre_250ms_exo_arr = np.array(cv_scores_pre_250ms_exo)
cv_scores_pre_250ms_exo_arr = np.abs(cv_scores_pre_250ms_exo_arr-cv_scores_pre_250ms_exo_arr.mean()) + .5
plt.plot(exo.times, cv_scores_pre_250ms_endo_arr)
plt.plot(exo.times, cv_scores_pre_250ms_exo_arr)

# %%
np.save('files/B3_decoding.npy', np.vstack([cv_scores_pre_250ms_endo_arr, cv_scores_pre_250ms_exo_arr]))
np.save('files/decoding_times.npy', exo.times)

# %%
# Initialize cross-validation scores list
cv_scores_pre_250ms_attention = []

# Iterate through each time point in pre-250ms data
for t in range(len(epochs_pre_250ms.times)):
    X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
    y_attention = epochs_pre_250ms.metadata['attention_type_block'].values
    fold_scores_attention = []
    
    # Iterate through each fold of cross-validation
    for train_index, test_index in skf.split(X_pre_250ms_attention, y_attention):
        X_train, X_test = X_pre_250ms_attention[train_index], X_pre_250ms_attention[test_index]
        y_train, y_test = y_attention[train_index], y_attention[test_index]
        
        # Use the previously trained model to predict on pre-250ms data
        predictions = clf_best.predict(X_pre_250ms_attention[test_index])
        score_attention = roc_auc_score(y_test, predictions)
        fold_scores_attention.append(score_attention)
    # Average score across folds for this time point
    avg_score_attention = np.mean(fold_scores_attention, axis=-1)
    cv_scores_pre_250ms_attention.append(avg_score_attention)
# Out:
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
# ...
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]
# /tmp/ipykernel_107845/3002719355.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_attention = epochs_pre_250ms.get_data()[:, :, t]

# %%
plt.plot(exo.times, cv_scores_pre_250ms_attention)

# %%
# Data preparation for post-250ms
epochs_post_250ms = epochs.copy().crop(tmin=-.2)
epochs_pre_250ms = epochs.copy().crop(tmax=0.6).copy()

# Data and class to predict for post-250ms
X = epochs_post_250ms.copy().get_data()
y = epochs_post_250ms.metadata['cued_side'].values


# Model fitting for post-250ms
clf = make_pipeline(StandardScaler(), LogisticRegression(solver="liblinear"))
time_decod = SlidingEstimator(clf, n_jobs=5, scoring="roc_auc", verbose=True)
scores = cross_val_multiscore(time_decod, X, y, cv=10, n_jobs=5)

# Mean scores across cross-validation splits for post-250ms
mean_scores = np.mean(scores, axis=0)

# Find the best time point after 250ms
best_time_idx = np.argmax(mean_scores)
best_time = epochs_post_250ms.times[best_time_idx]
best_score = mean_scores[best_time_idx]
print(f"Best time point post-250ms: {best_time} seconds with score: {best_score}")

# Train the model on the best time point after 250ms
best_time_data = X[:, :, best_time_idx]
clf_best = make_pipeline(StandardScaler(), LogisticRegression(solver="liblinear"))
clf_best.fit(best_time_data, y)


# Evaluate the model on pre-250ms data for each time point separately for endo and exo
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import StratifiedKFold
# Automatically perform kfold
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

# Initialize cross-validation scores list
cv_scores_pre_250ms_exo = []
cv_scores_pre_250ms_endo = []

exo = epochs_pre_250ms['attention_type_block==0'].copy()
endo = epochs_pre_250ms['attention_type_block==1'].copy()

# Iterate through each time point in pre-250ms data
for t in range(len(exo.times)):
    X_pre_250ms_exo = exo.get_data()[:, :, t]
    X_pre_250ms_endo = endo.get_data()[:, :, t]
    y_exo = exo.metadata['cued_side'].values
    y_endo = endo.metadata['cued_side'].values
    fold_scores_exo = []
    fold_scores_endo = []
    
    # Iterate through each fold of cross-validation
    for train_index, test_index in skf.split(X_pre_250ms_exo, y_exo):
        X_train, X_test = X_pre_250ms_exo[train_index], X_pre_250ms_exo[test_index]
        y_train, y_test = y_exo[train_index], y_exo[test_index]
        
        # Use the previously trained model to predict on pre-250ms data
        predictions = clf_best.predict(X_pre_250ms_exo[test_index])
        score_exo = roc_auc_score(y_test, predictions)
        fold_scores_exo.append(score_exo)
    # Average score across folds for this time point
    avg_score_exo = np.mean(fold_scores_exo, axis=-1)
    cv_scores_pre_250ms_exo.append(avg_score_exo)
    
    # Iterate through each fold of cross-validation
    for train_index, test_index in skf.split(X_pre_250ms_endo, y_endo):
        X_train, X_test = X_pre_250ms_endo[train_index], X_pre_250ms_endo[test_index]
        y_train, y_test = y_endo[train_index], y_endo[test_index]
        
        # Use the previously trained model to predict on pre-250ms data
        predictions = clf_best.predict(X_pre_250ms_endo[test_index])
        score_endo = roc_auc_score(y_test, predictions)
        fold_scores_endo.append(score_endo)
    
    # Average score across folds for this time point
    avg_score_endo = np.mean(fold_scores_endo, axis=-1)
    cv_scores_pre_250ms_endo.append(avg_score_endo)
# Out:
# /tmp/ipykernel_107845/2399489850.py:6: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X = epochs_post_250ms.copy().get_data()
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
#  33%|███▎      | Fitting SlidingEstimator : 362/1100 [00:02<00:04,  150.83it/s]
#  33%|███▎      | Fitting SlidingEstimator : 366/1100 [00:02<00:04,  148.64it/s]
#  34%|███▎      | Fitting SlidingEstimator : 370/1100 [00:02<00:04,  146.96it/s]A
#  34%|███▍      | Fitting SlidingEstimator : 376/1100 [00:02<00:04,  148.25it/s]A
#  35%|███▍      | Fitting SlidingEstimator : 381/1100 [00:02<00:04,  147.17it/s][A
#  35%|███▌      | Fitting SlidingEstimator : 385/1100 [00:02<00:04,  145.30it/s][A
#  35%|███▌      | Fitting SlidingEstimator : 389/1100 [00:02<00:04,  144.00it/s][A
#  36%|███▌      | Fitting SlidingEstimator : 392/1100 [00:02<00:05,  141.02it/s][A
#  36%|███▌      | Fitting SlidingEstimator : 398/1100 [00:02<00:04,  142.79it/s][A
#  36%|███▋      | Fitting SlidingEstimator : 401/1100 [00:02<00:04,  140.15it/s][A
#  37%|███▋      | Fitting SlidingEstimator : 407/1100 [00:02<00:04,  141.73it/s][A
#  37%|███▋      | Fitting SlidingEstimator : 412/1100 [00:02<00:04,  140.71it/s][A
#  38%|███▊      | Fitting SlidingEstimator : 414/1100 [00:02<00:05,  136.62it/s][A
#  38%|███▊      | Fitting SlidingEstimator : 419/1100 [00:02<00:04,  136.55it/s][A
#  39%|███▊      | Fitting SlidingEstimator : 425/1100 [00:02<00:04,  138.09it/s][A
#  39%|███▉      | Fitting SlidingEstimator : 428/1100 [00:02<00:04,  135.40it/s][A
#  39%|███▉      | Fitting SlidingEstimator : 432/1100 [00:02<00:05,  132.49it/s][A
#  40%|███▉      | Fitting SlidingEstimator : 438/1100 [00:02<00:04,  133.78it/s][A
#  40%|████      | Fitting SlidingEstimator : 444/1100 [00:02<00:04,  134.01it/s][A
#  41%|████      | Fitting SlidingEstimator : 449/1100 [00:03<00:04,  133.34it/s][A
#  41%|████▏     | Fitting SlidingEstimator : 454/1100 [00:03<00:04,  133.89it/s][A
#  42%|████▏     | Fitting SlidingEstimator : 457/1100 [00:03<00:04,  131.73it/s][A
#  42%|████▏     | Fitting SlidingEstimator : 464/1100 [00:03<00:04,  134.80it/s]
#  43%|████▎     | Fitting SlidingEstimator : 468/1100 [00:03<00:04,  133.70it/s]
#  43%|████▎     | Fitting SlidingEstimator : 474/1100 [00:03<00:04,  135.22it/s]
#  44%|████▎     | Fitting SlidingEstimator : 479/1100 [00:03<00:04,  135.81it/s]
#  44%|████▍     | Fitting SlidingEstimator : 485/1100 [00:03<00:04,  136.96it/s]
#  44%|████▍     | Fitting SlidingEstimator : 489/1100 [00:03<00:04,  135.97it/s]
#  45%|████▌     | Fitting SlidingEstimator : 495/1100 [00:03<00:04,  137.70it/s]
#  45%|████▌     | Fitting SlidingEstimator : 500/1100 [00:03<00:04,  137.55it/s]
#  46%|████▌     | Fitting SlidingEstimator : 505/1100 [00:03<00:04,  137.99it/s]
#  46%|████▋     | Fitting SlidingEstimator : 510/1100 [00:03<00:04,  138.45it/s]
#  47%|████▋     | Fitting SlidingEstimator : 515/1100 [00:03<00:04,  138.88it/s]
#  47%|████▋     | Fitting SlidingEstimator : 520/1100 [00:03<00:04,  139.23it/s]
#  48%|████▊     | Fitting SlidingEstimator : 524/1100 [00:03<00:04,  137.74it/s]
#  48%|████▊     | Fitting SlidingEstimator : 528/1100 [00:03<00:04,  136.39it/s]
#  48%|████▊     | Fitting SlidingEstimator : 532/1100 [00:03<00:04,  135.50it/s]
#  49%|████▊     | Fitting SlidingEstimator : 536/1100 [00:03<00:04,  134.10it/s]
#  49%|████▉     | Fitting SlidingEstimator : 541/1100 [00:03<00:04,  134.51it/s]
#  49%|████▉     | Fitting SlidingEstimator : 544/1100 [00:03<00:04,  132.25it/s]
#  50%|█████     | Fitting SlidingEstimator : 550/1100 [00:03<00:04,  134.11it/s]
#  50%|█████     | Fitting SlidingEstimator : 553/1100 [00:03<00:04,  131.04it/s]
#  51%|█████     | Fitting SlidingEstimator : 558/1100 [00:03<00:04,  131.49it/s]
#  51%|█████     | Fitting SlidingEstimator : 563/1100 [00:03<00:04,  131.94it/s]
#  52%|█████▏    | Fitting SlidingEstimator : 568/1100 [00:03<00:04,  132.21it/s]
#  52%|█████▏    | Fitting SlidingEstimator : 572/1100 [00:03<00:04,  131.41it/s]
#  53%|█████▎    | Fitting SlidingEstimator : 579/1100 [00:03<00:03,  133.54it/s]
#  53%|█████▎    | Fitting SlidingEstimator : 583/1100 [00:04<00:03,  132.50it/s]
#  53%|█████▎    | Fitting SlidingEstimator : 588/1100 [00:04<00:03,  132.68it/s]
#  54%|█████▍    | Fitting SlidingEstimator : 596/1100 [00:04<00:03,  130.84it/s]
#  55%|█████▍    | Fitting SlidingEstimator : 600/1100 [00:04<00:03,  130.12it/s]
#  55%|█████▌    | Fitting SlidingEstimator : 606/1100 [00:04<00:03,  132.09it/s]
#  56%|█████▌    | Fitting SlidingEstimator : 611/1100 [00:04<00:03,  132.44it/s]
#  24%|██▎       | Fitting SlidingEstimator : 259/1100 [00:01<00:06,  137.04it/s]
#  56%|█████▌    | Fitting SlidingEstimator : 614/1100 [00:04<00:03,  129.50it/s]
#  25%|██▍       | Fitting SlidingEstimator : 270/1100 [00:01<00:05,  139.27it/s]
#  57%|█████▋    | Fitting SlidingEstimator : 624/1100 [00:04<00:03,  130.21it/s]
#  57%|█████▋    | Fitting SlidingEstimator : 629/1100 [00:04<00:03,  129.90it/s]
#  58%|█████▊    | Fitting SlidingEstimator : 633/1100 [00:04<00:03,  129.31it/s]
#  58%|█████▊    | Fitting SlidingEstimator : 639/1100 [00:04<00:03,  131.31it/s]
#  58%|���████▊    | Fitting SlidingEstimator : 642/1100 [00:04<00:03,  129.09it/s]A
#  59%|█████▉    | Fitting SlidingEstimator : 647/1100 [00:04<00:03,  129.63it/s]
#  59%|█████▉    | Fitting SlidingEstimator : 653/1100 [00:04<00:03,  125.34it/s]
#  28%|██▊       | Fitting SlidingEstimator : 308/1100 [00:02<00:05,  134.94it/s]
#  60%|█████▉    | Fitting SlidingEstimator : 657/1100 [00:04<00:03,  123.77it/s]
#  60%|██████    | Fitting SlidingEstimator : 662/1100 [00:04<00:03,  124.47it/s]
#  60%|██████    | Fitting SlidingEstimator : 664/1100 [00:04<00:03,  121.13it/s]
#  61%|██████    | Fitting SlidingEstimator : 668/1100 [00:04<00:03,  120.62it/s]
#
#   0%|          | Fitting SlidingEstimator : 0/1100 [00:00<?,       ?it/s]
#  61%|██████    | Fitting SlidingEstimator : 673/1100 [00:04<00:03,  120.63it/s]
#  62%|██████▏   | Fitting SlidingEstimator : 678/1100 [00:04<00:03,  121.79it/s]
#
#   1%|          | Fitting SlidingEstimator : 6/1100 [00:00<00:15,   72.89it/s]
#  62%|██████▏   | Fitting SlidingEstimator : 682/1100 [00:04<00:03,  121.21it/s]
#
#   1%|          | Fitting SlidingEstimator : 12/1100 [00:00<00:11,   95.47it/s]
#  62%|██████▏   | Fitting SlidingEstimator : 687/1100 [00:04<00:03,  121.91it/s]s]
#
#   1%|▏         | Fitting SlidingEstimator : 15/1100 [00:00<00:11,   93.87it/s]
#  63%|██████▎   | Fitting SlidingEstimator : 689/1100 [00:04<00:03,  118.87it/s]
#
#   2%|▏         | Fitting SlidingEstimator : 19/1100 [00:00<00:11,   97.55it/s]
#  63%|██████▎   | Fitting SlidingEstimator : 693/1100 [00:04<00:03,  118.72it/s]
#
#   2%|▏         | Fitting SlidingEstimator : 23/1100 [00:00<00:10,  100.31it/s]
#  64%|██████▎   | Fitting SlidingEstimator : 699/1100 [00:05<00:03,  121.02it/s]
#
#   2%|▏         | Fitting SlidingEstimator : 27/1100 [00:00<00:10,  102.95it/s]
#  64%|██████▍   | Fitting SlidingEstimator : 702/1100 [00:05<00:03,  119.11it/s]
#
#   3%|▎         | Fitting SlidingEstimator : 32/1100 [00:00<00:09,  108.93it/s]
#  64%|██████▍   | Fitting SlidingEstimator : 706/1100 [00:05<00:03,  118.93it/s]
#
#   3%|▎         | Fitting SlidingEstimator : 36/1100 [00:00<00:09,  109.44it/s]
#  33%|███▎      | Fitting SlidingEstimator : 365/1100 [00:02<00:05,  124.54it/s]
#
#  65%|██████▍   | Fitting SlidingEstimator : 713/1100 [00:05<00:03,  117.29it/s][A
#  34%|███▎      | Fitting SlidingEstimator : 369/1100 [00:02<00:05,  123.49it/s]
#
#  65%|██████▌   | Fitting SlidingEstimator : 718/1100 [00:05<00:03,  118.70it/s][A
#  34%|███▍      | Fitting SlidingEstimator : 372/1100 [00:02<00:05,  121.72it/s]
#
#  66%|██████▌   | Fitting SlidingEstimator : 724/1100 [00:05<00:03,  121.12it/s][A
#  34%|███▍      | Fitting SlidingEstimator : 377/1100 [00:02<00:05,  122.57it/s]
#
#  66%|██████▌   | Fitting SlidingEstimator : 726/1100 [00:05<00:03,  118.03it/s][A
#  35%|███▍      | Fitting SlidingEstimator : 380/1100 [00:02<00:05,  120.15it/s]
#
#  66%|██████▋   | Fitting SlidingEstimator : 730/1100 [00:05<00:03,  117.90it/s][A
#  35%|███▌      | Fitting SlidingEstimator : 387/1100 [00:02<00:05,  123.88it/s]
#
#  67%|██████▋   | Fitting SlidingEstimator : 733/1100 [00:05<00:03,  116.14it/s][A
#  35%|███▌      | Fitting SlidingEstimator : 389/1100 [00:02<00:05,  120.82it/s]
#
#  67%|██████▋   | Fitting SlidingEstimator : 739/1100 [00:05<00:03,  118.36it/s][A
#  36%|███▌      | Fitting SlidingEstimator : 395/1100 [00:03<00:05,  121.63it/s]
#
#  68%|██████▊   | Fitting SlidingEstimator : 744/1100 [00:05<00:02,  119.58it/s][A
#  36%|███▋      | Fitting SlidingEstimator : 400/1100 [00:03<00:05,  122.30it/s]
#
#  68%|██████▊   | Fitting SlidingEstimator : 747/1100 [00:05<00:02,  117.87it/s][A
#  37%|███▋      | Fitting SlidingEstimator : 403/1100 [00:03<00:05,  120.62it/s]
#
#  68%|██████▊   | Fitting SlidingEstimator : 752/1100 [00:05<00:02,  119.15it/s][A
#  37%|███▋      | Fitting SlidingEstimator : 408/1100 [00:03<00:05,  121.53it/s]
#
#  69%|██████▊   | Fitting SlidingEstimator : 755/1100 [00:05<00:02,  117.71it/s][A
#  37%|███▋      | Fitting SlidingEstimator : 412/1100 [00:03<00:05,  121.08it/s]
#
#  69%|██████▉   | Fitting SlidingEstimator : 760/1100 [00:05<00:02,  118.71it/s][A
#  38%|███▊      | Fitting SlidingEstimator : 417/1100 [00:03<00:05,  121.01it/s]
#
#  69%|██████▉   | Fitting SlidingEstimator : 763/1100 [00:05<00:02,  116.82it/s][A
#  38%|███▊      | Fitting SlidingEstimator : 421/1100 [00:03<00:05,  120.68it/s]
#
#  70%|██████▉   | Fitting SlidingEstimator : 766/1100 [00:05<00:02,  115.44it/s][A
#
#   9%|▉         | Fitting SlidingEstimator : 98/1100 [00:00<00:08,  114.28it/s]
#  70%|███████   | Fitting SlidingEstimator : 774/1100 [00:05<00:02,  119.91it/s]
#  39%|███▉      | Fitting SlidingEstimator : 431/1100 [00:03<00:05,  122.40it/s]
#
#  70%|███████   | Fitting SlidingEstimator : 775/1100 [00:05<00:02,  115.61it/s]
#
#
#  71%|███████   | Fitting SlidingEstimator : 780/1100 [00:05<00:02,  117.02it/s]
#
#  10%|█         | Fitting SlidingEstimator : 111/1100 [00:00<00:08,  115.79it/s]
#  71%|███████▏  | Fitting SlidingEstimator : 784/1100 [00:05<00:02,  117.08it/s]
#
#  10%|█         | Fitting SlidingEstimator : 115/1100 [00:01<00:08,  115.92it/s]
#  41%|████      | Fitting SlidingEstimator : 446/1100 [00:03<00:05,  124.01it/s]
#
#  11%|█         | Fitting SlidingEstimator : 119/1100 [00:01<00:08,  115.80it/s]
#  72%|███████▏  | Fitting SlidingEstimator : 793/1100 [00:05<00:02,  117.99it/s]
#
#  11%|█▏        | Fitting SlidingEstimator : 126/1100 [00:01<00:08,  121.29it/s]
#  72%|███████▏  | Fitting SlidingEstimator : 797/1100 [00:05<00:02,  117.34it/s]
#
#  12%|█▏        | Fitting SlidingEstimator : 131/1100 [00:01<00:07,  122.10it/s]
#  42%|████▏     | Fitting SlidingEstimator : 462/1100 [00:03<00:05,  126.43it/s]
#
#  73%|███████▎  | Fitting SlidingEstimator : 808/1100 [00:05<00:02,  121.43it/s]
#  42%|████▏     | Fitting SlidingEstimator : 467/1100 [00:03<00:04,  126.89it/s]
#
#  74%|███████▍  | Fitting SlidingEstimator : 812/1100 [00:05<00:02,  121.09it/s]
#  43%|████▎     | Fitting SlidingEstimator : 472/1100 [00:03<00:04,  127.77it/s]
#
#  74%|███████▍  | Fitting SlidingEstimator : 814/1100 [00:05<00:02,  118.04it/s]
#  43%|████▎     | Fitting SlidingEstimator : 478/1100 [00:03<00:04,  129.96it/s]
#
#  74%|███████▍  | Fitting SlidingEstimator : 819/1100 [00:06<00:02,  118.81it/s]
#  44%|████▍     | Fitting SlidingEstimator : 483/1100 [00:03<00:04,  128.30it/s]
#
#  75%|███████▍  | Fitting SlidingEstimator : 824/1100 [00:06<00:02,  120.02it/s]
#  44%|████▍     | Fitting SlidingEstimator : 487/1100 [00:03<00:04,  127.71it/s]
#
#  75%|███████▌  | Fitting SlidingEstimator : 828/1100 [00:06<00:02,  118.96it/s]
#  45%|████▍     | Fitting SlidingEstimator : 492/1100 [00:03<00:04,  128.29it/s]
#
#  76%|███████▌  | Fitting SlidingEstimator : 833/1100 [00:06<00:02,  120.19it/s]
#  45%|████▌     | Fitting SlidingEstimator : 495/1100 [00:03<00:04,  126.23it/s]
#
#  76%|███████▋  | Fitting SlidingEstimator : 839/1100 [00:06<00:02,  122.80it/s]
#  45%|████▌     | Fitting SlidingEstimator : 499/1100 [00:03<00:04,  125.85it/s]
#
#  77%|███████▋  | Fitting SlidingEstimator : 844/1100 [00:06<00:02,  123.63it/s]
#  46%|████▌     | Fitting SlidingEstimator : 504/1100 [00:03<00:04,  126.85it/s]
#
#  77%|███████▋  | Fitting SlidingEstimator : 847/1100 [00:06<00:02,  121.69it/s]
#  46%|████▋     | Fitting SlidingEstimator : 509/1100 [00:03<00:04,  127.54it/s]
#
#  77%|███████▋  | Fitting SlidingEstimator : 852/1100 [00:06<00:02,  122.48it/s]
#  47%|████▋     | Fitting SlidingEstimator : 513/1100 [00:03<00:04,  126.75it/s]
#
#  78%|███████▊  | Fitting SlidingEstimator : 855/1100 [00:06<00:02,  120.24it/s]
#  47%|████▋     | Fitting SlidingEstimator : 518/1100 [00:03<00:04,  127.54it/s]
#
#  78%|███████▊  | Fitting SlidingEstimator : 860/1100 [00:06<00:01,  121.30it/s]
#  47%|████▋     | Fitting SlidingEstimator : 520/1100 [00:04<00:04,  124.25it/s]
#
#  18%|█▊        | Fitting SlidingEstimator : 194/1100 [00:01<00:07,  123.20it/s]
#  79%|███████▊  | Fitting SlidingEstimator : 865/1100 [00:06<00:01,  121.96it/s]
#
#  18%|█▊        | Fitting SlidingEstimator : 197/1100 [00:01<00:07,  121.11it/s]
#  79%|███████▉  | Fitting SlidingEstimator : 869/1100 [00:06<00:01,  120.42it/s]
#
#  18%|█▊        | Fitting SlidingEstimator : 199/1100 [00:01<00:07,  117.43it/s]
#  79%|███████▉  | Fitting SlidingEstimator : 874/1100 [00:06<00:01,  120.00it/s]
#
#  18%|█▊        | Fitting SlidingEstimator : 203/1100 [00:01<00:07,  116.53it/s]
#  80%|███████▉  | Fitting SlidingEstimator : 878/1100 [00:06<00:01,  119.16it/s]
#
#  19%|█▊        | Fitting SlidingEstimator : 206/1100 [00:01<00:07,  114.41it/s]
#  80%|████████  | Fitting SlidingEstimator : 882/1100 [00:06<00:01,  118.61it/s]
#  50%|████▉     | Fitting SlidingEstimator : 545/1100 [00:04<00:04,  122.35it/s]
#
#  80%|████████  | Fitting SlidingEstimator : 885/1100 [00:06<00:01,  117.22it/s]
#  81%|████████  | Fitting SlidingEstimator : 888/1100 [00:06<00:01,  115.75it/s]
#  50%|█████     | Fitting SlidingEstimator : 551/1100 [00:04<00:04,  119.30it/s]
#
#  81%|████████  | Fitting SlidingEstimator : 890/1100 [00:06<00:01,  112.41it/s]
#
#  20%|██        | Fitting SlidingEstimator : 220/1100 [00:01<00:07,  111.58it/s]
#  81%|████████  | Fitting SlidingEstimator : 893/1100 [00:06<00:01,  109.88it/s]
#
#  20%|██        | Fitting SlidingEstimator : 224/1100 [00:01<00:07,  111.60it/s]
#  82%|████████▏ | Fitting SlidingEstimator : 897/1100 [00:06<00:01,  109.56it/s]
#
#  21%|██        | Fitting SlidingEstimator : 228/1100 [00:01<00:07,  111.78it/s]
#  51%|█████     | Fitting SlidingEstimator : 561/1100 [00:04<00:04,  113.44it/s]
#
#  82%|████████▏ | Fitting SlidingEstimator : 900/1100 [00:06<00:01,  107.67it/s]
#  51%|█████▏    | Fitting SlidingEstimator : 565/1100 [00:04<00:04,  112.89it/s]
#
#  21%|██▏       | Fitting SlidingEstimator : 234/1100 [00:02<00:07,  108.90it/s]
#  82%|████████▏ | Fitting SlidingEstimator : 904/1100 [00:06<00:01,  104.76it/s]
#
#  22%|██▏       | Fitting SlidingEstimator : 237/1100 [00:02<00:08,  107.62it/s]
#  83%|████████▎ | Fitting SlidingEstimator : 909/1100 [00:06<00:01,  106.25it/s]
#
#  22%|██▏       | Fitting SlidingEstimator : 239/1100 [00:02<00:08,  104.77it/s]
#  83%|████████▎ | Fitting SlidingEstimator : 911/1100 [00:06<00:01,  103.16it/s]
#
#  22%|██▏       | Fitting SlidingEstimator : 242/1100 [00:02<00:08,  103.89it/s]
#  53%|█████▎    | Fitting SlidingEstimator : 580/1100 [00:04<00:04,  110.78it/s]
#
#  83%|████████▎ | Fitting SlidingEstimator : 916/1100 [00:06<00:01,  104.10it/s]
#  83%|████████▎ | Fitting SlidingEstimator : 918/1100 [00:06<00:01,  101.99it/s]
#
#  23%|██▎       | Fitting SlidingEstimator : 250/1100 [00:02<00:08,  104.50it/s]
#  84%|████████▎ | Fitting SlidingEstimator : 921/1100 [00:07<00:01,  101.35it/s]
#
#  23%|██▎       | Fitting SlidingEstimator : 253/1100 [00:02<00:08,  103.12it/s]
#  54%|█████▎    | Fitting SlidingEstimator : 589/1100 [00:04<00:04,  107.08it/s]
#
#  84%|████████▍ | Fitting SlidingEstimator : 928/1100 [00:07<00:01,  100.30it/s]
#  54%|█████▍    | Fitting SlidingEstimator : 595/1100 [00:04<00:04,  107.66it/s]
#
#  23%|██▎       | Fitting SlidingEstimator : 257/1100 [00:02<00:08,   98.29it/s]
#  85%|████████▍ | Fitting SlidingEstimator : 931/1100 [00:07<00:01,   98.56it/s]
#
#  24%|██▎       | Fitting SlidingEstimator : 259/1100 [00:02<00:08,   95.18it/s]
#  85%|████████▌ | Fitting SlidingEstimator : 935/1100 [00:07<00:01,   97.41it/s]
#
#  24%|██▍       | Fitting SlidingEstimator : 264/1100 [00:02<00:08,   95.12it/s]
#  85%|████████▌ | Fitting SlidingEstimator : 939/1100 [00:07<00:01,   98.17it/s]
#
#  24%|██▍       | Fitting SlidingEstimator : 267/1100 [00:02<00:08,   94.65it/s]
#  86%|████████▌ | Fitting SlidingEstimator : 942/1100 [00:07<00:01,   97.50it/s]
#
#  25%|██▍       | Fitting SlidingEstimator : 271/1100 [00:02<00:08,   95.33it/s]
#  86%|████████▌ | Fitting SlidingEstimator : 944/1100 [00:07<00:01,   95.59it/s]
#
#  25%|██▍       | Fitting SlidingEstimator : 272/1100 [00:02<00:09,   90.89it/s]
#  86%|████████▌ | Fitting SlidingEstimator : 947/1100 [00:07<00:01,   94.68it/s]
#
#  25%|██▌       | Fitting SlidingEstimator : 275/1100 [00:02<00:09,   90.61it/s]
#  56%|█████▌    | Fitting SlidingEstimator : 616/1100 [00:05<00:04,  100.01it/s]
#
#  25%|██▌       | Fitting SlidingEstimator : 279/1100 [00:02<00:08,   91.52it/s]
#  87%|████████▋ | Fitting SlidingEstimator : 953/1100 [00:07<00:01,   92.22it/s]
#  87%|████████▋ | Fitting SlidingEstimator : 957/1100 [00:07<00:01,   93.19it/s]
#
#  26%|██▌       | Fitting SlidingEstimator : 283/1100 [00:02<00:09,   87.94it/s]
#  87%|████████▋ | Fitting SlidingEstimator : 959/1100 [00:07<00:01,   91.28it/s]
#
#  26%|██▌       | Fitting SlidingEstimator : 285/1100 [00:02<00:09,   86.45it/s]
#  57%|█████▋    | Fitting SlidingEstimator : 628/1100 [00:05<00:04,   97.65it/s]
#
#
#  87%|████████▋ | Fitting SlidingEstimator : 961/1100 [00:07<00:01,   89.84it/s]
#
#  26%|██▋       | Fitting SlidingEstimator : 289/1100 [00:02<00:09,   87.44it/s]
#  88%|████████▊ | Fitting SlidingEstimator : 967/1100 [00:07<00:01,   93.53it/s]
#
#  27%|██▋       | Fitting SlidingEstimator : 292/1100 [00:02<00:09,   87.27it/s]
#  58%|█████▊    | Fitting SlidingEstimator : 636/1100 [00:05<00:04,   96.75it/s]
#
#  88%|████████▊ | Fitting SlidingEstimator : 969/1100 [00:07<00:01,   91.26it/s]
#
#
#   0%|          | Fitting SlidingEstimator : 3/1100 [00:00<00:38,   28.25it/s]
#
#  88%|████████▊ | Fitting SlidingEstimator : 973/1100 [00:07<00:01,   91.52it/s]
#  58%|█████▊    | Fitting SlidingEstimator : 642/1100 [00:05<00:04,   95.52it/s]
#
#
#   1%|          | Fitting SlidingEstimator : 8/1100 [00:00<00:21,   51.42it/s]
#
#  89%|████████▊ | Fitting SlidingEstimator : 975/1100 [00:07<00:01,   89.97it/s]
#  58%|█████▊    | Fitting SlidingEstimator : 643/1100 [00:05<00:04,   92.63it/s]
#
#
#   1%|          | Fitting SlidingEstimator : 12/1100 [00:00<00:17,   63.19it/s]
#
#  89%|████████▉ | Fitting SlidingEstimator : 980/1100 [00:07<00:01,   91.54it/s]
#  59%|█████▉    | Fitting SlidingEstimator : 648/1100 [00:05<00:04,   94.84it/s]
#
#
#   2%|▏         | Fitting SlidingEstimator : 17/1100 [00:00<00:14,   75.04it/s]
#
#  89%|████████▉ | Fitting SlidingEstimator : 982/1100 [00:07<00:01,   90.09it/s]
#  59%|█████▉    | Fitting SlidingEstimator : 650/1100 [00:05<00:04,   92.99it/s]
#
#
#   2%|▏         | Fitting SlidingEstimator : 20/1100 [00:00<00:14,   76.88it/s]
#
#  90%|████████▉ | Fitting SlidingEstimator : 987/1100 [00:07<00:01,   91.89it/s]
#  60%|█████▉    | Fitting SlidingEstimator : 655/1100 [00:05<00:04,   95.18it/s]
#
#
#  90%|████████▉ | Fitting SlidingEstimator : 988/1100 [00:07<00:01,   88.98it/s][A
#
#  29%|██▊       | Fitting SlidingEstimator : 315/1100 [00:03<00:08,   87.63it/s]
#  90%|█████████ | Fitting SlidingEstimator : 992/1100 [00:07<00:01,   90.29it/s]
#
#
#   3%|▎         | Fitting SlidingEstimator : 30/1100 [00:00<00:12,   85.17it/s]
#
#  29%|██▉       | Fitting SlidingEstimator : 319/1100 [00:03<00:08,   88.34it/s]
#  91%|█████████ | Fitting SlidingEstimator : 996/1100 [00:07<00:01,   91.54it/s]
#
#
#
#
#   3%|▎         | Fitting SlidingEstimator : 32/1100 [00:00<00:12,   82.20it/s]
#  91%|█████████ | Fitting SlidingEstimator : 999/1100 [00:07<00:01,   91.39it/s]
#
#  29%|██▉       | Fitting SlidingEstimator : 321/1100 [00:03<00:09,   83.20it/s]
#  61%|██████    | Fitting SlidingEstimator : 671/1100 [00:05<00:04,   98.21it/s]
#
#
#  91%|█████████▏| Fitting SlidingEstimator : 1004/1100 [00:07<00:01,   93.37it/s]A
#  61%|██████▏   | Fitting SlidingEstimator : 675/1100 [00:05<00:04,   99.09it/s]
#
#  30%|██▉       | Fitting SlidingEstimator : 326/1100 [00:03<00:09,   85.56it/s]
#
#
#  92%|█████████▏| Fitting SlidingEstimator : 1008/1100 [00:08<00:00,   94.12it/s]A
#  62%|██████▏   | Fitting SlidingEstimator : 678/1100 [00:05<00:04,   98.62it/s]
#
#  30%|██▉       | Fitting SlidingEstimator : 329/1100 [00:03<00:09,   85.64it/s]
#
#
#  92%|█████████▏| Fitting SlidingEstimator : 1009/1100 [00:08<00:00,   91.20it/s]A
#  62%|██████▏   | Fitting SlidingEstimator : 682/1100 [00:05<00:04,   99.48it/s]
#
#  30%|███       | Fitting SlidingEstimator : 333/1100 [00:03<00:08,   86.51it/s]
#
#
#  92%|█████████▏| Fitting SlidingEstimator : 1014/1100 [00:08<00:00,   93.71it/s]A
#  63%|██████▎   | Fitting SlidingEstimator : 688/1100 [00:05<00:04,  102.89it/s]
#
#  30%|███       | Fitting SlidingEstimator : 335/1100 [00:03<00:09,   84.67it/s]
#
#
#   4%|▍         | Fitting SlidingEstimator : 49/1100 [00:00<00:12,   83.10it/s]
#  93%|█████████▎| Fitting SlidingEstimator : 1018/1100 [00:08<00:00,   93.54it/s][A
#
#  31%|███       | Fitting SlidingEstimator : 340/1100 [00:03<00:08,   87.22it/s]
#
#
#   5%|▍         | Fitting SlidingEstimator : 53/1100 [00:00<00:12,   84.70it/s]
#  93%|█████████▎| Fitting SlidingEstimator : 1021/1100 [00:08<00:00,   92.47it/s][A
#
#  31%|███▏      | Fitting SlidingEstimator : 344/1100 [00:03<00:08,   88.42it/s]
#
#
#   5%|▌         | Fitting SlidingEstimator : 57/1100 [00:00<00:11,   87.06it/s]
#  63%|██████▎   | Fitting SlidingEstimator : 695/1100 [00:05<00:04,   97.62it/s]
#
#  93%|█████████▎| Fitting SlidingEstimator : 1025/1100 [00:08<00:00,   93.09it/s][A
#
#
#   5%|▌         | Fitting SlidingEstimator : 59/1100 [00:00<00:12,   84.71it/s]
#  64%|██████▎   | Fitting SlidingEstimator : 700/1100 [00:05<00:04,   99.92it/s]
#
#  32%|███▏      | Fitting SlidingEstimator : 352/1100 [00:03<00:08,   90.69it/s]
#  64%|██████▍   | Fitting SlidingEstimator : 703/1100 [00:05<00:04,   99.21it/s]
#
#
#   6%|▌         | Fitting SlidingEstimator : 64/1100 [00:00<00:12,   85.92it/s]
#
#  94%|█████████▎| Fitting SlidingEstimator : 1030/1100 [00:08<00:00,   91.04it/s][A
#  64%|██████▍   | Fitting SlidingEstimator : 706/1100 [00:05<00:04,   97.82it/s]
#
#
#   6%|▋         | Fitting SlidingEstimator : 70/1100 [00:00<00:11,   91.22it/s]
#
#  33%|███▎      | Fitting SlidingEstimator : 358/1100 [00:03<00:08,   89.98it/s]
#  64%|██████▍   | Fitting SlidingEstimator : 709/1100 [00:06<00:04,   96.70it/s]
#
#
#   6%|▋         | Fitting SlidingEstimator : 71/1100 [00:00<00:11,   86.84it/s]
#
#  94%|█████████▍| Fitting SlidingEstimator : 1039/1100 [00:08<00:00,   94.35it/s]
#  65%|██████▍   | Fitting SlidingEstimator : 713/1100 [00:06<00:03,   97.52it/s]
#
#
#  95%|█████████▍| Fitting SlidingEstimator : 1043/1100 [00:08<00:00,   95.33it/s]A
#
#  33%|███▎      | Fitting SlidingEstimator : 366/1100 [00:03<00:07,   91.86it/s]
#
#
#   7%|▋         | Fitting SlidingEstimator : 76/1100 [00:00<00:12,   84.79it/s]
#  65%|██████▌   | Fitting SlidingEstimator : 715/1100 [00:06<00:04,   94.94it/s]
#
#  95%|█████████▌| Fitting SlidingEstimator : 1046/1100 [00:08<00:00,   94.48it/s][A
#  65%|██████▌   | Fitting SlidingEstimator : 719/1100 [00:06<00:03,   95.95it/s]
#
#
#  95%|█████████▌| Fitting SlidingEstimator : 1049/1100 [00:08<00:00,   93.86it/s]A
#
#  34%|███▎      | Fitting SlidingEstimator : 370/1100 [00:03<00:08,   88.27it/s]
#  66%|██████▌   | Fitting SlidingEstimator : 722/1100 [00:06<00:03,   95.41it/s]
#
#  34%|███▍      | Fitting SlidingEstimator : 373/1100 [00:03<00:08,   88.28it/s]
#
#
#   8%|▊         | Fitting SlidingEstimator : 86/1100 [00:00<00:11,   89.10it/s]
#  96%|█████████▌| Fitting SlidingEstimator : 1057/1100 [00:08<00:00,   94.78it/s][A
#
#
#   8%|▊         | Fitting SlidingEstimator : 88/1100 [00:01<00:11,   86.96it/s]
#
#  34%|███▍      | Fitting SlidingEstimator : 378/1100 [00:03<00:08,   88.50it/s]
#  96%|█████████▋| Fitting SlidingEstimator : 1060/1100 [00:08<00:00,   94.50it/s][A
#
#
#   8%|▊         | Fitting SlidingEstimator : 90/1100 [00:01<00:11,   85.33it/s]
#
#  35%|███▍      | Fitting SlidingEstimator : 380/1100 [00:03<00:08,   87.17it/s]
#  97%|█████████▋| Fitting SlidingEstimator : 1066/1100 [00:08<00:00,   97.77it/s][A
#
#
#   9%|▊         | Fitting SlidingEstimator : 95/1100 [00:01<00:11,   88.89it/s]
#
#  35%|███▍      | Fitting SlidingEstimator : 383/1100 [00:03<00:08,   87.13it/s]
#  67%|██████▋   | Fitting SlidingEstimator : 735/1100 [00:06<00:03,   93.60it/s]
#
#
#   9%|▉         | Fitting SlidingEstimator : 98/1100 [00:01<00:11,   88.87it/s]
#
#  97%|█████████▋| Fitting SlidingEstimator : 1071/1100 [00:08<00:00,   95.51it/s][A
#
#
#   9%|▉         | Fitting SlidingEstimator : 103/1100 [00:01<00:10,   91.78it/s]
#  67%|██████▋   | Fitting SlidingEstimator : 740/1100 [00:06<00:03,   95.18it/s]
#
#  98%|█████████▊| Fitting SlidingEstimator : 1076/1100 [00:08<00:00,   97.04it/s][A
#
#  36%|███▌      | Fitting SlidingEstimator : 393/1100 [00:03<00:08,   88.24it/s]
#
#
#
#  98%|█████████▊| Fitting SlidingEstimator : 1079/1100 [00:08<00:00,   96.34it/s][A
#
#  36%|███▌      | Fitting SlidingEstimator : 398/1100 [00:03<00:07,   90.95it/s]
#  68%|██████▊   | Fitting SlidingEstimator : 747/1100 [00:06<00:03,   94.55it/s]
#
#
#  98%|█████████▊| Fitting SlidingEstimator : 1080/1100 [00:08<00:00,   93.29it/s][A
#
#  36%|███▋      | Fitting SlidingEstimator : 401/1100 [00:04<00:07,   90.72it/s]
#
#
#
#  99%|█████████▊| Fitting SlidingEstimator : 1086/1100 [00:08<00:00,   96.86it/s][A
#
#  37%|███▋      | Fitting SlidingEstimator : 405/1100 [00:04<00:07,   91.75it/s]
#
#
#  99%|█████████▉| Fitting SlidingEstimator : 1088/1100 [00:08<00:00,   95.11it/s][A
#  69%|██████▊   | Fitting SlidingEstimator : 754/1100 [00:06<00:03,   91.38it/s]
#
#  37%|███▋      | Fitting SlidingEstimator : 406/1100 [00:04<00:07,   88.48it/s]
#
#
#  99%|█████████▉| Fitting SlidingEstimator : 1091/1100 [00:08<00:00,   94.58it/s][A
#  69%|██████▉   | Fitting SlidingEstimator : 757/1100 [00:06<00:03,   91.25it/s]
#
#  37%|███▋      | Fitting SlidingEstimator : 411/1100 [00:04<00:07,   90.75it/s]
#
#
#  99%|█████████▉| Fitting SlidingEstimator : 1093/1100 [00:08<00:00,   92.92it/s][A
#  69%|██████▉   | Fitting SlidingEstimator : 761/1100 [00:06<00:03,   92.34it/s]
#
# 100%|█████████▉| Fitting SlidingEstimator : 1095/1100 [00:08<00:00,   91.35it/s][A
#
#
#  12%|█▏        | Fitting SlidingEstimator : 132/1100 [00:01<00:10,   96.37it/s]
#  70%|██████▉   | Fitting SlidingEstimator : 765/1100 [00:06<00:03,   93.46it/s]
#
# 100%|█████████▉| Fitting SlidingEstimator : 1098/1100 [00:08<00:00,   91.04it/s][A
#
#
#  12%|█▏        | Fitting SlidingEstimator : 135/1100 [00:01<00:10,   95.67it/s]
#  70%|██████▉   | Fitting SlidingEstimator : 769/1100 [00:06<00:03,   94.37it/s]
#
#  38%|███▊      | Fitting SlidingEstimator : 422/1100 [00:04<00:07,   91.04it/s]
#
#
# 100%|██████████| Fitting SlidingEstimator : 1100/1100 [00:09<00:00,   89.07it/s][A
# 100%|██████████| Fitting SlidingEstimator : 1100/1100 [00:09<00:00,  121.79it/s][A
#
#
#  39%|███▉      | Fitting SlidingEstimator : 427/1100 [00:04<00:07,   92.29it/s]
#  71%|███████   | Fitting SlidingEstimator : 777/1100 [00:06<00:03,   96.23it/s]
#
#
#  13%|█▎        | Fitting SlidingEstimator : 144/1100 [00:01<00:09,   98.75it/s]
#
#  39%|███▉      | Fitting SlidingEstimator : 430/1100 [00:04<00:07,   91.75it/s]
#  71%|███████   | Fitting SlidingEstimator : 780/1100 [00:06<00:03,   95.86it/s]
#
#
#  13%|█▎        | Fitting SlidingEstimator : 147/1100 [00:01<00:09,   98.22it/s]
#  71%|███████   | Fitting SlidingEstimator : 783/1100 [00:06<00:03,   95.52it/s]
#
#
#  14%|█▍        | Fitting SlidingEstimator : 152/1100 [00:01<00:09,  100.72it/s]
#
#  40%|███▉      | Fitting SlidingEstimator : 436/1100 [00:04<00:06,   94.95it/s]
#
#
#  72%|███████▏  | Fitting SlidingEstimator : 787/1100 [00:06<00:03,   96.31it/s]
#
#  40%|████      | Fitting SlidingEstimator : 442/1100 [00:04<00:06,   94.19it/s]
#
#
#  14%|█▍        | Fitting SlidingEstimator : 157/1100 [00:01<00:09,   97.96it/s]
#  72%|███████▏  | Fitting SlidingEstimator : 790/1100 [00:06<00:03,   94.02it/s]
#
#
#  14%|█▍        | Fitting SlidingEstimator : 159/1100 [00:01<00:09,   95.42it/s]
#
#  41%|████      | Fitting SlidingEstimator : 446/1100 [00:04<00:06,   94.63it/s]
#  72%|███████▏  | Fitting SlidingEstimator : 795/1100 [00:06<00:03,   95.63it/s]
#
#
#  15%|█▍        | Fitting SlidingEstimator : 163/1100 [00:01<00:09,   96.49it/s]
#
#  41%|████      | Fitting SlidingEstimator : 450/1100 [00:04<00:06,   94.95it/s]
#  73%|███████▎  | Fitting SlidingEstimator : 798/1100 [00:06<00:03,   94.72it/s]
#
#
#  15%|█▌        | Fitting SlidingEstimator : 166/1100 [00:01<00:09,   96.07it/s]
#
#  41%|████      | Fitting SlidingEstimator : 451/1100 [00:04<00:07,   91.78it/s]
#  73%|███████▎  | Fitting SlidingEstimator : 800/1100 [00:07<00:03,   92.70it/s]
#
#
#  16%|█▌        | Fitting SlidingEstimator : 171/1100 [00:01<00:09,   98.46it/s]
#
#  41%|████▏     | Fitting SlidingEstimator : 456/1100 [00:04<00:06,   94.32it/s]
#  73%|███████▎  | Fitting SlidingEstimator : 805/1100 [00:07<00:03,   94.38it/s]
#
#
#  16%|█▌        | Fitting SlidingEstimator : 175/1100 [00:01<00:09,   99.40it/s]
#
#  42%|████▏     | Fitting SlidingEstimator : 462/1100 [00:04<00:06,   95.43it/s]
#  74%|███████▎  | Fitting SlidingEstimator : 809/1100 [00:07<00:03,   94.98it/s]
#
#
#  16%|█▌        | Fitting SlidingEstimator : 178/1100 [00:01<00:09,   97.49it/s]
#  74%|███████▍  | Fitting SlidingEstimator : 812/1100 [00:07<00:03,   94.69it/s]
#
#
#  17%|█▋        | Fitting SlidingEstimator : 182/1100 [00:01<00:09,   97.79it/s]
#
#  42%|████▏     | Fitting SlidingEstimator : 466/1100 [00:04<00:06,   93.73it/s]
#  74%|███████▍  | Fitting SlidingEstimator : 815/1100 [00:07<00:03,   93.57it/s]
#
#
#  17%|█▋        | Fitting SlidingEstimator : 183/1100 [00:01<00:09,   94.54it/s]
#
#  43%|████▎     | Fitting SlidingEstimator : 469/1100 [00:04<00:06,   93.28it/s]
#
#
#
#  75%|███████▍  | Fitting SlidingEstimator : 820/1100 [00:07<00:02,   94.89it/s]
#
#  43%|████▎     | Fitting SlidingEstimator : 472/1100 [00:04<00:06,   92.65it/s]
#
#
#
#  17%|█▋        | Fitting SlidingEstimator : 192/1100 [00:02<00:09,   98.07it/s]
#
#  43%|████▎     | Fitting SlidingEstimator : 477/1100 [00:04<00:06,   95.01it/s]
#  75%|███████▌  | Fitting SlidingEstimator : 827/1100 [00:07<00:02,   95.62it/s]
#
#
#  18%|█▊        | Fitting SlidingEstimator : 194/1100 [00:02<00:09,   96.18it/s]
#
#  43%|████▎     | Fitting SlidingEstimator : 478/1100 [00:04<00:06,   92.11it/s]
#  75%|███████▌  | Fitting SlidingEstimator : 830/1100 [00:07<00:02,   95.30it/s]
#
#
#  18%|█▊        | Fitting SlidingEstimator : 198/1100 [00:02<00:09,   97.05it/s]
#
#  44%|████▍     | Fitting SlidingEstimator : 483/1100 [00:04<00:06,   94.49it/s]
#
#
#  18%|█▊        | Fitting SlidingEstimator : 201/1100 [00:02<00:09,   96.52it/s]
#
#  44%|████▍     | Fitting SlidingEstimator : 486/1100 [00:04<00:06,   94.23it/s]
#  76%|███████▌  | Fitting SlidingEstimator : 834/1100 [00:07<00:02,   94.77it/s]
#
#
#  19%|█▉        | Fitting SlidingEstimator : 207/1100 [00:02<00:08,  100.35it/s]
#
#  45%|████▍     | Fitting SlidingEstimator : 490/1100 [00:04<00:06,   95.21it/s]
#  76%|███████▋  | Fitting SlidingEstimator : 839/1100 [00:07<00:02,   97.05it/s]
#
#
#  19%|█▉        | Fitting SlidingEstimator : 211/1100 [00:02<00:08,  100.88it/s]
#  77%|███████▋  | Fitting SlidingEstimator : 843/1100 [00:07<00:02,   98.00it/s]
#
#  45%|████▍     | Fitting SlidingEstimator : 493/1100 [00:04<00:06,   94.26it/s]
#
#
#  19%|█▉        | Fitting SlidingEstimator : 214/1100 [00:02<00:08,   99.62it/s]
#  77%|███████▋  | Fitting SlidingEstimator : 846/1100 [00:07<00:02,   97.52it/s]
#
#  45%|████▌     | Fitting SlidingEstimator : 498/1100 [00:05<00:06,   96.07it/s]
#
#
#  20%|█▉        | Fitting SlidingEstimator : 218/1100 [00:02<00:08,  100.15it/s]
#  77%|███████▋  | Fitting SlidingEstimator : 850/1100 [00:07<00:02,   98.28it/s]
#
#  46%|████▌     | Fitting SlidingEstimator : 501/1100 [00:05<00:06,   95.75it/s]
#
#
#
#  20%|██        | Fitting SlidingEstimator : 221/1100 [00:02<00:08,   99.30it/s]
#
#  46%|████▌     | Fitting SlidingEstimator : 505/1100 [00:05<00:06,   96.75it/s]
#
#
#  21%|██        | Fitting SlidingEstimator : 227/1100 [00:02<00:08,  102.53it/s]
#
#  46%|████▌     | Fitting SlidingEstimator : 508/1100 [00:05<00:06,   95.83it/s]
#  78%|███████▊  | Fitting SlidingEstimator : 859/1100 [00:07<00:02,  100.04it/s]
#
#
#
#
#  21%|██        | Fitting SlidingEstimator : 232/1100 [00:02<00:08,  103.68it/s]
#  78%|███████▊  | Fitting SlidingEstimator : 862/1100 [00:07<00:02,   99.51it/s]
#  79%|███████▊  | Fitting SlidingEstimator : 865/1100 [00:07<00:02,   99.00it/s]
#
#  47%|████▋     | Fitting SlidingEstimator : 518/1100 [00:05<00:05,   99.75it/s]
#
#
#  21%|██▏       | Fitting SlidingEstimator : 234/1100 [00:02<00:08,  101.13it/s]
#
#
#  79%|███████▉  | Fitting SlidingEstimator : 870/1100 [00:07<00:02,  100.90it/s]
#
#
#  21%|██▏       | Fitting SlidingEstimator : 236/1100 [00:02<00:08,   98.99it/s]
#
#  48%|████▊     | Fitting SlidingEstimator : 524/1100 [00:05<00:05,   98.60it/s]
#
#
#  22%|██▏       | Fitting SlidingEstimator : 241/1100 [00:02<00:08,  101.20it/s]
#  80%|███████▉  | Fitting SlidingEstimator : 876/1100 [00:07<00:02,  103.05it/s]
#
#
#
#
#  22%|██▏       | Fitting SlidingEstimator : 244/1100 [00:02<00:08,  100.49it/s]
#  80%|███████▉  | Fitting SlidingEstimator : 878/1100 [00:07<00:02,   98.94it/s]
#
#  48%|████▊     | Fitting SlidingEstimator : 530/1100 [00:05<00:05,   96.54it/s]
#
#
#  22%|██▏       | Fitting SlidingEstimator : 247/1100 [00:02<00:08,   96.86it/s]
#  80%|████████  | Fitting SlidingEstimator : 881/1100 [00:07<00:02,   98.30it/s]
#
#  49%|████▊     | Fitting SlidingEstimator : 534/1100 [00:05<00:05,   97.50it/s]
#
#
#
#  80%|████████  | Fitting SlidingEstimator : 884/1100 [00:07<00:02,   97.57it/s]
#
#  49%|████▉     | Fitting SlidingEstimator : 537/1100 [00:05<00:05,   97.07it/s]
#
#
#  23%|██▎       | Fitting SlidingEstimator : 256/1100 [00:02<00:08,   99.23it/s]
#  81%|████████  | Fitting SlidingEstimator : 887/1100 [00:07<00:02,   97.02it/s]
#
#
#
#   0%|          | Fitting SlidingEstimator : 0/1100 [00:00<?,       ?it/s]
#
#  49%|████▉     | Fitting SlidingEstimator : 540/1100 [00:05<00:05,   96.45it/s]
#
#
#  24%|██▎       | Fitting SlidingEstimator : 260/1100 [00:02<00:08,   99.68it/s]
#
#
#  81%|████████  | Fitting SlidingEstimator : 892/1100 [00:07<00:02,   97.22it/s]
#
#
#  24%|██▍       | Fitting SlidingEstimator : 265/1100 [00:02<00:08,  101.88it/s]
#
#
#
#
#   0%|          | Fitting SlidingEstimator : 2/1100 [00:00<00:43,   25.05it/s]
#
#  49%|████▉     | Fitting SlidingEstimator : 544/1100 [00:05<00:06,   92.28it/s]
#
#
#  24%|██▍       | Fitting SlidingEstimator : 267/1100 [00:02<00:08,   99.33it/s]
#
#
#
#   0%|          | Fitting SlidingEstimator : 5/1100 [00:00<00:24,   44.61it/s]
#  82%|████████▏ | Fitting SlidingEstimator : 901/1100 [00:07<00:01,  100.09it/s]
#
#  50%|████▉     | Fitting SlidingEstimator : 549/1100 [00:05<00:05,   94.45it/s]
#
#
#  25%|██▍       | Fitting SlidingEstimator : 270/1100 [00:02<00:08,   98.23it/s]
#
#
#
#   1%|          | Fitting SlidingEstimator : 8/1100 [00:00<00:19,   55.05it/s]
#
#
#  50%|█████     | Fitting SlidingEstimator : 551/1100 [00:05<00:05,   92.80it/s]
#
#
#
#   1%|          | Fitting SlidingEstimator : 12/1100 [00:00<00:16,   67.89it/s]
#
#
#  25%|██▌       | Fitting SlidingEstimator : 276/1100 [00:02<00:08,  100.48it/s]
#  83%|████████▎ | Fitting SlidingEstimator : 909/1100 [00:08<00:01,  100.03it/s]
#
#
#
#   1%|▏         | Fitting SlidingEstimator : 15/1100 [00:00<00:15,   71.13it/s]
#
#  50%|█████     | Fitting SlidingEstimator : 555/1100 [00:05<00:06,   90.37it/s]
#  83%|████████▎ | Fitting SlidingEstimator : 912/1100 [00:08<00:01,   98.59it/s]
#
#
#  25%|██▌       | Fitting SlidingEstimator : 280/1100 [00:02<00:08,   98.37it/s]
#
#
#
#   2%|▏         | Fitting SlidingEstimator : 20/1100 [00:00<00:13,   83.07it/s]
#
#  51%|█████     | Fitting SlidingEstimator : 558/1100 [00:05<00:06,   90.28it/s]
#  83%|████████▎ | Fitting SlidingEstimator : 916/1100 [00:08<00:01,   99.33it/s]
#
#
#  26%|██▌       | Fitting SlidingEstimator : 284/1100 [00:02<00:08,   99.25it/s]
#
#
#
#   2%|▏         | Fitting SlidingEstimator : 24/1100 [00:00<00:12,   85.85it/s]
#
#  51%|█████     | Fitting SlidingEstimator : 562/1100 [00:05<00:05,   90.58it/s]
#  84%|████████▎ | Fitting SlidingEstimator : 921/1100 [00:08<00:01,  101.33it/s]
#
#
#  26%|██▌       | Fitting SlidingEstimator : 286/1100 [00:03<00:08,   97.45it/s]
#
#
#
#   2%|▏         | Fitting SlidingEstimator : 27/1100 [00:00<00:12,   85.69it/s]
#
#  51%|█████▏    | Fitting SlidingEstimator : 565/1100 [00:05<00:05,   90.49it/s]
#  84%|████████▍ | Fitting SlidingEstimator : 924/1100 [00:08<00:01,  100.19it/s]
#
#
#  26%|██▋       | Fitting SlidingEstimator : 291/1100 [00:03<00:08,   99.49it/s]
#
#
#
#   3%|▎         | Fitting SlidingEstimator : 31/1100 [00:00<00:12,   88.41it/s]
#
#  52%|█████▏    | Fitting SlidingEstimator : 570/1100 [00:05<00:05,   92.74it/s]
#  84%|████████▍ | Fitting SlidingEstimator : 929/1100 [00:08<00:01,  102.07it/s]
#
#
#  27%|██▋       | Fitting SlidingEstimator : 296/1100 [00:03<00:07,  100.68it/s]
#
#
#
#   3%|▎         | Fitting SlidingEstimator : 34/1100 [00:00<00:12,   87.52it/s]
#
#  52%|█████▏    | Fitting SlidingEstimator : 574/1100 [00:05<00:05,   93.48it/s]
#  85%|████████▍ | Fitting SlidingEstimator : 933/1100 [00:08<00:01,  102.14it/s]
#
#
#  27%|██▋       | Fitting SlidingEstimator : 298/1100 [00:03<00:08,   98.81it/s]
#
#
#
#   3%|▎         | Fitting SlidingEstimator : 38/1100 [00:00<00:11,   90.63it/s]
#
#  52%|█████▏    | Fitting SlidingEstimator : 576/1100 [00:05<00:05,   91.77it/s]
#
#
#  27%|██▋       | Fitting SlidingEstimator : 302/1100 [00:03<00:08,   99.69it/s]
#
#
#
#
#   4%|▎         | Fitting SlidingEstimator : 40/1100 [00:00<00:12,   86.06it/s]
#
#  85%|████████▌ | Fitting SlidingEstimator : 936/1100 [00:08<00:01,  100.73it/s]
#
#
#  28%|██▊       | Fitting SlidingEstimator : 306/1100 [00:03<00:08,   99.21it/s]
#
#
#
#   4%|▍         | Fitting SlidingEstimator : 44/1100 [00:00<00:11,   88.12it/s]
#
#  53%|█████▎    | Fitting SlidingEstimator : 586/1100 [00:05<00:05,   95.36it/s]
#
#
#  28%|██▊       | Fitting SlidingEstimator : 308/1100 [00:03<00:08,   97.36it/s]
#  86%|████████▌ | Fitting SlidingEstimator : 943/1100 [00:08<00:01,   99.56it/s]
#
#
#
#
#
#  54%|█████▎    | Fitting SlidingEstimator : 590/1100 [00:06<00:05,   96.38it/s][A
#
#
#  28%|██▊       | Fitting SlidingEstimator : 312/1100 [00:03<00:08,   97.77it/s]
#  86%|████████▌ | Fitting SlidingEstimator : 946/1100 [00:08<00:01,   99.04it/s]
#
#
#
#   4%|▍         | Fitting SlidingEstimator : 48/1100 [00:00<00:12,   82.44it/s]
#
#  54%|█████▍    | Fitting SlidingEstimator : 595/1100 [00:06<00:05,   97.68it/s]
#  86%|████████▋ | Fitting SlidingEstimator : 950/1100 [00:08<00:01,   99.84it/s]
#
#
#  29%|██▊       | Fitting SlidingEstimator : 315/1100 [00:03<00:08,   95.99it/s]
#
#
#
#   5%|▍         | Fitting SlidingEstimator : 51/1100 [00:00<00:12,   82.56it/s]
#
#  54%|█████▍    | Fitting SlidingEstimator : 598/1100 [00:06<00:05,   96.28it/s]
#  87%|████████▋ | Fitting SlidingEstimator : 953/1100 [00:08<00:01,   99.09it/s]
#
#
#  29%|██▉       | Fitting SlidingEstimator : 317/1100 [00:03<00:08,   94.12it/s]
#
#
#
#   5%|▍         | Fitting SlidingEstimator : 54/1100 [00:00<00:12,   82.50it/s]
#
#  55%|█████▍    | Fitting SlidingEstimator : 603/1100 [00:06<00:05,   98.57it/s]
#  87%|████████▋ | Fitting SlidingEstimator : 958/1100 [00:08<00:01,  101.21it/s]
#
#
#  29%|██▉       | Fitting SlidingEstimator : 322/1100 [00:03<00:08,   96.54it/s]
#
#
#
#   5%|▌         | Fitting SlidingEstimator : 59/1100 [00:00<00:11,   86.89it/s]
#
#  55%|█████▌    | Fitting SlidingEstimator : 607/1100 [00:06<00:05,   98.38it/s]
#  87%|████████▋ | Fitting SlidingEstimator : 960/1100 [00:08<00:01,   99.27it/s]
#
#
#  30%|██▉       | Fitting SlidingEstimator : 327/1100 [00:03<00:07,   98.34it/s]
#
#
#
#   6%|▌         | Fitting SlidingEstimator : 63/1100 [00:00<00:11,   88.70it/s]
#
#  56%|█████▌    | Fitting SlidingEstimator : 611/1100 [00:06<00:04,   98.80it/s]
#
#
#  30%|███       | Fitting SlidingEstimator : 332/1100 [00:03<00:07,  100.17it/s]
#
#
#
#
#   6%|▌         | Fitting SlidingEstimator : 65/1100 [00:00<00:11,   86.60it/s]
#
#  56%|█████▌    | Fitting SlidingEstimator : 614/1100 [00:06<00:04,   97.77it/s]
#
#
#  30%|███       | Fitting SlidingEstimator : 334/1100 [00:03<00:07,   98.10it/s]
#
#
#
#
#   6%|▌         | Fitting SlidingEstimator : 67/1100 [00:00<00:12,   84.59it/s]
#
#  56%|█████▌    | Fitting SlidingEstimator : 615/1100 [00:06<00:05,   94.70it/s]
#
#
#  31%|███       | Fitting SlidingEstimator : 338/1100 [00:03<00:07,   98.66it/s]
#  89%|████████▊ | Fitting SlidingEstimator : 975/1100 [00:08<00:01,  102.78it/s]
#
#
#
#   7%|▋         | Fitting SlidingEstimator : 73/1100 [00:00<00:11,   87.57it/s]
#
#  56%|█████▋    | Fitting SlidingEstimator : 621/1100 [00:06<00:04,   98.34it/s]
#
#
#  31%|███       | Fitting SlidingEstimator : 341/1100 [00:03<00:07,   98.15it/s]
#  89%|████████▉ | Fitting SlidingEstimator : 979/1100 [00:08<00:01,  103.21it/s]
#
#
#
#   7%|▋         | Fitting SlidingEstimator : 74/1100 [00:00<00:12,   83.70it/s]
#
#  57%|█████▋    | Fitting SlidingEstimator : 624/1100 [00:06<00:04,   97.58it/s]
#
#
#
#  89%|████████▉ | Fitting SlidingEstimator : 982/1100 [00:08<00:01,  102.30it/s]
#
#
#
#   7%|▋         | Fitting SlidingEstimator : 79/1100 [00:00<00:11,   86.85it/s]
#
#  57%|█████▋    | Fitting SlidingEstimator : 627/1100 [00:06<00:04,   96.77it/s]
#  90%|████████▉ | Fitting SlidingEstimator : 988/1100 [00:08<00:01,  105.11it/s]
#
#
#  32%|███▏      | Fitting SlidingEstimator : 349/1100 [00:03<00:07,   99.25it/s]
#
#
#
#   7%|▋         | Fitting SlidingEstimator : 80/1100 [00:00<00:12,   82.68it/s]
#
#  57%|█████▋    | Fitting SlidingEstimator : 630/1100 [00:06<00:04,   95.77it/s]
#
#
#
#  90%|█████████ | Fitting SlidingEstimator : 991/1100 [00:08<00:01,  104.16it/s]
#
#  58%|█████▊    | Fitting SlidingEstimator : 634/1100 [00:06<00:04,   96.23it/s]
#
#
#
#   8%|▊         | Fitting SlidingEstimator : 85/1100 [00:01<00:11,   85.51it/s]
#  90%|█████████ | Fitting SlidingEstimator : 995/1100 [00:08<00:01,  104.38it/s]
#
#
#  33%|███▎      | Fitting SlidingEstimator : 358/1100 [00:03<00:07,  101.11it/s]
#
#  58%|█████▊    | Fitting SlidingEstimator : 638/1100 [00:06<00:04,   97.19it/s]
#
#
#
#   8%|▊         | Fitting SlidingEstimator : 90/1100 [00:01<00:11,   88.87it/s]
#  91%|█████████ | Fitting SlidingEstimator : 996/1100 [00:08<00:01,  100.91it/s]
#
#
#  33%|███▎      | Fitting SlidingEstimator : 361/1100 [00:03<00:07,  100.39it/s]
#
#  58%|█████▊    | Fitting SlidingEstimator : 641/1100 [00:06<00:04,   96.50it/s]
#
#
#
#   8%|▊         | Fitting SlidingEstimator : 93/1100 [00:01<00:11,   88.43it/s]
#
#
#  33%|███▎      | Fitting SlidingEstimator : 365/1100 [00:03<00:07,  101.21it/s]
#  91%|█████████ | Fitting SlidingEstimator : 1001/1100 [00:08<00:00,   99.92it/s]
#
#  59%|█████▊    | Fitting SlidingEstimator : 645/1100 [00:06<00:04,   97.37it/s]
#
#
#  33%|███▎      | Fitting SlidingEstimator : 368/1100 [00:03<00:07,  100.64it/s]
#
#
#
#   9%|▉         | Fitting SlidingEstimator : 98/1100 [00:01<00:11,   90.15it/s]
#
#  59%|█████▊    | Fitting SlidingEstimator : 646/1100 [00:06<00:04,   93.93it/s]
#
#
#  34%|███▎      | Fitting SlidingEstimator : 370/1100 [00:03<00:07,   98.73it/s]
#
#
#
#   9%|▉         | Fitting SlidingEstimator : 100/1100 [00:01<00:11,   87.79it/s]
#  92%|█████████▏| Fitting SlidingEstimator : 1008/1100 [00:09<00:00,  102.04it/s]
#
#  59%|█████▉    | Fitting SlidingEstimator : 651/1100 [00:06<00:04,   96.19it/s]
#
#
#  34%|███▍      | Fitting SlidingEstimator : 372/1100 [00:03<00:07,   96.89it/s]
#
#
#
#   9%|▉         | Fitting SlidingEstimator : 103/1100 [00:01<00:11,   87.85it/s]
#  92%|█████████▏| Fitting SlidingEstimator : 1012/1100 [00:09<00:00,  102.29it/s]
#
#  59%|█████▉    | Fitting SlidingEstimator : 653/1100 [00:06<00:04,   94.43it/s]
#
#
#  34%|███▍      | Fitting SlidingEstimator : 376/1100 [00:03<00:07,   97.27it/s]
#
#
#
#  10%|▉         | Fitting SlidingEstimator : 109/1100 [00:01<00:10,   92.69it/s]
#  92%|█████████▏| Fitting SlidingEstimator : 1016/1100 [00:09<00:00,  102.75it/s]
#
#  60%|█████▉    | Fitting SlidingEstimator : 657/1100 [00:06<00:04,   95.44it/s]
#
#
#  34%|███▍      | Fitting SlidingEstimator : 379/1100 [00:03<00:07,   96.87it/s]
#
#
#
#  10%|█         | Fitting SlidingEstimator : 112/1100 [00:01<00:10,   92.05it/s]
#  93%|█████████▎| Fitting SlidingEstimator : 1019/1100 [00:09<00:00,  102.12it/s]
#
#
#
#
#  35%|███▍      | Fitting SlidingEstimator : 384/1100 [00:03<00:07,   99.22it/s]
#  93%|█████████▎| Fitting SlidingEstimator : 1024/1100 [00:09<00:00,  103.99it/s]
#
#
#
#  11%|█         | Fitting SlidingEstimator : 116/1100 [00:01<00:10,   91.89it/s]
#
#  60%|██████    | Fitting SlidingEstimator : 665/1100 [00:06<00:04,   96.29it/s]
#
#
#  35%|███▌      | Fitting SlidingEstimator : 386/1100 [00:04<00:07,   95.95it/s]
#  93%|█████████▎| Fitting SlidingEstimator : 1026/1100 [00:09<00:00,  101.41it/s]
#
#
#
#  11%|█         | Fitting SlidingEstimator : 119/1100 [00:01<00:10,   91.30it/s]
#
#  61%|██████    | Fitting SlidingEstimator : 668/1100 [00:06<00:04,   95.93it/s]
#
#
#  35%|███▌      | Fitting SlidingEstimator : 389/1100 [00:04<00:07,   95.57it/s]
#  94%|█████████▎| Fitting SlidingEstimator : 1029/1100 [00:09<00:00,  100.51it/s]
#
#
#
#  11%|█         | Fitting SlidingEstimator : 122/1100 [00:01<00:10,   91.16it/s]
#
#  61%|██████    | Fitting SlidingEstimator : 672/1100 [00:06<00:04,   96.95it/s]
#
#
#  36%|███▌      | Fitting SlidingEstimator : 393/1100 [00:04<00:07,   96.19it/s]
#  94%|█████████▍| Fitting SlidingEstimator : 1034/1100 [00:09<00:00,  102.55it/s]
#
#
#
#  11%|█▏        | Fitting SlidingEstimator : 125/1100 [00:01<00:10,   90.86it/s]
#
#  61%|██████▏   | Fitting SlidingEstimator : 675/1100 [00:06<00:04,   96.20it/s]
#
#
#  36%|███▌      | Fitting SlidingEstimator : 397/1100 [00:04<00:07,   97.03it/s]
#  94%|█████████▍| Fitting SlidingEstimator : 1037/1100 [00:09<00:00,  101.74it/s]
#
#
#
#  12%|█▏        | Fitting SlidingEstimator : 130/1100 [00:01<00:10,   93.67it/s]
#
#  62%|██████▏   | Fitting SlidingEstimator : 680/1100 [00:06<00:04,   98.42it/s]
#
#
#
#  12%|█▏        | Fitting SlidingEstimator : 133/1100 [00:01<00:10,   93.42it/s]
#
#
#  36%|███▋      | Fitting SlidingEstimator : 400/1100 [00:04<00:07,   95.09it/s]
#  95%|█████████▍| Fitting SlidingEstimator : 1042/1100 [00:09<00:00,  102.43it/s]
#
#  62%|██████▏   | Fitting SlidingEstimator : 682/1100 [00:06<00:04,   96.48it/s]
#
#
#  37%|███▋      | Fitting SlidingEstimator : 405/1100 [00:04<00:07,   97.49it/s]
#
#
#
#  12%|█▏        | Fitting SlidingEstimator : 137/1100 [00:01<00:10,   93.43it/s]
#  95%|█████████▌| Fitting SlidingEstimator : 1048/1100 [00:09<00:00,  105.23it/s]
#
#  62%|██████▏   | Fitting SlidingEstimator : 687/1100 [00:06<00:04,   98.54it/s]
#
#
#  37%|███▋      | Fitting SlidingEstimator : 407/1100 [00:04<00:07,   95.68it/s]
#
#
#
#  13%|█▎        | Fitting SlidingEstimator : 140/1100 [00:01<00:10,   93.09it/s]
#  95%|█████████▌| Fitting SlidingEstimator : 1050/1100 [00:09<00:00,  103.19it/s]
#
#  63%|██████▎   | Fitting SlidingEstimator : 691/1100 [00:07<00:04,   99.28it/s]
#
#
#
#  13%|█▎        | Fitting SlidingEstimator : 144/1100 [00:01<00:10,   94.35it/s]
#  96%|█████████▌| Fitting SlidingEstimator : 1055/1100 [00:09<00:00,  105.13it/s]
#
#
#  38%|███▊      | Fitting SlidingEstimator : 413/1100 [00:04<00:06,   98.53it/s]
#
#  63%|██████▎   | Fitting SlidingEstimator : 696/1100 [00:07<00:03,  101.17it/s]
#
#
#
#
#  96%|█████████▌| Fitting SlidingEstimator : 1057/1100 [00:09<00:00,  103.02it/s]
#
#
#
#
#  38%|███▊      | Fitting SlidingEstimator : 417/1100 [00:04<00:06,   98.23it/s]
#  96%|█████████▋| Fitting SlidingEstimator : 1061/1100 [00:09<00:00,  103.01it/s]
#
#
#
#  14%|█▍        | Fitting SlidingEstimator : 152/1100 [00:01<00:09,   95.93it/s]
#
#  64%|██████▍   | Fitting SlidingEstimator : 704/1100 [00:07<00:03,  102.52it/s]
#
#
#  38%|███▊      | Fitting SlidingEstimator : 420/1100 [00:04<00:07,   96.22it/s]
#  97%|█████████▋| Fitting SlidingEstimator : 1066/1100 [00:09<00:00,  104.98it/s]
#
#
#
#  14%|█▍        | Fitting SlidingEstimator : 155/1100 [00:01<00:09,   95.19it/s]
#
#  64%|██████▍   | Fitting SlidingEstimator : 708/1100 [00:07<00:03,  103.26it/s]
#
#
#  39%|███▊      | Fitting SlidingEstimator : 424/1100 [00:04<00:06,   96.60it/s]
#
#
#
# ...
# /tmp/ipykernel_107845/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:45: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_exo = exo.get_data()[:, :, t]
# /tmp/ipykernel_107845/2399489850.py:46: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X_pre_250ms_endo = endo.get_data()[:, :, t]

# %%
cv_scores_pre_250ms_endo_arr = np.array(cv_scores_pre_250ms_endo)
cv_scores_pre_250ms_endo_arr = np.abs(cv_scores_pre_250ms_endo_arr-cv_scores_pre_250ms_endo_arr.mean()) + .5
cv_scores_pre_250ms_exo_arr = np.array(cv_scores_pre_250ms_exo)
cv_scores_pre_250ms_exo_arr = np.abs(cv_scores_pre_250ms_exo_arr-cv_scores_pre_250ms_exo_arr.mean()) + .5
plt.plot(exo.times, cv_scores_pre_250ms_endo_arr)
plt.plot(exo.times, cv_scores_pre_250ms_exo_arr)

# %%
np.save('files/B3_decoding.npy', np.vstack([cv_scores_pre_250ms_endo_arr, cv_scores_pre_250ms_exo_arr]))
np.save('files/decoding_times.npy', exo.times)
